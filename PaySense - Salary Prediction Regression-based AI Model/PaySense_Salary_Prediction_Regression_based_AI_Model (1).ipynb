# %% [markdown]
# # **Title: PaySense - Salary Prediction Regression-based AI Model**

# %% [markdown]
# ![Screenshot 2023-07-12 130942.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Overview/Introduction:
# This project aims to develop an AI-based salary prediction model using regression analysis. The model will leverage the "Salary Dataset" to estimate an individual's salary based on their years of experience. By utilizing machine learning techniques, this project seeks to provide accurate predictions and valuable insights into salary trends.
#
# ## Problem Statement:
# The salary prediction project addresses the challenge of estimating an individual's salary based on their years of experience. Traditionally, salary negotiations heavily rely on subjective factors, leaving room for biases and inconsistencies. By employing an AI model, we can introduce objectivity and data-driven decision-making into salary predictions, empowering both employers and employees.
#
# ## Objectives:
# 1. Develop a regression-based AI model to predict salaries based on years of experience.
# 2. Provide accurate salary estimates for individuals with varying levels of experience.
# 3. Identify and understand the key factors influencing salary trends.
# 4. Create an open-source project on GitHub to showcase the implementation and results.
#
# ## Dataset Description:
# The "Salary Dataset" is a comprehensive and well-curated collection of salary information in CSV format. This dataset has been widely utilized in the "Machine Learning A to Z" course series, attesting to its quality and reliability. It consists of two columns:
#
# 1. YearsExperience: This column represents the number of years of professional experience an individual possesses. It serves as the independent variable for predicting salary.
#
# 2. Salary: This column contains the corresponding salary figures for each individual in the dataset. It serves as the dependent variable for regression analysis.
#
# By leveraging this dataset, our AI model will be trained to establish a mathematical relationship between years of experience and salary, enabling accurate predictions for unseen data.
#
# **Dataset URL:** https://www.kaggle.com/datasets/abhishek14398/salary-dataset-simple-linear-regression

# %% [markdown]
# # Technologies Used:
#
# This study made extensive use of Python-based libraries and frameworks for data preprocessing, visualization, statistical analysis, and machine learning. Here are the primary tools utilized:
#
# 1. **Pandas:** For data manipulation and analysis.
# 2. **Numpy:** To support numerical operations in Python.
# 3. **Matplotlib & Seaborn:** For data visualization.
# 4. **Scikit-Learn:** For traditional machine learning models, specifically Linear Regression in this case.
# 5. **Tensorflow:** An open-source deep learning library for training neural networks.
# 6. **Keras:** A high-level API to build and train models in TensorFlow.
#
# # Methodology:
#
# The project started by importing the dataset and performing basic data cleaning and exploration, which included dropping unnecessary columns, identifying duplicates, handling missing values, and visualizing the data with scatter and line plots. Then, the correlation between features was examined using a correlation matrix and heatmap.
#
# Three models were implemented to predict salary based on years of experience:
#
# 1. A simple linear regression model using sklearn's LinearRegression
# 2. A single-layer dense neural network using tensorflow
# 3. A multi-layer dense neural network with dropout and regularization using tensorflow
#
# The data was split into a training set and a test set, with 80% of the data used for training the models and 20% used for testing them. For the neural networks, the input features were normalized using MinMaxScaler, and an EarlyStopping callback was used to prevent overfitting. Model performance was evaluated using various metrics, including Mean Absolute Error (MAE), Mean Squared Error (MSE), Root Mean Squared Error (RMSE), Mean Absolute Percentage Error (MAPE), Mean Absolute Scaled Error (MASE), and the coefficient of determination (R^2).
#
# # Implementation:
#
# The linear regression model was implemented using sklearn's LinearRegression, which was fit on the training data and evaluated on the test data. The first neural network model was a simple dense model with a single layer, implemented using tensorflow's Keras API. This model was compiled with Mean Absolute Error (MAE) loss and Stochastic Gradient Descent (SGD) as the optimizer.
#
# The second neural network model was a more complex model with two hidden layers and dropout layers for regularization. It also used a L2 regularizer to prevent overfitting. This model was also compiled with MAE loss and SGD optimizer, and it was trained for 1000 epochs with a batch size of 32.
#
# # Results:
#
# The R^2 value for the simple linear regression model was 0.957, indicating that about 95.7% of the variability in the salary can be explained by years of experience.
#
# The first neural network model achieved an MAE of 6029.6655, an MSE of 50422412.0, an RMSE of 7100.874, a MAPE of 7.65%, a MASE of 0.20482035, and an R^2 of 0.9012866 on the test set. The second neural network model achieved an MAE of 6132.689, an MSE of 41141120.0, an RMSE of 6414.1343, a MAPE of 7.77%, a MASE of 0.20831993, and an R^2 of 0.91945684 on the test set.
#
# # Discussion/Interpretation of Results:
#
# All three models performed well in predicting salaries based on years of experience, with the linear regression model explaining about 95.7% of the variability in the salary. Although the neural network models had slightly lower R^2 scores, they demonstrated the capability of deep learning models in learning from the dataset and predicting the salaries. The second neural network model, despite its complexity, did not significantly outperform the first neural network model. This could be due to the simplicity of the dataset, which may not require a complex model to accurately predict the target variable.
#
# The results of the salary prediction models have significant implications for both employers and employees. By leveraging the years of experience, the models provide accurate salary estimates, enabling fair and data-driven salary negotiations. The difference and percentage difference between predicted and actual values reveal the model's ability to capture salary trends accurately. Employers can use these insights to make informed decisions regarding salary adjustments, promotions, and talent acquisition. Employees can leverage the predictions to negotiate fair compensation based on their years of experience, leading to increased job satisfaction and reduced salary disparities.
#
# # Conclusion:
#
# The salary prediction project utilizing regression-based AI models demonstrates the potential to revolutionize salary negotiations. By accurately estimating salaries based on years of experience, the models offer objective and data-driven insights into compensation trends. The implementation of linear regression and neural network models provides accurate predictions and valuable evaluation metrics, reflecting the models' effectiveness.
#
# The project represents a significant step toward addressing the challenges associated with salary prediction and empowers both employers and employees to make informed decisions based on data-driven insights.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/salary-dataset-simple-linear-regression/Salary_dataset.csv

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# The following code shows a function seed_everything() that sets the seed values for random number generators in TensorFlow, NumPy, and Python's random library, ensuring reproducibility of results for future use cases.

# %%
import random

# Seed Everything to reproduce results for future use cases
def seed_everything(seed=42):
    # Seed value for TensorFlow
    tf.random.set_seed(seed)
    # Seed value for NumPy
    np.random.seed(seed)
    # Seed value for Python's random library
    random.seed(seed)

seed_everything()

# %% [markdown]
# The next code reads in a dataset from a CSV file and assigns it to the variable df. It then displays the first few rows of the dataset using the head() function.

# %%
# Read in the dataset
df = pd.read_csv("/kaggle/input/salary-dataset-simple-linear-regression/Salary_dataset.csv")
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %% [markdown]
# n the next code, the "Unnamed: 0" column is dropped from the dataset df.

# %%
df= df.drop("Unnamed: 0", axis=1)

# %%
df.describe().T
# Out:
#                  count          mean           std      min       25%  \
# YearsExperience   30.0      5.413333      2.837888      1.2      3.30
# Salary            30.0  76004.000000  27414.429785  37732.0  56721.75
#
#                      50%        75%       max
# YearsExperience      4.8       7.80      10.6
# Salary           65238.0  100545.75  122392.0

# %%
df.shape
# Out:
# (30, 2)

# %% [markdown]
# The next code generates a scatter plot using the matplotlib.pyplot library to visualize the relationship between the "YearsExperience" and "Salary" columns in the dataset.

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['YearsExperience'], df['Salary'])
plt.title('Years of Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# The following code uses the sns.lineplot function to create a line plot of the "YearsExperience" against the "Salary" column.

# %%
sns.lineplot(x = 'YearsExperience', y = 'Salary', data = df)
plt.show()

# %% [markdown]
# The next code utilizes the sns.regplot function to create a scatter plot with a fitted regression line representing the relationship between the "YearsExperience" and "Salary" columns

# %%
sns.regplot(x = 'YearsExperience', y = 'Salary', data = df)
plt.show()

# %% [markdown]
# The code calculates the slope and intercept of the regression line using the np.polyfit function and creates a function that represents the line using np.poly1d. It then prints the equation of the line. The next code displays a scatter plot with the "YearsExperience" on the x-axis and the fitted regression line on the y-axis, using the previously calculated line function.

# %%
# get the slope and intercept of the line
slope, intercept = np.polyfit(df['YearsExperience'], df['Salary'], 1)

# create a function that represents the line
line = np.poly1d([slope, intercept])

# Create the equation of the line
equation = f"y = {slope:.2f}x + {intercept:.2f}"
print(equation)

# plot the scatter plot
plt.figure(figsize=(10,6))
plt.scatter(df['YearsExperience'], df['Salary'])

# plot the line
plt.plot(df['YearsExperience'], line(df['YearsExperience']), color='red')

plt.title('Years of Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
# Out:
# y = 9449.96x + 24848.20

# %% [markdown]
# The following code creates a histogram of the dataset using the df.hist function, providing a visualization of the distribution of each numerical column.

# %%
df.hist(figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'YearsExperience'}>,
#         <Axes: title={'center': 'Salary'}>]], dtype=object)

# %%
target='Salary'
target
# Out:
# 'Salary'

# %% [markdown]
# **Duplicates and Null values**
#
# The code prints the number of data points in the dataset. The next code checks for duplicates in the dataset and prints the number of duplicates found. The code then checks for missing values in the dataset by calculating the sum of missing values for each column and prints the results. The code also replaces empty strings with NaN values in the dataset and recalculates the number of missing values.

# %%
import numpy as np

# How many reviews do we have?
print('There are', df.shape[0], 'data in this dataset')

# Do we have duplicates?
print('Number of Duplicates:', len(df[df.duplicated()]))

# Do we have missing values?
missing_values = df.isnull().sum()
print('Number of Missing Values by column:\n',missing_values)

print('Number of Missing Values:', df.isnull().sum().sum())

df.replace("", np.nan, inplace=True)
missing_values = df.isnull().sum()
print('Number of Missing Values by column after replacement:\n',missing_values)
print('Number of Missing Values after replacement:', df.isnull().sum().sum())
# Out:
# There are 30 data in this dataset
# Number of Duplicates: 0
# Number of Missing Values by column:
#  YearsExperience    0
# Salary             0
# dtype: int64
# Number of Missing Values: 0
# Number of Missing Values by column after replacement:
#  YearsExperience    0
# Salary             0
# dtype: int64
# Number of Missing Values after replacement: 0

# %% [markdown]
# **Correlation Matrix**
#
# The following code displays a heatmap using the sns.heatmap function, showing the correlation matrix of the dataset.

# %%
plt.subplots(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, fmt='.2f')
pass

# %% [markdown]
# The code calculates the correlation of the "Salary" column with other features and sorts them in descending order.

# %%
# Calculate the correlation matrix
corr_matrix = df.corr(numeric_only=True)

# Get the correlation of 'price' with other features
corr_with_price = corr_matrix[target]

# Sort these correlations in descending order
sorted_correlations = corr_with_price.sort_values(ascending=False)
sorted_correlations
# Out:
# Salary             1.000000
# YearsExperience    0.978242
# Name: Salary, dtype: float64

# %% [markdown]
# The next code plots a bar chart of the sorted correlations with the "Salary" column.

# %%
sorted_correlations.sort_values(ascending=0).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# **EDA**
#
# The code sets the style and creates a distribution plot using sns.distplot to visualize the distribution of the "Salary" column.

# %%
sns.set(style='whitegrid')
f, ax = plt.subplots(1,1, figsize=(12, 8))
ax = sns.distplot(df[target], kde = True, color = 'c')
plt.title(f'Distribution of {target}')
# Out:
# Text(0.5, 1.0, 'Distribution of Salary')

# %% [markdown]
# The code provides descriptive statistics of the "Salary" column.

# %%
df[target].describe()
# Out:
# count        30.000000
# mean      76004.000000
# std       27414.429785
# min       37732.000000
# 25%       56721.750000
# 50%       65238.000000
# 75%      100545.750000
# max      122392.000000
# Name: Salary, dtype: float64

# %% [markdown]
# **Evaluation Metrics**
#
# The next code block defines two utility functions: mean_absolute_scaled_error() and evaluate_preds(). The mean_absolute_scaled_error() function calculates the Mean Absolute Scaled Error (MASE), assuming no seasonality of the data. The evaluate_preds() function calculates various metrics, including MAE, MSE, RMSE, MAPE, MASE, and R-squared score, for evaluating the predictions.

# %%
# MASE implemented courtesy of sktime - https://github.com/alan-turing-institute/sktime/blob/ee7a06843a44f4aaec7582d847e36073a9ab0566/sktime/performance_metrics/forecasting/_functions.py#L16
def mean_absolute_scaled_error(y_true, y_pred):
  """
  Implement MASE (assuming no seasonality of data).
  """
  mae = tf.reduce_mean(tf.abs(y_true - y_pred))

  # Find MAE of naive forecast (no seasonality)
  mae_naive_no_season = tf.reduce_mean(tf.abs(y_true[1:] - y_true[:-1])) # our seasonality is 1 day (hence the shifting of 1 day)

  return mae / mae_naive_no_season

def evaluate_preds(y_true, y_pred):
    # Make sure float32 (for metric calculations)
    y_true = tf.cast(y_true, dtype=tf.float32)
    y_pred = tf.cast(y_pred, dtype=tf.float32)

    # Calculate various metrics
    mae = tf.keras.metrics.mean_absolute_error(y_true, y_pred)
    mse = tf.keras.metrics.mean_squared_error(y_true, y_pred)
    rmse = tf.sqrt(mse)
    mape = tf.keras.metrics.mean_absolute_percentage_error(y_true, y_pred)
    mase = mean_absolute_scaled_error(y_true, y_pred)

    # Calculate R-squared score
    ss_res = tf.reduce_sum((y_true - y_pred)**2)
    ss_tot = tf.reduce_sum((y_true - tf.reduce_mean(y_true))**2)
    r2 = 1 - (ss_res / ss_tot)

    # Account for different sized metrics
    if mae.ndim > 0:
        mae = tf.reduce_mean(mae)
        mse = tf.reduce_mean(mse)
        rmse = tf.reduce_mean(rmse)
        mape = tf.reduce_mean(mape)
        mase = tf.reduce_mean(mase)
        r2 = tf.reduce_mean(r2)

    return {"mae": mae.numpy(),
            "mse": mse.numpy(),
            "rmse": rmse.numpy(),
            "mape": str(mape.numpy()) + "%",
            "mase": mase.numpy(),
            "r2": r2.numpy()}

# %% [markdown]
# **Model: LinearRegression sklearn**
#
# The following code imports the LinearRegression class from the sklearn.linear_model module and creates an instance of the linear regression model. The code prepares the input features (x) and target variable (y) for the linear regression model.The code fits the linear regression model to the data and prints the R2 score, a measure of the model's goodness of fit.

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
x = np.array(df['Salary']).reshape((-1, 1))
y = np.array(df['YearsExperience']).reshape((-1, 1))

model.fit(x, y)
print(f'Linear regression R2 value: {model.score(x, y):3.3f}')
# Out:
# Linear regression R2 value: 0.957

# %% [markdown]
# **Data X,y**
#
# The next code assigns the input features (X) and target variable (y) for further data preprocessing.

# %%
X=df.drop([target],axis=1)
y=df[[target]]
X
# Out:
#     YearsExperience
# 0               1.2
# 1               1.4
# 2               1.6
# 3               2.1
# 4               2.3
# 5               3.0
# 6               3.1
# 7               3.3
# 8               3.3
# 9               3.8
# 10              4.0
# 11              4.1
# 12              4.1
# 13              4.2
# 14              4.6
# 15              5.0
# 16              5.2
# 17              5.4
# 18              6.0
# 19              6.1
# 20              6.9
# 21              7.2
# 22              8.0
# 23              8.3
# 24              8.8
# 25              9.1
# 26              9.6
# 27              9.7
# 28             10.4
# 29             10.6

# %% [markdown]
# The code splits the data into training and test sets using the train_test_split function from sklearn.model_selection.

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %% [markdown]
# The code creates a list of numerical columns and categorical columns in the dataset.

# %%
# Get list of numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Remove 'price' from num_cols
num_cols.remove(target)

# Get list of categorical columns
cat_cols = df.select_dtypes(include=['object']).columns.tolist()

# Print the numerical columns
print("Numerical columns are:", num_cols)

# Print the categorical columns
print("Categorical columns are:", cat_cols)
# Out:
# Numerical columns are: ['YearsExperience']
# Categorical columns are: []

# %% [markdown]
# The next code utilizes make_column_transformer and MinMaxScaler from sklearn.compose and sklearn.preprocessing respectively, to create a column transformer object that normalizes the numerical columns.

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# creating column transformer (this will help us normalize/preprocess our data)
ct = make_column_transformer((MinMaxScaler(), num_cols))

# %% [markdown]
# The code fits the column transformer on the training data and transforms both the training and test data using the fitted transformer.

# %%
# fitting column transformer on training data
ct.fit(xtrain)

# transforming training and test data with normalizing (MinMaxScaler) and one hot encoding (OneHotEncoder)
xtrain = ct.transform(xtrain)
xtest = ct.transform(xtest)

# %%
xtrain.shape, xtest.shape, ytrain.shape, ytest.shape
# Out:
# ((24, 1), (6, 1), (24, 1), (6, 1))

# %% [markdown]
# The next code calculates the average value of the "Salary" column in the dataset and prints it. This helps to understand the central tendency of the target variable.

# %%
average_ytrain = df['Salary'].mean()
print('Average of ytrain:', average_ytrain)
# Out:
# Average of ytrain: 76004.0

# %% [markdown]
# The ModelCheckpoint callback is used to save the best model based on the validation loss, while the EarlyStopping callback is used to stop the training process if the validation loss does not improve for a certain number of epochs.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
ES=EarlyStopping(patience=150, restore_best_weights=True),

# %% [markdown]
# **Model: Dense, SGD optimizer**
#
# The next code defines a sequential model using the tf.keras.Sequential class and adds two dense layers to the model. The model is compiled with a mean absolute error (MAE) loss function, stochastic gradient descent (SGD) optimizer, and MAE metric. The code fits the model to the training data for a specified number of epochs and validates the model on the test data. The EarlyStopping and ModelCheckpoint callbacks are used during training.

# %%
model = tf.keras.Sequential([
  tf.keras.layers.Dense(64),
  tf.keras.layers.Dense(1)
])

model.compile(loss=tf.keras.losses.mae,
                          optimizer=tf.keras.optimizers.SGD(),
                          metrics=['mae'])

model_history = model.fit(xtrain,
                          ytrain,
                          epochs=1000,
                          validation_data=(xtest, ytest),
                          callbacks=[ES,checkpoint])
# Out:
# Epoch 1/1000
# 1/1 [==============================] - ETA: 0s - loss: 74208.6250 - mae: 74208.6250
# Epoch 1: val_loss improved from inf to 83185.46094, saving model to best_model.h5
# 1/1 [==============================] - 1s 849ms/step - loss: 74208.6250 - mae: 74208.6250 - val_loss: 83185.4609 - val_mae: 83185.4609
# Epoch 2/1000
# 1/1 [==============================] - ETA: 0s - loss: 74208.5859 - mae: 74208.5859
# Epoch 2: val_loss improved from 83185.46094 to 83185.41406, saving model to best_model.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 74208.5859 - mae: 74208.5859 - val_loss: 83185.4141 - val_mae: 83185.4141
# Epoch 3/1000
# 1/1 [==============================] - ETA: 0s - loss: 74208.5391 - mae: 74208.5391
# Epoch 3: val_loss improved from 83185.41406 to 83185.37500, saving model to best_model.h5
# 1/1 [==============================] - 0s 47ms/step - loss: 74208.5391 - mae: 74208.5391 - val_loss: 83185.3750 - val_mae: 83185.3750
# Epoch 4/1000
# ...

# %% [markdown]
# The following code defines a function called plot_losses that takes the training history as input and plots the losses over epochs. This helps visualize the training progress and identify any overfitting or underfitting.

# %%
def plot_losses(history):
    losses = pd.DataFrame(history.history)
    losses.plot()

# %% [markdown]
# The code calls the plot_losses function and passes the model_history (training history) as an argument.

# %%
plot_losses(model_history)

# %% [markdown]
# The next code makes predictions on the training and test data using the trained model.

# %%
# Make predictions
train_pred = model.predict(xtrain)
test_pred = model.predict(xtest)
# Out:
# ...
# 1/1 [==============================] - 0s 23ms/step

# %% [markdown]
# The code creates a scatter plot to compare the actual values (ytest) with the predicted values (test_pred) on the test data.

# %%
plt.figure(figsize=(10, 7))
plt.scatter(xtest,ytest, c="b", label="Testing data")
plt.scatter(xtest,test_pred, c="g", label="Pred data")
plt.legend();

# %%
# Ensure 'ytest' and 'test_pred' are 1D
ytest = tf.squeeze(ytest)
test_pred = tf.squeeze(test_pred)

# %% [markdown]
# The next code evaluates the predictions by calling the evaluate_preds function and passing the actual (ytest) and predicted (test_pred) values.

# %%
evaluate_preds(ytest,test_pred)
# Out:
# {'mae': 6029.6655,
#  'mse': 50422412.0,
#  'rmse': 7100.874,
#  'mape': '7.651294%',
#  'mase': 0.20482035,
#  'r2': 0.9012866}

# %% [markdown]
# The following code creates a DataFrame (dr) to store the actual and predicted values, as well as the difference and percentage difference between them.

# %%
# Now create the DataFrame
dr = pd.DataFrame({'Actual': ytest, 'Predicted': test_pred})

# Calculate the difference
dr['Difference'] = dr['Predicted'] - dr['Actual']

# Calculate the percentage difference
dr['Percentage Difference'] = (dr['Difference'] / dr['Actual']) * 100

dr = dr.round(2)
dr.head(20)
# Out:
#      Actual      Predicted  Difference  Percentage Difference
# 0  112636.0  112663.953125       27.95                   0.02
# 1   67939.0   73199.578125     5260.58                   7.74
# 2  113813.0  100908.609375   -12904.39                 -11.34
# 3   83089.0   76558.257812    -6530.74                  -7.86
# 4   64446.0   58925.230469    -5520.77                  -8.57
# 5   57190.0   63123.558594     5933.57                  10.38

# %% [markdown]
# The code assigns the predicted values (test_pred) to y_pred_sub and the actual values (ytest) to y_test_sub. The code plots a line graph comparing the predicted values (y_pred_sub) with the actual values (y_test_sub) using the index as the x-axis.

# %%
y_pred_sub = test_pred
y_test_sub = ytest

plt.figure(figsize=(10, 5))
plt.plot(range(len(y_pred_sub)), y_pred_sub, label='Predicted')
plt.plot(range(len(y_test_sub)), y_test_sub, label='Actual')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.title("Actual vs Predicted")
plt.show()

# %% [markdown]
# **Model: Dense, Dropout, Regulizers**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Bidirectional, LSTM, Dropout, Dense, Lambda
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# The next code creates a new instance of the ModelCheckpoint callback, specifying a different filename for the saved best model.

# %%
checkpoint = ModelCheckpoint('best_model2.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)

# %% [markdown]
# The following code defines a new model (model_1) with additional hidden layers and dropout regularization. It compiles the model with mean squared error (MSE) loss, SGD optimizer, and mean absolute error (MAE) metric. The code fits the new model to the training data, validating it on the test data, and using the ModelCheckpoint callback to save the best model.

# %%
from tensorflow.keras import regularizers

# Set random seed
tf.random.set_seed(42)

# Define the model
model_1 = tf.keras.Sequential([
  tf.keras.layers.Dense(256, activation="relu", kernel_regularizer=regularizers.l2(0.01)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=regularizers.l2(0.01)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(1)
])

# Compile the model
model_1.compile(loss=tf.keras.losses.mae,
                          optimizer=tf.keras.optimizers.SGD(),
                          metrics=['mae'])

# Fit the model
history1 = model_1.fit(xtrain,
                      ytrain,
                      epochs=1000,
                      batch_size=32,
                      validation_data=(xtest, ytest),
                      callbacks=[checkpoint])
# Out:
# Epoch 1/1000
# 1/1 [==============================] - ETA: 0s - loss: 74210.3906 - mae: 74208.6641
# Epoch 1: val_loss improved from inf to 83187.22656, saving model to best_model2.h5
# 1/1 [==============================] - 1s 875ms/step - loss: 74210.3906 - mae: 74208.6641 - val_loss: 83187.2266 - val_mae: 83185.5000
# Epoch 2/1000
# 1/1 [==============================] - ETA: 0s - loss: 74210.3438 - mae: 74208.6172
# Epoch 2: val_loss improved from 83187.22656 to 83187.19531, saving model to best_model2.h5
# 1/1 [==============================] - 0s 50ms/step - loss: 74210.3438 - mae: 74208.6172 - val_loss: 83187.1953 - val_mae: 83185.4688
# Epoch 3/1000
# 1/1 [==============================] - ETA: 0s - loss: 74210.3203 - mae: 74208.5938
# Epoch 3: val_loss improved from 83187.19531 to 83187.17188, saving model to best_model2.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 74210.3203 - mae: 74208.5938 - val_loss: 83187.1719 - val_mae: 83185.4453
# Epoch 4/1000
# ...

# %% [markdown]
# The code calls the plot_losses function to visualize the training losses.

# %%
plot_losses(history1)

# %% [markdown]
# The next code loads the best saved model (best_model2.h5) using the load_model function.

# %%
from tensorflow.keras.models import load_model

# Load the best saved model
model_1 = load_model('best_model2.h5')

# %% [markdown]
# The code evaluates the loaded model on the test data.

# %%
model_1.evaluate(xtest, ytest)
# Out:
# 1/1 [==============================] - 0s 138ms/step - loss: 6180.1733 - mae: 6132.6895
# [6180.17333984375, 6132.689453125]

# %% [markdown]
# The code makes predictions on the training and test data using the loaded model.

# %%
# Make predictions
train_pred = model_1.predict(xtrain)
test_pred = model_1.predict(xtest)
# Out:
# ...
# 1/1 [==============================] - 0s 22ms/step

# %%
# Ensure 'ytest' and 'test_pred' are 1D
ytest = tf.squeeze(ytest)
test_pred = tf.squeeze(test_pred)

# %% [markdown]
# The next code calls the evaluate_preds function to evaluate the predictions by passing the actual (ytest) and predicted (test_pred) values.

# %%
evaluate_preds(ytest,test_pred)
# Out:
# {'mae': 6132.689,
#  'mse': 41141120.0,
#  'rmse': 6414.1343,
#  'mape': '7.770145%',
#  'mase': 0.20831993,
#  'r2': 0.91945684}

# %% [markdown]
# The following code creates a DataFrame (dr) to store the actual and predicted values, as well as the difference and percentage difference between them.

# %%
# Now create the DataFrame
dr = pd.DataFrame({'Actual': ytest, 'Predicted': test_pred})

# Calculate the difference
dr['Difference'] = dr['Predicted'] - dr['Actual']

# Calculate the percentage difference
dr['Percentage Difference'] = (dr['Difference'] / dr['Actual']) * 100

dr = dr.round(2)
dr.head(20)
# Out:
#      Actual      Predicted  Difference  Percentage Difference
# 0  112636.0  116530.757812     3894.76                   3.46
# 1   67939.0   73910.179688     5971.18                   8.79
# 2  113813.0  103835.273438    -9977.73                  -8.77
# 3   83089.0   77537.476562    -5551.52                  -6.68
# 4   64446.0   59318.839844    -5127.16                  -7.96
# 5   57190.0   63463.789062     6273.79                  10.97

# %% [markdown]
# The code assigns the predicted values (test_pred) to y_pred_sub and the actual values (ytest) to y_test_sub. The code plots a line graph comparing the predicted values (y_pred_sub) with the actual values (y_test_sub) using the index as the x-axis.

# %%
y_pred_sub = test_pred
y_test_sub = ytest

plt.figure(figsize=(10, 5))
plt.plot(range(len(y_pred_sub)), y_pred_sub, label='Predicted')
plt.plot(range(len(y_test_sub)), y_test_sub, label='Actual')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.title("Actual vs Predicted")
plt.show()
