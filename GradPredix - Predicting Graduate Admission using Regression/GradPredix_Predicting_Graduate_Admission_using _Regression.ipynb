# %% [markdown]
# # **Title: GradPredix - Predicting Graduate Admission from Important Parameters**

# %% [markdown]
# ![Screenshot 2023-07-12 105055.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Overview/Introduction
#
# This project aims to develop an AI-based predictive model to estimate the likelihood of admission to graduate programs from an Indian perspective. By analyzing key parameters, such as GRE scores, TOEFL scores, university rating, statement of purpose and letter of recommendation strength, undergraduate GPA, research experience, and chance of admission, this project will provide valuable insights to prospective graduate students.
#
# ## Problem Statement
#
# The process of applying to graduate programs is highly competitive and challenging for students. Admissions committees receive a large number of applications, making it difficult to thoroughly evaluate each candidate. Consequently, there is a need for an efficient and reliable method to predict a student's chances of admission based on their application parameters.
#
# Moreover, the decision-making process for admissions committees can be subjective and influenced by various factors. This subjectivity may lead to inconsistencies and biases, unintentionally disadvantaging certain applicants. By leveraging artificial intelligence and machine learning techniques, this project aims to address these issues and provide an objective assessment of admission probabilities.
#
# ## Objectives
#
# The primary objectives of this project are as follows:
#
# 1. **Develop a predictive model**: Create an accurate and robust predictive model using machine learning algorithms to estimate the probability of admission based on the provided parameters.
#
# 2. **Identify influential factors**: Determine the relative importance of each parameter in predicting admission outcomes. Identify which factors have the strongest influence on admission decisions and explore any underlying relationships between these factors.
#
# 3. **Reduce subjectivity and bias**: By relying on objective data analysis, the project aims to minimize subjectivity and biases that might arise during the admission evaluation process. This will result in a fairer and more transparent admission system.
#
# 4. **Provide valuable insights**: Generate meaningful insights and recommendations for prospective students to enhance their application strategies. By understanding the significance of each parameter, students can focus on improving their strengths and addressing any weaknesses in their applications.
#
# 5. **Improve admissions process**: Contribute to the advancement of the admissions process by proposing a reliable and data-driven method for evaluating applicants. The insights gained from this project can help admissions committees make more informed decisions and streamline the selection process.
#
# ## Dataset Description
#
# The dataset used for this project comprises various essential parameters considered during the application process for Master's programs. These parameters include:
#
# - **GRE Scores**: The Graduate Record Examination scores, measured on a scale of 340.
# - **TOEFL Scores**: The Test of English as a Foreign Language scores, measured on a scale of 120.
# - **University Rating**: A rating assigned to universities on a scale of 1 to 5, indicating their reputation and quality.
# - **Statement of Purpose and Letter of Recommendation Strength**: Ratings ranging from 1 to 5, evaluating the quality and effectiveness of the applicant's statement of purpose and recommendation letters.
# - **Undergraduate GPA**: The Grade Point Average achieved during the applicant's undergraduate studies, measured on a scale of 10.
# - **Research Experience**: A binary parameter indicating whether the applicant has any prior research experience (0 for no, 1 for yes).
# - **Chance of Admit**: A probability score ranging from 0 to 1, representing the likelihood of admission.
#
# The dataset has been inspired by the UCLA Graduate Dataset, with the test scores and GPA presented in the older format. It is important to note that this dataset is owned by Mohan S Acharya, who has made it available for analysis and research purposes.
#
# **Citation:**
# Mohan S Acharya, Asfia Armaan, Aneeta S Antony : A Comparison of Regression Models for Prediction of Graduate Admissions, IEEE International Conference on Computational Intelligence in Data Science 2019
#
# **Dataset URL:** https://www.kaggle.com/datasets/mohansacharya/graduate-admissions

# %% [markdown]
# # Technologies Used
#
# 1. **Python**: The code was written in Python, a versatile and widely-used programming language for data analysis and machine learning.
#
# 2. **Pandas**: The Pandas library was utilized for data manipulation and analysis. It provides powerful data structures and functions for handling tabular data.
#
# 3. **NumPy**: NumPy, a fundamental library for numerical computing in Python, was used for mathematical operations and array manipulation.
#
# 4. **Matplotlib**: Matplotlib was employed for data visualization, enabling the creation of various plots and charts to visualize the distribution and relationships between different variables.
#
# 5. **Seaborn**: Seaborn, a data visualization library based on Matplotlib, was used to create attractive and informative statistical graphics, including heatmaps and histograms.
#
# 6. **scikit-learn**: The scikit-learn library was utilized for data preprocessing, feature scaling, and model evaluation. It provides a wide range of machine learning algorithms and utilities for building predictive models.
#
# 7. **TensorFlow**: TensorFlow, an open-source machine learning framework, was used for building and training neural network models. It offers a high-level API for creating deep learning models and efficient computation on GPUs.
#
# 8. **Keras Tuner**: Keras Tuner was employed for hyperparameter tuning. It provides an efficient way to search and optimize the hyperparameters of machine learning models.
#
# # Methodology
#
# The project followed the following methodology:
#
# 1. **Data Loading**: The dataset was loaded into a Pandas DataFrame using `pd.read_csv()`.
#
# 2. **Data Preprocessing**: Irrelevant columns were dropped, missing values were handled, and renaming was performed.
#
# 3. **Exploratory Data Analysis**: Visualizations like correlation matrix heatmap and histograms provided insights into the dataset.
#
# 4. **Handling Outliers**: Outliers were identified and removed using boxplots.
#
# 5. **Data Splitting**: The dataset was split into training and testing sets.
#
# 6. **Data Normalization**: Numerical features were normalized using MinMaxScaler and categorical features were one-hot encoded.
#
# 7. **Model Building**: A neural network model with dropout regularization was constructed using TensorFlow's Sequential API.
#
# 8. **Model Training**: The model was trained with hyperparameter optimization, early stopping, and model checkpoints.
#
# 9. **Model Evaluation**: The trained model was evaluated on the testing data using metrics like MAE and MSE.
#
# 10. **Hyperparameter Tuning**: Keras Tuner was used for hyperparameter tuning with a function to build customizable models.
#
# 11. **Best Model Training**: The best model obtained from hyperparameter tuning was trained, utilizing early stopping and model checkpoints.
#
# This methodology ensured effective data processing, model construction, and evaluation to achieve accurate predictions for graduate admission.
#
# # Results
#
# The project yielded the following results:
#
# 1. Before hyperparameter tuning, the model was evaluated on the testing data, resulting in a validation loss (MSE) of 0.0044 and a validation MAE of 0.0480.
#
# 2. After hyperparameter tuning, the best model achieved improved performance on the testing data, with a validation loss (MSE) of 0.0044 and a validation MAE of 0.0479.
#
# These results indicate that the hyperparameter tuning process helped optimize the model's performance, reducing the mean squared error and mean absolute error on the testing data.
#
# # Discussion/Interpretation of Results
#
# The results of this project demonstrate the effectiveness of machine learning models in predicting graduate admission based on important parameters. By leveraging various features such as GRE scores, TOEFL scores, university ratings, statements of purpose, recommendation strength, undergraduate GPA, and research experience, the model can estimate the likelihood of admission.
#
# The actual results of the model evaluation showed a validation loss (MSE) of 0.0044 and a validation mean absolute error (MAE) of 0.0480 before hyperparameter tuning. After hyperparameter tuning, the model achieved improved performance with a validation loss (MSE) of 0.0044 and a validation MAE of 0.0479. These results indicate that the model's predictions are accurate and reliable, providing valuable insights into the likelihood of graduate admission based on the given parameters.
#
#
# # Conclusion
#
# The successful implementation of an AI project aimed to predict graduate admission from important parameters. Leveraging machine learning techniques and a comprehensive dataset, the project addressed key issues in the admissions process, providing valuable insights for prospective students and admissions committees. The results showcased the model's effectiveness in predicting graduate admission probabilities. After hyperparameter tuning, the neural network model achieved improved performance, demonstrating low mean squared error and mean absolute error on the testing data.
#
# This project has the potential to revolutionize the graduate admission process by offering a data-driven approach to assess applicants' chances of admission. It leverages important parameters to provide valuable insights and recommendations for prospective students, enhancing their application strategies. Additionally, it promotes fairness and transparency in admissions by reducing subjectivity and bias.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/graduate-admissions/Admission_Predict.csv
# /kaggle/input/graduate-admissions/Admission_Predict_Ver1.1.csv

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, LSTM, GRU, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler
import itertools
import random
import os
import csv
# !pip install keras-tuner
import keras_tuner as kt
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Requirement already satisfied: keras-tuner in /opt/conda/lib/python3.10/site-packages (1.3.5)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from keras-tuner) (21.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from keras-tuner) (2.31.0)
# Requirement already satisfied: kt-legacy in /opt/conda/lib/python3.10/site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->keras-tuner) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->keras-tuner) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->keras-tuner) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->keras-tuner) (2023.5.7)

# %% [markdown]
# The following code shows a function seed_everything() that sets the seed values for random number generators in TensorFlow, NumPy, and Python's random library, ensuring reproducibility of results for future use cases.

# %%
# Seed Everything to reproduce results for future use cases
def seed_everything(seed=42):
    # Seed value for TensorFlow
    tf.random.set_seed(seed)

    # Seed value for NumPy
    np.random.seed(seed)

    # Seed value for Python's random library
    random.seed(seed)

seed_everything()

# %% [markdown]
# The next code reads in a dataset from a CSV file and assigns it to the variable df. It then displays the first few rows of the dataset using the head() function.

# %%
df = pd.read_csv("/kaggle/input/graduate-admissions/Admission_Predict_Ver1.1.csv")
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %% [markdown]
# This code computes descriptive statistics for each column in the DataFrame and transposes the result.

# %%
df.describe().T
# Out:
#                    count       mean         std     min       25%     50%  \
# Serial No.         500.0  250.50000  144.481833    1.00  125.7500  250.50
# GRE Score          500.0  316.47200   11.295148  290.00  308.0000  317.00
# TOEFL Score        500.0  107.19200    6.081868   92.00  103.0000  107.00
# University Rating  500.0    3.11400    1.143512    1.00    2.0000    3.00
# SOP                500.0    3.37400    0.991004    1.00    2.5000    3.50
# LOR                500.0    3.48400    0.925450    1.00    3.0000    3.50
# CGPA               500.0    8.57644    0.604813    6.80    8.1275    8.56
# Research           500.0    0.56000    0.496884    0.00    0.0000    1.00
# Chance of Admit    500.0    0.72174    0.141140    0.34    0.6300    0.72
#
#                       75%     max
# Serial No.         375.25  500.00
# GRE Score          325.00  340.00
# TOEFL Score        112.00  120.00
# University Rating    4.00    5.00
# SOP                  4.00    5.00
# LOR                  4.00    5.00
# CGPA                 9.04    9.92
# Research             1.00    1.00
# Chance of Admit      0.82    0.97

# %% [markdown]
# The code snippet assigns the values of the 'Serial No.' column to the variable 'serialNo'. Then, it drops the 'Serial No.' column from the DataFrame 'df'. Finally, it renames the column 'Chance of Admit ' to 'Chance of Admit'.

# %%
# it may be needed in the future.
serialNo = df["Serial No."].values

df.drop(["Serial No."],axis=1,inplace = True)

df=df.rename(columns = {'Chance of Admit ':'Chance of Admit'})

# %% [markdown]
# **Duplicates and Null values**
#
# The code prints the number of data points in the dataset. The next code checks for duplicates in the dataset and prints the number of duplicates found. The code then checks for missing values in the dataset by calculating the sum of missing values for each column and prints the results. The code also replaces empty strings with NaN values in the dataset and recalculates the number of missing values.

# %%
# How many reviews do we have?
print('There are', df.shape[0], 'data in this dataset')

# Do we have duplicates?
print('Number of Duplicates:', len(df[df.duplicated()]))

# Do we have missing values?
missing_values = df.isnull().sum()
print('Number of Missing Values by column:\n',missing_values)

print('Number of Missing Values:', df.isnull().sum().sum())

df.replace("", np.nan, inplace=True)
missing_values = df.isnull().sum()
print('Number of Missing Values by column:\n',missing_values)
# Out:
# There are 500 data in this dataset
# Number of Duplicates: 0
# Number of Missing Values by column:
#  GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64
# Number of Missing Values: 0
# Number of Missing Values by column:
#  GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# **Correlation Matrix**
#
# A heatmap is generated to visualize the correlation between the features in the DataFrame using the df.corr() function. The annot=True parameter enables displaying the correlation values on the heatmap.

# %%
sns.heatmap(df.corr(), annot=True, cmap='PuOr')
# Out:
# <Axes: >

# %% [markdown]
# The correlation matrix of the DataFrame is calculated, and the correlation of "Chance of Admit" with other features is extracted and sorted in descending order.

# %%
# Calculate the correlation matrix
corr_matrix = df.corr(numeric_only=True)

# Get the correlation of 'price' with other features
corr_with_price = corr_matrix['Chance of Admit']

# Sort these correlations in descending order
sorted_correlations = corr_with_price.sort_values(ascending=False)

# Print out the sorted correlations
sorted_correlations
# Out:
# Chance of Admit      1.000000
# CGPA                 0.882413
# GRE Score            0.810351
# TOEFL Score          0.792228
# University Rating    0.690132
# SOP                  0.684137
# LOR                  0.645365
# Research             0.545871
# Name: Chance of Admit, dtype: float64

# %% [markdown]
# **EDA**
#
# The code sets the style and creates a distribution plot using sns.distplot to visualize the distribution of the "Chance of Admit" column.

# %%
sns.set(style='whitegrid')
f, ax = plt.subplots(1,1, figsize=(12, 8))
ax = sns.histplot(df['Chance of Admit'], kde = True, color = 'c')
plt.title('Distribution of chance of admission')
# Out:
# Text(0.5, 1.0, 'Distribution of chance of admission')

# %% [markdown]
# The code generates histograms to visualize the distribution of various features in the DataFrame 'df'. Each histogram is created using the seaborn library's 'histplot' function. The features being plotted include 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP Ratings', and 'CGPA'. The 'kde=False' argument indicates that the kernel density estimation plot should not be included. Each histogram is given an appropriate title and displayed using 'plt.show()'. This allows for a quick visual understanding of the distribution of these features in the dataset.

# %%
sns.histplot(df['GRE Score'], kde=False)
plt.title("Distribution of GRE Scores")
plt.show()

sns.histplot(df['TOEFL Score'], kde=False)
plt.title("Distribution of TOEFL Scores")
plt.show()

sns.histplot(df['University Rating'], kde=False)
plt.title("Distribution of University Rating")
plt.show()

sns.histplot(df['SOP'], kde=False)
plt.title("Distribution of SOP Ratings")
plt.show()

sns.histplot(df['CGPA'], kde=False)
plt.title("Distribution of CGPA")
plt.show()

# %% [markdown]
# **Handling Outliers**
#
# The following code shows the selection of numerical features from a dataframe and the subsequent plotting of boxplots for each of those features. This code is important for visualizing and analyzing the distribution of numerical data, identifying potential outliers in the data.

# %%
import math

# Selecting the numerical features
numerical_features = df.select_dtypes(include=['float64','int64']).columns

rounded_up_value = math.ceil(len(numerical_features)/3)

# Plotting boxplots for all numerical features
fig, axes = plt.subplots(rounded_up_value, 3, figsize=(15, 15))
fig.subplots_adjust(wspace=0.1, hspace=0.3)
fig.suptitle('Outlier Analysis using Boxplot', fontsize=30)
axes = axes.ravel()
font = {
    'family': 'serif',
    'color':  'darkred',
    'weight': 'normal',
    'size': 16,
}
for i, col in enumerate(numerical_features):
    sns.boxplot(df[col], ax=axes[i])
    axes[i].set_title(col, fontdict=font, fontsize=25)

# %% [markdown]
# The next code defines a function called "detect_outliers" that takes a dataframe and a column as input. It calculates the lower and upper limits for outlier detection using the interquartile range (IQR) method and identifies outliers in the specified column. If no outliers are present, it returns an empty list; otherwise, it returns the indices and values of the outliers.

# %%
# Function to detect outliers
def detect_outliers(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_limit = Q1 - (1.5 * IQR)
    upper_limit = Q3 + (1.5 * IQR)
    outliers = df[(df[col] < lower_limit) | (df[col] > upper_limit)]

    if len(outliers) == 0:
        return [], 'No Outliers Present'
    else:
        return outliers.index.tolist(), outliers

# %% [markdown]
# In the following code, all the outlier indices are collected by iterating over the numerical features and applying the "detect_outliers" function. The outliers and their indices are printed for each feature.

# %%
# Collect all outlier indices
all_outlier_indices = []

# Outliers values are --
for col in numerical_features:
    print('-' * 27, col,'-' * 26)
    outlier_indices, outliers = detect_outliers(df, col)
    all_outlier_indices.extend(outlier_indices)
    print(outliers)
    print('\n')
# Out:
# --------------------------- GRE Score --------------------------
# No Outliers Present
#
#
# --------------------------- TOEFL Score --------------------------
# No Outliers Present
#
#
# --------------------------- University Rating --------------------------
# No Outliers Present
#
#
# --------------------------- SOP --------------------------
# No Outliers Present
#
#
# --------------------------- LOR  --------------------------
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 347        299           94                  1  1.0   1.0  7.34         0
#
#      Chance of Admit
# 347             0.42
#
#
# --------------------------- CGPA --------------------------
# No Outliers Present
#
#
# --------------------------- Research --------------------------
# No Outliers Present
#
#
# --------------------------- Chance of Admit --------------------------
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 92         298           98                  2  4.0   3.0  8.03         0
# 376        297           96                  2  2.5   2.0  7.43         0
#
#      Chance of Admit
# 92              0.34
# 376             0.34

# %% [markdown]
# The code then gets the unique outlier indices by removing any duplicates from the previously collected outlier indices. The unique outlier indices and their count are printed, providing information about the overall number of unique outliers in the dataset.

# %%
# Get unique outlier indices
unique_outlier_indices = list(set(all_outlier_indices))

# Print the unique indices and their count
print("Unique outlier indices:", unique_outlier_indices)
print("Number of unique outlier indices:", len(unique_outlier_indices))
# Out:
# Unique outlier indices: [376, 347, 92]
# Number of unique outlier indices: 3

# %% [markdown]
# Next, the code drops the rows with unique outlier indices from the original dataframe, creating a new dataframe called "data" that excludes those outliers.

# %%
df = df.drop(unique_outlier_indices)

# %% [markdown]
# **Feature Selection**
#
# Following that, the code splits the preprocessed data into input features (X) and target variable (y) by dropping the "price" column from the "data" dataframe.

# %%
X = df.drop('Chance of Admit', axis=1)
y = df['Chance of Admit']

# %% [markdown]
# The subsequent code imports the "train_test_split" function from the "sklearn.model_selection" module. This function is used to split the data into training and testing sets for model evaluation. The data is split such that 80% is used for training and 20% is used for testing, and a random seed of 42 is set for reproducibility.

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %% [markdown]
# The code then defines two lists: "num_cols" to store the names of numerical columns (excluding the target variable "Chance of Admit") and "cat_cols" to store the names of categorical columns in the "data" dataframe.

# %%
# Get list of numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Remove 'price' from num_cols
num_cols.remove('Chance of Admit')

# Get list of categorical columns
cat_cols = df.select_dtypes(include=['object']).columns.tolist()

# Print the numerical columns
print("Numerical columns are:", num_cols)

# Print the categorical columns
print("Categorical columns are:", cat_cols)
# Out:
# Numerical columns are: ['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA', 'Research']
# Categorical columns are: []

# %% [markdown]
# In the subsequent code, a column transformer is created using the "make_column_transformer" function from the "sklearn.compose" module. This column transformer applies scaling (MinMaxScaler) to the numerical columns.

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# creating column transformer (this will help us normalize/preprocess our data)

ct = make_column_transformer((MinMaxScaler(), num_cols))

# %% [markdown]
# The column transformer is then fitted on the training data, and the same transformation is applied to both the training and test data.

# %%
# fitting column transformer on training data
ct.fit(xtrain)

# transforming training and test data with normalizing (MinMaxScaler) and one hot encoding (OneHotEncoder)
xtrain = ct.transform(xtrain)
xtest = ct.transform(xtest)

# %% [markdown]
# **Model Building**
#
# Next, the code imports necessary modules from TensorFlow and defines a neural network model called "model_1" using the Sequential API. The model consists of multiple dense layers with dropout regularization to prevent overfitting. The model is compiled with a mean squared error loss function, an Adam optimizer, and metrics to monitor mean absolute error during training.

# %%
from tensorflow.keras import regularizers

# Set random seed
tf.random.set_seed(42)

# Define the model
model_1 = tf.keras.Sequential([
  tf.keras.layers.Dense(512, activation="relu", kernel_regularizer=regularizers.l2(0.01)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=regularizers.l2(0.01)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(1)
])

# Define the optimizer
optimizer = tf.keras.optimizers.Adam()

# Compile the model
model_1.compile(loss="mean_squared_error",
                optimizer=optimizer,
                metrics=["mean_absolute_error"])

# %% [markdown]
# A learning rate schedule is defined using a learning rate scheduler callback. This allows the learning rate to change dynamically during training, potentially improving model performance. The model is then trained on the preprocessed training data, using the validation data for evaluation and the learning rate scheduler callback.

# %%
# Define the learning rate schedule
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-6 * 10**(-epoch / 20))

# Fit the model
history = model_1.fit(xtrain,
                      ytrain,
                      epochs=100,
                      batch_size=32,
                      validation_data=(xtest, ytest),
                      callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 13/13 [==============================] - 1s 24ms/step - loss: 2.7795 - mean_absolute_error: 0.7525 - val_loss: 2.7099 - val_mean_absolute_error: 0.7105 - lr: 1.0000e-06
# Epoch 2/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7744 - mean_absolute_error: 0.7509 - val_loss: 2.7064 - val_mean_absolute_error: 0.7085 - lr: 8.9125e-07
# Epoch 3/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7759 - mean_absolute_error: 0.7514 - val_loss: 2.7034 - val_mean_absolute_error: 0.7068 - lr: 7.9433e-07
# Epoch 4/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7613 - mean_absolute_error: 0.7426 - val_loss: 2.7007 - val_mean_absolute_error: 0.7053 - lr: 7.0795e-07
# Epoch 5/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7650 - mean_absolute_error: 0.7447 - val_loss: 2.6984 - val_mean_absolute_error: 0.7039 - lr: 6.3096e-07
# Epoch 6/100
# 13/13 [==============================] - 0s 9ms/step - loss: 2.7619 - mean_absolute_error: 0.7432 - val_loss: 2.6962 - val_mean_absolute_error: 0.7027 - lr: 5.6234e-07
# Epoch 7/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7605 - mean_absolute_error: 0.7426 - val_loss: 2.6943 - val_mean_absolute_error: 0.7016 - lr: 5.0119e-07
# Epoch 8/100
# 13/13 [==============================] - 0s 9ms/step - loss: 2.7629 - mean_absolute_error: 0.7446 - val_loss: 2.6927 - val_mean_absolute_error: 0.7006 - lr: 4.4668e-07
# Epoch 9/100
# 13/13 [==============================] - 0s 9ms/step - loss: 2.7504 - mean_absolute_error: 0.7359 - val_loss: 2.6912 - val_mean_absolute_error: 0.6998 - lr: 3.9811e-07
# Epoch 10/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7509 - mean_absolute_error: 0.7371 - val_loss: 2.6899 - val_mean_absolute_error: 0.6990 - lr: 3.5481e-07
# Epoch 11/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7506 - mean_absolute_error: 0.7371 - val_loss: 2.6887 - val_mean_absolute_error: 0.6983 - lr: 3.1623e-07
# Epoch 12/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7401 - mean_absolute_error: 0.7309 - val_loss: 2.6877 - val_mean_absolute_error: 0.6977 - lr: 2.8184e-07
# Epoch 13/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7586 - mean_absolute_error: 0.7413 - val_loss: 2.6867 - val_mean_absolute_error: 0.6972 - lr: 2.5119e-07
# Epoch 14/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7557 - mean_absolute_error: 0.7395 - val_loss: 2.6859 - val_mean_absolute_error: 0.6967 - lr: 2.2387e-07
# Epoch 15/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7439 - mean_absolute_error: 0.7329 - val_loss: 2.6852 - val_mean_absolute_error: 0.6963 - lr: 1.9953e-07
# Epoch 16/100
# 13/13 [==============================] - 0s 6ms/step - loss: 2.7475 - mean_absolute_error: 0.7346 - val_loss: 2.6845 - val_mean_absolute_error: 0.6959 - lr: 1.7783e-07
# Epoch 17/100
# 13/13 [==============================] - 0s 6ms/step - loss: 2.7521 - mean_absolute_error: 0.7380 - val_loss: 2.6839 - val_mean_absolute_error: 0.6955 - lr: 1.5849e-07
# Epoch 18/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7402 - mean_absolute_error: 0.7297 - val_loss: 2.6834 - val_mean_absolute_error: 0.6952 - lr: 1.4125e-07
# Epoch 19/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7514 - mean_absolute_error: 0.7380 - val_loss: 2.6829 - val_mean_absolute_error: 0.6950 - lr: 1.2589e-07
# Epoch 20/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7479 - mean_absolute_error: 0.7366 - val_loss: 2.6825 - val_mean_absolute_error: 0.6947 - lr: 1.1220e-07
# Epoch 21/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7474 - mean_absolute_error: 0.7355 - val_loss: 2.6821 - val_mean_absolute_error: 0.6945 - lr: 1.0000e-07
# Epoch 22/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7440 - mean_absolute_error: 0.7327 - val_loss: 2.6818 - val_mean_absolute_error: 0.6943 - lr: 8.9125e-08
# Epoch 23/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7457 - mean_absolute_error: 0.7334 - val_loss: 2.6815 - val_mean_absolute_error: 0.6941 - lr: 7.9433e-08
# Epoch 24/100
# 13/13 [==============================] - 0s 6ms/step - loss: 2.7469 - mean_absolute_error: 0.7351 - val_loss: 2.6813 - val_mean_absolute_error: 0.6940 - lr: 7.0795e-08
# Epoch 25/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7368 - mean_absolute_error: 0.7289 - val_loss: 2.6810 - val_mean_absolute_error: 0.6939 - lr: 6.3096e-08
# Epoch 26/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7312 - mean_absolute_error: 0.7254 - val_loss: 2.6808 - val_mean_absolute_error: 0.6937 - lr: 5.6234e-08
# Epoch 27/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7487 - mean_absolute_error: 0.7357 - val_loss: 2.6806 - val_mean_absolute_error: 0.6936 - lr: 5.0119e-08
# Epoch 28/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7421 - mean_absolute_error: 0.7328 - val_loss: 2.6805 - val_mean_absolute_error: 0.6935 - lr: 4.4668e-08
# Epoch 29/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7449 - mean_absolute_error: 0.7338 - val_loss: 2.6803 - val_mean_absolute_error: 0.6935 - lr: 3.9811e-08
# Epoch 30/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7459 - mean_absolute_error: 0.7343 - val_loss: 2.6802 - val_mean_absolute_error: 0.6934 - lr: 3.5481e-08
# Epoch 31/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7384 - mean_absolute_error: 0.7306 - val_loss: 2.6801 - val_mean_absolute_error: 0.6933 - lr: 3.1623e-08
# Epoch 32/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7376 - mean_absolute_error: 0.7299 - val_loss: 2.6800 - val_mean_absolute_error: 0.6933 - lr: 2.8184e-08
# Epoch 33/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7340 - mean_absolute_error: 0.7271 - val_loss: 2.6799 - val_mean_absolute_error: 0.6932 - lr: 2.5119e-08
# Epoch 34/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7501 - mean_absolute_error: 0.7368 - val_loss: 2.6798 - val_mean_absolute_error: 0.6931 - lr: 2.2387e-08
# Epoch 35/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7465 - mean_absolute_error: 0.7346 - val_loss: 2.6797 - val_mean_absolute_error: 0.6931 - lr: 1.9953e-08
# Epoch 36/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7351 - mean_absolute_error: 0.7285 - val_loss: 2.6797 - val_mean_absolute_error: 0.6931 - lr: 1.7783e-08
# Epoch 37/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7376 - mean_absolute_error: 0.7291 - val_loss: 2.6796 - val_mean_absolute_error: 0.6930 - lr: 1.5849e-08
# Epoch 38/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7453 - mean_absolute_error: 0.7348 - val_loss: 2.6796 - val_mean_absolute_error: 0.6930 - lr: 1.4125e-08
# Epoch 39/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7461 - mean_absolute_error: 0.7348 - val_loss: 2.6795 - val_mean_absolute_error: 0.6930 - lr: 1.2589e-08
# Epoch 40/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7402 - mean_absolute_error: 0.7310 - val_loss: 2.6795 - val_mean_absolute_error: 0.6930 - lr: 1.1220e-08
# Epoch 41/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7384 - mean_absolute_error: 0.7297 - val_loss: 2.6794 - val_mean_absolute_error: 0.6929 - lr: 1.0000e-08
# Epoch 42/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7341 - mean_absolute_error: 0.7278 - val_loss: 2.6794 - val_mean_absolute_error: 0.6929 - lr: 8.9125e-09
# Epoch 43/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7477 - mean_absolute_error: 0.7359 - val_loss: 2.6794 - val_mean_absolute_error: 0.6929 - lr: 7.9433e-09
# Epoch 44/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7378 - mean_absolute_error: 0.7297 - val_loss: 2.6793 - val_mean_absolute_error: 0.6929 - lr: 7.0795e-09
# Epoch 45/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7399 - mean_absolute_error: 0.7305 - val_loss: 2.6793 - val_mean_absolute_error: 0.6929 - lr: 6.3096e-09
# Epoch 46/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7415 - mean_absolute_error: 0.7316 - val_loss: 2.6793 - val_mean_absolute_error: 0.6929 - lr: 5.6234e-09
# Epoch 47/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7416 - mean_absolute_error: 0.7314 - val_loss: 2.6793 - val_mean_absolute_error: 0.6928 - lr: 5.0119e-09
# Epoch 48/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7418 - mean_absolute_error: 0.7318 - val_loss: 2.6793 - val_mean_absolute_error: 0.6928 - lr: 4.4668e-09
# Epoch 49/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7483 - mean_absolute_error: 0.7352 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 3.9811e-09
# Epoch 50/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7440 - mean_absolute_error: 0.7334 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 3.5481e-09
# Epoch 51/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7397 - mean_absolute_error: 0.7320 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 3.1623e-09
# Epoch 52/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7412 - mean_absolute_error: 0.7319 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 2.8184e-09
# Epoch 53/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7425 - mean_absolute_error: 0.7324 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 2.5119e-09
# Epoch 54/100
# 13/13 [==============================] - 0s 9ms/step - loss: 2.7499 - mean_absolute_error: 0.7363 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 2.2387e-09
# Epoch 55/100
# 13/13 [==============================] - 0s 9ms/step - loss: 2.7463 - mean_absolute_error: 0.7351 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.9953e-09
# Epoch 56/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7364 - mean_absolute_error: 0.7293 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.7783e-09
# Epoch 57/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7335 - mean_absolute_error: 0.7266 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.5849e-09
# Epoch 58/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7349 - mean_absolute_error: 0.7284 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.4125e-09
# Epoch 59/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7450 - mean_absolute_error: 0.7341 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.2589e-09
# Epoch 60/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7322 - mean_absolute_error: 0.7259 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.1220e-09
# Epoch 61/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7394 - mean_absolute_error: 0.7315 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.0000e-09
# Epoch 62/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7522 - mean_absolute_error: 0.7387 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 8.9125e-10
# Epoch 63/100
# 13/13 [==============================] - 0s 6ms/step - loss: 2.7380 - mean_absolute_error: 0.7302 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 7.9433e-10
# Epoch 64/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7412 - mean_absolute_error: 0.7315 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 7.0795e-10
# Epoch 65/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7402 - mean_absolute_error: 0.7316 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 6.3096e-10
# Epoch 66/100
# 13/13 [==============================] - 0s 6ms/step - loss: 2.7352 - mean_absolute_error: 0.7288 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 5.6234e-10
# Epoch 67/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7343 - mean_absolute_error: 0.7263 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 5.0119e-10
# Epoch 68/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7448 - mean_absolute_error: 0.7339 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 4.4668e-10
# Epoch 69/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7389 - mean_absolute_error: 0.7304 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 3.9811e-10
# Epoch 70/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7364 - mean_absolute_error: 0.7291 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 3.5481e-10
# Epoch 71/100
# 13/13 [==============================] - 0s 6ms/step - loss: 2.7483 - mean_absolute_error: 0.7364 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 3.1623e-10
# Epoch 72/100
# 13/13 [==============================] - 0s 6ms/step - loss: 2.7442 - mean_absolute_error: 0.7334 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 2.8184e-10
# Epoch 73/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7409 - mean_absolute_error: 0.7330 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 2.5119e-10
# Epoch 74/100
# 13/13 [==============================] - 0s 6ms/step - loss: 2.7417 - mean_absolute_error: 0.7323 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 2.2387e-10
# Epoch 75/100
# 13/13 [==============================] - 0s 6ms/step - loss: 2.7493 - mean_absolute_error: 0.7365 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.9953e-10
# Epoch 76/100
# 13/13 [==============================] - 0s 6ms/step - loss: 2.7364 - mean_absolute_error: 0.7288 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.7783e-10
# Epoch 77/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7385 - mean_absolute_error: 0.7300 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.5849e-10
# Epoch 78/100
# 13/13 [==============================] - 0s 6ms/step - loss: 2.7510 - mean_absolute_error: 0.7374 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.4125e-10
# Epoch 79/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7444 - mean_absolute_error: 0.7337 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.2589e-10
# Epoch 80/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7336 - mean_absolute_error: 0.7278 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.1220e-10
# Epoch 81/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7403 - mean_absolute_error: 0.7311 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.0000e-10
# Epoch 82/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7486 - mean_absolute_error: 0.7367 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 8.9125e-11
# Epoch 83/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7406 - mean_absolute_error: 0.7315 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 7.9433e-11
# Epoch 84/100
# 13/13 [==============================] - 0s 6ms/step - loss: 2.7362 - mean_absolute_error: 0.7298 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 7.0795e-11
# Epoch 85/100
# 13/13 [==============================] - 0s 6ms/step - loss: 2.7461 - mean_absolute_error: 0.7342 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 6.3096e-11
# Epoch 86/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7446 - mean_absolute_error: 0.7333 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 5.6234e-11
# Epoch 87/100
# 13/13 [==============================] - 0s 6ms/step - loss: 2.7388 - mean_absolute_error: 0.7311 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 5.0119e-11
# Epoch 88/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7448 - mean_absolute_error: 0.7343 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 4.4668e-11
# Epoch 89/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7435 - mean_absolute_error: 0.7332 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 3.9811e-11
# Epoch 90/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7377 - mean_absolute_error: 0.7293 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 3.5481e-11
# Epoch 91/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7443 - mean_absolute_error: 0.7329 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 3.1623e-11
# Epoch 92/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7312 - mean_absolute_error: 0.7259 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 2.8184e-11
# Epoch 93/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7403 - mean_absolute_error: 0.7311 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 2.5119e-11
# Epoch 94/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7411 - mean_absolute_error: 0.7319 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 2.2387e-11
# Epoch 95/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7390 - mean_absolute_error: 0.7304 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.9953e-11
# Epoch 96/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7392 - mean_absolute_error: 0.7309 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.7783e-11
# Epoch 97/100
# 13/13 [==============================] - 0s 8ms/step - loss: 2.7382 - mean_absolute_error: 0.7297 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.5849e-11
# Epoch 98/100
# 13/13 [==============================] - 0s 9ms/step - loss: 2.7369 - mean_absolute_error: 0.7294 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.4125e-11
# Epoch 99/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7333 - mean_absolute_error: 0.7281 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.2589e-11
# Epoch 100/100
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7467 - mean_absolute_error: 0.7361 - val_loss: 2.6792 - val_mean_absolute_error: 0.6928 - lr: 1.1220e-11

# %% [markdown]
# The subsequent code plots the learning rate versus the loss to visualize the relationship between the learning rate and the model's performance. This can help in choosing an appropriate learning rate for training the model.

# %%
# Plot the learning rate versus the loss
lrs = 1e-6 * (10 ** (np.arange(100)/20))
plt.figure(figsize=(10, 7))
plt.semilogx(lrs, history.history["loss"]) # we want the x-axis (learning rate) to be log scale
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Learning rate vs. loss");

# %% [markdown]
# After that, the code resets the TensorFlow session and the weights of the model to ensure a clean state for further experiments or model retraining. A learning rate value (lrx) is also assigned.

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

lrx=1e-4
lrx
# Out:
# 0.0001

# %% [markdown]
# The code recompiles the model with the specified learning rate and fits it on the preprocessed training data again, this time using the early stopping callback and model checkpoint.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
ES=EarlyStopping(patience=150, restore_best_weights=True),

# Define the optimizer
optimizer = tf.keras.optimizers.Adam(lr=lrx)

# Compile the model
model_1.compile(loss="mean_squared_error",
                optimizer=optimizer,
                metrics=["mean_absolute_error"])

# Fit the model
history = model_1.fit(xtrain,
                      ytrain,
                      epochs=500,
                      batch_size=32,
                      validation_data=(xtest, ytest),
                      callbacks=[ES,checkpoint])
# Out:
# Epoch 1/500
#  1/13 [=>............................] - ETA: 10s - loss: 2.7482 - mean_absolute_error: 0.7375
# Epoch 1: val_loss improved from inf to 1.63181, saving model to best_model.h5
# 13/13 [==============================] - 1s 24ms/step - loss: 2.0622 - mean_absolute_error: 0.2816 - val_loss: 1.6318 - val_mean_absolute_error: 0.0979
# Epoch 2/500
#  1/13 [=>............................] - ETA: 0s - loss: 1.6491 - mean_absolute_error: 0.1434
# Epoch 2: val_loss improved from 1.63181 to 1.16062, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 1.4297 - mean_absolute_error: 0.1452 - val_loss: 1.1606 - val_mean_absolute_error: 0.0782
# Epoch 3/500
#  1/13 [=>............................] - ETA: 0s - loss: 1.1676 - mean_absolute_error: 0.1088
# Epoch 3: val_loss improved from 1.16062 to 0.81859, saving model to best_model.h5
# 13/13 [==============================] - 0s 10ms/step - loss: 1.0089 - mean_absolute_error: 0.1091 - val_loss: 0.8186 - val_mean_absolute_error: 0.0757
# Epoch 4/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.8237 - mean_absolute_error: 0.0975
# Epoch 4: val_loss improved from 0.81859 to 0.57757, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.7120 - mean_absolute_error: 0.0981 - val_loss: 0.5776 - val_mean_absolute_error: 0.0603
# Epoch 5/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.5849 - mean_absolute_error: 0.0974
# Epoch 5: val_loss improved from 0.57757 to 0.41305, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.5058 - mean_absolute_error: 0.0885 - val_loss: 0.4130 - val_mean_absolute_error: 0.0559
# Epoch 6/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.4191 - mean_absolute_error: 0.0897
# Epoch 6: val_loss improved from 0.41305 to 0.30155, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.3651 - mean_absolute_error: 0.0798 - val_loss: 0.3015 - val_mean_absolute_error: 0.0562
# Epoch 7/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.3113 - mean_absolute_error: 0.1036
# Epoch 7: val_loss improved from 0.30155 to 0.22533, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.2701 - mean_absolute_error: 0.0775 - val_loss: 0.2253 - val_mean_absolute_error: 0.0499
# Epoch 8/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.2346 - mean_absolute_error: 0.0969
# Epoch 8: val_loss improved from 0.22533 to 0.17316, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.2054 - mean_absolute_error: 0.0745 - val_loss: 0.1732 - val_mean_absolute_error: 0.0492
# Epoch 9/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.1774 - mean_absolute_error: 0.0692
# Epoch 9: val_loss improved from 0.17316 to 0.13665, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.1595 - mean_absolute_error: 0.0692 - val_loss: 0.1366 - val_mean_absolute_error: 0.0521
# Epoch 10/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.1416 - mean_absolute_error: 0.0791
# Epoch 10: val_loss improved from 0.13665 to 0.11086, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.1288 - mean_absolute_error: 0.0737 - val_loss: 0.1109 - val_mean_absolute_error: 0.0489
# Epoch 11/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.1140 - mean_absolute_error: 0.0760
# Epoch 11: val_loss improved from 0.11086 to 0.09068, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.1067 - mean_absolute_error: 0.0769 - val_loss: 0.0907 - val_mean_absolute_error: 0.0467
# Epoch 12/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0949 - mean_absolute_error: 0.0734
# Epoch 12: val_loss improved from 0.09068 to 0.07583, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0878 - mean_absolute_error: 0.0716 - val_loss: 0.0758 - val_mean_absolute_error: 0.0491
# Epoch 13/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0775 - mean_absolute_error: 0.0612
# Epoch 13: val_loss improved from 0.07583 to 0.06426, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0744 - mean_absolute_error: 0.0709 - val_loss: 0.0643 - val_mean_absolute_error: 0.0485
# Epoch 14/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0698 - mean_absolute_error: 0.0743
# Epoch 14: val_loss improved from 0.06426 to 0.05562, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0633 - mean_absolute_error: 0.0684 - val_loss: 0.0556 - val_mean_absolute_error: 0.0484
# Epoch 15/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0582 - mean_absolute_error: 0.0682
# Epoch 15: val_loss improved from 0.05562 to 0.04776, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0556 - mean_absolute_error: 0.0716 - val_loss: 0.0478 - val_mean_absolute_error: 0.0475
# Epoch 16/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0491 - mean_absolute_error: 0.0600
# Epoch 16: val_loss improved from 0.04776 to 0.04186, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0480 - mean_absolute_error: 0.0669 - val_loss: 0.0419 - val_mean_absolute_error: 0.0472
# Epoch 17/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0436 - mean_absolute_error: 0.0521
# Epoch 17: val_loss improved from 0.04186 to 0.03668, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0422 - mean_absolute_error: 0.0661 - val_loss: 0.0367 - val_mean_absolute_error: 0.0478
# Epoch 18/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0396 - mean_absolute_error: 0.0654
# Epoch 18: val_loss improved from 0.03668 to 0.03240, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0379 - mean_absolute_error: 0.0680 - val_loss: 0.0324 - val_mean_absolute_error: 0.0481
# Epoch 19/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0355 - mean_absolute_error: 0.0686
# Epoch 19: val_loss improved from 0.03240 to 0.02876, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0335 - mean_absolute_error: 0.0667 - val_loss: 0.0288 - val_mean_absolute_error: 0.0491
# Epoch 20/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0292 - mean_absolute_error: 0.0549
# Epoch 20: val_loss improved from 0.02876 to 0.02583, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0302 - mean_absolute_error: 0.0665 - val_loss: 0.0258 - val_mean_absolute_error: 0.0535
# Epoch 21/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0278 - mean_absolute_error: 0.0678
# Epoch 21: val_loss improved from 0.02583 to 0.02336, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0273 - mean_absolute_error: 0.0664 - val_loss: 0.0234 - val_mean_absolute_error: 0.0531
# Epoch 22/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0265 - mean_absolute_error: 0.0683
# Epoch 22: val_loss improved from 0.02336 to 0.02126, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0265 - mean_absolute_error: 0.0731 - val_loss: 0.0213 - val_mean_absolute_error: 0.0498
# Epoch 23/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0226 - mean_absolute_error: 0.0593
# Epoch 23: val_loss improved from 0.02126 to 0.01941, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0234 - mean_absolute_error: 0.0675 - val_loss: 0.0194 - val_mean_absolute_error: 0.0517
# Epoch 24/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0225 - mean_absolute_error: 0.0690
# Epoch 24: val_loss improved from 0.01941 to 0.01801, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0221 - mean_absolute_error: 0.0684 - val_loss: 0.0180 - val_mean_absolute_error: 0.0547
# Epoch 25/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0206 - mean_absolute_error: 0.0594
# Epoch 25: val_loss improved from 0.01801 to 0.01729, saving model to best_model.h5
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0210 - mean_absolute_error: 0.0681 - val_loss: 0.0173 - val_mean_absolute_error: 0.0606
# Epoch 26/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0205 - mean_absolute_error: 0.0682
# Epoch 26: val_loss improved from 0.01729 to 0.01554, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0197 - mean_absolute_error: 0.0686 - val_loss: 0.0155 - val_mean_absolute_error: 0.0521
# Epoch 27/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0175 - mean_absolute_error: 0.0617
# Epoch 27: val_loss improved from 0.01554 to 0.01478, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0179 - mean_absolute_error: 0.0671 - val_loss: 0.0148 - val_mean_absolute_error: 0.0484
# Epoch 28/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0140 - mean_absolute_error: 0.0477
# Epoch 28: val_loss improved from 0.01478 to 0.01441, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0167 - mean_absolute_error: 0.0654 - val_loss: 0.0144 - val_mean_absolute_error: 0.0490
# Epoch 29/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0189 - mean_absolute_error: 0.0736
# Epoch 29: val_loss improved from 0.01441 to 0.01319, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0168 - mean_absolute_error: 0.0709 - val_loss: 0.0132 - val_mean_absolute_error: 0.0489
# Epoch 30/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0120 - mean_absolute_error: 0.0444
# Epoch 30: val_loss did not improve from 0.01319
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0149 - mean_absolute_error: 0.0637 - val_loss: 0.0139 - val_mean_absolute_error: 0.0530
# Epoch 31/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0123 - mean_absolute_error: 0.0507
# Epoch 31: val_loss improved from 0.01319 to 0.01309, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0147 - mean_absolute_error: 0.0648 - val_loss: 0.0131 - val_mean_absolute_error: 0.0513
# Epoch 32/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0153 - mean_absolute_error: 0.0679
# Epoch 32: val_loss improved from 0.01309 to 0.01170, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0146 - mean_absolute_error: 0.0673 - val_loss: 0.0117 - val_mean_absolute_error: 0.0491
# Epoch 33/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0122 - mean_absolute_error: 0.0539
# Epoch 33: val_loss improved from 0.01170 to 0.01156, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0140 - mean_absolute_error: 0.0662 - val_loss: 0.0116 - val_mean_absolute_error: 0.0607
# Epoch 34/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0122 - mean_absolute_error: 0.0668
# Epoch 34: val_loss improved from 0.01156 to 0.01067, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0151 - mean_absolute_error: 0.0748 - val_loss: 0.0107 - val_mean_absolute_error: 0.0546
# Epoch 35/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0154 - mean_absolute_error: 0.0741
# Epoch 35: val_loss improved from 0.01067 to 0.01029, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0133 - mean_absolute_error: 0.0664 - val_loss: 0.0103 - val_mean_absolute_error: 0.0517
# Epoch 36/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0126 - mean_absolute_error: 0.0667
# Epoch 36: val_loss improved from 0.01029 to 0.01007, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0134 - mean_absolute_error: 0.0687 - val_loss: 0.0101 - val_mean_absolute_error: 0.0537
# Epoch 37/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0172 - mean_absolute_error: 0.0898
# Epoch 37: val_loss did not improve from 0.01007
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0130 - mean_absolute_error: 0.0687 - val_loss: 0.0103 - val_mean_absolute_error: 0.0600
# Epoch 38/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0113 - mean_absolute_error: 0.0603
# Epoch 38: val_loss improved from 0.01007 to 0.00962, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0127 - mean_absolute_error: 0.0683 - val_loss: 0.0096 - val_mean_absolute_error: 0.0541
# Epoch 39/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0168 - mean_absolute_error: 0.0876
# Epoch 39: val_loss improved from 0.00962 to 0.00940, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0121 - mean_absolute_error: 0.0650 - val_loss: 0.0094 - val_mean_absolute_error: 0.0516
# Epoch 40/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0101 - mean_absolute_error: 0.0577
# Epoch 40: val_loss did not improve from 0.00940
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0120 - mean_absolute_error: 0.0661 - val_loss: 0.0094 - val_mean_absolute_error: 0.0554
# Epoch 41/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0107 - mean_absolute_error: 0.0584
# Epoch 41: val_loss improved from 0.00940 to 0.00939, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0115 - mean_absolute_error: 0.0643 - val_loss: 0.0094 - val_mean_absolute_error: 0.0574
# Epoch 42/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0119 - mean_absolute_error: 0.0693
# Epoch 42: val_loss did not improve from 0.00939
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0116 - mean_absolute_error: 0.0664 - val_loss: 0.0095 - val_mean_absolute_error: 0.0487
# Epoch 43/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0161 - mean_absolute_error: 0.0779
# Epoch 43: val_loss improved from 0.00939 to 0.00925, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0109 - mean_absolute_error: 0.0627 - val_loss: 0.0093 - val_mean_absolute_error: 0.0485
# Epoch 44/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0119 - mean_absolute_error: 0.0669
# Epoch 44: val_loss improved from 0.00925 to 0.00919, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0116 - mean_absolute_error: 0.0660 - val_loss: 0.0092 - val_mean_absolute_error: 0.0484
# Epoch 45/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0148 - mean_absolute_error: 0.0766
# Epoch 45: val_loss improved from 0.00919 to 0.00875, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0110 - mean_absolute_error: 0.0642 - val_loss: 0.0088 - val_mean_absolute_error: 0.0513
# Epoch 46/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0126 - mean_absolute_error: 0.0709
# Epoch 46: val_loss improved from 0.00875 to 0.00860, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0112 - mean_absolute_error: 0.0670 - val_loss: 0.0086 - val_mean_absolute_error: 0.0545
# Epoch 47/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0121 - mean_absolute_error: 0.0708
# Epoch 47: val_loss improved from 0.00860 to 0.00849, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0117 - mean_absolute_error: 0.0683 - val_loss: 0.0085 - val_mean_absolute_error: 0.0517
# Epoch 48/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0123 - mean_absolute_error: 0.0698
# Epoch 48: val_loss did not improve from 0.00849
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0115 - mean_absolute_error: 0.0667 - val_loss: 0.0087 - val_mean_absolute_error: 0.0486
# Epoch 49/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0115 - mean_absolute_error: 0.0638
# Epoch 49: val_loss did not improve from 0.00849
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0111 - mean_absolute_error: 0.0668 - val_loss: 0.0095 - val_mean_absolute_error: 0.0508
# Epoch 50/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0086 - mean_absolute_error: 0.0518
# Epoch 50: val_loss did not improve from 0.00849
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0115 - mean_absolute_error: 0.0690 - val_loss: 0.0092 - val_mean_absolute_error: 0.0496
# Epoch 51/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0098 - mean_absolute_error: 0.0542
# Epoch 51: val_loss did not improve from 0.00849
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0111 - mean_absolute_error: 0.0658 - val_loss: 0.0091 - val_mean_absolute_error: 0.0491
# Epoch 52/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0142 - mean_absolute_error: 0.0820
# Epoch 52: val_loss improved from 0.00849 to 0.00841, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0111 - mean_absolute_error: 0.0669 - val_loss: 0.0084 - val_mean_absolute_error: 0.0497
# Epoch 53/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0106 - mean_absolute_error: 0.0657
# Epoch 53: val_loss improved from 0.00841 to 0.00831, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0109 - mean_absolute_error: 0.0650 - val_loss: 0.0083 - val_mean_absolute_error: 0.0545
# Epoch 54/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0088 - mean_absolute_error: 0.0586
# Epoch 54: val_loss improved from 0.00831 to 0.00818, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0104 - mean_absolute_error: 0.0638 - val_loss: 0.0082 - val_mean_absolute_error: 0.0510
# Epoch 55/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0090 - mean_absolute_error: 0.0583
# Epoch 55: val_loss did not improve from 0.00818
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0103 - mean_absolute_error: 0.0626 - val_loss: 0.0082 - val_mean_absolute_error: 0.0492
# Epoch 56/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0104 - mean_absolute_error: 0.0662
# Epoch 56: val_loss did not improve from 0.00818
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0104 - mean_absolute_error: 0.0643 - val_loss: 0.0084 - val_mean_absolute_error: 0.0570
# Epoch 57/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0096 - mean_absolute_error: 0.0630
# Epoch 57: val_loss improved from 0.00818 to 0.00808, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0102 - mean_absolute_error: 0.0645 - val_loss: 0.0081 - val_mean_absolute_error: 0.0523
# Epoch 58/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0118 - mean_absolute_error: 0.0741
# Epoch 58: val_loss did not improve from 0.00808
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0116 - mean_absolute_error: 0.0699 - val_loss: 0.0096 - val_mean_absolute_error: 0.0530
# Epoch 59/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0100 - mean_absolute_error: 0.0631
# Epoch 59: val_loss did not improve from 0.00808
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0116 - mean_absolute_error: 0.0692 - val_loss: 0.0091 - val_mean_absolute_error: 0.0502
# Epoch 60/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0097 - mean_absolute_error: 0.0629
# Epoch 60: val_loss did not improve from 0.00808
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0112 - mean_absolute_error: 0.0686 - val_loss: 0.0086 - val_mean_absolute_error: 0.0487
# Epoch 61/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0141 - mean_absolute_error: 0.0742
# Epoch 61: val_loss did not improve from 0.00808
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0107 - mean_absolute_error: 0.0654 - val_loss: 0.0084 - val_mean_absolute_error: 0.0484
# Epoch 62/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0151 - mean_absolute_error: 0.0842
# Epoch 62: val_loss improved from 0.00808 to 0.00801, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0109 - mean_absolute_error: 0.0661 - val_loss: 0.0080 - val_mean_absolute_error: 0.0512
# Epoch 63/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0096 - mean_absolute_error: 0.0581
# Epoch 63: val_loss did not improve from 0.00801
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0106 - mean_absolute_error: 0.0663 - val_loss: 0.0083 - val_mean_absolute_error: 0.0490
# Epoch 64/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0103 - mean_absolute_error: 0.0640
# Epoch 64: val_loss did not improve from 0.00801
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0103 - mean_absolute_error: 0.0640 - val_loss: 0.0086 - val_mean_absolute_error: 0.0609
# Epoch 65/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0073 - mean_absolute_error: 0.0513
# Epoch 65: val_loss improved from 0.00801 to 0.00798, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0102 - mean_absolute_error: 0.0650 - val_loss: 0.0080 - val_mean_absolute_error: 0.0539
# Epoch 66/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0100 - mean_absolute_error: 0.0632
# Epoch 66: val_loss did not improve from 0.00798
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0100 - mean_absolute_error: 0.0632 - val_loss: 0.0085 - val_mean_absolute_error: 0.0612
# Epoch 67/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0103 - mean_absolute_error: 0.0657
# Epoch 67: val_loss did not improve from 0.00798
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0103 - mean_absolute_error: 0.0657 - val_loss: 0.0083 - val_mean_absolute_error: 0.0590
# Epoch 68/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0102 - mean_absolute_error: 0.0699
# Epoch 68: val_loss did not improve from 0.00798
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0107 - mean_absolute_error: 0.0666 - val_loss: 0.0084 - val_mean_absolute_error: 0.0590
# Epoch 69/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0151 - mean_absolute_error: 0.0893
# Epoch 69: val_loss did not improve from 0.00798
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0105 - mean_absolute_error: 0.0676 - val_loss: 0.0089 - val_mean_absolute_error: 0.0508
# Epoch 70/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0093 - mean_absolute_error: 0.0578
# Epoch 70: val_loss did not improve from 0.00798
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0113 - mean_absolute_error: 0.0689 - val_loss: 0.0084 - val_mean_absolute_error: 0.0487
# Epoch 71/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0091 - mean_absolute_error: 0.0611
# Epoch 71: val_loss did not improve from 0.00798
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0102 - mean_absolute_error: 0.0645 - val_loss: 0.0082 - val_mean_absolute_error: 0.0575
# Epoch 72/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0097 - mean_absolute_error: 0.0658
# Epoch 72: val_loss improved from 0.00798 to 0.00789, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0104 - mean_absolute_error: 0.0663 - val_loss: 0.0079 - val_mean_absolute_error: 0.0544
# Epoch 73/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0102 - mean_absolute_error: 0.0689
# Epoch 73: val_loss improved from 0.00789 to 0.00783, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0103 - mean_absolute_error: 0.0659 - val_loss: 0.0078 - val_mean_absolute_error: 0.0540
# Epoch 74/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0100 - mean_absolute_error: 0.0684
# Epoch 74: val_loss did not improve from 0.00783
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0102 - mean_absolute_error: 0.0656 - val_loss: 0.0081 - val_mean_absolute_error: 0.0486
# Epoch 75/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0084 - mean_absolute_error: 0.0558
# Epoch 75: val_loss did not improve from 0.00783
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0099 - mean_absolute_error: 0.0630 - val_loss: 0.0084 - val_mean_absolute_error: 0.0491
# Epoch 76/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0077 - mean_absolute_error: 0.0412
# Epoch 76: val_loss did not improve from 0.00783
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0092 - mean_absolute_error: 0.0589 - val_loss: 0.0079 - val_mean_absolute_error: 0.0560
# Epoch 77/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0081 - mean_absolute_error: 0.0564
# Epoch 77: val_loss did not improve from 0.00783
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0095 - mean_absolute_error: 0.0604 - val_loss: 0.0083 - val_mean_absolute_error: 0.0487
# Epoch 78/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0101 - mean_absolute_error: 0.0665
# Epoch 78: val_loss did not improve from 0.00783
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0094 - mean_absolute_error: 0.0611 - val_loss: 0.0091 - val_mean_absolute_error: 0.0528
# Epoch 79/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0135 - mean_absolute_error: 0.0792
# Epoch 79: val_loss did not improve from 0.00783
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0115 - mean_absolute_error: 0.0726 - val_loss: 0.0155 - val_mean_absolute_error: 0.0880
# Epoch 80/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0140 - mean_absolute_error: 0.0840
# Epoch 80: val_loss did not improve from 0.00783
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0117 - mean_absolute_error: 0.0745 - val_loss: 0.0162 - val_mean_absolute_error: 0.0919
# Epoch 81/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0179 - mean_absolute_error: 0.0989
# Epoch 81: val_loss did not improve from 0.00783
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0123 - mean_absolute_error: 0.0766 - val_loss: 0.0113 - val_mean_absolute_error: 0.0650
# Epoch 82/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0145 - mean_absolute_error: 0.0836
# Epoch 82: val_loss did not improve from 0.00783
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0108 - mean_absolute_error: 0.0677 - val_loss: 0.0103 - val_mean_absolute_error: 0.0592
# Epoch 83/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0106 - mean_absolute_error: 0.0687
# Epoch 83: val_loss did not improve from 0.00783
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0102 - mean_absolute_error: 0.0649 - val_loss: 0.0085 - val_mean_absolute_error: 0.0500
# Epoch 84/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0119 - mean_absolute_error: 0.0651
# Epoch 84: val_loss did not improve from 0.00783
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0100 - mean_absolute_error: 0.0652 - val_loss: 0.0084 - val_mean_absolute_error: 0.0494
# Epoch 85/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0104 - mean_absolute_error: 0.0660
# Epoch 85: val_loss did not improve from 0.00783
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0095 - mean_absolute_error: 0.0610 - val_loss: 0.0078 - val_mean_absolute_error: 0.0503
# Epoch 86/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0103 - mean_absolute_error: 0.0630
# Epoch 86: val_loss improved from 0.00783 to 0.00776, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0098 - mean_absolute_error: 0.0631 - val_loss: 0.0078 - val_mean_absolute_error: 0.0516
# Epoch 87/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0075 - mean_absolute_error: 0.0520
# Epoch 87: val_loss did not improve from 0.00776
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0093 - mean_absolute_error: 0.0622 - val_loss: 0.0079 - val_mean_absolute_error: 0.0492
# Epoch 88/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0081 - mean_absolute_error: 0.0544
# Epoch 88: val_loss improved from 0.00776 to 0.00768, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0094 - mean_absolute_error: 0.0617 - val_loss: 0.0077 - val_mean_absolute_error: 0.0507
# Epoch 89/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0093 - mean_absolute_error: 0.0603
# Epoch 89: val_loss improved from 0.00768 to 0.00764, saving model to best_model.h5
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0098 - mean_absolute_error: 0.0609 - val_loss: 0.0076 - val_mean_absolute_error: 0.0499
# Epoch 90/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0090 - mean_absolute_error: 0.0583
# Epoch 90: val_loss did not improve from 0.00764
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0098 - mean_absolute_error: 0.0656 - val_loss: 0.0079 - val_mean_absolute_error: 0.0484
# Epoch 91/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0108 - mean_absolute_error: 0.0643
# Epoch 91: val_loss did not improve from 0.00764
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0096 - mean_absolute_error: 0.0622 - val_loss: 0.0084 - val_mean_absolute_error: 0.0496
# Epoch 92/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0075 - mean_absolute_error: 0.0477
# Epoch 92: val_loss did not improve from 0.00764
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0096 - mean_absolute_error: 0.0613 - val_loss: 0.0077 - val_mean_absolute_error: 0.0501
# Epoch 93/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0084 - mean_absolute_error: 0.0565
# Epoch 93: val_loss did not improve from 0.00764
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0091 - mean_absolute_error: 0.0621 - val_loss: 0.0077 - val_mean_absolute_error: 0.0496
# Epoch 94/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0088 - mean_absolute_error: 0.0579
# Epoch 94: val_loss improved from 0.00764 to 0.00756, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0093 - mean_absolute_error: 0.0608 - val_loss: 0.0076 - val_mean_absolute_error: 0.0519
# Epoch 95/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0079 - mean_absolute_error: 0.0571
# Epoch 95: val_loss did not improve from 0.00756
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0091 - mean_absolute_error: 0.0604 - val_loss: 0.0076 - val_mean_absolute_error: 0.0538
# Epoch 96/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0075 - mean_absolute_error: 0.0566
# Epoch 96: val_loss did not improve from 0.00756
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0098 - mean_absolute_error: 0.0650 - val_loss: 0.0076 - val_mean_absolute_error: 0.0520
# Epoch 97/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0091 - mean_absolute_error: 0.0572
# Epoch 97: val_loss did not improve from 0.00756
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0096 - mean_absolute_error: 0.0637 - val_loss: 0.0076 - val_mean_absolute_error: 0.0484
# Epoch 98/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0100 - mean_absolute_error: 0.0624
# Epoch 98: val_loss did not improve from 0.00756
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0094 - mean_absolute_error: 0.0611 - val_loss: 0.0076 - val_mean_absolute_error: 0.0504
# Epoch 99/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0114 - mean_absolute_error: 0.0695
# Epoch 99: val_loss did not improve from 0.00756
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0089 - mean_absolute_error: 0.0602 - val_loss: 0.0077 - val_mean_absolute_error: 0.0554
# Epoch 100/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0109 - mean_absolute_error: 0.0751
# Epoch 100: val_loss did not improve from 0.00756
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0096 - mean_absolute_error: 0.0630 - val_loss: 0.0076 - val_mean_absolute_error: 0.0504
# Epoch 101/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0087 - mean_absolute_error: 0.0599
# Epoch 101: val_loss did not improve from 0.00756
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0097 - mean_absolute_error: 0.0646 - val_loss: 0.0076 - val_mean_absolute_error: 0.0493
# Epoch 102/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0070 - mean_absolute_error: 0.0469
# Epoch 102: val_loss did not improve from 0.00756
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0088 - mean_absolute_error: 0.0585 - val_loss: 0.0076 - val_mean_absolute_error: 0.0505
# Epoch 103/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0087 - mean_absolute_error: 0.0600
# Epoch 103: val_loss did not improve from 0.00756
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0104 - mean_absolute_error: 0.0678 - val_loss: 0.0076 - val_mean_absolute_error: 0.0511
# Epoch 104/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0096 - mean_absolute_error: 0.0645
# Epoch 104: val_loss did not improve from 0.00756
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0089 - mean_absolute_error: 0.0597 - val_loss: 0.0077 - val_mean_absolute_error: 0.0549
# Epoch 105/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0076 - mean_absolute_error: 0.0523
# Epoch 105: val_loss improved from 0.00756 to 0.00751, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0100 - mean_absolute_error: 0.0646 - val_loss: 0.0075 - val_mean_absolute_error: 0.0512
# Epoch 106/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0129 - mean_absolute_error: 0.0809
# Epoch 106: val_loss improved from 0.00751 to 0.00750, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0097 - mean_absolute_error: 0.0646 - val_loss: 0.0075 - val_mean_absolute_error: 0.0496
# Epoch 107/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0113 - mean_absolute_error: 0.0670
# Epoch 107: val_loss did not improve from 0.00750
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0096 - mean_absolute_error: 0.0624 - val_loss: 0.0076 - val_mean_absolute_error: 0.0486
# Epoch 108/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0123 - mean_absolute_error: 0.0782
# Epoch 108: val_loss did not improve from 0.00750
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0092 - mean_absolute_error: 0.0611 - val_loss: 0.0077 - val_mean_absolute_error: 0.0487
# Epoch 109/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0081 - mean_absolute_error: 0.0585
# Epoch 109: val_loss did not improve from 0.00750
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0093 - mean_absolute_error: 0.0630 - val_loss: 0.0076 - val_mean_absolute_error: 0.0490
# Epoch 110/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0095 - mean_absolute_error: 0.0583
# Epoch 110: val_loss improved from 0.00750 to 0.00747, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0089 - mean_absolute_error: 0.0589 - val_loss: 0.0075 - val_mean_absolute_error: 0.0509
# Epoch 111/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0108 - mean_absolute_error: 0.0739
# Epoch 111: val_loss did not improve from 0.00747
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0090 - mean_absolute_error: 0.0606 - val_loss: 0.0075 - val_mean_absolute_error: 0.0510
# Epoch 112/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0080 - mean_absolute_error: 0.0605
# Epoch 112: val_loss did not improve from 0.00747
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0092 - mean_absolute_error: 0.0620 - val_loss: 0.0075 - val_mean_absolute_error: 0.0528
# Epoch 113/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0086 - mean_absolute_error: 0.0550
# Epoch 113: val_loss improved from 0.00747 to 0.00746, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0096 - mean_absolute_error: 0.0621 - val_loss: 0.0075 - val_mean_absolute_error: 0.0512
# Epoch 114/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0090 - mean_absolute_error: 0.0602
# Epoch 114: val_loss did not improve from 0.00746
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0097 - mean_absolute_error: 0.0638 - val_loss: 0.0081 - val_mean_absolute_error: 0.0496
# Epoch 115/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0110 - mean_absolute_error: 0.0630
# Epoch 115: val_loss did not improve from 0.00746
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0097 - mean_absolute_error: 0.0615 - val_loss: 0.0075 - val_mean_absolute_error: 0.0540
# Epoch 116/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0075 - mean_absolute_error: 0.0539
# Epoch 116: val_loss improved from 0.00746 to 0.00744, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0088 - mean_absolute_error: 0.0608 - val_loss: 0.0074 - val_mean_absolute_error: 0.0519
# Epoch 117/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0095 - mean_absolute_error: 0.0648
# Epoch 117: val_loss did not improve from 0.00744
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0092 - mean_absolute_error: 0.0599 - val_loss: 0.0079 - val_mean_absolute_error: 0.0492
# Epoch 118/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0094 - mean_absolute_error: 0.0602
# Epoch 118: val_loss did not improve from 0.00744
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0099 - mean_absolute_error: 0.0649 - val_loss: 0.0075 - val_mean_absolute_error: 0.0513
# Epoch 119/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0094 - mean_absolute_error: 0.0617
# Epoch 119: val_loss did not improve from 0.00744
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0094 - mean_absolute_error: 0.0617 - val_loss: 0.0075 - val_mean_absolute_error: 0.0494
# Epoch 120/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0093 - mean_absolute_error: 0.0613
# Epoch 120: val_loss improved from 0.00744 to 0.00738, saving model to best_model.h5
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0093 - mean_absolute_error: 0.0613 - val_loss: 0.0074 - val_mean_absolute_error: 0.0518
# Epoch 121/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0117 - mean_absolute_error: 0.0630
# Epoch 121: val_loss did not improve from 0.00738
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0095 - mean_absolute_error: 0.0618 - val_loss: 0.0075 - val_mean_absolute_error: 0.0486
# Epoch 122/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0073 - mean_absolute_error: 0.0508
# Epoch 122: val_loss did not improve from 0.00738
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0090 - mean_absolute_error: 0.0602 - val_loss: 0.0075 - val_mean_absolute_error: 0.0484
# Epoch 123/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0063 - mean_absolute_error: 0.0436
# Epoch 123: val_loss did not improve from 0.00738
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0091 - mean_absolute_error: 0.0596 - val_loss: 0.0075 - val_mean_absolute_error: 0.0491
# Epoch 124/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0081 - mean_absolute_error: 0.0607
# Epoch 124: val_loss did not improve from 0.00738
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0089 - mean_absolute_error: 0.0619 - val_loss: 0.0074 - val_mean_absolute_error: 0.0525
# Epoch 125/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0063 - mean_absolute_error: 0.0476
# Epoch 125: val_loss did not improve from 0.00738
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0086 - mean_absolute_error: 0.0582 - val_loss: 0.0076 - val_mean_absolute_error: 0.0556
# Epoch 126/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0092 - mean_absolute_error: 0.0630
# Epoch 126: val_loss did not improve from 0.00738
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0095 - mean_absolute_error: 0.0638 - val_loss: 0.0078 - val_mean_absolute_error: 0.0484
# Epoch 127/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0087 - mean_absolute_error: 0.0609
# Epoch 127: val_loss did not improve from 0.00738
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0093 - mean_absolute_error: 0.0642 - val_loss: 0.0080 - val_mean_absolute_error: 0.0491
# Epoch 128/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0101 - mean_absolute_error: 0.0610
# Epoch 128: val_loss did not improve from 0.00738
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0091 - mean_absolute_error: 0.0609 - val_loss: 0.0075 - val_mean_absolute_error: 0.0546
# Epoch 129/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0086 - mean_absolute_error: 0.0577
# Epoch 129: val_loss improved from 0.00738 to 0.00738, saving model to best_model.h5
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0086 - mean_absolute_error: 0.0577 - val_loss: 0.0074 - val_mean_absolute_error: 0.0492
# Epoch 130/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0100 - mean_absolute_error: 0.0600
# Epoch 130: val_loss did not improve from 0.00738
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0092 - mean_absolute_error: 0.0611 - val_loss: 0.0076 - val_mean_absolute_error: 0.0559
# Epoch 131/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0122 - mean_absolute_error: 0.0797
# Epoch 131: val_loss improved from 0.00738 to 0.00730, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0090 - mean_absolute_error: 0.0606 - val_loss: 0.0073 - val_mean_absolute_error: 0.0499
# Epoch 132/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0075 - mean_absolute_error: 0.0474
# Epoch 132: val_loss did not improve from 0.00730
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0093 - mean_absolute_error: 0.0609 - val_loss: 0.0078 - val_mean_absolute_error: 0.0486
# Epoch 133/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0090 - mean_absolute_error: 0.0646
# Epoch 133: val_loss did not improve from 0.00730
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0089 - mean_absolute_error: 0.0599 - val_loss: 0.0081 - val_mean_absolute_error: 0.0501
# Epoch 134/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0124 - mean_absolute_error: 0.0782
# Epoch 134: val_loss did not improve from 0.00730
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0095 - mean_absolute_error: 0.0608 - val_loss: 0.0075 - val_mean_absolute_error: 0.0506
# Epoch 135/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0106 - mean_absolute_error: 0.0713
# Epoch 135: val_loss did not improve from 0.00730
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0097 - mean_absolute_error: 0.0645 - val_loss: 0.0080 - val_mean_absolute_error: 0.0609
# Epoch 136/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0105 - mean_absolute_error: 0.0699
# Epoch 136: val_loss did not improve from 0.00730
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0091 - mean_absolute_error: 0.0622 - val_loss: 0.0074 - val_mean_absolute_error: 0.0490
# Epoch 137/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0088 - mean_absolute_error: 0.0569
# Epoch 137: val_loss did not improve from 0.00730
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0092 - mean_absolute_error: 0.0604 - val_loss: 0.0075 - val_mean_absolute_error: 0.0555
# Epoch 138/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0089 - mean_absolute_error: 0.0566
# Epoch 138: val_loss improved from 0.00730 to 0.00723, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0089 - mean_absolute_error: 0.0585 - val_loss: 0.0072 - val_mean_absolute_error: 0.0506
# Epoch 139/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0082 - mean_absolute_error: 0.0537
# Epoch 139: val_loss did not improve from 0.00723
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0086 - mean_absolute_error: 0.0575 - val_loss: 0.0073 - val_mean_absolute_error: 0.0529
# Epoch 140/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0099 - mean_absolute_error: 0.0659
# Epoch 140: val_loss did not improve from 0.00723
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0096 - mean_absolute_error: 0.0652 - val_loss: 0.0075 - val_mean_absolute_error: 0.0570
# Epoch 141/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0064 - mean_absolute_error: 0.0480
# Epoch 141: val_loss improved from 0.00723 to 0.00723, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0090 - mean_absolute_error: 0.0603 - val_loss: 0.0072 - val_mean_absolute_error: 0.0509
# Epoch 142/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0101 - mean_absolute_error: 0.0713
# Epoch 142: val_loss did not improve from 0.00723
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0092 - mean_absolute_error: 0.0625 - val_loss: 0.0107 - val_mean_absolute_error: 0.0653
# Epoch 143/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0134 - mean_absolute_error: 0.0772
# Epoch 143: val_loss did not improve from 0.00723
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0112 - mean_absolute_error: 0.0715 - val_loss: 0.0081 - val_mean_absolute_error: 0.0497
# Epoch 144/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0088 - mean_absolute_error: 0.0558
# Epoch 144: val_loss did not improve from 0.00723
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0099 - mean_absolute_error: 0.0633 - val_loss: 0.0078 - val_mean_absolute_error: 0.0595
# Epoch 145/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0114 - mean_absolute_error: 0.0716
# Epoch 145: val_loss did not improve from 0.00723
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0090 - mean_absolute_error: 0.0631 - val_loss: 0.0075 - val_mean_absolute_error: 0.0559
# Epoch 146/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0088 - mean_absolute_error: 0.0563
# Epoch 146: val_loss did not improve from 0.00723
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0091 - mean_absolute_error: 0.0608 - val_loss: 0.0083 - val_mean_absolute_error: 0.0515
# Epoch 147/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0089 - mean_absolute_error: 0.0575
# Epoch 147: val_loss did not improve from 0.00723
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0098 - mean_absolute_error: 0.0625 - val_loss: 0.0073 - val_mean_absolute_error: 0.0507
# Epoch 148/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0095 - mean_absolute_error: 0.0624
# Epoch 148: val_loss improved from 0.00723 to 0.00720, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0089 - mean_absolute_error: 0.0608 - val_loss: 0.0072 - val_mean_absolute_error: 0.0503
# Epoch 149/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0077 - mean_absolute_error: 0.0530
# Epoch 149: val_loss did not improve from 0.00720
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0095 - mean_absolute_error: 0.0624 - val_loss: 0.0072 - val_mean_absolute_error: 0.0499
# ...
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0067 - mean_absolute_error: 0.0539 - val_loss: 0.0062 - val_mean_absolute_error: 0.0472
# Epoch 450/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0063 - mean_absolute_error: 0.0505
# Epoch 450: val_loss did not improve from 0.00600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0067 - mean_absolute_error: 0.0537 - val_loss: 0.0061 - val_mean_absolute_error: 0.0504
# Epoch 451/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0079 - mean_absolute_error: 0.0557
# Epoch 451: val_loss did not improve from 0.00600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0066 - mean_absolute_error: 0.0522 - val_loss: 0.0067 - val_mean_absolute_error: 0.0493
# Epoch 452/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0048 - mean_absolute_error: 0.0425
# Epoch 452: val_loss did not improve from 0.00600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0067 - mean_absolute_error: 0.0542 - val_loss: 0.0060 - val_mean_absolute_error: 0.0498
# Epoch 453/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0049 - mean_absolute_error: 0.0429
# Epoch 453: val_loss did not improve from 0.00600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0070 - mean_absolute_error: 0.0552 - val_loss: 0.0063 - val_mean_absolute_error: 0.0482
# Epoch 454/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0057 - mean_absolute_error: 0.0444
# Epoch 454: val_loss did not improve from 0.00600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0066 - mean_absolute_error: 0.0527 - val_loss: 0.0065 - val_mean_absolute_error: 0.0562
# Epoch 455/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0069 - mean_absolute_error: 0.0609
# Epoch 455: val_loss did not improve from 0.00600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0068 - mean_absolute_error: 0.0536 - val_loss: 0.0064 - val_mean_absolute_error: 0.0478
# Epoch 456/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0071 - mean_absolute_error: 0.0593
# Epoch 456: val_loss did not improve from 0.00600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0067 - mean_absolute_error: 0.0540 - val_loss: 0.0071 - val_mean_absolute_error: 0.0518
# Epoch 457/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0069 - mean_absolute_error: 0.0542
# Epoch 457: val_loss did not improve from 0.00600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0068 - mean_absolute_error: 0.0532 - val_loss: 0.0060 - val_mean_absolute_error: 0.0480
# Epoch 458/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0076 - mean_absolute_error: 0.0569
# Epoch 458: val_loss did not improve from 0.00600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0065 - mean_absolute_error: 0.0522 - val_loss: 0.0061 - val_mean_absolute_error: 0.0532
# Epoch 459/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0050 - mean_absolute_error: 0.0506
# Epoch 459: val_loss did not improve from 0.00600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0069 - mean_absolute_error: 0.0546 - val_loss: 0.0060 - val_mean_absolute_error: 0.0505
# Epoch 460/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0050 - mean_absolute_error: 0.0451
# Epoch 460: val_loss did not improve from 0.00600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0063 - mean_absolute_error: 0.0528 - val_loss: 0.0067 - val_mean_absolute_error: 0.0491
# Epoch 461/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0081 - mean_absolute_error: 0.0570
# Epoch 461: val_loss did not improve from 0.00600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0070 - mean_absolute_error: 0.0545 - val_loss: 0.0062 - val_mean_absolute_error: 0.0537
# Epoch 462/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0091 - mean_absolute_error: 0.0732
# Epoch 462: val_loss did not improve from 0.00600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0069 - mean_absolute_error: 0.0555 - val_loss: 0.0062 - val_mean_absolute_error: 0.0493
# Epoch 463/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0080 - mean_absolute_error: 0.0569
# Epoch 463: val_loss did not improve from 0.00600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0069 - mean_absolute_error: 0.0536 - val_loss: 0.0060 - val_mean_absolute_error: 0.0490
# Epoch 464/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0052 - mean_absolute_error: 0.0440
# Epoch 464: val_loss did not improve from 0.00600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0065 - mean_absolute_error: 0.0529 - val_loss: 0.0060 - val_mean_absolute_error: 0.0507
# Epoch 465/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0070 - mean_absolute_error: 0.0511
# Epoch 465: val_loss improved from 0.00600 to 0.00597, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0066 - mean_absolute_error: 0.0520 - val_loss: 0.0060 - val_mean_absolute_error: 0.0486
# Epoch 466/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0081 - mean_absolute_error: 0.0613
# Epoch 466: val_loss did not improve from 0.00597
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0065 - mean_absolute_error: 0.0523 - val_loss: 0.0063 - val_mean_absolute_error: 0.0551
# Epoch 467/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0069 - mean_absolute_error: 0.0563
# Epoch 467: val_loss did not improve from 0.00597
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0069 - mean_absolute_error: 0.0563 - val_loss: 0.0060 - val_mean_absolute_error: 0.0498
# Epoch 468/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0046 - mean_absolute_error: 0.0444
# Epoch 468: val_loss improved from 0.00597 to 0.00595, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0068 - mean_absolute_error: 0.0539 - val_loss: 0.0060 - val_mean_absolute_error: 0.0491
# Epoch 469/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0065 - mean_absolute_error: 0.0512
# Epoch 469: val_loss did not improve from 0.00595
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0064 - mean_absolute_error: 0.0523 - val_loss: 0.0074 - val_mean_absolute_error: 0.0535
# Epoch 470/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0073 - mean_absolute_error: 0.0540
# Epoch 470: val_loss did not improve from 0.00595
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0073 - mean_absolute_error: 0.0563 - val_loss: 0.0068 - val_mean_absolute_error: 0.0610
# Epoch 471/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0080 - mean_absolute_error: 0.0646
# Epoch 471: val_loss did not improve from 0.00595
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0071 - mean_absolute_error: 0.0575 - val_loss: 0.0071 - val_mean_absolute_error: 0.0514
# Epoch 472/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0103 - mean_absolute_error: 0.0676
# Epoch 472: val_loss did not improve from 0.00595
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0069 - mean_absolute_error: 0.0540 - val_loss: 0.0061 - val_mean_absolute_error: 0.0500
# Epoch 473/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0070 - mean_absolute_error: 0.0588
# Epoch 473: val_loss did not improve from 0.00595
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0066 - mean_absolute_error: 0.0528 - val_loss: 0.0065 - val_mean_absolute_error: 0.0500
# Epoch 474/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0087 - mean_absolute_error: 0.0628
# Epoch 474: val_loss did not improve from 0.00595
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0073 - mean_absolute_error: 0.0568 - val_loss: 0.0063 - val_mean_absolute_error: 0.0551
# Epoch 475/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0096 - mean_absolute_error: 0.0712
# Epoch 475: val_loss did not improve from 0.00595
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0069 - mean_absolute_error: 0.0567 - val_loss: 0.0060 - val_mean_absolute_error: 0.0478
# Epoch 476/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0054 - mean_absolute_error: 0.0458
# Epoch 476: val_loss did not improve from 0.00595
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0066 - mean_absolute_error: 0.0524 - val_loss: 0.0060 - val_mean_absolute_error: 0.0479
# Epoch 477/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0073 - mean_absolute_error: 0.0540
# Epoch 477: val_loss did not improve from 0.00595
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0066 - mean_absolute_error: 0.0532 - val_loss: 0.0061 - val_mean_absolute_error: 0.0483
# Epoch 478/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0058 - mean_absolute_error: 0.0461
# Epoch 478: val_loss did not improve from 0.00595
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0065 - mean_absolute_error: 0.0514 - val_loss: 0.0062 - val_mean_absolute_error: 0.0537
# Epoch 479/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0062 - mean_absolute_error: 0.0521
# Epoch 479: val_loss did not improve from 0.00595
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0066 - mean_absolute_error: 0.0528 - val_loss: 0.0061 - val_mean_absolute_error: 0.0475
# Epoch 480/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0073 - mean_absolute_error: 0.0531
# Epoch 480: val_loss did not improve from 0.00595
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0065 - mean_absolute_error: 0.0517 - val_loss: 0.0062 - val_mean_absolute_error: 0.0545
# Epoch 481/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0076 - mean_absolute_error: 0.0642
# Epoch 481: val_loss did not improve from 0.00595
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0068 - mean_absolute_error: 0.0550 - val_loss: 0.0061 - val_mean_absolute_error: 0.0478
# Epoch 482/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0077 - mean_absolute_error: 0.0562
# Epoch 482: val_loss did not improve from 0.00595
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0063 - mean_absolute_error: 0.0501 - val_loss: 0.0064 - val_mean_absolute_error: 0.0556
# Epoch 483/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0048 - mean_absolute_error: 0.0481
# Epoch 483: val_loss did not improve from 0.00595
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0067 - mean_absolute_error: 0.0564 - val_loss: 0.0068 - val_mean_absolute_error: 0.0507
# Epoch 484/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0092 - mean_absolute_error: 0.0574
# Epoch 484: val_loss improved from 0.00595 to 0.00594, saving model to best_model.h5
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0064 - mean_absolute_error: 0.0514 - val_loss: 0.0059 - val_mean_absolute_error: 0.0500
# Epoch 485/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0055 - mean_absolute_error: 0.0453
# Epoch 485: val_loss did not improve from 0.00594
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0064 - mean_absolute_error: 0.0520 - val_loss: 0.0064 - val_mean_absolute_error: 0.0565
# Epoch 486/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0070 - mean_absolute_error: 0.0603
# Epoch 486: val_loss did not improve from 0.00594
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0067 - mean_absolute_error: 0.0539 - val_loss: 0.0065 - val_mean_absolute_error: 0.0495
# Epoch 487/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0056 - mean_absolute_error: 0.0503
# Epoch 487: val_loss did not improve from 0.00594
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0063 - mean_absolute_error: 0.0509 - val_loss: 0.0060 - val_mean_absolute_error: 0.0495
# Epoch 488/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0076 - mean_absolute_error: 0.0579
# Epoch 488: val_loss did not improve from 0.00594
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0063 - mean_absolute_error: 0.0518 - val_loss: 0.0065 - val_mean_absolute_error: 0.0495
# Epoch 489/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0074 - mean_absolute_error: 0.0553
# Epoch 489: val_loss did not improve from 0.00594
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0063 - mean_absolute_error: 0.0508 - val_loss: 0.0060 - val_mean_absolute_error: 0.0487
# Epoch 490/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0067 - mean_absolute_error: 0.0550
# Epoch 490: val_loss did not improve from 0.00594
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0063 - mean_absolute_error: 0.0513 - val_loss: 0.0060 - val_mean_absolute_error: 0.0502
# Epoch 491/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0058 - mean_absolute_error: 0.0532
# Epoch 491: val_loss did not improve from 0.00594
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0061 - mean_absolute_error: 0.0494 - val_loss: 0.0068 - val_mean_absolute_error: 0.0503
# Epoch 492/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0080 - mean_absolute_error: 0.0586
# Epoch 492: val_loss did not improve from 0.00594
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0074 - mean_absolute_error: 0.0586 - val_loss: 0.0061 - val_mean_absolute_error: 0.0481
# Epoch 493/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0084 - mean_absolute_error: 0.0573
# Epoch 493: val_loss did not improve from 0.00594
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0066 - mean_absolute_error: 0.0532 - val_loss: 0.0061 - val_mean_absolute_error: 0.0529
# Epoch 494/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0068 - mean_absolute_error: 0.0587
# Epoch 494: val_loss did not improve from 0.00594
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0067 - mean_absolute_error: 0.0546 - val_loss: 0.0064 - val_mean_absolute_error: 0.0488
# Epoch 495/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0074 - mean_absolute_error: 0.0555
# Epoch 495: val_loss did not improve from 0.00594
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0065 - mean_absolute_error: 0.0532 - val_loss: 0.0059 - val_mean_absolute_error: 0.0481
# Epoch 496/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0047 - mean_absolute_error: 0.0414
# Epoch 496: val_loss did not improve from 0.00594
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0069 - mean_absolute_error: 0.0548 - val_loss: 0.0060 - val_mean_absolute_error: 0.0488
# Epoch 497/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0051 - mean_absolute_error: 0.0480
# Epoch 497: val_loss did not improve from 0.00594
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0065 - mean_absolute_error: 0.0537 - val_loss: 0.0062 - val_mean_absolute_error: 0.0483
# Epoch 498/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0064 - mean_absolute_error: 0.0543
# Epoch 498: val_loss did not improve from 0.00594
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0067 - mean_absolute_error: 0.0546 - val_loss: 0.0060 - val_mean_absolute_error: 0.0504
# Epoch 499/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0044 - mean_absolute_error: 0.0422
# Epoch 499: val_loss did not improve from 0.00594
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0065 - mean_absolute_error: 0.0524 - val_loss: 0.0060 - val_mean_absolute_error: 0.0501
# Epoch 500/500
#  1/13 [=>............................] - ETA: 0s - loss: 0.0087 - mean_absolute_error: 0.0638
# Epoch 500: val_loss did not improve from 0.00594
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0063 - mean_absolute_error: 0.0516 - val_loss: 0.0060 - val_mean_absolute_error: 0.0492

# %% [markdown]
# A function called "plot_losses" is defined to plot the losses (training and validation) from the history object returned by the model training process.

# %%
def plot_losses(history):
    losses = pd.DataFrame(history.history)
    losses.plot()

# %%
plot_losses(history)

# %% [markdown]
# The next code loads the best saved model from the model checkpoint file ("best_model.h5").

# %%
from tensorflow.keras.models import load_model

# Load the best saved model
model = load_model('best_model.h5')

# %%
model.evaluate(xtest, ytest)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0059 - mean_absolute_error: 0.0500
# [0.005938103422522545, 0.04997042566537857]

# %%
# Predictions
testPredict = model.predict(xtest)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %% [markdown]
# Test predictions are made using the loaded model, and an evaluation function is defined to calculate and print the mean absolute error (MAE) and mean squared error (MSE) between the true target values (ytest) and the predicted values (testPredict).

# %%
# Evaluate model
def evaluate_model(y_true, y_pred):
    mae = tf.keras.metrics.mean_absolute_error(y_true, y_pred)
    mse = tf.keras.metrics.mean_squared_error(y_true, y_pred)

    print('Mean Absolute Error: ', mae.numpy())
    print('Mean Squared Error: ', mse.numpy())

# %% [markdown]
# The code then evaluates the model's performance by calling the evaluation function with the true target values and the predicted values. The MAE and MSE are printed, providing an assessment of the model's predictive accuracy.

# %%
evaluate_model(ytest, tf.squeeze(testPredict))  # Flatten the prediction array to match the shape
# Out:
# Mean Absolute Error:  0.049970426
# Mean Squared Error:  0.0041945516

# %% [markdown]
# **Hyperparameter Tuning**
#
# The following code defines a function called "build_model" that constructs a neural network model with customizable hyperparameters. The model includes multiple layers, dropout regularization, and batch normalization. It is compiled with an Adam optimizer and mean squared error loss.

# %%
def build_model(hp):
    from keras.layers import BatchNormalization
    from keras.regularizers import l1_l2

    # Define all hyperparameters
    n_layers = hp.Choice('n_layers', [2, 4, 6])
    dropout_rate = hp.Choice('rate', [0.2, 0.4, 0.5, 0.7])
    n_units = hp.Choice('units', [64, 128, 256, 512])
    l1_reg = hp.Choice('l1', [0.0, 0.01, 0.001, 0.0001])
    l2_reg = hp.Choice('l2', [0.0, 0.01, 0.001, 0.0001])

    # Model architecture
    model = Sequential()

    # Input layer
    model.add(Dense(n_units, input_dim=xtrain.shape[1], activation='relu', kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)))
    model.add(BatchNormalization())

    # Add hidden layers
    for _ in range(n_layers):
        model.add(Dense(n_units, activation='relu', kernel_initializer='he_normal', kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)))
        model.add(BatchNormalization())

    # Add Dropout Layer
    model.add(Dropout(dropout_rate))

    # Output Layer
    model.add(Dense(1))

    # Define the optimizer
    optimizer = tf.keras.optimizers.Adam(lr=lrx)

    # Compile the model
    model.compile(loss="mean_squared_error",
                    optimizer=optimizer,
                    metrics=["mean_absolute_error"])

    # Return model
    return model

# %% [markdown]
# In the next code block, a random search is initialized to find the best model architecture. The search explores different hyperparameter combinations and aims to minimize validation loss. This approach helps in identifying the optimal model configuration.

# %%
# Initialize Random Searcher
random_searcher = kt.RandomSearch(
    hypermodel=build_model,
    objective='val_loss',
    max_trials=30,
    seed=42,
    project_name="Pgt-Search"
)

# Start Searching
search = random_searcher.search(
    xtrain, ytrain,
    validation_data=(xtest, ytest),
    epochs = 30,
    batch_size = 64
)
# Out:
# Trial 30 Complete [00h 00m 07s]
# val_loss: 0.11169211566448212
#
# Best val_loss So Far: 0.013833854347467422
# Total elapsed time: 00h 04m 16s

# %%
BATCH_SIZE=64

# %% [markdown]
# The code then imports necessary modules for callbacks and collects the best model architecture from the random search. The model is compiled and trained on the preprocessed data, with early stopping and model checkpoint implemented to prevent overfitting and save the best model based on validation loss.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Collect the best model Architecture obtained by Random Searcher
best_model = build_model(random_searcher.get_best_hyperparameters(num_trials=1)[0])

# Model Architecture
best_model.summary()

optimizer = tf.keras.optimizers.Adam(lr=lrx)

# Compile Model
best_model.compile(loss="mean_squared_error",
                    optimizer=optimizer,
                    metrics=["mean_absolute_error"])
# Model Training
best_model_history = best_model.fit(
    xtrain, ytrain,
    validation_data=(xtest, ytest),
    epochs = 500,
    batch_size = BATCH_SIZE*2,
    callbacks = [
  EarlyStopping(patience=150, restore_best_weights=True),
  ModelCheckpoint('best-model.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)]
)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 64)                512
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  batch_normalization_6 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  batch_normalization_7 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 9,665
# Trainable params: 9,281
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/500
# 1/4 [======>.......................] - ETA: 5s - loss: 6.0772 - mean_absolute_error: 1.8706
# Epoch 1: val_loss improved from inf to 0.41360, saving model to best-model.h5
# 4/4 [==============================] - 2s 101ms/step - loss: 5.1503 - mean_absolute_error: 1.7338 - val_loss: 0.4136 - val_mean_absolute_error: 0.6248
# Epoch 2/500
# 1/4 [======>.......................] - ETA: 0s - loss: 3.6835 - mean_absolute_error: 1.5533
# Epoch 2: val_loss improved from 0.41360 to 0.28459, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 3.1698 - mean_absolute_error: 1.4075 - val_loss: 0.2846 - val_mean_absolute_error: 0.5158
# Epoch 3/500
# 1/4 [======>.......................] - ETA: 0s - loss: 3.3615 - mean_absolute_error: 1.4292
# Epoch 3: val_loss improved from 0.28459 to 0.24629, saving model to best-model.h5
# 4/4 [==============================] - 0s 33ms/step - loss: 3.1810 - mean_absolute_error: 1.3905 - val_loss: 0.2463 - val_mean_absolute_error: 0.4783
# Epoch 4/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2.7545 - mean_absolute_error: 1.3095
# Epoch 4: val_loss improved from 0.24629 to 0.22794, saving model to best-model.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 3.0181 - mean_absolute_error: 1.3877 - val_loss: 0.2279 - val_mean_absolute_error: 0.4583
# Epoch 5/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2.9195 - mean_absolute_error: 1.3727
# Epoch 5: val_loss improved from 0.22794 to 0.19708, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 2.9535 - mean_absolute_error: 1.3549 - val_loss: 0.1971 - val_mean_absolute_error: 0.4236
# Epoch 6/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2.0040 - mean_absolute_error: 1.0636
# Epoch 6: val_loss improved from 0.19708 to 0.16945, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 2.6732 - mean_absolute_error: 1.2435 - val_loss: 0.1695 - val_mean_absolute_error: 0.3897
# Epoch 7/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2.8209 - mean_absolute_error: 1.3201
# Epoch 7: val_loss improved from 0.16945 to 0.15157, saving model to best-model.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 2.4487 - mean_absolute_error: 1.1947 - val_loss: 0.1516 - val_mean_absolute_error: 0.3646
# Epoch 8/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2.7785 - mean_absolute_error: 1.3310
# Epoch 8: val_loss improved from 0.15157 to 0.13570, saving model to best-model.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 2.3914 - mean_absolute_error: 1.2089 - val_loss: 0.1357 - val_mean_absolute_error: 0.3404
# Epoch 9/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2.1138 - mean_absolute_error: 1.1031
# Epoch 9: val_loss improved from 0.13570 to 0.12633, saving model to best-model.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 2.2436 - mean_absolute_error: 1.1392 - val_loss: 0.1263 - val_mean_absolute_error: 0.3247
# Epoch 10/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2.1672 - mean_absolute_error: 1.1506
# Epoch 10: val_loss improved from 0.12633 to 0.11241, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 2.0946 - mean_absolute_error: 1.1327 - val_loss: 0.1124 - val_mean_absolute_error: 0.3040
# Epoch 11/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2.6160 - mean_absolute_error: 1.2348
# Epoch 11: val_loss improved from 0.11241 to 0.09467, saving model to best-model.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 2.3384 - mean_absolute_error: 1.1640 - val_loss: 0.0947 - val_mean_absolute_error: 0.2779
# Epoch 12/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.8511 - mean_absolute_error: 1.0594
# Epoch 12: val_loss improved from 0.09467 to 0.08071, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 2.0086 - mean_absolute_error: 1.1128 - val_loss: 0.0807 - val_mean_absolute_error: 0.2557
# Epoch 13/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2.2275 - mean_absolute_error: 1.1270
# Epoch 13: val_loss improved from 0.08071 to 0.07208, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 2.0992 - mean_absolute_error: 1.1158 - val_loss: 0.0721 - val_mean_absolute_error: 0.2417
# Epoch 14/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.5123 - mean_absolute_error: 0.9799
# Epoch 14: val_loss improved from 0.07208 to 0.06429, saving model to best-model.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 1.8599 - mean_absolute_error: 1.0807 - val_loss: 0.0643 - val_mean_absolute_error: 0.2283
# Epoch 15/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2.2557 - mean_absolute_error: 1.1351
# Epoch 15: val_loss improved from 0.06429 to 0.05834, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 2.0112 - mean_absolute_error: 1.0805 - val_loss: 0.0583 - val_mean_absolute_error: 0.2162
# Epoch 16/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2.2177 - mean_absolute_error: 1.1277
# Epoch 16: val_loss improved from 0.05834 to 0.05657, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 1.9804 - mean_absolute_error: 1.0615 - val_loss: 0.0566 - val_mean_absolute_error: 0.2127
# Epoch 17/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.8622 - mean_absolute_error: 1.1180
# Epoch 17: val_loss did not improve from 0.05657
# 4/4 [==============================] - 0s 13ms/step - loss: 1.6866 - mean_absolute_error: 1.0421 - val_loss: 0.0569 - val_mean_absolute_error: 0.2135
# Epoch 18/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.8083 - mean_absolute_error: 1.0220
# Epoch 18: val_loss improved from 0.05657 to 0.05378, saving model to best-model.h5
# 4/4 [==============================] - 0s 31ms/step - loss: 1.9070 - mean_absolute_error: 1.0407 - val_loss: 0.0538 - val_mean_absolute_error: 0.2068
# Epoch 19/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.8786 - mean_absolute_error: 1.0546
# Epoch 19: val_loss improved from 0.05378 to 0.04475, saving model to best-model.h5
# 4/4 [==============================] - 0s 34ms/step - loss: 1.7309 - mean_absolute_error: 1.0114 - val_loss: 0.0448 - val_mean_absolute_error: 0.1849
# Epoch 20/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.4083 - mean_absolute_error: 0.8994
# Epoch 20: val_loss improved from 0.04475 to 0.03374, saving model to best-model.h5
# 4/4 [==============================] - 0s 29ms/step - loss: 1.9910 - mean_absolute_error: 1.0620 - val_loss: 0.0337 - val_mean_absolute_error: 0.1553
# Epoch 21/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.5716 - mean_absolute_error: 0.9435
# Epoch 21: val_loss improved from 0.03374 to 0.02637, saving model to best-model.h5
# 4/4 [==============================] - 0s 35ms/step - loss: 1.5576 - mean_absolute_error: 0.9614 - val_loss: 0.0264 - val_mean_absolute_error: 0.1346
# Epoch 22/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.6777 - mean_absolute_error: 1.0063
# Epoch 22: val_loss improved from 0.02637 to 0.02154, saving model to best-model.h5
# 4/4 [==============================] - 0s 29ms/step - loss: 1.4109 - mean_absolute_error: 0.9068 - val_loss: 0.0215 - val_mean_absolute_error: 0.1219
# Epoch 23/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3645 - mean_absolute_error: 0.9215
# Epoch 23: val_loss improved from 0.02154 to 0.02037, saving model to best-model.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 1.4783 - mean_absolute_error: 0.9306 - val_loss: 0.0204 - val_mean_absolute_error: 0.1192
# Epoch 24/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.4117 - mean_absolute_error: 0.8769
# Epoch 24: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 1.4713 - mean_absolute_error: 0.9244 - val_loss: 0.0206 - val_mean_absolute_error: 0.1191
# Epoch 25/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.7416 - mean_absolute_error: 1.0442
# Epoch 25: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 1.6654 - mean_absolute_error: 0.9910 - val_loss: 0.0208 - val_mean_absolute_error: 0.1188
# Epoch 26/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.4879 - mean_absolute_error: 0.8598
# Epoch 26: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 1.5338 - mean_absolute_error: 0.9269 - val_loss: 0.0213 - val_mean_absolute_error: 0.1194
# Epoch 27/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.4399 - mean_absolute_error: 0.9114
# Epoch 27: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 1.5870 - mean_absolute_error: 0.9599 - val_loss: 0.0212 - val_mean_absolute_error: 0.1184
# Epoch 28/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.1288 - mean_absolute_error: 0.8315
# Epoch 28: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 1.3060 - mean_absolute_error: 0.8769 - val_loss: 0.0212 - val_mean_absolute_error: 0.1175
# Epoch 29/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.2233 - mean_absolute_error: 0.8395
# Epoch 29: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 1.1611 - mean_absolute_error: 0.8399 - val_loss: 0.0221 - val_mean_absolute_error: 0.1190
# Epoch 30/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.1138 - mean_absolute_error: 0.7888
# Epoch 30: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 1.2674 - mean_absolute_error: 0.8405 - val_loss: 0.0224 - val_mean_absolute_error: 0.1198
# Epoch 31/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3018 - mean_absolute_error: 0.8688
# Epoch 31: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 19ms/step - loss: 1.2929 - mean_absolute_error: 0.8853 - val_loss: 0.0222 - val_mean_absolute_error: 0.1195
# Epoch 32/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3386 - mean_absolute_error: 0.8798
# Epoch 32: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 1.2240 - mean_absolute_error: 0.8481 - val_loss: 0.0219 - val_mean_absolute_error: 0.1193
# Epoch 33/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.1837 - mean_absolute_error: 0.8212
# Epoch 33: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 1.1020 - mean_absolute_error: 0.7965 - val_loss: 0.0219 - val_mean_absolute_error: 0.1188
# Epoch 34/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.4385 - mean_absolute_error: 0.9489
# Epoch 34: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 1.2767 - mean_absolute_error: 0.8816 - val_loss: 0.0235 - val_mean_absolute_error: 0.1246
# Epoch 35/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.2614 - mean_absolute_error: 0.8826
# Epoch 35: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 1.1963 - mean_absolute_error: 0.8523 - val_loss: 0.0277 - val_mean_absolute_error: 0.1385
# Epoch 36/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.0704 - mean_absolute_error: 0.8379
# Epoch 36: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0874 - mean_absolute_error: 0.8041 - val_loss: 0.0291 - val_mean_absolute_error: 0.1403
# Epoch 37/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.5020 - mean_absolute_error: 0.8951
# Epoch 37: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 1.2756 - mean_absolute_error: 0.8493 - val_loss: 0.0296 - val_mean_absolute_error: 0.1399
# Epoch 38/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.1678 - mean_absolute_error: 0.8088
# Epoch 38: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0248 - mean_absolute_error: 0.7776 - val_loss: 0.0288 - val_mean_absolute_error: 0.1367
# Epoch 39/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.2104 - mean_absolute_error: 0.8397
# Epoch 39: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 1.1399 - mean_absolute_error: 0.8233 - val_loss: 0.0292 - val_mean_absolute_error: 0.1364
# Epoch 40/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.0943 - mean_absolute_error: 0.7703
# Epoch 40: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0593 - mean_absolute_error: 0.7736 - val_loss: 0.0320 - val_mean_absolute_error: 0.1428
# Epoch 41/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.0627 - mean_absolute_error: 0.7808
# Epoch 41: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9974 - mean_absolute_error: 0.7436 - val_loss: 0.0346 - val_mean_absolute_error: 0.1490
# Epoch 42/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.1167 - mean_absolute_error: 0.7911
# Epoch 42: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0709 - mean_absolute_error: 0.7915 - val_loss: 0.0358 - val_mean_absolute_error: 0.1519
# Epoch 43/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.9623 - mean_absolute_error: 0.7312
# Epoch 43: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 20ms/step - loss: 0.9826 - mean_absolute_error: 0.7499 - val_loss: 0.0379 - val_mean_absolute_error: 0.1558
# Epoch 44/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.8781 - mean_absolute_error: 0.7415
# Epoch 44: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9096 - mean_absolute_error: 0.7579 - val_loss: 0.0405 - val_mean_absolute_error: 0.1597
# Epoch 45/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.0637 - mean_absolute_error: 0.7608
# Epoch 45: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9775 - mean_absolute_error: 0.7354 - val_loss: 0.0433 - val_mean_absolute_error: 0.1633
# Epoch 46/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.0114 - mean_absolute_error: 0.7881
# Epoch 46: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9232 - mean_absolute_error: 0.7435 - val_loss: 0.0457 - val_mean_absolute_error: 0.1682
# Epoch 47/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1.0394 - mean_absolute_error: 0.7672
# Epoch 47: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 19ms/step - loss: 0.9470 - mean_absolute_error: 0.7483 - val_loss: 0.0485 - val_mean_absolute_error: 0.1750
# Epoch 48/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.9459 - mean_absolute_error: 0.7302
# Epoch 48: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8134 - mean_absolute_error: 0.6938 - val_loss: 0.0505 - val_mean_absolute_error: 0.1811
# Epoch 49/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7334 - mean_absolute_error: 0.6879
# Epoch 49: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8957 - mean_absolute_error: 0.7193 - val_loss: 0.0541 - val_mean_absolute_error: 0.1884
# Epoch 50/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.8243 - mean_absolute_error: 0.6717
# Epoch 50: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8203 - mean_absolute_error: 0.7018 - val_loss: 0.0561 - val_mean_absolute_error: 0.1935
# Epoch 51/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.8845 - mean_absolute_error: 0.7070
# Epoch 51: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8214 - mean_absolute_error: 0.6806 - val_loss: 0.0546 - val_mean_absolute_error: 0.1898
# Epoch 52/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7297 - mean_absolute_error: 0.6335
# Epoch 52: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7447 - mean_absolute_error: 0.6558 - val_loss: 0.0513 - val_mean_absolute_error: 0.1833
# Epoch 53/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.8176 - mean_absolute_error: 0.6671
# Epoch 53: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7398 - mean_absolute_error: 0.6365 - val_loss: 0.0483 - val_mean_absolute_error: 0.1771
# Epoch 54/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6008 - mean_absolute_error: 0.6029
# Epoch 54: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7088 - mean_absolute_error: 0.6493 - val_loss: 0.0448 - val_mean_absolute_error: 0.1693
# Epoch 55/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7816 - mean_absolute_error: 0.6553
# Epoch 55: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7767 - mean_absolute_error: 0.6760 - val_loss: 0.0421 - val_mean_absolute_error: 0.1636
# Epoch 56/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7180 - mean_absolute_error: 0.6813
# Epoch 56: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6974 - mean_absolute_error: 0.6540 - val_loss: 0.0394 - val_mean_absolute_error: 0.1593
# Epoch 57/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7393 - mean_absolute_error: 0.6678
# Epoch 57: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8208 - mean_absolute_error: 0.6909 - val_loss: 0.0381 - val_mean_absolute_error: 0.1564
# Epoch 58/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6351 - mean_absolute_error: 0.6045
# Epoch 58: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8657 - mean_absolute_error: 0.6971 - val_loss: 0.0371 - val_mean_absolute_error: 0.1521
# Epoch 59/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7669 - mean_absolute_error: 0.6524
# Epoch 59: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7188 - mean_absolute_error: 0.6349 - val_loss: 0.0359 - val_mean_absolute_error: 0.1491
# Epoch 60/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7005 - mean_absolute_error: 0.6466
# Epoch 60: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7494 - mean_absolute_error: 0.6581 - val_loss: 0.0361 - val_mean_absolute_error: 0.1507
# Epoch 61/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5678 - mean_absolute_error: 0.5716
# Epoch 61: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6087 - mean_absolute_error: 0.6070 - val_loss: 0.0372 - val_mean_absolute_error: 0.1554
# Epoch 62/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6600 - mean_absolute_error: 0.6174
# Epoch 62: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6236 - mean_absolute_error: 0.6201 - val_loss: 0.0381 - val_mean_absolute_error: 0.1601
# Epoch 63/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5181 - mean_absolute_error: 0.5677
# Epoch 63: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7111 - mean_absolute_error: 0.6332 - val_loss: 0.0397 - val_mean_absolute_error: 0.1654
# Epoch 64/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5916 - mean_absolute_error: 0.6100
# Epoch 64: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6133 - mean_absolute_error: 0.6067 - val_loss: 0.0416 - val_mean_absolute_error: 0.1711
# Epoch 65/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5475 - mean_absolute_error: 0.5842
# Epoch 65: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6134 - mean_absolute_error: 0.6179 - val_loss: 0.0402 - val_mean_absolute_error: 0.1686
# Epoch 66/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4492 - mean_absolute_error: 0.5208
# Epoch 66: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5668 - mean_absolute_error: 0.5899 - val_loss: 0.0370 - val_mean_absolute_error: 0.1607
# Epoch 67/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5603 - mean_absolute_error: 0.5737
# Epoch 67: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5639 - mean_absolute_error: 0.5885 - val_loss: 0.0349 - val_mean_absolute_error: 0.1557
# Epoch 68/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5165 - mean_absolute_error: 0.5421
# Epoch 68: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5690 - mean_absolute_error: 0.5792 - val_loss: 0.0348 - val_mean_absolute_error: 0.1567
# Epoch 69/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5616 - mean_absolute_error: 0.5947
# Epoch 69: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5525 - mean_absolute_error: 0.5977 - val_loss: 0.0353 - val_mean_absolute_error: 0.1584
# Epoch 70/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5046 - mean_absolute_error: 0.5475
# Epoch 70: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5783 - mean_absolute_error: 0.5844 - val_loss: 0.0345 - val_mean_absolute_error: 0.1565
# Epoch 71/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6857 - mean_absolute_error: 0.6213
# Epoch 71: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6582 - mean_absolute_error: 0.6229 - val_loss: 0.0338 - val_mean_absolute_error: 0.1533
# Epoch 72/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6397 - mean_absolute_error: 0.6262
# Epoch 72: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5477 - mean_absolute_error: 0.5739 - val_loss: 0.0340 - val_mean_absolute_error: 0.1512
# Epoch 73/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5744 - mean_absolute_error: 0.5674
# Epoch 73: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4876 - mean_absolute_error: 0.5415 - val_loss: 0.0342 - val_mean_absolute_error: 0.1493
# Epoch 74/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4294 - mean_absolute_error: 0.5046
# Epoch 74: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4905 - mean_absolute_error: 0.5512 - val_loss: 0.0343 - val_mean_absolute_error: 0.1479
# Epoch 75/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4380 - mean_absolute_error: 0.5229
# Epoch 75: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4544 - mean_absolute_error: 0.5195 - val_loss: 0.0340 - val_mean_absolute_error: 0.1469
# Epoch 76/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4930 - mean_absolute_error: 0.5468
# Epoch 76: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4694 - mean_absolute_error: 0.5413 - val_loss: 0.0348 - val_mean_absolute_error: 0.1491
# Epoch 77/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4852 - mean_absolute_error: 0.5076
# Epoch 77: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4596 - mean_absolute_error: 0.5128 - val_loss: 0.0360 - val_mean_absolute_error: 0.1518
# Epoch 78/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4102 - mean_absolute_error: 0.4909
# Epoch 78: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4426 - mean_absolute_error: 0.5164 - val_loss: 0.0373 - val_mean_absolute_error: 0.1542
# Epoch 79/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3641 - mean_absolute_error: 0.4723
# Epoch 79: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4310 - mean_absolute_error: 0.5026 - val_loss: 0.0385 - val_mean_absolute_error: 0.1570
# Epoch 80/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3857 - mean_absolute_error: 0.4849
# Epoch 80: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3942 - mean_absolute_error: 0.4951 - val_loss: 0.0387 - val_mean_absolute_error: 0.1584
# Epoch 81/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3852 - mean_absolute_error: 0.4642
# Epoch 81: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4729 - mean_absolute_error: 0.5160 - val_loss: 0.0389 - val_mean_absolute_error: 0.1587
# Epoch 82/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4491 - mean_absolute_error: 0.5501
# Epoch 82: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4137 - mean_absolute_error: 0.5027 - val_loss: 0.0387 - val_mean_absolute_error: 0.1575
# Epoch 83/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3138 - mean_absolute_error: 0.4521
# Epoch 83: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3889 - mean_absolute_error: 0.4798 - val_loss: 0.0398 - val_mean_absolute_error: 0.1590
# Epoch 84/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3120 - mean_absolute_error: 0.4375
# Epoch 84: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3795 - mean_absolute_error: 0.4789 - val_loss: 0.0400 - val_mean_absolute_error: 0.1595
# Epoch 85/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3675 - mean_absolute_error: 0.4691
# Epoch 85: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3793 - mean_absolute_error: 0.4711 - val_loss: 0.0383 - val_mean_absolute_error: 0.1561
# Epoch 86/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3678 - mean_absolute_error: 0.4516
# Epoch 86: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3975 - mean_absolute_error: 0.4760 - val_loss: 0.0354 - val_mean_absolute_error: 0.1517
# Epoch 87/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4709 - mean_absolute_error: 0.5355
# Epoch 87: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4245 - mean_absolute_error: 0.4908 - val_loss: 0.0336 - val_mean_absolute_error: 0.1496
# Epoch 88/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3534 - mean_absolute_error: 0.4600
# Epoch 88: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3768 - mean_absolute_error: 0.4636 - val_loss: 0.0335 - val_mean_absolute_error: 0.1499
# Epoch 89/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2632 - mean_absolute_error: 0.3923
# Epoch 89: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3233 - mean_absolute_error: 0.4265 - val_loss: 0.0340 - val_mean_absolute_error: 0.1505
# Epoch 90/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3870 - mean_absolute_error: 0.4875
# Epoch 90: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3908 - mean_absolute_error: 0.4637 - val_loss: 0.0342 - val_mean_absolute_error: 0.1504
# Epoch 91/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2592 - mean_absolute_error: 0.4017
# Epoch 91: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2886 - mean_absolute_error: 0.4150 - val_loss: 0.0335 - val_mean_absolute_error: 0.1483
# Epoch 92/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3443 - mean_absolute_error: 0.4084
# Epoch 92: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3199 - mean_absolute_error: 0.4203 - val_loss: 0.0327 - val_mean_absolute_error: 0.1476
# Epoch 93/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2988 - mean_absolute_error: 0.4193
# Epoch 93: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3077 - mean_absolute_error: 0.4373 - val_loss: 0.0319 - val_mean_absolute_error: 0.1461
# Epoch 94/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3296 - mean_absolute_error: 0.4278
# Epoch 94: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3642 - mean_absolute_error: 0.4549 - val_loss: 0.0325 - val_mean_absolute_error: 0.1489
# Epoch 95/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3043 - mean_absolute_error: 0.4314
# Epoch 95: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3046 - mean_absolute_error: 0.4252 - val_loss: 0.0328 - val_mean_absolute_error: 0.1513
# Epoch 96/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3969 - mean_absolute_error: 0.5103
# Epoch 96: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3528 - mean_absolute_error: 0.4726 - val_loss: 0.0328 - val_mean_absolute_error: 0.1524
# Epoch 97/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3374 - mean_absolute_error: 0.4456
# Epoch 97: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2816 - mean_absolute_error: 0.4061 - val_loss: 0.0337 - val_mean_absolute_error: 0.1533
# Epoch 98/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2733 - mean_absolute_error: 0.3990
# Epoch 98: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2957 - mean_absolute_error: 0.4276 - val_loss: 0.0341 - val_mean_absolute_error: 0.1540
# Epoch 99/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3406 - mean_absolute_error: 0.4582
# Epoch 99: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3086 - mean_absolute_error: 0.4315 - val_loss: 0.0343 - val_mean_absolute_error: 0.1545
# Epoch 100/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3317 - mean_absolute_error: 0.4506
# Epoch 100: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2823 - mean_absolute_error: 0.4059 - val_loss: 0.0344 - val_mean_absolute_error: 0.1548
# Epoch 101/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3014 - mean_absolute_error: 0.4232
# Epoch 101: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3276 - mean_absolute_error: 0.4396 - val_loss: 0.0348 - val_mean_absolute_error: 0.1550
# Epoch 102/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2915 - mean_absolute_error: 0.4098
# Epoch 102: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3177 - mean_absolute_error: 0.4267 - val_loss: 0.0348 - val_mean_absolute_error: 0.1554
# Epoch 103/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3288 - mean_absolute_error: 0.4226
# Epoch 103: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2866 - mean_absolute_error: 0.4117 - val_loss: 0.0346 - val_mean_absolute_error: 0.1557
# Epoch 104/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2311 - mean_absolute_error: 0.3813
# Epoch 104: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2547 - mean_absolute_error: 0.3969 - val_loss: 0.0345 - val_mean_absolute_error: 0.1555
# Epoch 105/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2597 - mean_absolute_error: 0.4101
# Epoch 105: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3050 - mean_absolute_error: 0.4242 - val_loss: 0.0340 - val_mean_absolute_error: 0.1548
# Epoch 106/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3118 - mean_absolute_error: 0.4155
# Epoch 106: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3340 - mean_absolute_error: 0.4360 - val_loss: 0.0328 - val_mean_absolute_error: 0.1519
# Epoch 107/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2584 - mean_absolute_error: 0.3855
# Epoch 107: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2730 - mean_absolute_error: 0.3989 - val_loss: 0.0310 - val_mean_absolute_error: 0.1478
# Epoch 108/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3000 - mean_absolute_error: 0.4275
# Epoch 108: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2807 - mean_absolute_error: 0.4218 - val_loss: 0.0295 - val_mean_absolute_error: 0.1450
# Epoch 109/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2730 - mean_absolute_error: 0.4338
# Epoch 109: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2371 - mean_absolute_error: 0.3909 - val_loss: 0.0282 - val_mean_absolute_error: 0.1423
# Epoch 110/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1965 - mean_absolute_error: 0.3541
# Epoch 110: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2652 - mean_absolute_error: 0.3967 - val_loss: 0.0268 - val_mean_absolute_error: 0.1389
# Epoch 111/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1934 - mean_absolute_error: 0.3466
# Epoch 111: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2234 - mean_absolute_error: 0.3715 - val_loss: 0.0264 - val_mean_absolute_error: 0.1377
# Epoch 112/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2085 - mean_absolute_error: 0.3452
# Epoch 112: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2536 - mean_absolute_error: 0.3855 - val_loss: 0.0258 - val_mean_absolute_error: 0.1358
# Epoch 113/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2561 - mean_absolute_error: 0.4047
# Epoch 113: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2354 - mean_absolute_error: 0.3783 - val_loss: 0.0250 - val_mean_absolute_error: 0.1341
# Epoch 114/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2483 - mean_absolute_error: 0.3712
# Epoch 114: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2525 - mean_absolute_error: 0.3805 - val_loss: 0.0244 - val_mean_absolute_error: 0.1323
# Epoch 115/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2259 - mean_absolute_error: 0.3504
# Epoch 115: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2317 - mean_absolute_error: 0.3645 - val_loss: 0.0238 - val_mean_absolute_error: 0.1306
# Epoch 116/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2497 - mean_absolute_error: 0.3861
# Epoch 116: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2235 - mean_absolute_error: 0.3686 - val_loss: 0.0230 - val_mean_absolute_error: 0.1284
# Epoch 117/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2289 - mean_absolute_error: 0.3692
# Epoch 117: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2220 - mean_absolute_error: 0.3652 - val_loss: 0.0223 - val_mean_absolute_error: 0.1270
# Epoch 118/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2120 - mean_absolute_error: 0.3733
# Epoch 118: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2131 - mean_absolute_error: 0.3611 - val_loss: 0.0219 - val_mean_absolute_error: 0.1263
# Epoch 119/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1598 - mean_absolute_error: 0.3071
# Epoch 119: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1901 - mean_absolute_error: 0.3338 - val_loss: 0.0217 - val_mean_absolute_error: 0.1257
# Epoch 120/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1665 - mean_absolute_error: 0.3160
# Epoch 120: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2180 - mean_absolute_error: 0.3594 - val_loss: 0.0223 - val_mean_absolute_error: 0.1275
# Epoch 121/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2032 - mean_absolute_error: 0.3603
# Epoch 121: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1922 - mean_absolute_error: 0.3457 - val_loss: 0.0229 - val_mean_absolute_error: 0.1296
# Epoch 122/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1965 - mean_absolute_error: 0.3325
# Epoch 122: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2051 - mean_absolute_error: 0.3570 - val_loss: 0.0237 - val_mean_absolute_error: 0.1324
# Epoch 123/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1803 - mean_absolute_error: 0.3325
# Epoch 123: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1928 - mean_absolute_error: 0.3396 - val_loss: 0.0237 - val_mean_absolute_error: 0.1321
# Epoch 124/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1673 - mean_absolute_error: 0.3280
# Epoch 124: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1780 - mean_absolute_error: 0.3299 - val_loss: 0.0230 - val_mean_absolute_error: 0.1289
# Epoch 125/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1865 - mean_absolute_error: 0.3456
# Epoch 125: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1798 - mean_absolute_error: 0.3398 - val_loss: 0.0226 - val_mean_absolute_error: 0.1269
# Epoch 126/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1395 - mean_absolute_error: 0.2865
# Epoch 126: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1606 - mean_absolute_error: 0.3149 - val_loss: 0.0224 - val_mean_absolute_error: 0.1257
# Epoch 127/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1910 - mean_absolute_error: 0.3538
# Epoch 127: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1753 - mean_absolute_error: 0.3354 - val_loss: 0.0218 - val_mean_absolute_error: 0.1236
# Epoch 128/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1400 - mean_absolute_error: 0.2967
# Epoch 128: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1720 - mean_absolute_error: 0.3195 - val_loss: 0.0218 - val_mean_absolute_error: 0.1232
# Epoch 129/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1676 - mean_absolute_error: 0.3229
# Epoch 129: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1892 - mean_absolute_error: 0.3316 - val_loss: 0.0220 - val_mean_absolute_error: 0.1233
# Epoch 130/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1662 - mean_absolute_error: 0.3267
# Epoch 130: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1674 - mean_absolute_error: 0.3235 - val_loss: 0.0218 - val_mean_absolute_error: 0.1229
# Epoch 131/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1522 - mean_absolute_error: 0.2975
# Epoch 131: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1730 - mean_absolute_error: 0.3174 - val_loss: 0.0215 - val_mean_absolute_error: 0.1230
# Epoch 132/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2178 - mean_absolute_error: 0.3700
# Epoch 132: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1760 - mean_absolute_error: 0.3292 - val_loss: 0.0209 - val_mean_absolute_error: 0.1217
# Epoch 133/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2014 - mean_absolute_error: 0.3424
# Epoch 133: val_loss did not improve from 0.02037
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1687 - mean_absolute_error: 0.3173 - val_loss: 0.0205 - val_mean_absolute_error: 0.1208
# Epoch 134/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1489 - mean_absolute_error: 0.3119
# Epoch 134: val_loss improved from 0.02037 to 0.02013, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1523 - mean_absolute_error: 0.3048 - val_loss: 0.0201 - val_mean_absolute_error: 0.1202
# Epoch 135/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1415 - mean_absolute_error: 0.2911
# Epoch 135: val_loss improved from 0.02013 to 0.01975, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1493 - mean_absolute_error: 0.3025 - val_loss: 0.0197 - val_mean_absolute_error: 0.1193
# Epoch 136/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1349 - mean_absolute_error: 0.2827
# Epoch 136: val_loss improved from 0.01975 to 0.01942, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1557 - mean_absolute_error: 0.3027 - val_loss: 0.0194 - val_mean_absolute_error: 0.1185
# Epoch 137/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1425 - mean_absolute_error: 0.2916
# Epoch 137: val_loss improved from 0.01942 to 0.01889, saving model to best-model.h5
# 4/4 [==============================] - 0s 29ms/step - loss: 0.1465 - mean_absolute_error: 0.2936 - val_loss: 0.0189 - val_mean_absolute_error: 0.1171
# Epoch 138/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1478 - mean_absolute_error: 0.2928
# Epoch 138: val_loss improved from 0.01889 to 0.01817, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1523 - mean_absolute_error: 0.3043 - val_loss: 0.0182 - val_mean_absolute_error: 0.1152
# Epoch 139/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1276 - mean_absolute_error: 0.2983
# Epoch 139: val_loss improved from 0.01817 to 0.01760, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1466 - mean_absolute_error: 0.3067 - val_loss: 0.0176 - val_mean_absolute_error: 0.1138
# Epoch 140/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1567 - mean_absolute_error: 0.3125
# Epoch 140: val_loss improved from 0.01760 to 0.01730, saving model to best-model.h5
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1563 - mean_absolute_error: 0.3096 - val_loss: 0.0173 - val_mean_absolute_error: 0.1131
# Epoch 141/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1646 - mean_absolute_error: 0.3287
# Epoch 141: val_loss improved from 0.01730 to 0.01676, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1514 - mean_absolute_error: 0.3051 - val_loss: 0.0168 - val_mean_absolute_error: 0.1115
# Epoch 142/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1352 - mean_absolute_error: 0.2873
# Epoch 142: val_loss improved from 0.01676 to 0.01636, saving model to best-model.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 0.1433 - mean_absolute_error: 0.2969 - val_loss: 0.0164 - val_mean_absolute_error: 0.1105
# Epoch 143/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1429 - mean_absolute_error: 0.2908
# Epoch 143: val_loss improved from 0.01636 to 0.01595, saving model to best-model.h5
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1280 - mean_absolute_error: 0.2782 - val_loss: 0.0160 - val_mean_absolute_error: 0.1098
# Epoch 144/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1256 - mean_absolute_error: 0.2850
# Epoch 144: val_loss improved from 0.01595 to 0.01585, saving model to best-model.h5
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1218 - mean_absolute_error: 0.2758 - val_loss: 0.0158 - val_mean_absolute_error: 0.1096
# Epoch 145/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1095 - mean_absolute_error: 0.2611
# Epoch 145: val_loss improved from 0.01585 to 0.01573, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1175 - mean_absolute_error: 0.2700 - val_loss: 0.0157 - val_mean_absolute_error: 0.1092
# Epoch 146/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1307 - mean_absolute_error: 0.2801
# Epoch 146: val_loss improved from 0.01573 to 0.01561, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1258 - mean_absolute_error: 0.2704 - val_loss: 0.0156 - val_mean_absolute_error: 0.1087
# Epoch 147/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1350 - mean_absolute_error: 0.3062
# Epoch 147: val_loss improved from 0.01561 to 0.01549, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1202 - mean_absolute_error: 0.2755 - val_loss: 0.0155 - val_mean_absolute_error: 0.1082
# Epoch 148/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1508 - mean_absolute_error: 0.2967
# Epoch 148: val_loss improved from 0.01549 to 0.01532, saving model to best-model.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1390 - mean_absolute_error: 0.2928 - val_loss: 0.0153 - val_mean_absolute_error: 0.1073
# Epoch 149/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1112 - mean_absolute_error: 0.2730
# ...
# Epoch 449/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0049 - mean_absolute_error: 0.0550
# Epoch 449: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0056 - mean_absolute_error: 0.0582 - val_loss: 0.0045 - val_mean_absolute_error: 0.0499
# Epoch 450/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0067 - mean_absolute_error: 0.0653
# Epoch 450: val_loss improved from 0.00444 to 0.00444, saving model to best-model.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0062 - mean_absolute_error: 0.0627 - val_loss: 0.0044 - val_mean_absolute_error: 0.0501
# Epoch 451/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0068 - mean_absolute_error: 0.0635
# Epoch 451: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0064 - mean_absolute_error: 0.0640 - val_loss: 0.0044 - val_mean_absolute_error: 0.0503
# Epoch 452/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0050 - mean_absolute_error: 0.0556
# Epoch 452: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0060 - mean_absolute_error: 0.0602 - val_loss: 0.0045 - val_mean_absolute_error: 0.0506
# Epoch 453/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0058 - mean_absolute_error: 0.0608
# Epoch 453: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0057 - mean_absolute_error: 0.0596 - val_loss: 0.0045 - val_mean_absolute_error: 0.0511
# Epoch 454/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0046 - mean_absolute_error: 0.0546
# Epoch 454: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0061 - mean_absolute_error: 0.0605 - val_loss: 0.0046 - val_mean_absolute_error: 0.0516
# Epoch 455/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0058 - mean_absolute_error: 0.0606
# Epoch 455: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0059 - mean_absolute_error: 0.0607 - val_loss: 0.0046 - val_mean_absolute_error: 0.0518
# Epoch 456/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0073 - mean_absolute_error: 0.0709
# Epoch 456: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0066 - mean_absolute_error: 0.0635 - val_loss: 0.0046 - val_mean_absolute_error: 0.0515
# Epoch 457/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0057 - mean_absolute_error: 0.0589
# Epoch 457: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0058 - mean_absolute_error: 0.0615 - val_loss: 0.0045 - val_mean_absolute_error: 0.0512
# Epoch 458/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0059 - mean_absolute_error: 0.0618
# Epoch 458: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0063 - mean_absolute_error: 0.0634 - val_loss: 0.0045 - val_mean_absolute_error: 0.0507
# Epoch 459/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0048 - mean_absolute_error: 0.0548
# Epoch 459: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0061 - mean_absolute_error: 0.0601 - val_loss: 0.0045 - val_mean_absolute_error: 0.0502
# Epoch 460/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0064 - mean_absolute_error: 0.0641
# Epoch 460: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0057 - mean_absolute_error: 0.0599 - val_loss: 0.0045 - val_mean_absolute_error: 0.0504
# Epoch 461/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0056 - mean_absolute_error: 0.0621
# Epoch 461: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0056 - mean_absolute_error: 0.0595 - val_loss: 0.0045 - val_mean_absolute_error: 0.0503
# Epoch 462/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0061 - mean_absolute_error: 0.0604
# Epoch 462: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0052 - mean_absolute_error: 0.0569 - val_loss: 0.0045 - val_mean_absolute_error: 0.0503
# Epoch 463/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0073 - mean_absolute_error: 0.0695
# Epoch 463: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0059 - mean_absolute_error: 0.0606 - val_loss: 0.0046 - val_mean_absolute_error: 0.0502
# Epoch 464/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0057 - mean_absolute_error: 0.0563
# Epoch 464: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0061 - mean_absolute_error: 0.0610 - val_loss: 0.0046 - val_mean_absolute_error: 0.0502
# Epoch 465/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0055 - mean_absolute_error: 0.0581
# Epoch 465: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0055 - mean_absolute_error: 0.0583 - val_loss: 0.0046 - val_mean_absolute_error: 0.0506
# Epoch 466/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0068 - mean_absolute_error: 0.0673
# Epoch 466: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0057 - mean_absolute_error: 0.0605 - val_loss: 0.0046 - val_mean_absolute_error: 0.0505
# Epoch 467/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0064 - mean_absolute_error: 0.0613
# Epoch 467: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0058 - mean_absolute_error: 0.0575 - val_loss: 0.0046 - val_mean_absolute_error: 0.0507
# Epoch 468/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0064 - mean_absolute_error: 0.0633
# Epoch 468: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0053 - mean_absolute_error: 0.0570 - val_loss: 0.0046 - val_mean_absolute_error: 0.0506
# Epoch 469/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0065 - mean_absolute_error: 0.0671
# Epoch 469: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0060 - mean_absolute_error: 0.0610 - val_loss: 0.0046 - val_mean_absolute_error: 0.0508
# Epoch 470/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0057 - mean_absolute_error: 0.0602
# Epoch 470: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0059 - mean_absolute_error: 0.0594 - val_loss: 0.0046 - val_mean_absolute_error: 0.0509
# Epoch 471/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0061 - mean_absolute_error: 0.0604
# Epoch 471: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0053 - mean_absolute_error: 0.0572 - val_loss: 0.0046 - val_mean_absolute_error: 0.0516
# Epoch 472/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0057 - mean_absolute_error: 0.0595
# Epoch 472: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0061 - mean_absolute_error: 0.0617 - val_loss: 0.0046 - val_mean_absolute_error: 0.0516
# Epoch 473/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0048 - mean_absolute_error: 0.0523
# Epoch 473: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0058 - mean_absolute_error: 0.0584 - val_loss: 0.0046 - val_mean_absolute_error: 0.0519
# Epoch 474/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0052 - mean_absolute_error: 0.0568
# Epoch 474: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0061 - mean_absolute_error: 0.0625 - val_loss: 0.0046 - val_mean_absolute_error: 0.0516
# Epoch 475/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0047 - mean_absolute_error: 0.0536
# Epoch 475: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0052 - mean_absolute_error: 0.0559 - val_loss: 0.0046 - val_mean_absolute_error: 0.0511
# Epoch 476/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0059 - mean_absolute_error: 0.0617
# Epoch 476: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0058 - mean_absolute_error: 0.0597 - val_loss: 0.0046 - val_mean_absolute_error: 0.0509
# Epoch 477/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0062 - mean_absolute_error: 0.0604
# Epoch 477: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0057 - mean_absolute_error: 0.0580 - val_loss: 0.0046 - val_mean_absolute_error: 0.0507
# Epoch 478/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0057 - mean_absolute_error: 0.0565
# Epoch 478: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0056 - mean_absolute_error: 0.0582 - val_loss: 0.0045 - val_mean_absolute_error: 0.0506
# Epoch 479/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0069 - mean_absolute_error: 0.0673
# Epoch 479: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0064 - mean_absolute_error: 0.0622 - val_loss: 0.0045 - val_mean_absolute_error: 0.0505
# Epoch 480/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0051 - mean_absolute_error: 0.0576
# Epoch 480: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0053 - mean_absolute_error: 0.0573 - val_loss: 0.0045 - val_mean_absolute_error: 0.0503
# Epoch 481/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0056 - mean_absolute_error: 0.0585
# Epoch 481: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0056 - mean_absolute_error: 0.0588 - val_loss: 0.0046 - val_mean_absolute_error: 0.0504
# Epoch 482/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0051 - mean_absolute_error: 0.0538
# Epoch 482: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0056 - mean_absolute_error: 0.0573 - val_loss: 0.0046 - val_mean_absolute_error: 0.0502
# Epoch 483/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0048 - mean_absolute_error: 0.0571
# Epoch 483: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0057 - mean_absolute_error: 0.0593 - val_loss: 0.0045 - val_mean_absolute_error: 0.0502
# Epoch 484/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0052 - mean_absolute_error: 0.0572
# Epoch 484: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0050 - mean_absolute_error: 0.0548 - val_loss: 0.0045 - val_mean_absolute_error: 0.0498
# Epoch 485/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0054 - mean_absolute_error: 0.0602
# Epoch 485: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0054 - mean_absolute_error: 0.0582 - val_loss: 0.0045 - val_mean_absolute_error: 0.0495
# Epoch 486/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0052 - mean_absolute_error: 0.0599
# Epoch 486: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0054 - mean_absolute_error: 0.0577 - val_loss: 0.0045 - val_mean_absolute_error: 0.0494
# Epoch 487/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0056 - mean_absolute_error: 0.0601
# Epoch 487: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0054 - mean_absolute_error: 0.0573 - val_loss: 0.0045 - val_mean_absolute_error: 0.0496
# Epoch 488/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0050 - mean_absolute_error: 0.0561
# Epoch 488: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0048 - mean_absolute_error: 0.0543 - val_loss: 0.0045 - val_mean_absolute_error: 0.0496
# Epoch 489/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0059 - mean_absolute_error: 0.0624
# Epoch 489: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0051 - mean_absolute_error: 0.0574 - val_loss: 0.0045 - val_mean_absolute_error: 0.0494
# Epoch 490/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0057 - mean_absolute_error: 0.0602
# Epoch 490: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0052 - mean_absolute_error: 0.0558 - val_loss: 0.0045 - val_mean_absolute_error: 0.0489
# Epoch 491/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0057 - mean_absolute_error: 0.0620
# Epoch 491: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0057 - mean_absolute_error: 0.0594 - val_loss: 0.0045 - val_mean_absolute_error: 0.0490
# Epoch 492/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0067 - mean_absolute_error: 0.0613
# Epoch 492: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0059 - mean_absolute_error: 0.0602 - val_loss: 0.0045 - val_mean_absolute_error: 0.0493
# Epoch 493/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0052 - mean_absolute_error: 0.0560
# Epoch 493: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0054 - mean_absolute_error: 0.0574 - val_loss: 0.0045 - val_mean_absolute_error: 0.0492
# Epoch 494/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0056 - mean_absolute_error: 0.0603
# Epoch 494: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0057 - mean_absolute_error: 0.0596 - val_loss: 0.0045 - val_mean_absolute_error: 0.0489
# Epoch 495/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0046 - mean_absolute_error: 0.0516
# Epoch 495: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0054 - mean_absolute_error: 0.0575 - val_loss: 0.0045 - val_mean_absolute_error: 0.0486
# Epoch 496/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0040 - mean_absolute_error: 0.0503
# Epoch 496: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0045 - mean_absolute_error: 0.0527 - val_loss: 0.0045 - val_mean_absolute_error: 0.0486
# Epoch 497/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0048 - mean_absolute_error: 0.0550
# Epoch 497: val_loss did not improve from 0.00444
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0048 - mean_absolute_error: 0.0545 - val_loss: 0.0045 - val_mean_absolute_error: 0.0484
# Epoch 498/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0064 - mean_absolute_error: 0.0598
# Epoch 498: val_loss improved from 0.00444 to 0.00443, saving model to best-model.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0055 - mean_absolute_error: 0.0564 - val_loss: 0.0044 - val_mean_absolute_error: 0.0482
# Epoch 499/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0049 - mean_absolute_error: 0.0564
# Epoch 499: val_loss improved from 0.00443 to 0.00442, saving model to best-model.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0059 - mean_absolute_error: 0.0600 - val_loss: 0.0044 - val_mean_absolute_error: 0.0480
# Epoch 500/500
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0055 - mean_absolute_error: 0.0568
# Epoch 500: val_loss did not improve from 0.00442
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0048 - mean_absolute_error: 0.0530 - val_loss: 0.0044 - val_mean_absolute_error: 0.0477

# %% [markdown]
# After training, the best model is loaded and its architecture summary is printed.

# %%
#  Load model
best_model = tf.keras.models.load_model('best-model.h5')
best_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 64)                512
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  batch_normalization_6 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  batch_normalization_7 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 9,665
# Trainable params: 9,281
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# Next, the best model's performance is evaluated by calculating mean squared error and mean absolute error on the test data. This assessment provides insights into the model's predictive accuracy.

# %%
# Evaluate the best model
best_test_loss, best_test_acc = best_model.evaluate(xtest, ytest)
print(f"Validation loss (MSE) after Tuning     : {best_test_loss} ")
print(f"Validation MAE after Tuning : {best_test_acc}  ")
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0480
# Validation loss (MSE) after Tuning     : 0.004418535158038139
# Validation MAE after Tuning : 0.047969259321689606

# %% [markdown]
# The subsequent code extracts training and validation metrics from the best model's training history. These metrics, including mean absolute error and loss, are plotted over epochs. This visualization helps in understanding the model's learning progress.

# %%
# Extract the history from the best model
accuracy = best_model_history.history['mean_absolute_error']
val_accuracy = best_model_history.history['val_mean_absolute_error']

loss = best_model_history.history['loss']
val_loss = best_model_history.history['val_loss']

epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'b', label='Training mean_absolute_error')
plt.plot(epochs, val_accuracy, 'r', label='Validation mean_absolute_error')

plt.title('Training and validation mean_absolute_error')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')

plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# A function called "make_sample_prediction" is defined to make predictions on individual test samples using the best model. It calculates differences and percentage differences between true and predicted prices.

# %%
def make_sample_prediction(index, xtest, ytest, model, transformed_cols, original_data):
    # Select the corresponding test sample and true price
    sample, true_price = xtest[index], ytest.iloc[index]
    original_sample = original_data.iloc[index]

    # Reshape the sample to be a batch of size 1
    sample = sample.reshape(1, -1)

    # Make a prediction
    predicted_price = model.predict(sample)[0][0]

    # Calculate the difference
    difference = true_price - predicted_price

    # Calculate the percentage difference
    pct_difference = (difference / true_price) * 100

    # Create a data frame for the scaled sample
    sample_df = pd.DataFrame(sample, columns=transformed_cols)

    # Print out the sample, the true price, and the predicted price
    print(f"Prediction {index+1}")
    print("Original Features:")
    print(original_sample)
#     print("Features (scaled):")
    sample_df
    print("True Price: ", true_price)
    print("Predicted Price: ", predicted_price)
    print("Difference: ", difference)
    print("Percentage Difference: ", pct_difference, "%")
    print("\n---------------------\n")

transformed_cols = ct.transformers_[0][2]

# %% [markdown]
# Then, the code calls the "make_sample_prediction" function for the first 10 samples in the test data, providing predictions, true prices, differences, and percentage differences. This step aids in understanding the model's predictive capabilities on specific samples.

# %%
# Call the function for the first 10 samples
for i in range(10):
    make_sample_prediction(i, xtest, ytest, best_model, transformed_cols, df)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# Prediction 1
# Original Features:
# GRE Score            337.00
# TOEFL Score          118.00
# University Rating      4.00
# SOP                    4.50
# LOR                    4.50
# CGPA                   9.65
# Research               1.00
# Chance of Admit        0.92
# Name: 0, dtype: float64
# True Price:  0.68
# Predicted Price:  0.638045
# Difference:  0.04195498704910283
# Percentage Difference:  6.169851036632769 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 22ms/step
# Prediction 2
# Original Features:
# GRE Score            324.00
# TOEFL Score          107.00
# University Rating      4.00
# SOP                    4.00
# LOR                    4.50
# CGPA                   8.87
# Research               1.00
# Chance of Admit        0.76
# Name: 1, dtype: float64
# True Price:  0.84
# Predicted Price:  0.81797177
# Difference:  0.022028234004974334
# Percentage Difference:  2.6224088101159926 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 22ms/step
# Prediction 3
# Original Features:
# GRE Score            316.00
# TOEFL Score          104.00
# University Rating      3.00
# SOP                    3.00
# LOR                    3.50
# CGPA                   8.00
# Research               1.00
# Chance of Admit        0.72
# Name: 2, dtype: float64
# True Price:  0.69
# Predicted Price:  0.6648418
# Difference:  0.02515822887420649
# Percentage Difference:  3.6461201266965926 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 24ms/step
# Prediction 4
# Original Features:
# GRE Score            322.00
# TOEFL Score          110.00
# University Rating      3.00
# SOP                    3.50
# LOR                    2.50
# CGPA                   8.67
# Research               1.00
# Chance of Admit        0.80
# Name: 3, dtype: float64
# True Price:  0.9
# Predicted Price:  0.8674424
# Difference:  0.032557570934295677
# Percentage Difference:  3.6175078815884083 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 26ms/step
# Prediction 5
# Original Features:
# GRE Score            314.00
# TOEFL Score          103.00
# University Rating      2.00
# SOP                    2.00
# LOR                    3.00
# CGPA                   8.21
# Research               0.00
# Chance of Admit        0.65
# Name: 4, dtype: float64
# True Price:  0.7
# Predicted Price:  0.65406424
# Difference:  0.045935761928558305
# Percentage Difference:  6.562251704079758 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 23ms/step
# Prediction 6
# Original Features:
# GRE Score            330.00
# TOEFL Score          115.00
# University Rating      5.00
# SOP                    4.50
# LOR                    3.00
# CGPA                   9.34
# Research               1.00
# Chance of Admit        0.90
# Name: 5, dtype: float64
# True Price:  0.71
# Predicted Price:  0.70600164
# Difference:  0.003998360633850062
# Percentage Difference:  0.5631493850493046 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 24ms/step
# Prediction 7
# Original Features:
# GRE Score            321.00
# TOEFL Score          109.00
# University Rating      3.00
# SOP                    3.00
# LOR                    4.00
# CGPA                   8.20
# Research               1.00
# Chance of Admit        0.75
# Name: 6, dtype: float64
# True Price:  0.7
# Predicted Price:  0.62159103
# Difference:  0.07840896844863887
# Percentage Difference:  11.201281206948412 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 24ms/step
# Prediction 8
# Original Features:
# GRE Score            308.00
# TOEFL Score          101.00
# University Rating      2.00
# SOP                    3.00
# LOR                    4.00
# CGPA                   7.90
# Research               0.00
# Chance of Admit        0.68
# Name: 7, dtype: float64
# True Price:  0.64
# Predicted Price:  0.63355947
# Difference:  0.006440534591674818
# Percentage Difference:  1.0063335299491902 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 25ms/step
# Prediction 9
# Original Features:
# GRE Score            302.0
# TOEFL Score          102.0
# University Rating      1.0
# SOP                    2.0
# LOR                    1.5
# CGPA                   8.0
# Research               0.0
# Chance of Admit        0.5
# Name: 8, dtype: float64
# True Price:  0.62
# Predicted Price:  0.59130794
# Difference:  0.028692061901092525
# Percentage Difference:  4.627751919531052 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 23ms/step
# Prediction 10
# Original Features:
# GRE Score            323.00
# TOEFL Score          108.00
# University Rating      3.00
# SOP                    3.50
# LOR                    3.00
# CGPA                   8.60
# Research               0.00
# Chance of Admit        0.45
# Name: 9, dtype: float64
# True Price:  0.45
# Predicted Price:  0.6937797
# Difference:  -0.24377970695495604
# Percentage Difference:  -54.173268212212456 %
#
# ---------------------
