# %% [markdown]
# # **Title: VeggieTrend - Time Series Price Analysis of Vegetables and Fruits: Forecasting and Insights**

# %% [markdown]
# ![Screenshot 2023-07-11 114941.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Overview/Introduction:
# In this AI project, we dive into the fascinating world of time series analysis, focusing on the price evolution of major vegetables and fruits (specifically Ginger) in Nepal from 2013 to 2021. By harnessing the power of historical price data, we aim to unlock valuable insights that can aid in forecasting future prices, analyzing price trends and seasonality, identifying anomalies, and even developing effective pricing strategies. With the potential to benefit farmers, traders, and stakeholders in the agricultural sector, this project offers a comprehensive exploration of the dataset and showcases the capabilities of AI in addressing crucial challenges in the realm of agricultural commodities.
#
# ## Problem Statement:
# Accurate price forecasting and analysis of agricultural commodities are essential for informed decision-making, optimal resource allocation, and sustainable economic growth. However, the dynamic nature of vegetable and fruit prices, influenced by factors such as climate, market demand, and production conditions, presents a complex challenge. Traditional methods of analysis often fall short in capturing the intricate patterns and subtle variations inherent in time series data.
#
# To address this problem, we propose an AI-powered solution that utilizes advanced time series forecasting techniques and machine learning algorithms. By leveraging the wealth of historical price data, we aim to develop models capable of accurately predicting future prices, identifying trends and seasonality. These insights can empower stakeholders in the agricultural sector with the knowledge to make informed decisions, optimize pricing strategies, and navigate market fluctuations effectively.
#
# ## Objectives:
# 1. Forecast Future Prices: By applying time series forecasting models to the historical price data, we aim to predict future prices of vegetables and fruits in Nepal. This will enable stakeholders to anticipate market trends, plan production, and optimize their pricing strategies accordingly.
#
# 2. Analyze Price Trends and Seasonality: Leveraging time series analysis techniques, we aim to uncover underlying patterns, trends, and seasonality in the price data. This analysis will provide valuable insights into the cyclical nature of prices and help stakeholders adapt their strategies to capitalize on seasonal variations.
#
# 3. Develop Pricing Strategies: By exploring the relationships between different vegetable and fruit prices, we aim to develop machine learning models capable of suggesting effective pricing strategies for farmers and traders. These strategies can optimize revenue, maximize profitability, and enhance market competitiveness.
#
# By achieving these objectives, this AI project not only demonstrates the capabilities of advanced analytical techniques but also provides valuable insights and tools that can drive informed decision-making, promote sustainability in the agricultural sector, and ultimately contribute to the overall economic growth and well-being of Nepal.
#
# **Dataset URL:**
# https://www.kaggle.com/datasets/ramkrijal/agriculture-vegetables-fruits-time-series-prices

# %% [markdown]
# ## Technologies Used:
#
# The AI project utilizes several technologies to analyze and forecast the time series price of vegetables and fruits (specifically Ginger). These technologies include:
#
# - **Python**: The project is implemented in Python, a versatile and widely-used programming language known for its simplicity and rich ecosystem of libraries and tools.
#
# - **Pandas**: The Pandas library is employed for data manipulation and analysis. It provides powerful data structures, such as DataFrames, to handle time series data efficiently.
#
# - **NumPy**: NumPy is used for numerical computations and handling arrays. It enables efficient storage and manipulation of large numerical datasets.
#
# - **Matplotlib**: Matplotlib is employed for data visualization. It provides a flexible and comprehensive set of tools for creating informative plots and charts.
#
# - **TensorFlow**: TensorFlow, an open-source machine learning framework, is utilized to build and train deep learning models. It offers a high-level API, Keras, which simplifies the implementation of complex neural networks.
#
# - **CSV**: The project reads data from CSV files, a common format for storing structured data. The CSV module in Python is used to read and parse the data from the files.
#
# ## Methodology:
#
# The project follows a systematic methodology to analyze and forecast the time series price of vegetables and fruits. The methodology involves the following steps:
#
# 1. **Data Import and Preprocessing**: The project starts by importing the dataset using the Pandas library. The data is parsed and transformed to ensure it is in the appropriate format for analysis. Missing values and duplicates are handled, and irrelevant columns are dropped to focus on the relevant data.
#
# 2. **Data Exploration and Visualization**: The project explores the dataset by visualizing the time series price data using Matplotlib. This step helps to understand the patterns, trends, and seasonality present in the data, providing insights into the behavior of vegetable and fruit prices over time.
#
# 3. **Feature Preparation**: To train machine learning models, the project prepares the features and labels. A windowed dataset is generated, where each window represents a sequence of time steps. This allows the models to learn from the historical patterns and make predictions.
#
# 4. **Model Building**: The project builds various models to forecast future prices. Different models, including Dense, SimpleRNN, Bi-directional LSTM, and Conv1D + LSTM, are implemented using TensorFlow's Keras API. These models capture different aspects of the time series data and employ deep learning techniques to make accurate predictions.
#
# 5. **Model Training and Evaluation**: The models are trained using the prepared dataset, and their performance is evaluated. The training process involves optimizing the model parameters using the provided loss function and optimizer. The evaluation metrics, such as mean absolute error (MAE), mean squared error (MSE), root mean squared error (RMSE), mean absolute percentage error (MAPE), mean absolute scaled error (MASE), and R-squared (R2) are computed to assess the models' performance.
#
# 6. **Forecasting and Visualization**: The trained models are used to generate predictions for the validation dataset. The forecasted results are visualized alongside the actual prices to observe the model's accuracy and effectiveness in capturing the underlying patterns and trends.
#
# 7. **Model Comparison**: The project compares the performance of different models based on the evaluation metrics. This allows for an informed selection of the most suitable model for the given dataset and forecasting task.
#
# ## Implementation:
#
# The project implements the aforementioned methodology using the Python programming language and various libraries and frameworks. It leverages the capabilities of Pandas for data manipulation, Matplotlib for data visualization, and TensorFlow for building and training deep learning models. The dataset is imported, preprocessed, and explored to gain insights into the time series price data. Different models, including Dense, SimpleRNN, Bi-directional LSTM, and Conv1D + LSTM, are constructed using TensorFlow's Keras API. The models are trained, evaluated, and used to generate predictions for the validation dataset. The results are visualized to assess the models' performance and compare their forecasting abilities.
#
#
# ## Results:
#
# The performance of different models in forecasting the time series price of vegetables and fruits is evaluated using various metrics. The results obtained from the models are as follows:
#
# - Simple RNN: MAE = 2.908, MSE = 94.790, RMSE = 9.736, MAPE = 2.932, MASE = 1.214, R2 = 0.929.
# - Model_Dense1 (Dense Model): MAE = 2.981, MSE = 93.789, RMSE = 9.684, MAPE = 3.103, MASE = 1.245, R2 = 0.929.
# - Bi-LSTM: MAE = 3.782, MSE = 86.494, RMSE = 9.300, MAPE = 3.955, MASE = 1.579, R2 = 0.935.
# - Conv1D + LSTM: MAE = 4.061, MSE = 85.644, RMSE = 9.254, MAPE = 3.992, MASE = 1.696, R2 = 0.936.
# - Conv1D: MAE = 4.406, MSE = 93.219, RMSE = 9.655, MAPE = 4.719, MASE = 1.840, R2 = 0.930.
#
# ## Discussion/Interpretation:
#
# The evaluation metrics provide insights into the performance of each model in forecasting the time series price of vegetables and fruits. The Simple RNN model achieves the lowest MAE and exhibits a high R2 value, indicating accurate predictions and a good fit to the data. The Model_Dense1 (Dense Model) performs slightly worse but still provides reasonably accurate forecasts. The Bi-LSTM model outperforms the Conv1D + LSTM and Conv1D models. The Conv1D + LSTM and Conv1D models have higher MAE values, suggesting limitations in accurately forecasting future prices.
#
# ## Conclusion:
#
# The Simple RNN model emerges as the most accurate, effectively capturing the underlying patterns and dynamics of the price data. The Model_Dense1 (Dense Model) performs slightly worse but still offers reasonably accurate forecasts. The Bi-LSTM model outperforms the Conv1D + LSTM and Conv1D models. Deep learning models with recurrent layers, such as RNNs and LSTMs, are well-suited for capturing the temporal dependencies in time series data. Further experimentation and fine-tuning of the models may be required to improve their performance. Nonetheless, the results obtained from this AI project lay the foundation for employing advanced forecasting techniques in the agricultural domain, leading to informed decision-making and improved market competitiveness.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/agriculture-vegetables-fruits-time-series-prices/kalimati_tarkari_dataset.csv

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# The following code imports the pandas library and reads a CSV file containing agricultural data, parsing the dates and setting the date column as the index. It then displays the first few rows of the dataframe.

# %%
# Import with pandas
import pandas as pd
# Parse dates and set date column to index
df = pd.read_csv("/kaggle/input/agriculture-vegetables-fruits-time-series-prices/kalimati_tarkari_dataset.csv",
                 parse_dates=["Date"],
                 index_col=["Date"]) # parse the date column (tell pandas column 1 is a datetime)
df.head()
# Out:
#             SN            Commodity Unit  Minimum  Maximum  Average
# Date
# 2013-06-16   0   Tomato Big(Nepali)   Kg     35.0     40.0     37.5
# 2013-06-16   1  Tomato Small(Local)   Kg     26.0     32.0     29.0
# 2013-06-16   2           Potato Red   Kg     20.0     21.0     20.5
# 2013-06-16   3         Potato White   Kg     15.0     16.0     15.5
# 2013-06-16   4   Onion Dry (Indian)   Kg     28.0     30.0     29.0

# %%
# How many samples do we have?
len(df)
# Out:
# 197161

# %% [markdown]
# The next code calculates and prints the number of data points in the dataset. The subsequent code checks for duplicates in the dataset and prints the number of duplicates found. The code then checks for missing values in the dataset and prints the number of missing values in each column and the total number of missing values. After that, the code replaces empty strings with NaN values in the dataset and checks for missing values again, printing the updated counts.

# %%
import numpy as np

# How many data do we have?
print('There are', df.shape[0], 'data in this dataset')

# Do we have duplicates?
print('Number of Duplicates:', len(df[df.duplicated()]))

# Do we have missing values?
missing_values = df.isnull().sum()
print('Number of Missing Values by column:\n',missing_values)

print('Number of Missing Values:', df.isnull().sum().sum())

df.replace("", np.nan, inplace=True)
missing_values = df.isnull().sum()
print('Number of Missing Values by column after replacement:\n',missing_values)
print('Number of Missing Values after replacement:', df.isnull().sum().sum())
# Out:
# There are 197161 data in this dataset
# Number of Duplicates: 0
# Number of Missing Values by column:
#  SN           0
# Commodity    0
# Unit         0
# Minimum      0
# Maximum      0
# Average      0
# dtype: int64
# Number of Missing Values: 0
# Number of Missing Values by column after replacement:
#  SN           0
# Commodity    0
# Unit         0
# Minimum      0
# Maximum      0
# Average      0
# dtype: int64
# Number of Missing Values after replacement: 0

# %% [markdown]
# The next code converts the 'Commodity' column in the dataframe to string data type.

# %%
# Commodity is string value
df['Commodity'] = df['Commodity'].astype(str)

# %% [markdown]
# Now we will find the top 10 commodities based on their frequency in the dataset.

# %%
top_commodities = df['Commodity'].value_counts().nlargest(10).index.tolist()
top_commodities
# Out:
# ['Ginger',
#  'Cauli Local',
#  'Cabbage(Local)',
#  'Chilli Dry',
#  'Raddish White(Local)',
#  'Potato Red',
#  'Bamboo Shoot',
#  'Banana',
#  'Brd Leaf Mustard',
#  'Onion Dry (Indian)']

# %% [markdown]
# The next code filters the dataframe to include only data for the commodity 'Ginger', drops the 'Commodity' column, and displays the first few rows of the resulting dataframe.

# %%
df = df[df.Commodity == 'Ginger']
df.drop(['Commodity'],1,inplace=True)
df.head()
# Out:
# /tmp/ipykernel_33/1055044532.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(['Commodity'],1,inplace=True)
#              SN Unit  Minimum  Maximum  Average
# Date
# 2013-06-16   63   Kg    140.0    150.0    145.0
# 2013-06-17  136   Kg    140.0    150.0    145.0
# 2013-06-18  209   Kg    140.0    150.0    145.0
# 2013-06-19  282   Kg    140.0    150.0    145.0
# 2013-06-20  356   Kg    140.0    150.0    145.0

# %% [markdown]
# The code retrieves the first and last dates from the index of the dataframe and combines them into a single string representing the date range.

# %%
# get the first and last date from the index
first_date = df.index.min().strftime('%Y-%m-%d')
last_date = df.index.max().strftime('%Y-%m-%d')

# combine the dates into a single string
date_range = f"{first_date} to {last_date}"
date_range
# Out:
# '2013-06-16 to 2021-05-13'

# %% [markdown]
# The code imports the matplotlib.pyplot library and plots a line graph of the 'Average' values from the dataframe against the corresponding dates. The title of the graph includes the date range.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Average'])
plt.title(f"values from from {date_range}", fontsize=16)
plt.xlabel('Datetime')
plt.ylabel('Average')
plt.show()

# %% [markdown]
# The code plots three lines representing the 'Minimum', 'Maximum', and 'Average' values from the dataframe against the corresponding dates. The graph includes a legend and a title with the date range.

# %%
plt.figure(figsize=(10, 6))

plt.plot(df.index, df['Minimum'], label='Minimum', color='blue')
plt.plot(df.index, df['Maximum'], label='Maximum', color='red')
plt.plot(df.index, df['Average'], label='Average', color='green')

plt.title(f"Values from from {date_range}", fontsize=16)
plt.xlabel('Datetime')
plt.ylabel('Value')
plt.legend()

plt.show()

# %%
df.describe().T
# Out:
#           count          mean           std   min      25%      50%       75%  \
# SN       2751.0  96566.304980  55248.032724  63.0  49246.5  97449.0  142316.0
# Minimum  2751.0     94.552526     46.527842  40.0     55.0     80.0     120.0
# Maximum  2751.0    103.842239     47.507196  45.0     60.0     90.0     130.0
# Average  2751.0     99.197383     46.998827  42.5     57.5     85.0     125.0
#
#               max
# SN       197146.0
# Minimum     280.0
# Maximum     290.0
# Average     285.0

# %% [markdown]
# **Utilities**
#
# The code defines a function named 'plot_series' that visualizes time series data. It takes the time steps, series measurements, line format, start and end time steps as arguments. The function plots the time series data and labels the axes.

# %%
def plot_series(time, series, format="-", start=0, end=None):
    """
    Visualizes time series data

    Args:
      time (array of int) - contains the time steps
      series (array of int) - contains the measurements for each time step
      format - line style when plotting the graph
      start - first time step to plot
      end - last time step to plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))

    if type(series) is tuple:

      for series_num in series:
        # Plot the time series data
        plt.plot(time[start:end], series_num[start:end], format)

    else:
      # Plot the time series data
      plt.plot(time[start:end], series[start:end], format)

    # Label the x-axis
    plt.xlabel("Time")

    # Label the y-axis
    plt.ylabel("Value")

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

# %% [markdown]
# **Import Data with Python**
#
# The code imports the csv module and opens a CSV file. It reads the first row (header) of the CSV file and prints the column names. It also finds the indices of columns with specific names ('Date', 'Commodity', 'Average') and prints the corresponding indices.

# %%
import csv

# Open the CSV file
with open("/kaggle/input/agriculture-vegetables-fruits-time-series-prices/kalimati_tarkari_dataset.csv", "r") as f:

    # Create a CSV reader object
    reader = csv.reader(f)

    # Read the first row (header) of the CSV file
    header = next(reader)

    # Print the column names
    print(header)

    # Find the indices of columns with names "Date" and "Close"
    date_index = header.index("Date")
    cm_index = header.index("Commodity")
    avg_index = header.index("Average")

    # Print the indices for columns "Date" and "Close"
    print("Index for column 'Date':", date_index)
    print("Index for column 'Commodity':", cm_index)
    print("Index for column 'Average':", avg_index)
# Out:
# ['SN', 'Commodity', 'Date', 'Unit', 'Minimum', 'Maximum', 'Average']
# Index for column 'Date': 2
# Index for column 'Commodity': 1
# Index for column 'Average': 6

# %% [markdown]
# The code imports the csv module and datetime module. It reads the CSV file and retrieves the 'Ginger' commodity data by extracting the dates and average prices. It converts the dates to datetime objects and the average prices to float values. It then prints the first 10 entries of the dates and average prices.

# %%
import csv
from datetime import datetime

time = []
series = []

with open("/kaggle/input/agriculture-vegetables-fruits-time-series-prices/kalimati_tarkari_dataset.csv", "r") as f:
  csv_reader = csv.reader(f, delimiter=",") # read in the target CSV
  next(csv_reader) # skip first line (this gets rid of the column titles)
  for line in csv_reader:
    if line[cm_index] == 'Ginger':
        time.append(datetime.strptime(line[date_index], "%Y-%m-%d")) # get the dates as dates (not strings), strptime = string parse time
        series.append(float(line[avg_index])) # get the average price as float

# View first 10 of each
time[:10], series[:10]
# Out:
# ([datetime.datetime(2013, 6, 16, 0, 0),
#   datetime.datetime(2013, 6, 17, 0, 0),
#   datetime.datetime(2013, 6, 18, 0, 0),
#   datetime.datetime(2013, 6, 19, 0, 0),
#   datetime.datetime(2013, 6, 20, 0, 0),
#   datetime.datetime(2013, 6, 21, 0, 0),
#   datetime.datetime(2013, 6, 25, 0, 0),
#   datetime.datetime(2013, 6, 26, 0, 0),
#   datetime.datetime(2013, 6, 27, 0, 0),
#   datetime.datetime(2013, 6, 28, 0, 0)],
#  [145.0, 145.0, 145.0, 145.0, 145.0, 135.0, 145.0, 135.0, 135.0, 135.0])

# %% [markdown]
# **Split the Dataset**
#
# The code defines the split ratio and calculates the split time based on the series length. It splits the time and series data into training and validation sets.

# %%
# Define the split time
split_ratio = 0.8  # 80% for the training set
split_time = int(len(series) * split_ratio)

# Get the train set
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

# %%
time_train[:2], x_train[:2], time_valid[:2], x_valid[:2]
# Out:
# ([datetime.datetime(2013, 6, 16, 0, 0), datetime.datetime(2013, 6, 17, 0, 0)],
#  [145.0, 145.0],
#  [datetime.datetime(2019, 10, 31, 0, 0), datetime.datetime(2019, 11, 1, 0, 0)],
#  [145.0, 145.0])

# %%
len(time_train), len(x_train), len(time_valid), len(x_valid),
# Out:
# (2200, 2200, 551, 551)

# %% [markdown]
# The code displays a plot showing the train-test split of the time series data, with the training data in orange and the test data in purple. The plot is labeled with the date and value axes.

# %%
#displays a plot of the train/test split
fig = plt.figure(figsize=(15,5))
plt.plot(time_train, x_train, color='orange', label='Train Data')
plt.plot(time_valid, x_valid, color='purple', label='Test Data')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Train-Test Split')
plt.legend()
plt.show()

# %% [markdown]
# **Prepare Features and Labels**

# %% [markdown]
# The next code block defines the parameters for creating windowed datasets for time series analysis. It specifies the window size, batch size, and shuffle buffer size.

# %%
# Parameters
window_size = 7
batch_size = 32
shuffle_buffer_size = 1000

# %% [markdown]
# The windowed_dataset function generates a TensorFlow Dataset object containing time windows. It takes the series data, window size, batch size, and shuffle buffer size as inputs and returns the dataset.

# %%
import tensorflow as tf

def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    dataset = dataset.shuffle(shuffle_buffer)

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)

    return dataset

# %% [markdown]
# The code block generates the dataset windows for the training set using the windowed_dataset function.

# %%
# Generate the dataset windows
dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# The next code block generates data windows for the validation set using the windowed_dataset function.

# %%
# Generate data windows of the validation set
val_set = windowed_dataset(x_valid, window_size, batch_size, shuffle_buffer_size)

# %%
dataset, val_set
# Out:
# (<_PrefetchDataset element_spec=(TensorSpec(shape=(None, None), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>,
#  <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>)

# %% [markdown]
# The code block prints the shape of a sample batch from the training dataset, showing the shape of the input features and labels.

# %%
for a,b in dataset.take(1):
    print(a.shape)
    print(b.shape)
# Out:
# (32, 7)
# (32,)

# %% [markdown]
# The code block prints the shape of a sample batch from the validation dataset, showing the shape of the input features and labels.

# %%
for c,d in val_set.take(1):
    print(c.shape)
    print(d.shape)
# Out:
# (32, 7)
# (32,)

# %% [markdown]
# **Model: Dense**
#
# The following code block builds a baseline model using the Sequential API of TensorFlow's Keras module. The model consists of three dense layers with 32, 16, and 1 units, respectively, and ReLU activation. It then prints a summary of the model, which provides an overview of the model's architecture and the number of parameters.

# %%
tf.random.set_seed(42)

# Build the model
model_baseline = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, input_shape=[window_size], activation="relu"),
    tf.keras.layers.Dense(16, activation="relu"),
    tf.keras.layers.Dense(1)
])

# Print the model summary
model_baseline.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                256
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 801
# Trainable params: 801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The next code block imports necessary modules for defining the loss function (Huber) and optimizer (Adam). It sets the training parameters for the baseline model by specifying the loss function, optimizer, and metrics (mean absolute error).

# %%
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam

# Set the training parameters
model_baseline.compile(
    loss=Huber(),
    optimizer=Adam(),
    metrics=['mae']
)

# %% [markdown]
# The code block trains the baseline model using the fit method, providing the training dataset (dataset) and the validation dataset (val_set) as input, and specifying the number of epochs.

# %%
# Train the model
model_baseline.fit(dataset,validation_data=val_set, epochs=100)
# Out:
# Epoch 1/100
# 69/69 [==============================] - 2s 10ms/step - loss: 13.8980 - mae: 14.3488 - val_loss: 3.8231 - val_mae: 4.1088
# Epoch 2/100
# 69/69 [==============================] - 0s 5ms/step - loss: 3.0547 - mae: 3.4557 - val_loss: 3.8535 - val_mae: 4.3248
# Epoch 3/100
# 69/69 [==============================] - 0s 5ms/step - loss: 3.0118 - mae: 3.4385 - val_loss: 3.3809 - val_mae: 3.6695
# Epoch 4/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.6717 - mae: 3.0596 - val_loss: 3.2425 - val_mae: 3.5042
# Epoch 5/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.5399 - mae: 2.8912 - val_loss: 3.3044 - val_mae: 3.7239
# Epoch 6/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.5102 - mae: 2.8627 - val_loss: 3.1841 - val_mae: 3.4907
# Epoch 7/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.4577 - mae: 2.8078 - val_loss: 3.3203 - val_mae: 3.7666
# Epoch 8/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.5603 - mae: 2.9317 - val_loss: 3.9274 - val_mae: 4.4092
# Epoch 9/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.5290 - mae: 2.9252 - val_loss: 3.1610 - val_mae: 3.5769
# Epoch 10/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.4213 - mae: 2.7998 - val_loss: 3.0854 - val_mae: 3.4581
# Epoch 11/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.4468 - mae: 2.8365 - val_loss: 3.4478 - val_mae: 3.9194
# Epoch 12/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.3467 - mae: 2.6920 - val_loss: 3.7167 - val_mae: 4.1982
# Epoch 13/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.4287 - mae: 2.8223 - val_loss: 3.1540 - val_mae: 3.5982
# Epoch 14/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.3207 - mae: 2.6823 - val_loss: 3.5141 - val_mae: 3.9885
# Epoch 15/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.3511 - mae: 2.7325 - val_loss: 3.9370 - val_mae: 4.4218
# Epoch 16/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.3923 - mae: 2.7714 - val_loss: 2.9295 - val_mae: 3.2497
# Epoch 17/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.2500 - mae: 2.5935 - val_loss: 2.9809 - val_mae: 3.3894
# Epoch 18/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.2427 - mae: 2.5967 - val_loss: 2.9990 - val_mae: 3.4160
# Epoch 19/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.1928 - mae: 2.5219 - val_loss: 2.8715 - val_mae: 3.2294
# Epoch 20/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.1808 - mae: 2.5296 - val_loss: 2.9523 - val_mae: 3.3758
# Epoch 21/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.2550 - mae: 2.6278 - val_loss: 3.8311 - val_mae: 4.3152
# Epoch 22/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.1772 - mae: 2.5120 - val_loss: 2.9726 - val_mae: 3.4139
# Epoch 23/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.1635 - mae: 2.5066 - val_loss: 2.7560 - val_mae: 3.0810
# Epoch 24/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.1252 - mae: 2.4649 - val_loss: 2.7268 - val_mae: 3.0442
# Epoch 25/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.1386 - mae: 2.4862 - val_loss: 2.9038 - val_mae: 3.3447
# Epoch 26/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.1127 - mae: 2.4555 - val_loss: 3.1989 - val_mae: 3.6738
# Epoch 27/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.1063 - mae: 2.4522 - val_loss: 2.6671 - val_mae: 2.9595
# Epoch 28/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.0539 - mae: 2.3696 - val_loss: 2.8023 - val_mae: 3.2233
# Epoch 29/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.0362 - mae: 2.3527 - val_loss: 2.6259 - val_mae: 2.8517
# Epoch 30/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.1483 - mae: 2.5174 - val_loss: 2.7073 - val_mae: 3.1030
# Epoch 31/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.0407 - mae: 2.3718 - val_loss: 2.6183 - val_mae: 2.8713
# Epoch 32/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.0208 - mae: 2.3410 - val_loss: 2.6314 - val_mae: 2.9405
# Epoch 33/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.1570 - mae: 2.5391 - val_loss: 3.3269 - val_mae: 3.8123
# Epoch 34/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.0962 - mae: 2.4448 - val_loss: 2.8304 - val_mae: 3.2789
# Epoch 35/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.0025 - mae: 2.3041 - val_loss: 2.5973 - val_mae: 2.9048
# Epoch 36/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.0319 - mae: 2.3608 - val_loss: 2.5525 - val_mae: 2.8258
# Epoch 37/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9975 - mae: 2.3090 - val_loss: 2.7851 - val_mae: 3.2308
# Epoch 38/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.0161 - mae: 2.3478 - val_loss: 2.5960 - val_mae: 2.9613
# Epoch 39/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9889 - mae: 2.3019 - val_loss: 2.5639 - val_mae: 2.9027
# Epoch 40/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.0629 - mae: 2.4014 - val_loss: 2.9299 - val_mae: 3.3978
# Epoch 41/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9405 - mae: 2.2061 - val_loss: 2.5838 - val_mae: 2.9264
# Epoch 42/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.0024 - mae: 2.3225 - val_loss: 2.4973 - val_mae: 2.7011
# Epoch 43/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.0665 - mae: 2.4220 - val_loss: 2.7240 - val_mae: 3.1658
# Epoch 44/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9453 - mae: 2.2411 - val_loss: 2.5043 - val_mae: 2.7977
# Epoch 45/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9901 - mae: 2.3197 - val_loss: 2.4599 - val_mae: 2.6983
# Epoch 46/100
# 69/69 [==============================] - 0s 5ms/step - loss: 2.0071 - mae: 2.3145 - val_loss: 2.4849 - val_mae: 2.7074
# Epoch 47/100
# 69/69 [==============================] - 0s 3ms/step - loss: 1.9902 - mae: 2.3252 - val_loss: 2.9592 - val_mae: 3.4303
# Epoch 48/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9735 - mae: 2.2973 - val_loss: 2.4843 - val_mae: 2.7275
# Epoch 49/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9836 - mae: 2.2920 - val_loss: 2.8000 - val_mae: 3.2610
# Epoch 50/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9496 - mae: 2.2364 - val_loss: 2.6363 - val_mae: 3.0466
# Epoch 51/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9416 - mae: 2.2424 - val_loss: 2.5149 - val_mae: 2.8550
# Epoch 52/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9602 - mae: 2.2720 - val_loss: 2.5192 - val_mae: 2.7500
# Epoch 53/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9117 - mae: 2.1560 - val_loss: 2.5643 - val_mae: 2.9385
# Epoch 54/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9096 - mae: 2.1673 - val_loss: 2.5841 - val_mae: 2.9987
# Epoch 55/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9440 - mae: 2.2417 - val_loss: 2.4935 - val_mae: 2.8280
# Epoch 56/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9079 - mae: 2.1506 - val_loss: 2.4522 - val_mae: 2.6661
# Epoch 57/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9121 - mae: 2.1710 - val_loss: 2.4491 - val_mae: 2.6076
# Epoch 58/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9625 - mae: 2.2674 - val_loss: 2.4764 - val_mae: 2.7514
# Epoch 59/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9322 - mae: 2.1998 - val_loss: 2.4485 - val_mae: 2.6941
# Epoch 60/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9136 - mae: 2.1679 - val_loss: 2.4346 - val_mae: 2.5873
# Epoch 61/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.0543 - mae: 2.3918 - val_loss: 2.5323 - val_mae: 2.9121
# Epoch 62/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.0775 - mae: 2.4490 - val_loss: 2.7712 - val_mae: 3.2313
# Epoch 63/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.0566 - mae: 2.3772 - val_loss: 2.4553 - val_mae: 2.6478
# Epoch 64/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9854 - mae: 2.2683 - val_loss: 2.4789 - val_mae: 2.7518
# Epoch 65/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.0152 - mae: 2.3514 - val_loss: 2.4378 - val_mae: 2.6141
# Epoch 66/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9576 - mae: 2.2611 - val_loss: 2.4782 - val_mae: 2.8002
# Epoch 67/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9202 - mae: 2.1790 - val_loss: 2.4473 - val_mae: 2.7054
# Epoch 68/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.8897 - mae: 2.1260 - val_loss: 2.4740 - val_mae: 2.6441
# Epoch 69/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9527 - mae: 2.2483 - val_loss: 2.6198 - val_mae: 3.0474
# Epoch 70/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9132 - mae: 2.1629 - val_loss: 2.5349 - val_mae: 2.9033
# Epoch 71/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9685 - mae: 2.2659 - val_loss: 2.5441 - val_mae: 2.9238
# Epoch 72/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9281 - mae: 2.2038 - val_loss: 2.4598 - val_mae: 2.6706
# Epoch 73/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9156 - mae: 2.1759 - val_loss: 2.4898 - val_mae: 2.8164
# Epoch 74/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9178 - mae: 2.1861 - val_loss: 2.4488 - val_mae: 2.7056
# Epoch 75/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9270 - mae: 2.1973 - val_loss: 2.5203 - val_mae: 2.8678
# Epoch 76/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9436 - mae: 2.2398 - val_loss: 2.5772 - val_mae: 2.9759
# Epoch 77/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9454 - mae: 2.2499 - val_loss: 2.4607 - val_mae: 2.7044
# Epoch 78/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.8880 - mae: 2.1125 - val_loss: 2.4888 - val_mae: 2.7782
# Epoch 79/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.8886 - mae: 2.1164 - val_loss: 2.5042 - val_mae: 2.7709
# Epoch 80/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9110 - mae: 2.1803 - val_loss: 2.4533 - val_mae: 2.6725
# Epoch 81/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9568 - mae: 2.2444 - val_loss: 2.4311 - val_mae: 2.5985
# Epoch 82/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.8874 - mae: 2.1031 - val_loss: 2.4997 - val_mae: 2.8065
# Epoch 83/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9654 - mae: 2.2746 - val_loss: 2.4760 - val_mae: 2.7921
# Epoch 84/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.0099 - mae: 2.3228 - val_loss: 2.4276 - val_mae: 2.6546
# Epoch 85/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9811 - mae: 2.2946 - val_loss: 2.6591 - val_mae: 3.1025
# Epoch 86/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.0326 - mae: 2.3584 - val_loss: 2.5505 - val_mae: 2.9151
# Epoch 87/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9475 - mae: 2.2099 - val_loss: 2.5096 - val_mae: 2.8588
# Epoch 88/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9696 - mae: 2.2603 - val_loss: 2.4424 - val_mae: 2.6002
# Epoch 89/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9022 - mae: 2.1596 - val_loss: 2.4639 - val_mae: 2.7359
# Epoch 90/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9333 - mae: 2.2259 - val_loss: 2.6024 - val_mae: 3.0129
# Epoch 91/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9067 - mae: 2.1530 - val_loss: 2.4754 - val_mae: 2.7329
# Epoch 92/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9457 - mae: 2.2421 - val_loss: 2.7793 - val_mae: 3.2398
# Epoch 93/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9236 - mae: 2.1979 - val_loss: 2.4409 - val_mae: 2.5943
# Epoch 94/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9392 - mae: 2.2322 - val_loss: 3.1267 - val_mae: 3.6178
# Epoch 95/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9838 - mae: 2.3194 - val_loss: 2.5692 - val_mae: 2.9729
# Epoch 96/100
# 69/69 [==============================] - 0s 4ms/step - loss: 2.0187 - mae: 2.3499 - val_loss: 2.4506 - val_mae: 2.7356
# Epoch 97/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.8941 - mae: 2.1250 - val_loss: 2.5368 - val_mae: 2.9254
# Epoch 98/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9899 - mae: 2.3149 - val_loss: 2.4572 - val_mae: 2.6359
# Epoch 99/100
# 69/69 [==============================] - 0s 5ms/step - loss: 1.9184 - mae: 2.1894 - val_loss: 2.4416 - val_mae: 2.6905
# Epoch 100/100
# 69/69 [==============================] - 0s 4ms/step - loss: 1.9679 - mae: 2.2572 - val_loss: 2.5887 - val_mae: 3.0090

# %% [markdown]
# After training the model, the code block evaluates the model's performance on the validation dataset using the evaluate method, which returns the loss and metrics values.

# %%
# Evaluate model on test data
model_baseline.evaluate(val_set)
# Out:
# 17/17 [==============================] - 0s 2ms/step - loss: 2.5887 - mae: 3.0090
# [2.5886943340301514, 3.0090320110321045]

# %% [markdown]
# The code uses the trained model to generate predictions on the validation dataset and assigns the predictions to the model_1_preds variable.

# %%
model_1_preds = model_baseline.predict(val_set)
model_1_preds.shape
# Out:
# 17/17 [==============================] - 0s 2ms/step
# (544, 1)

# %% [markdown]
# The next code block defines the model_forecast function, which takes a trained model, a time series, window size, and batch size as inputs, and returns the model's predictions on the input data. It uses TensorFlow's Dataset API to prepare the input data and generates predictions using the trained model.

# %%
def model_forecast(model, series, window_size, batch_size):
    """Uses an input model to generate predictions on data windows

    Args:
      model (TF Keras Model) - model that accepts data windows
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the window
      batch_size (int) - the batch size

    Returns:
      forecast (numpy array) - array containing predictions
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda w: w.batch(window_size))

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)

    # Get predictions on the entire dataset
    forecast = model.predict(dataset)

    return forecast

# %% [markdown]
# The code block reduces the original series by selecting a subset of data from the validation set for forecasting. It then calls the model_forecast function to generate predictions using the baseline model and the reduced series. The predictions are stored in the forecast variable. Next, the code block drops the single-dimensional axis from the forecast and the original validation data. It then plots the results, showing the actual values (x_valid) and the predicted values (results) against time.

# %%
# Reduce the original series
forecast_series = series[split_time - window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model_baseline, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 18/18 [==============================] - 0s 4ms/step

# %% [markdown]
# The code block defines several evaluation metrics functions, including mean absolute scaled error (MASE), R-squared, and metrics for evaluating predictions. These functions are used to evaluate the performance of the model.

# %%
# MASE implemented courtesy of sktime - https://github.com/alan-turing-institute/sktime/blob/ee7a06843a44f4aaec7582d847e36073a9ab0566/sktime/performance_metrics/forecasting/_functions.py#L16
def mean_absolute_scaled_error(y_true, y_pred):
  """
  Implement MASE (assuming no seasonality of data).
  """
  mae = tf.reduce_mean(tf.abs(y_true - y_pred))

  # Find MAE of naive forecast (no seasonality)
  mae_naive_no_season = tf.reduce_mean(tf.abs(y_true[1:] - y_true[:-1])) # our seasonality is 1 day (hence the shifting of 1 day)

  return mae / mae_naive_no_season

def r_squared(y_true, y_pred):
    residual = tf.reduce_sum(tf.square(tf.subtract(y_true, y_pred)))
    total = tf.reduce_sum(tf.square(tf.subtract(y_true, tf.reduce_mean(y_true))))
    r2 = tf.subtract(1.0, tf.divide(residual, total))
    return r2

def evaluate_preds(y_true, y_pred):
  # Make sure float32 (for metric calculations)
  y_true = tf.cast(y_true, dtype=tf.float32)
  y_pred = tf.cast(y_pred, dtype=tf.float32)

  # Calculate various metrics
  mae = tf.keras.metrics.mean_absolute_error(y_true, y_pred)
  mse = tf.keras.metrics.mean_squared_error(y_true, y_pred)
  rmse = tf.sqrt(mse)
  mape = tf.keras.metrics.mean_absolute_percentage_error(y_true, y_pred)
  mase = mean_absolute_scaled_error(y_true, y_pred)
  r2 = r_squared(y_true, y_pred)

  # Account for different sized metrics (for longer horizons, reduce to single number)
  if mae.ndim > 0: # if mae isn't already a scalar, reduce it to one by aggregating tensors to mean
    mae = tf.reduce_mean(mae)
    mse = tf.reduce_mean(mse)
    rmse = tf.reduce_mean(rmse)
    mape = tf.reduce_mean(mape)
    mase = tf.reduce_mean(mase)

  return {"mae": mae.numpy(),
          "mse": mse.numpy(),
          "rmse": rmse.numpy(),
          "mape": mape.numpy(),
          "mase": mase.numpy(),
          "r2": r2.numpy()}  # Add R2 score

# %% [markdown]
# The code block calculates and prints the evaluation metrics for the baseline model's predictions on the validation data.

# %%
# Evaluate preds
results_baseline = evaluate_preds(y_true=x_valid, # reduce to right shape
                                 y_pred=results)
results_baseline
# Out:
# {'mae': 2.9807944,
#  'mse': 93.788734,
#  'rmse': 9.684459,
#  'mape': 3.1033626,
#  'mase': 1.2448268,
#  'r2': 0.92944795}

# %%
# Find average temp in test dataset
tf.reduce_mean(x_valid).numpy()
# Out:
# 107.77405

# %% [markdown]
# **Model: SimpleRNN**
#
# The next code block builds a model using a simple RNN (recurrent neural network) architecture. The model includes two layers of SimpleRNN cells with 256 and 128 units, respectively. It also includes a Dense layer with 1 unit for the output. The model is compiled with the Huber loss function, Adam optimizer, and mean absolute error (MAE) metric. The code next trains the RNN model using the fit method, providing the training dataset (dataset) and the validation dataset (val_set) as input, and specifying the number of epochs.

# %%
# Build the model
model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[window_size]),
  tf.keras.layers.SimpleRNN(256, return_sequences=True),
  tf.keras.layers.SimpleRNN(128),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100.0)
])

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(), optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), metrics=['mae'])

# Train the model
history = model.fit(dataset,epochs=100, validation_data=val_set)
# Out:
# Epoch 1/100
# 69/69 [==============================] - 3s 15ms/step - loss: 11.3568 - mae: 11.8392 - val_loss: 4.1851 - val_mae: 4.6492
# Epoch 2/100
# 69/69 [==============================] - 1s 11ms/step - loss: 4.5476 - mae: 5.0145 - val_loss: 3.4208 - val_mae: 3.8513
# Epoch 3/100
# 69/69 [==============================] - 1s 14ms/step - loss: 3.3683 - mae: 3.8144 - val_loss: 7.8729 - val_mae: 8.3697
# Epoch 4/100
# 69/69 [==============================] - 1s 11ms/step - loss: 4.6145 - mae: 5.0993 - val_loss: 3.0414 - val_mae: 3.4370
# Epoch 5/100
# 69/69 [==============================] - 1s 11ms/step - loss: 3.3105 - mae: 3.7689 - val_loss: 3.2436 - val_mae: 3.7073
# Epoch 6/100
# 69/69 [==============================] - 1s 12ms/step - loss: 3.9019 - mae: 4.3621 - val_loss: 3.6613 - val_mae: 4.1528
# Epoch 7/100
# 69/69 [==============================] - 1s 11ms/step - loss: 3.5690 - mae: 4.0379 - val_loss: 3.5249 - val_mae: 4.0152
# Epoch 8/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.7685 - mae: 3.2116 - val_loss: 2.7071 - val_mae: 3.1163
# Epoch 9/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.3927 - mae: 2.8018 - val_loss: 2.5772 - val_mae: 2.9218
# Epoch 10/100
# 69/69 [==============================] - 1s 11ms/step - loss: 3.3040 - mae: 3.7705 - val_loss: 4.9803 - val_mae: 5.4785
# Epoch 11/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.6242 - mae: 3.0599 - val_loss: 3.2103 - val_mae: 3.7027
# Epoch 12/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.4620 - mae: 2.8681 - val_loss: 2.4442 - val_mae: 2.7171
# Epoch 13/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.2080 - mae: 2.5776 - val_loss: 2.5222 - val_mae: 2.8916
# Epoch 14/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.5587 - mae: 2.9784 - val_loss: 4.8127 - val_mae: 5.3120
# Epoch 15/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.7060 - mae: 3.1344 - val_loss: 3.9425 - val_mae: 4.4373
# Epoch 16/100
# 69/69 [==============================] - 1s 12ms/step - loss: 3.0341 - mae: 3.4970 - val_loss: 2.8395 - val_mae: 3.3131
# Epoch 17/100
# 69/69 [==============================] - 1s 14ms/step - loss: 2.2921 - mae: 2.6933 - val_loss: 2.5941 - val_mae: 2.9890
# Epoch 18/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.2794 - mae: 2.6615 - val_loss: 3.9216 - val_mae: 4.4173
# Epoch 19/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.6156 - mae: 3.0646 - val_loss: 2.7873 - val_mae: 3.2625
# Epoch 20/100
# 69/69 [==============================] - 1s 12ms/step - loss: 2.3300 - mae: 2.7449 - val_loss: 3.4968 - val_mae: 3.9934
# Epoch 21/100
# 69/69 [==============================] - 1s 12ms/step - loss: 2.5995 - mae: 3.0353 - val_loss: 4.3385 - val_mae: 4.8366
# Epoch 22/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.2791 - mae: 2.6634 - val_loss: 2.5693 - val_mae: 3.0205
# Epoch 23/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.1417 - mae: 2.5224 - val_loss: 2.5866 - val_mae: 3.0357
# Epoch 24/100
# 69/69 [==============================] - 1s 12ms/step - loss: 2.4043 - mae: 2.8384 - val_loss: 2.4370 - val_mae: 2.7387
# Epoch 25/100
# 69/69 [==============================] - 1s 10ms/step - loss: 2.2862 - mae: 2.6943 - val_loss: 3.1163 - val_mae: 3.6122
# Epoch 26/100
# 69/69 [==============================] - 1s 10ms/step - loss: 2.4262 - mae: 2.8567 - val_loss: 2.3978 - val_mae: 2.6797
# Epoch 27/100
# 69/69 [==============================] - 1s 10ms/step - loss: 2.3382 - mae: 2.7235 - val_loss: 2.8242 - val_mae: 3.3123
# Epoch 28/100
# 69/69 [==============================] - 1s 9ms/step - loss: 2.0973 - mae: 2.4579 - val_loss: 2.3522 - val_mae: 2.5767
# Epoch 29/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.2809 - mae: 2.6924 - val_loss: 2.6944 - val_mae: 3.1775
# Epoch 30/100
# 69/69 [==============================] - 1s 12ms/step - loss: 2.6101 - mae: 3.0532 - val_loss: 3.0414 - val_mae: 3.5275
# Epoch 31/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.3919 - mae: 2.8173 - val_loss: 2.3687 - val_mae: 2.6269
# Epoch 32/100
# 69/69 [==============================] - 1s 12ms/step - loss: 2.1079 - mae: 2.4543 - val_loss: 2.5843 - val_mae: 3.0524
# Epoch 33/100
# 69/69 [==============================] - 1s 12ms/step - loss: 2.0347 - mae: 2.3825 - val_loss: 2.3577 - val_mae: 2.5694
# Epoch 34/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.1892 - mae: 2.5600 - val_loss: 3.6175 - val_mae: 4.1099
# Epoch 35/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.1816 - mae: 2.5683 - val_loss: 3.1149 - val_mae: 3.6095
# Epoch 36/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.9084 - mae: 3.3638 - val_loss: 4.5608 - val_mae: 5.0580
# Epoch 37/100
# 69/69 [==============================] - 1s 12ms/step - loss: 2.7781 - mae: 3.2275 - val_loss: 2.9016 - val_mae: 3.3762
# Epoch 38/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.7849 - mae: 3.2368 - val_loss: 3.1155 - val_mae: 3.6105
# Epoch 39/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.3707 - mae: 2.7778 - val_loss: 2.3953 - val_mae: 2.6692
# Epoch 40/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0586 - mae: 2.4052 - val_loss: 2.3944 - val_mae: 2.6572
# Epoch 41/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.1632 - mae: 2.5564 - val_loss: 2.5537 - val_mae: 3.0040
# Epoch 42/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.2042 - mae: 2.6161 - val_loss: 2.5985 - val_mae: 3.0601
# Epoch 43/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.1083 - mae: 2.4751 - val_loss: 2.4142 - val_mae: 2.7639
# Epoch 44/100
# 69/69 [==============================] - 1s 12ms/step - loss: 2.6941 - mae: 3.1510 - val_loss: 2.6688 - val_mae: 3.0178
# Epoch 45/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.1433 - mae: 2.5239 - val_loss: 2.3531 - val_mae: 2.5773
# Epoch 46/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0760 - mae: 2.4440 - val_loss: 2.3480 - val_mae: 2.5656
# Epoch 47/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0562 - mae: 2.3912 - val_loss: 2.3372 - val_mae: 2.5185
# Epoch 48/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.1744 - mae: 2.5226 - val_loss: 3.7930 - val_mae: 4.2913
# Epoch 49/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.2177 - mae: 2.6148 - val_loss: 3.0008 - val_mae: 3.4969
# Epoch 50/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0711 - mae: 2.3965 - val_loss: 2.8858 - val_mae: 3.3839
# Epoch 51/100
# 69/69 [==============================] - 1s 12ms/step - loss: 2.1428 - mae: 2.5205 - val_loss: 2.5492 - val_mae: 2.9867
# Epoch 52/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.1844 - mae: 2.5778 - val_loss: 2.3819 - val_mae: 2.6510
# Epoch 53/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.4733 - mae: 2.9094 - val_loss: 2.4046 - val_mae: 2.7140
# Epoch 54/100
# 69/69 [==============================] - 1s 12ms/step - loss: 2.0214 - mae: 2.3413 - val_loss: 2.3294 - val_mae: 2.4829
# Epoch 55/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.1072 - mae: 2.4729 - val_loss: 2.9494 - val_mae: 3.3995
# Epoch 56/100
# 69/69 [==============================] - 1s 12ms/step - loss: 2.2485 - mae: 2.6712 - val_loss: 2.4787 - val_mae: 2.8256
# Epoch 57/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.3102 - mae: 2.7034 - val_loss: 4.0078 - val_mae: 4.5042
# Epoch 58/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.6892 - mae: 3.1284 - val_loss: 2.4155 - val_mae: 2.7798
# Epoch 59/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0625 - mae: 2.4240 - val_loss: 2.5375 - val_mae: 2.9829
# Epoch 60/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0711 - mae: 2.4410 - val_loss: 2.9022 - val_mae: 3.3980
# Epoch 61/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.2843 - mae: 2.7053 - val_loss: 2.3301 - val_mae: 2.5180
# Epoch 62/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.1227 - mae: 2.4842 - val_loss: 2.4585 - val_mae: 2.8813
# Epoch 63/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.1096 - mae: 2.4860 - val_loss: 3.2234 - val_mae: 3.7211
# Epoch 64/100
# 69/69 [==============================] - 1s 12ms/step - loss: 1.9935 - mae: 2.3097 - val_loss: 2.3289 - val_mae: 2.5263
# Epoch 65/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.1762 - mae: 2.5772 - val_loss: 2.3432 - val_mae: 2.5829
# Epoch 66/100
# 69/69 [==============================] - 1s 11ms/step - loss: 1.9763 - mae: 2.2900 - val_loss: 2.3984 - val_mae: 2.6995
# Epoch 67/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0186 - mae: 2.3464 - val_loss: 2.6553 - val_mae: 3.0428
# Epoch 68/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.1073 - mae: 2.4608 - val_loss: 2.3431 - val_mae: 2.5606
# Epoch 69/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.2744 - mae: 2.6744 - val_loss: 3.4070 - val_mae: 3.9037
# Epoch 70/100
# 69/69 [==============================] - 1s 12ms/step - loss: 2.2872 - mae: 2.6805 - val_loss: 2.4602 - val_mae: 2.8747
# Epoch 71/100
# 69/69 [==============================] - 1s 11ms/step - loss: 1.9741 - mae: 2.2879 - val_loss: 2.3387 - val_mae: 2.5705
# Epoch 72/100
# 69/69 [==============================] - 1s 12ms/step - loss: 1.9862 - mae: 2.3152 - val_loss: 2.5500 - val_mae: 2.9746
# Epoch 73/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.5316 - mae: 2.9713 - val_loss: 3.4289 - val_mae: 3.9232
# Epoch 74/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.1534 - mae: 2.5397 - val_loss: 2.3634 - val_mae: 2.6676
# Epoch 75/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0070 - mae: 2.3325 - val_loss: 2.7914 - val_mae: 3.2738
# Epoch 76/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0354 - mae: 2.3993 - val_loss: 2.3942 - val_mae: 2.7366
# Epoch 77/100
# 69/69 [==============================] - 1s 12ms/step - loss: 2.2705 - mae: 2.6707 - val_loss: 2.3582 - val_mae: 2.5944
# Epoch 78/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0689 - mae: 2.4451 - val_loss: 2.5447 - val_mae: 2.9406
# Epoch 79/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0281 - mae: 2.3688 - val_loss: 2.3418 - val_mae: 2.6241
# Epoch 80/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.2397 - mae: 2.6468 - val_loss: 2.6322 - val_mae: 3.1071
# Epoch 81/100
# 69/69 [==============================] - 1s 12ms/step - loss: 1.9888 - mae: 2.3205 - val_loss: 2.5823 - val_mae: 3.0503
# Epoch 82/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.2390 - mae: 2.6503 - val_loss: 3.0204 - val_mae: 3.5178
# Epoch 83/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0914 - mae: 2.4601 - val_loss: 2.6720 - val_mae: 3.1286
# Epoch 84/100
# 69/69 [==============================] - 1s 12ms/step - loss: 2.0591 - mae: 2.4183 - val_loss: 2.5138 - val_mae: 2.8911
# Epoch 85/100
# 69/69 [==============================] - 1s 11ms/step - loss: 1.9535 - mae: 2.2622 - val_loss: 2.5309 - val_mae: 2.9912
# Epoch 86/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.2073 - mae: 2.6133 - val_loss: 2.4155 - val_mae: 2.7822
# Epoch 87/100
# 69/69 [==============================] - 1s 11ms/step - loss: 1.9742 - mae: 2.2911 - val_loss: 3.0978 - val_mae: 3.5953
# Epoch 88/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.1922 - mae: 2.6010 - val_loss: 2.6352 - val_mae: 3.1196
# Epoch 89/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.2646 - mae: 2.6756 - val_loss: 2.4277 - val_mae: 2.8024
# Epoch 90/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0091 - mae: 2.3440 - val_loss: 2.3687 - val_mae: 2.6336
# Epoch 91/100
# 69/69 [==============================] - 1s 11ms/step - loss: 1.9655 - mae: 2.2897 - val_loss: 2.3358 - val_mae: 2.5709
# Epoch 92/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0703 - mae: 2.4308 - val_loss: 2.3412 - val_mae: 2.5907
# Epoch 93/100
# 69/69 [==============================] - 1s 11ms/step - loss: 1.9955 - mae: 2.3256 - val_loss: 2.8997 - val_mae: 3.3928
# Epoch 94/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0303 - mae: 2.3784 - val_loss: 2.3514 - val_mae: 2.5786
# Epoch 95/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0666 - mae: 2.4068 - val_loss: 2.6503 - val_mae: 3.1245
# Epoch 96/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.2983 - mae: 2.7166 - val_loss: 3.0164 - val_mae: 3.4455
# Epoch 97/100
# 69/69 [==============================] - 1s 12ms/step - loss: 2.1271 - mae: 2.4987 - val_loss: 2.8139 - val_mae: 3.3024
# Epoch 98/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.1290 - mae: 2.5240 - val_loss: 3.2477 - val_mae: 3.6929
# Epoch 99/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0882 - mae: 2.4583 - val_loss: 2.3322 - val_mae: 2.5384
# Epoch 100/100
# 69/69 [==============================] - 1s 11ms/step - loss: 2.0207 - mae: 2.3341 - val_loss: 2.5540 - val_mae: 2.9303

# %% [markdown]
# After training the model, the code block generates predictions using the trained model and the reduced series from the validation set. It then drops the single-dimensional axis from the forecast and the original validation data. Finally, it plots the results, showing the actual values and the predicted values.

# %%
# Reduce the original series
forecast_series = series[split_time - window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 18/18 [==============================] - 0s 6ms/step

# %% [markdown]
# The code block evaluates the predictions of the RNN model using the evaluation metrics defined earlier and prints the results.

# %%
# Evaluate preds
results_rnn = evaluate_preds(y_true=x_valid, # reduce to right shape
                                 y_pred=results)
results_rnn
# Out:
# {'mae': 2.9078507,
#  'mse': 94.79036,
#  'rmse': 9.736034,
#  'mape': 2.9322324,
#  'mase': 1.2143643,
#  'r2': 0.9286945}

# %% [markdown]
# **Model: Bi-directional LSTM**
#
# The next code block builds a model using a bidirectional LSTM (long short-term memory) architecture. First, it resets the states generated by Keras to ensure a clean state for building the next model. The model includes two layers of bidirectional LSTM cells with 128 units each. It also includes a Dense layer with 256 units and a dropout layer with a rate of 0.4. The model is compiled with the Huber loss function, Adam optimizer, and mean absolute error (MAE) metric. The code block trains the LSTM model using the fit method, providing the training dataset (dataset) and the validation dataset (val_set) as input, and specifying the number of epochs.

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

# Build the model
model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[window_size]),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True)),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128)),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(1),
#   tf.keras.layers.Lambda(lambda x: x * 100.0)
])

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(), optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), metrics=['mae'])

# Train the model
history = model.fit(dataset,epochs=100, validation_data=val_set)
# Out:
# Epoch 1/100
# 69/69 [==============================] - 9s 48ms/step - loss: 90.8770 - mae: 91.3770 - val_loss: 92.6718 - val_mae: 93.1718
# Epoch 2/100
# 69/69 [==============================] - 2s 30ms/step - loss: 68.7294 - mae: 69.2294 - val_loss: 64.3845 - val_mae: 64.8839
# Epoch 3/100
# 69/69 [==============================] - 2s 31ms/step - loss: 45.5488 - mae: 46.0441 - val_loss: 43.9066 - val_mae: 44.3980
# Epoch 4/100
# 69/69 [==============================] - 2s 31ms/step - loss: 39.5861 - mae: 40.0827 - val_loss: 39.0066 - val_mae: 39.5066
# Epoch 5/100
# 69/69 [==============================] - 2s 30ms/step - loss: 38.5371 - mae: 39.0347 - val_loss: 37.3894 - val_mae: 37.8888
# Epoch 6/100
# 69/69 [==============================] - 2s 32ms/step - loss: 38.3926 - mae: 38.8902 - val_loss: 36.6405 - val_mae: 37.1379
# Epoch 7/100
# 69/69 [==============================] - 2s 31ms/step - loss: 34.6804 - mae: 35.1752 - val_loss: 30.0078 - val_mae: 30.5050
# Epoch 8/100
# 69/69 [==============================] - 2s 31ms/step - loss: 23.0581 - mae: 23.5446 - val_loss: 16.4461 - val_mae: 16.9301
# Epoch 9/100
# 69/69 [==============================] - 2s 30ms/step - loss: 17.3309 - mae: 17.8179 - val_loss: 9.3103 - val_mae: 9.7855
# Epoch 10/100
# 69/69 [==============================] - 2s 32ms/step - loss: 13.6526 - mae: 14.1370 - val_loss: 8.0700 - val_mae: 8.5549
# Epoch 11/100
# 69/69 [==============================] - 2s 33ms/step - loss: 11.7896 - mae: 12.2760 - val_loss: 6.5451 - val_mae: 7.0139
# Epoch 12/100
# 69/69 [==============================] - 2s 30ms/step - loss: 10.5899 - mae: 11.0747 - val_loss: 5.5937 - val_mae: 6.0630
# Epoch 13/100
# 69/69 [==============================] - 2s 32ms/step - loss: 9.5802 - mae: 10.0648 - val_loss: 5.1243 - val_mae: 5.6014
# Epoch 14/100
# 69/69 [==============================] - 2s 31ms/step - loss: 8.8311 - mae: 9.3139 - val_loss: 4.0352 - val_mae: 4.4782
# Epoch 15/100
# 69/69 [==============================] - 2s 30ms/step - loss: 8.5044 - mae: 8.9894 - val_loss: 4.3203 - val_mae: 4.7721
# Epoch 16/100
# 69/69 [==============================] - 2s 30ms/step - loss: 8.2784 - mae: 8.7647 - val_loss: 4.6830 - val_mae: 5.1712
# Epoch 17/100
# 69/69 [==============================] - 2s 30ms/step - loss: 7.9876 - mae: 8.4691 - val_loss: 4.1529 - val_mae: 4.6312
# Epoch 18/100
# 69/69 [==============================] - 2s 30ms/step - loss: 7.9912 - mae: 8.4728 - val_loss: 4.0597 - val_mae: 4.4938
# Epoch 19/100
# 69/69 [==============================] - 2s 30ms/step - loss: 7.8363 - mae: 8.3186 - val_loss: 3.6764 - val_mae: 4.1195
# Epoch 20/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.5898 - mae: 8.0702 - val_loss: 5.0914 - val_mae: 5.5432
# Epoch 21/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.8535 - mae: 8.3355 - val_loss: 4.0677 - val_mae: 4.5496
# Epoch 22/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.3771 - mae: 7.8562 - val_loss: 3.4590 - val_mae: 3.9020
# Epoch 23/100
# 69/69 [==============================] - 2s 30ms/step - loss: 7.5952 - mae: 8.0778 - val_loss: 3.6803 - val_mae: 4.1076
# Epoch 24/100
# 69/69 [==============================] - 2s 33ms/step - loss: 7.2778 - mae: 7.7576 - val_loss: 3.2211 - val_mae: 3.5876
# Epoch 25/100
# 69/69 [==============================] - 2s 30ms/step - loss: 7.3226 - mae: 7.8071 - val_loss: 3.9393 - val_mae: 4.4149
# Epoch 26/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.3792 - mae: 7.8608 - val_loss: 5.9123 - val_mae: 6.4042
# Epoch 27/100
# 69/69 [==============================] - 2s 32ms/step - loss: 7.6460 - mae: 8.1273 - val_loss: 4.0914 - val_mae: 4.5621
# Epoch 28/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.3672 - mae: 7.8474 - val_loss: 3.4537 - val_mae: 3.8734
# Epoch 29/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.4923 - mae: 7.9757 - val_loss: 3.5220 - val_mae: 3.9559
# Epoch 30/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.1283 - mae: 7.6106 - val_loss: 3.9715 - val_mae: 4.4386
# Epoch 31/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.1330 - mae: 7.6113 - val_loss: 3.8858 - val_mae: 4.3737
# Epoch 32/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.2843 - mae: 7.7658 - val_loss: 5.1058 - val_mae: 5.6016
# Epoch 33/100
# 69/69 [==============================] - 2s 30ms/step - loss: 7.3510 - mae: 7.8314 - val_loss: 2.9973 - val_mae: 3.3739
# Epoch 34/100
# 69/69 [==============================] - 2s 30ms/step - loss: 7.2868 - mae: 7.7684 - val_loss: 3.3136 - val_mae: 3.7605
# Epoch 35/100
# 69/69 [==============================] - 2s 30ms/step - loss: 7.2922 - mae: 7.7761 - val_loss: 3.5584 - val_mae: 4.0376
# Epoch 36/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.2217 - mae: 7.7043 - val_loss: 3.8363 - val_mae: 4.3266
# Epoch 37/100
# 69/69 [==============================] - 2s 31ms/step - loss: 6.8772 - mae: 7.3586 - val_loss: 3.1446 - val_mae: 3.5520
# Epoch 38/100
# 69/69 [==============================] - 2s 31ms/step - loss: 6.9920 - mae: 7.4730 - val_loss: 3.3478 - val_mae: 3.8269
# Epoch 39/100
# 69/69 [==============================] - 2s 32ms/step - loss: 7.3193 - mae: 7.7985 - val_loss: 4.0342 - val_mae: 4.5147
# Epoch 40/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.3711 - mae: 7.8524 - val_loss: 2.7975 - val_mae: 3.1921
# Epoch 41/100
# 69/69 [==============================] - 2s 31ms/step - loss: 6.9825 - mae: 7.4661 - val_loss: 3.9842 - val_mae: 4.4714
# Epoch 42/100
# 69/69 [==============================] - 2s 32ms/step - loss: 7.0045 - mae: 7.4845 - val_loss: 4.4843 - val_mae: 4.9749
# Epoch 43/100
# 69/69 [==============================] - 2s 32ms/step - loss: 7.0302 - mae: 7.5102 - val_loss: 3.5276 - val_mae: 4.0036
# Epoch 44/100
# 69/69 [==============================] - 2s 32ms/step - loss: 7.1364 - mae: 7.6196 - val_loss: 5.4551 - val_mae: 5.9468
# Epoch 45/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.2439 - mae: 7.7283 - val_loss: 4.0579 - val_mae: 4.5413
# Epoch 46/100
# 69/69 [==============================] - 2s 30ms/step - loss: 6.9284 - mae: 7.4102 - val_loss: 5.0952 - val_mae: 5.5857
# Epoch 47/100
# 69/69 [==============================] - 2s 30ms/step - loss: 7.1647 - mae: 7.6454 - val_loss: 4.7589 - val_mae: 5.2341
# Epoch 48/100
# 69/69 [==============================] - 2s 31ms/step - loss: 6.9688 - mae: 7.4473 - val_loss: 3.2234 - val_mae: 3.6393
# Epoch 49/100
# 69/69 [==============================] - 2s 32ms/step - loss: 7.1387 - mae: 7.6192 - val_loss: 3.3691 - val_mae: 3.8101
# Epoch 50/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.1101 - mae: 7.5923 - val_loss: 3.4395 - val_mae: 3.9191
# Epoch 51/100
# 69/69 [==============================] - 2s 31ms/step - loss: 6.9655 - mae: 7.4460 - val_loss: 2.9347 - val_mae: 3.3746
# Epoch 52/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.2237 - mae: 7.7067 - val_loss: 2.8099 - val_mae: 3.1467
# Epoch 53/100
# 69/69 [==============================] - 2s 31ms/step - loss: 6.9823 - mae: 7.4643 - val_loss: 4.3603 - val_mae: 4.8098
# Epoch 54/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.0099 - mae: 7.4924 - val_loss: 5.5728 - val_mae: 6.0684
# Epoch 55/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.0642 - mae: 7.5437 - val_loss: 2.7200 - val_mae: 3.1059
# Epoch 56/100
# 69/69 [==============================] - 2s 32ms/step - loss: 6.9449 - mae: 7.4251 - val_loss: 3.8882 - val_mae: 4.3749
# Epoch 57/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.0291 - mae: 7.5095 - val_loss: 3.3347 - val_mae: 3.7988
# Epoch 58/100
# 69/69 [==============================] - 2s 32ms/step - loss: 7.0086 - mae: 7.4898 - val_loss: 3.4578 - val_mae: 3.9384
# Epoch 59/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.0974 - mae: 7.5814 - val_loss: 2.5301 - val_mae: 2.8432
# Epoch 60/100
# 69/69 [==============================] - 2s 30ms/step - loss: 6.8363 - mae: 7.3166 - val_loss: 2.8273 - val_mae: 3.2554
# Epoch 61/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.0697 - mae: 7.5488 - val_loss: 5.1823 - val_mae: 5.6778
# Epoch 62/100
# 69/69 [==============================] - 2s 33ms/step - loss: 7.1645 - mae: 7.6479 - val_loss: 4.8887 - val_mae: 5.3724
# Epoch 63/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.1170 - mae: 7.5994 - val_loss: 4.8340 - val_mae: 5.3305
# Epoch 64/100
# 69/69 [==============================] - 2s 31ms/step - loss: 6.9671 - mae: 7.4470 - val_loss: 2.8166 - val_mae: 3.2017
# Epoch 65/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.1298 - mae: 7.6117 - val_loss: 3.1590 - val_mae: 3.6192
# Epoch 66/100
# 69/69 [==============================] - 2s 30ms/step - loss: 6.8463 - mae: 7.3276 - val_loss: 3.3760 - val_mae: 3.8122
# Epoch 67/100
# 69/69 [==============================] - 2s 30ms/step - loss: 7.0941 - mae: 7.5744 - val_loss: 4.2939 - val_mae: 4.7115
# Epoch 68/100
# 69/69 [==============================] - 2s 31ms/step - loss: 6.9975 - mae: 7.4767 - val_loss: 3.5498 - val_mae: 4.0313
# Epoch 69/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.1261 - mae: 7.6078 - val_loss: 3.0624 - val_mae: 3.5398
# Epoch 70/100
# 69/69 [==============================] - 2s 30ms/step - loss: 7.1327 - mae: 7.6121 - val_loss: 2.6963 - val_mae: 3.0772
# Epoch 71/100
# 69/69 [==============================] - 2s 30ms/step - loss: 6.8220 - mae: 7.3029 - val_loss: 4.3970 - val_mae: 4.8880
# Epoch 72/100
# 69/69 [==============================] - 2s 30ms/step - loss: 6.9823 - mae: 7.4649 - val_loss: 2.5283 - val_mae: 2.8450
# Epoch 73/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.0022 - mae: 7.4835 - val_loss: 3.4120 - val_mae: 3.8760
# Epoch 74/100
# 69/69 [==============================] - 2s 33ms/step - loss: 7.0440 - mae: 7.5251 - val_loss: 5.3564 - val_mae: 5.8470
# Epoch 75/100
# 69/69 [==============================] - 2s 30ms/step - loss: 6.9499 - mae: 7.4310 - val_loss: 2.6923 - val_mae: 3.0559
# Epoch 76/100
# 69/69 [==============================] - 2s 30ms/step - loss: 6.9707 - mae: 7.4514 - val_loss: 4.4281 - val_mae: 4.8678
# Epoch 77/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.0642 - mae: 7.5416 - val_loss: 2.9885 - val_mae: 3.3365
# Epoch 78/100
# 69/69 [==============================] - 2s 30ms/step - loss: 6.7967 - mae: 7.2769 - val_loss: 2.9189 - val_mae: 3.3308
# Epoch 79/100
# 69/69 [==============================] - 2s 31ms/step - loss: 6.9786 - mae: 7.4583 - val_loss: 3.3422 - val_mae: 3.7700
# Epoch 80/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.1663 - mae: 7.6459 - val_loss: 2.9631 - val_mae: 3.3771
# Epoch 81/100
# 69/69 [==============================] - 2s 31ms/step - loss: 6.8592 - mae: 7.3411 - val_loss: 2.5149 - val_mae: 2.8455
# Epoch 82/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.1843 - mae: 7.6658 - val_loss: 2.9808 - val_mae: 3.4100
# Epoch 83/100
# 69/69 [==============================] - 2s 30ms/step - loss: 7.3242 - mae: 7.8083 - val_loss: 4.6524 - val_mae: 5.1421
# Epoch 84/100
# 69/69 [==============================] - 2s 30ms/step - loss: 7.2730 - mae: 7.7547 - val_loss: 2.7862 - val_mae: 3.2431
# Epoch 85/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.0246 - mae: 7.5045 - val_loss: 4.3163 - val_mae: 4.8107
# Epoch 86/100
# 69/69 [==============================] - 2s 32ms/step - loss: 6.9041 - mae: 7.3863 - val_loss: 3.3141 - val_mae: 3.7308
# Epoch 87/100
# 69/69 [==============================] - 2s 32ms/step - loss: 6.7722 - mae: 7.2540 - val_loss: 4.1114 - val_mae: 4.5612
# Epoch 88/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.0057 - mae: 7.4887 - val_loss: 2.6075 - val_mae: 2.9955
# Epoch 89/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.0889 - mae: 7.5707 - val_loss: 3.0841 - val_mae: 3.5521
# Epoch 90/100
# 69/69 [==============================] - 2s 31ms/step - loss: 6.9517 - mae: 7.4312 - val_loss: 3.2111 - val_mae: 3.6968
# Epoch 91/100
# 69/69 [==============================] - 2s 31ms/step - loss: 6.8814 - mae: 7.3620 - val_loss: 2.5948 - val_mae: 2.9746
# Epoch 92/100
# 69/69 [==============================] - 2s 30ms/step - loss: 6.9797 - mae: 7.4618 - val_loss: 2.9989 - val_mae: 3.3325
# Epoch 93/100
# 69/69 [==============================] - 2s 31ms/step - loss: 6.9136 - mae: 7.3957 - val_loss: 2.5185 - val_mae: 2.8373
# Epoch 94/100
# 69/69 [==============================] - 2s 30ms/step - loss: 6.7817 - mae: 7.2639 - val_loss: 3.0298 - val_mae: 3.4494
# Epoch 95/100
# 69/69 [==============================] - 2s 32ms/step - loss: 6.9210 - mae: 7.4011 - val_loss: 2.6148 - val_mae: 2.9452
# Epoch 96/100
# 69/69 [==============================] - 2s 30ms/step - loss: 6.9254 - mae: 7.4025 - val_loss: 4.9652 - val_mae: 5.4531
# Epoch 97/100
# 69/69 [==============================] - 2s 31ms/step - loss: 6.8716 - mae: 7.3519 - val_loss: 4.0791 - val_mae: 4.5731
# Epoch 98/100
# 69/69 [==============================] - 2s 30ms/step - loss: 7.0984 - mae: 7.5786 - val_loss: 3.3934 - val_mae: 3.8833
# Epoch 99/100
# 69/69 [==============================] - 2s 32ms/step - loss: 7.1537 - mae: 7.6333 - val_loss: 2.6867 - val_mae: 3.0824
# Epoch 100/100
# 69/69 [==============================] - 2s 31ms/step - loss: 7.0081 - mae: 7.4858 - val_loss: 3.3194 - val_mae: 3.8030

# %% [markdown]
# After training the model, the code block generates predictions using the trained model and the reduced series from the validation set. It then drops the single-dimensional axis from the forecast and the original validation data. Finally, it plots the results, showing the actual values and the predicted values.

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 18/18 [==============================] - 1s 11ms/step

# %% [markdown]
# The code block evaluates the predictions of the LSTM model using the evaluation metrics defined earlier and prints the results.

# %%
# Evaluate preds
results_bilstm = evaluate_preds(y_true=x_valid, # reduce to right shape
                                 y_pred=results)
results_bilstm
# Out:
# {'mae': 3.7817338,
#  'mse': 86.493576,
#  'rmse': 9.300192,
#  'mape': 3.955055,
#  'mase': 1.5793117,
#  'r2': 0.9349357}

# %% [markdown]
# **Model: Conv1D + LSTM**
#
# The code block builds a model using a combination of convolutional and LSTM layers. The model includes a 1D convolutional layer with 64 filters, a kernel size of 3, and "causal" padding. It also includes two layers of bidirectional LSTM cells with 128 units each. The model further includes a dropout layer with a rate of 0.3, a dense layer with 512 units and "relu" activation, and a dense layer with 1 unit. The model's output is multiplied by 400 using a lambda layer.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Lambda, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import Huber

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

# Build the model
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=64, kernel_size=3,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[window_size, 1]),
  tf.keras.layers.Bidirectional(LSTM(128, return_sequences=True)),
  tf.keras.layers.Bidirectional(LSTM(128)),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 400)
])

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 7, 64)             256
#
#  bidirectional (Bidirectiona  (None, 7, 256)           197632
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 256)              394240
#  nal)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 512)               131584
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
#  lambda (Lambda)             (None, 1)                 0
#
# =================================================================
# Total params: 724,225
# Trainable params: 724,225
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The code block sets the training parameters for the model, compiling it with the Huber loss function, Adam optimizer, and mean absolute error (MAE) metric.

# %%
# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(), optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), metrics=['mae'])

# %% [markdown]
# The code block trains the model using the fit method, providing the training dataset (dataset) and the validation dataset (val_set) as input, and specifying the number of epochs.

# %%
# Train the model
history = model.fit(dataset, epochs=100, validation_data=val_set)
# Out:
# Epoch 1/100
# 69/69 [==============================] - 10s 52ms/step - loss: 39.2073 - mae: 39.7041 - val_loss: 14.2092 - val_mae: 14.7077
# Epoch 2/100
# 69/69 [==============================] - 2s 34ms/step - loss: 20.5857 - mae: 21.0795 - val_loss: 24.8864 - val_mae: 25.3858
# Epoch 3/100
# 69/69 [==============================] - 2s 34ms/step - loss: 14.7258 - mae: 15.2171 - val_loss: 12.0144 - val_mae: 12.5131
# Epoch 4/100
# 69/69 [==============================] - 2s 34ms/step - loss: 12.7829 - mae: 13.2730 - val_loss: 13.7104 - val_mae: 14.2099
# Epoch 5/100
# 69/69 [==============================] - 3s 35ms/step - loss: 11.3343 - mae: 11.8229 - val_loss: 21.8780 - val_mae: 22.3773
# Epoch 6/100
# 69/69 [==============================] - 2s 35ms/step - loss: 10.5744 - mae: 11.0629 - val_loss: 16.8101 - val_mae: 17.3093
# Epoch 7/100
# 69/69 [==============================] - 2s 34ms/step - loss: 9.8333 - mae: 10.3210 - val_loss: 19.6683 - val_mae: 20.1683
# Epoch 8/100
# 69/69 [==============================] - 3s 37ms/step - loss: 9.5384 - mae: 10.0250 - val_loss: 19.6101 - val_mae: 20.1101
# Epoch 9/100
# 69/69 [==============================] - 2s 35ms/step - loss: 9.1203 - mae: 9.6062 - val_loss: 19.5336 - val_mae: 20.0334
# Epoch 10/100
# 69/69 [==============================] - 2s 33ms/step - loss: 8.5043 - mae: 8.9897 - val_loss: 17.8124 - val_mae: 18.3111
# Epoch 11/100
# 69/69 [==============================] - 3s 35ms/step - loss: 9.0455 - mae: 9.5314 - val_loss: 20.4955 - val_mae: 20.9955
# Epoch 12/100
# 69/69 [==============================] - 2s 34ms/step - loss: 8.6531 - mae: 9.1378 - val_loss: 20.3389 - val_mae: 20.8389
# Epoch 13/100
# 69/69 [==============================] - 2s 35ms/step - loss: 8.4766 - mae: 8.9629 - val_loss: 16.7370 - val_mae: 17.2370
# Epoch 14/100
# 69/69 [==============================] - 2s 34ms/step - loss: 8.2030 - mae: 8.6863 - val_loss: 14.6543 - val_mae: 15.1519
# Epoch 15/100
# 69/69 [==============================] - 2s 34ms/step - loss: 7.8832 - mae: 8.3696 - val_loss: 10.1995 - val_mae: 10.6959
# Epoch 16/100
# 69/69 [==============================] - 2s 34ms/step - loss: 7.5845 - mae: 8.0691 - val_loss: 16.0051 - val_mae: 16.5008
# Epoch 17/100
# 69/69 [==============================] - 3s 35ms/step - loss: 7.5568 - mae: 8.0404 - val_loss: 14.1899 - val_mae: 14.6895
# Epoch 18/100
# 69/69 [==============================] - 2s 34ms/step - loss: 7.4223 - mae: 7.9051 - val_loss: 12.2491 - val_mae: 12.7480
# Epoch 19/100
# 69/69 [==============================] - 2s 35ms/step - loss: 7.5216 - mae: 8.0034 - val_loss: 14.7689 - val_mae: 15.2671
# Epoch 20/100
# 69/69 [==============================] - 3s 36ms/step - loss: 7.2389 - mae: 7.7215 - val_loss: 17.3040 - val_mae: 17.8036
# Epoch 21/100
# 69/69 [==============================] - 2s 34ms/step - loss: 7.1723 - mae: 7.6537 - val_loss: 12.1377 - val_mae: 12.6350
# Epoch 22/100
# 69/69 [==============================] - 2s 34ms/step - loss: 7.1904 - mae: 7.6701 - val_loss: 11.3774 - val_mae: 11.8748
# Epoch 23/100
# 69/69 [==============================] - 2s 33ms/step - loss: 7.0317 - mae: 7.5116 - val_loss: 11.9674 - val_mae: 12.4615
# Epoch 24/100
# 69/69 [==============================] - 2s 34ms/step - loss: 7.1642 - mae: 7.6462 - val_loss: 12.4576 - val_mae: 12.9554
# Epoch 25/100
# 69/69 [==============================] - 3s 36ms/step - loss: 6.7954 - mae: 7.2756 - val_loss: 12.2547 - val_mae: 12.7514
# Epoch 26/100
# 69/69 [==============================] - 2s 34ms/step - loss: 6.9828 - mae: 7.4636 - val_loss: 16.2037 - val_mae: 16.7014
# Epoch 27/100
# 69/69 [==============================] - 3s 35ms/step - loss: 7.0828 - mae: 7.5657 - val_loss: 12.4452 - val_mae: 12.9445
# Epoch 28/100
# 69/69 [==============================] - 3s 36ms/step - loss: 6.6100 - mae: 7.0901 - val_loss: 16.2842 - val_mae: 16.7832
# Epoch 29/100
# 69/69 [==============================] - 3s 35ms/step - loss: 6.3102 - mae: 6.7895 - val_loss: 11.1868 - val_mae: 11.6860
# Epoch 30/100
# 69/69 [==============================] - 3s 35ms/step - loss: 6.5389 - mae: 7.0183 - val_loss: 12.4408 - val_mae: 12.9367
# Epoch 31/100
# 69/69 [==============================] - 3s 35ms/step - loss: 6.5741 - mae: 7.0538 - val_loss: 13.4054 - val_mae: 13.9021
# Epoch 32/100
# 69/69 [==============================] - 3s 35ms/step - loss: 6.5057 - mae: 6.9867 - val_loss: 7.8788 - val_mae: 8.3669
# Epoch 33/100
# 69/69 [==============================] - 3s 35ms/step - loss: 6.1979 - mae: 6.6766 - val_loss: 10.6125 - val_mae: 11.1112
# Epoch 34/100
# 69/69 [==============================] - 2s 35ms/step - loss: 6.1475 - mae: 6.6252 - val_loss: 7.4277 - val_mae: 7.9242
# Epoch 35/100
# 69/69 [==============================] - 2s 34ms/step - loss: 6.2222 - mae: 6.7014 - val_loss: 10.3840 - val_mae: 10.8809
# Epoch 36/100
# 69/69 [==============================] - 2s 33ms/step - loss: 5.9979 - mae: 6.4738 - val_loss: 12.5938 - val_mae: 13.0857
# Epoch 37/100
# 69/69 [==============================] - 2s 34ms/step - loss: 6.2112 - mae: 6.6904 - val_loss: 6.5469 - val_mae: 7.0404
# Epoch 38/100
# 69/69 [==============================] - 3s 35ms/step - loss: 6.1783 - mae: 6.6560 - val_loss: 5.7873 - val_mae: 6.2743
# Epoch 39/100
# 69/69 [==============================] - 3s 35ms/step - loss: 6.1354 - mae: 6.6143 - val_loss: 9.9326 - val_mae: 10.4253
# Epoch 40/100
# 69/69 [==============================] - 2s 35ms/step - loss: 5.9111 - mae: 6.3871 - val_loss: 9.8891 - val_mae: 10.3862
# Epoch 41/100
# 69/69 [==============================] - 3s 36ms/step - loss: 5.8526 - mae: 6.3313 - val_loss: 7.5813 - val_mae: 8.0746
# Epoch 42/100
# 69/69 [==============================] - 3s 35ms/step - loss: 6.1000 - mae: 6.5795 - val_loss: 8.9061 - val_mae: 9.4020
# Epoch 43/100
# 69/69 [==============================] - 2s 34ms/step - loss: 5.9476 - mae: 6.4268 - val_loss: 14.6021 - val_mae: 15.1009
# Epoch 44/100
# 69/69 [==============================] - 2s 34ms/step - loss: 6.0488 - mae: 6.5271 - val_loss: 5.8341 - val_mae: 6.3252
# Epoch 45/100
# 69/69 [==============================] - 2s 34ms/step - loss: 5.6831 - mae: 6.1584 - val_loss: 6.8770 - val_mae: 7.3698
# Epoch 46/100
# 69/69 [==============================] - 2s 34ms/step - loss: 5.6722 - mae: 6.1488 - val_loss: 7.8121 - val_mae: 8.3061
# Epoch 47/100
# 69/69 [==============================] - 3s 36ms/step - loss: 5.7126 - mae: 6.1870 - val_loss: 11.2846 - val_mae: 11.7808
# Epoch 48/100
# 69/69 [==============================] - 3s 35ms/step - loss: 5.7068 - mae: 6.1813 - val_loss: 4.5400 - val_mae: 4.9939
# Epoch 49/100
# 69/69 [==============================] - 3s 35ms/step - loss: 6.1326 - mae: 6.6118 - val_loss: 10.0847 - val_mae: 10.5822
# Epoch 50/100
# 69/69 [==============================] - 3s 36ms/step - loss: 5.9225 - mae: 6.3957 - val_loss: 11.3312 - val_mae: 11.8292
# Epoch 51/100
# 69/69 [==============================] - 3s 35ms/step - loss: 5.6808 - mae: 6.1585 - val_loss: 5.7146 - val_mae: 6.2045
# Epoch 52/100
# 69/69 [==============================] - 3s 35ms/step - loss: 5.8118 - mae: 6.2882 - val_loss: 6.1947 - val_mae: 6.6881
# Epoch 53/100
# 69/69 [==============================] - 3s 35ms/step - loss: 5.7682 - mae: 6.2449 - val_loss: 6.1113 - val_mae: 6.5975
# Epoch 54/100
# 69/69 [==============================] - 2s 35ms/step - loss: 5.4628 - mae: 5.9345 - val_loss: 9.0140 - val_mae: 9.5055
# Epoch 55/100
# 69/69 [==============================] - 3s 35ms/step - loss: 5.5253 - mae: 5.9986 - val_loss: 8.6264 - val_mae: 9.1215
# Epoch 56/100
# 69/69 [==============================] - 3s 36ms/step - loss: 5.5427 - mae: 6.0173 - val_loss: 9.3964 - val_mae: 9.8928
# Epoch 57/100
# 69/69 [==============================] - 3s 36ms/step - loss: 5.6176 - mae: 6.0920 - val_loss: 7.9833 - val_mae: 8.4774
# Epoch 58/100
# 69/69 [==============================] - 3s 37ms/step - loss: 5.4560 - mae: 5.9267 - val_loss: 3.5070 - val_mae: 3.9874
# Epoch 59/100
# 69/69 [==============================] - 3s 35ms/step - loss: 5.2577 - mae: 5.7280 - val_loss: 6.6967 - val_mae: 7.1884
# Epoch 60/100
# 69/69 [==============================] - 3s 36ms/step - loss: 5.2025 - mae: 5.6728 - val_loss: 5.7364 - val_mae: 6.2310
# Epoch 61/100
# 69/69 [==============================] - 2s 34ms/step - loss: 5.0648 - mae: 5.5359 - val_loss: 6.7119 - val_mae: 7.2029
# Epoch 62/100
# 69/69 [==============================] - 2s 34ms/step - loss: 4.9107 - mae: 5.3784 - val_loss: 7.5473 - val_mae: 8.0402
# Epoch 63/100
# 69/69 [==============================] - 2s 34ms/step - loss: 5.4143 - mae: 5.8871 - val_loss: 4.7822 - val_mae: 5.2752
# Epoch 64/100
# 69/69 [==============================] - 3s 36ms/step - loss: 5.2250 - mae: 5.6956 - val_loss: 2.8190 - val_mae: 3.1659
# Epoch 65/100
# 69/69 [==============================] - 2s 34ms/step - loss: 5.0933 - mae: 5.5616 - val_loss: 4.3665 - val_mae: 4.8504
# Epoch 66/100
# 69/69 [==============================] - 2s 34ms/step - loss: 5.2529 - mae: 5.7247 - val_loss: 7.3105 - val_mae: 7.8057
# Epoch 67/100
# 69/69 [==============================] - 2s 34ms/step - loss: 4.9002 - mae: 5.3689 - val_loss: 6.4739 - val_mae: 6.9708
# Epoch 68/100
# 69/69 [==============================] - 3s 36ms/step - loss: 5.2689 - mae: 5.7403 - val_loss: 6.5463 - val_mae: 7.0366
# Epoch 69/100
# 69/69 [==============================] - 2s 33ms/step - loss: 5.0849 - mae: 5.5555 - val_loss: 7.5361 - val_mae: 8.0315
# Epoch 70/100
# 69/69 [==============================] - 2s 33ms/step - loss: 5.0151 - mae: 5.4834 - val_loss: 5.2004 - val_mae: 5.6918
# Epoch 71/100
# 69/69 [==============================] - 2s 34ms/step - loss: 5.0702 - mae: 5.5400 - val_loss: 5.9049 - val_mae: 6.3982
# Epoch 72/100
# 69/69 [==============================] - 2s 33ms/step - loss: 4.8204 - mae: 5.2900 - val_loss: 6.6713 - val_mae: 7.1677
# Epoch 73/100
# 69/69 [==============================] - 2s 32ms/step - loss: 5.2266 - mae: 5.6965 - val_loss: 6.6622 - val_mae: 7.1580
# Epoch 74/100
# 69/69 [==============================] - 2s 34ms/step - loss: 4.9732 - mae: 5.4437 - val_loss: 6.4586 - val_mae: 6.9542
# Epoch 75/100
# 69/69 [==============================] - 2s 33ms/step - loss: 5.1620 - mae: 5.6328 - val_loss: 5.4626 - val_mae: 5.9304
# Epoch 76/100
# 69/69 [==============================] - 2s 34ms/step - loss: 5.1020 - mae: 5.5739 - val_loss: 4.7636 - val_mae: 5.2600
# Epoch 77/100
# 69/69 [==============================] - 2s 32ms/step - loss: 4.9076 - mae: 5.3800 - val_loss: 3.7789 - val_mae: 4.2485
# Epoch 78/100
# 69/69 [==============================] - 2s 33ms/step - loss: 4.6914 - mae: 5.1577 - val_loss: 3.7377 - val_mae: 4.1962
# Epoch 79/100
# 69/69 [==============================] - 2s 34ms/step - loss: 5.0283 - mae: 5.5031 - val_loss: 5.5386 - val_mae: 6.0321
# Epoch 80/100
# 69/69 [==============================] - 2s 33ms/step - loss: 4.8583 - mae: 5.3280 - val_loss: 3.2334 - val_mae: 3.6464
# Epoch 81/100
# 69/69 [==============================] - 2s 32ms/step - loss: 4.7776 - mae: 5.2456 - val_loss: 6.0391 - val_mae: 6.5345
# Epoch 82/100
# 69/69 [==============================] - 2s 32ms/step - loss: 4.7170 - mae: 5.1841 - val_loss: 7.9257 - val_mae: 8.4222
# Epoch 83/100
# 69/69 [==============================] - 2s 31ms/step - loss: 4.4817 - mae: 4.9491 - val_loss: 7.5670 - val_mae: 8.0627
# Epoch 84/100
# 69/69 [==============================] - 2s 32ms/step - loss: 4.8009 - mae: 5.2671 - val_loss: 4.1520 - val_mae: 4.6359
# Epoch 85/100
# 69/69 [==============================] - 2s 33ms/step - loss: 4.5744 - mae: 5.0425 - val_loss: 10.0400 - val_mae: 10.5359
# Epoch 86/100
# 69/69 [==============================] - 2s 34ms/step - loss: 4.8065 - mae: 5.2750 - val_loss: 3.2304 - val_mae: 3.6771
# Epoch 87/100
# 69/69 [==============================] - 2s 32ms/step - loss: 4.5675 - mae: 5.0325 - val_loss: 5.0972 - val_mae: 5.5456
# Epoch 88/100
# 69/69 [==============================] - 2s 32ms/step - loss: 4.6996 - mae: 5.1678 - val_loss: 6.1974 - val_mae: 6.6933
# Epoch 89/100
# 69/69 [==============================] - 2s 32ms/step - loss: 4.8055 - mae: 5.2768 - val_loss: 3.3354 - val_mae: 3.8165
# Epoch 90/100
# 69/69 [==============================] - 2s 34ms/step - loss: 4.6219 - mae: 5.0878 - val_loss: 6.1428 - val_mae: 6.6391
# Epoch 91/100
# 69/69 [==============================] - 2s 33ms/step - loss: 4.6173 - mae: 5.0835 - val_loss: 7.2070 - val_mae: 7.7030
# Epoch 92/100
# 69/69 [==============================] - 3s 37ms/step - loss: 4.6478 - mae: 5.1140 - val_loss: 3.1348 - val_mae: 3.5844
# Epoch 93/100
# 69/69 [==============================] - 2s 34ms/step - loss: 4.6528 - mae: 5.1217 - val_loss: 4.1169 - val_mae: 4.5598
# Epoch 94/100
# 69/69 [==============================] - 2s 34ms/step - loss: 4.5729 - mae: 5.0363 - val_loss: 4.8174 - val_mae: 5.2892
# Epoch 95/100
# 69/69 [==============================] - 2s 32ms/step - loss: 4.6344 - mae: 5.1018 - val_loss: 3.2274 - val_mae: 3.6932
# Epoch 96/100
# 69/69 [==============================] - 2s 33ms/step - loss: 4.5836 - mae: 5.0476 - val_loss: 3.0650 - val_mae: 3.4811
# Epoch 97/100
# 69/69 [==============================] - 2s 32ms/step - loss: 4.3497 - mae: 4.8144 - val_loss: 3.9788 - val_mae: 4.4111
# Epoch 98/100
# 69/69 [==============================] - 2s 34ms/step - loss: 4.5390 - mae: 5.0041 - val_loss: 2.8399 - val_mae: 3.2149
# Epoch 99/100
# 69/69 [==============================] - 2s 33ms/step - loss: 4.8867 - mae: 5.3560 - val_loss: 6.9291 - val_mae: 7.4260
# Epoch 100/100
# 69/69 [==============================] - 2s 33ms/step - loss: 4.2655 - mae: 4.7285 - val_loss: 3.6166 - val_mae: 4.0708

# %% [markdown]
# After training the model, the code block generates predictions using the trained model and the reduced series from the validation set. It then drops the single-dimensional axes from the forecast and the original validation data. Finally, it plots the results, showing the actual values and the predicted values.

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axes
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 18/18 [==============================] - 1s 13ms/step

# %% [markdown]
# The code block evaluates the predictions of the model using the evaluation metrics defined earlier and prints the results.

# %%
# Evaluate preds
results_convlstm = evaluate_preds(y_true=x_valid, # reduce to right shape
                                 y_pred=results)
results_convlstm
# Out:
# {'mae': 4.0612574,
#  'mse': 85.643906,
#  'rmse': 9.254399,
#  'mape': 3.9920905,
#  'mase': 1.6960452,
#  'r2': 0.9355748}

# %% [markdown]
# **Model: Conv1D**
#
# The following code defines a CNN (Convolutional Neural Network) model using TensorFlow's Keras API. The model includes Conv1D layers, GlobalAveragePooling1D, Flatten, Dropout, and Dense layers. The Lambda layer is used to add an extra axis to the input data. The model is compiled with the Huber loss function, Adam optimizer, and mean absolute error (MAE) metric. It then prints a summary of the model, providing an overview of its architecture and the number of parameters.

# %%
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D, Flatten


cnn_model = Sequential([
    # add extra axis to input data
    Lambda(lambda x: tf.expand_dims(x, axis=-1), input_shape=[window_size]),
    Conv1D(filters=256, kernel_size=3, strides=1,
           padding='causal', activation='relu'),
    Conv1D(filters=256, kernel_size=3, strides=1,
           padding='causal', activation='relu'),
    GlobalAveragePooling1D(),
    Flatten(),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.4),
    Dense(1)
])

cnn_model.compile(
    loss=Huber(),
    optimizer=Adam(),
    metrics=['mae']
)

cnn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda_2 (Lambda)           (None, 7, 1)              0
#
#  conv1d_3 (Conv1D)           (None, 7, 256)            1024
#
#  conv1d_4 (Conv1D)           (None, 7, 256)            196864
#
#  global_average_pooling1d_1   (None, 256)              0
#  (GlobalAveragePooling1D)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 230,913
# Trainable params: 230,913
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The code block trains the CNN model using the fit method, providing the training dataset (dataset) and the validation dataset (val_set) as input, and specifying the number of epochs. The verbose=0 argument is used to suppress the progress output during training.

# %%
#Trains CNN Model
cnn_history = cnn_model.fit(dataset, epochs=100, validation_data=val_set,verbose=0)

# %% [markdown]
# After training the model, the code block generates predictions using the trained CNN model and the reduced series from the validation set. It then drops the single-dimensional axes from the forecast and the original validation data. Finally, it plots the results, showing the actual values and the predicted values.

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(cnn_model, forecast_series, window_size, batch_size)

# Drop single dimensional axes
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 18/18 [==============================] - 0s 5ms/step

# %% [markdown]
# The code block evaluates the predictions of the CNN model using the evaluation metrics defined earlier and stores the results in the results_conv variable.

# %%
# Evaluate preds
results_conv = evaluate_preds(y_true=x_valid, # reduce to right shape
                                 y_pred=results)
results_conv
# Out:
# {'mae': 4.405998,
#  'mse': 93.219086,
#  'rmse': 9.655004,
#  'mape': 4.718836,
#  'mase': 1.8400143,
#  'r2': 0.92987645}

# %% [markdown]
# **Compare Models**
#
# The next code block creates a DataFrame, model_results, to compare the results of different models. It includes the MAE values of the baseline model, Simple RNN model, Bi-LSTM model, Conv1D + LSTM model, and the CNN model. The DataFrame is then sorted based on the MAE values.

# %%
# Compare different model results
model_results = pd.DataFrame({"Model_Dense1": results_baseline,
                              "Simple RNN": results_rnn,
                              "Bi-LSTM": results_bilstm,
                              "Conv1D + LSTM": results_convlstm,
                              "Conv1D": results_conv,
                             }).T
model_results = model_results.sort_values(by="mae")

model_results.head(10)
# Out:
#                     mae        mse      rmse      mape      mase        r2
# Simple RNN     2.907851  94.790359  9.736034  2.932232  1.214364  0.928694
# Model_Dense1   2.980794  93.788734  9.684459  3.103363  1.244827  0.929448
# Bi-LSTM        3.781734  86.493576  9.300192  3.955055  1.579312  0.934936
# Conv1D + LSTM  4.061257  85.643906  9.254399  3.992090  1.696045  0.935575
# Conv1D         4.405998  93.219086  9.655004  4.718836  1.840014  0.929876

# %% [markdown]
# The table above presents the results of different models used for a certain task, sorted by the mean absolute error (MAE) in ascending order. The Simple RNN model achieved the lowest MAE of 2.907851, followed closely by the Model_Dense1 with an MAE of 2.980794. The Bi-LSTM model obtained an MAE of 3.781734, while the Conv1D + LSTM model had a slightly higher MAE of 4.061257. The Conv1D model had the highest MAE among the compared models, reaching 4.405998. It's worth noting that all models achieved relatively low MAE values, indicating good performance in predicting the target variable. However, the Simple RNN and Model_Dense1 models exhibited the best performance with the lowest MAE values.

# %% [markdown]
# The code block plots a bar chart to visualize the MAE values of the different models, sorted in ascending order. This allows for a visual comparison of the model performance based on the MAE metric.

# %%
# Sort model results by MAE and plot them
model_results[["mae"]].sort_values(by="mae").plot(figsize=(10, 7), kind="bar");
