# %% [markdown]
# # **Title: LyricMaster - David Guetta Song Lyrics Dataset**

# %% [markdown]
# ![Screenshot 2023-07-13 073925.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Overview/Introduction:
# The David Guetta Song Lyrics Dataset is a comprehensive collection of lyrics from the popular DJ and producer David Guetta. This dataset serves as the ultimate resource for all his hit songs, providing a consolidated repository for fans, researchers, and AI enthusiasts. By leveraging this dataset, we aim to develop an AI project that utilizes Natural Language Processing (NLP) techniques to generate David Guetta-inspired song lyrics. The project, which we refer to as LyricMaster, will revolutionize the way songwriters, musicians, and music enthusiasts create captivating lyrics inspired by David Guetta's musical style.
#
# ## Problem Statement:
# Crafting engaging and impactful song lyrics is a complex task that often poses challenges to aspiring artists and songwriters. They struggle to find the right words, themes, and stylistic elements that resonate with their audience. Understanding an artist's unique musical style and infusing it into their own compositions can be particularly difficult. To address these challenges, LyricMaster will harness the power of NLP AI to provide an intuitive and accessible solution for generating David Guetta-inspired lyrics. This project aims to empower users with a tool that not only assists in the creative process but also facilitates artistic growth and collaboration.
#
# ## Objectives:
# 1. **Generate David Guetta-inspired lyrics:** Develop an AI model that can generate lyrics in the style of David Guetta, capturing the essence of his musical repertoire and lyrical themes.
#
# 2. **Utilize a comprehensive dataset:** Leverage the David Guetta Song Lyrics Dataset, which includes the complete lyrics of his extensive discography. By training the AI model on this dataset, we can enable it to learn the patterns, themes, and linguistic style unique to David Guetta's music.
#
# 3. **Ensure user-friendliness and accessibility:** Design an intuitive user interface that allows users to interact seamlessly with LyricMaster. Regardless of their technical expertise, users should be able to effortlessly generate David Guetta-inspired lyrics and explore the creative possibilities of AI.
#
# 4. **Promote creativity and inspiration:** Provide a platform for artists, songwriters, and music enthusiasts to discover new lyrical ideas and experiment with David Guetta's distinctive style. LyricMaster will serve as a valuable resource for inspiration, sparking creativity, and facilitating the composition of captivating songs.
#
#
# ## Dataset Description:
#
# The David Guetta Song Lyrics Dataset is a comprehensive collection of lyrics from the renowned DJ and producer, David Guetta. It serves as the ultimate resource for all his hit songs, providing a consolidated repository of his lyrical works. The dataset was meticulously compiled from the official lyrics website, azlyrics.com, ensuring accuracy and completeness.
#
# This dataset is stored in a CSV file format, featuring two columns: *song_title* and *lyrics*. The *song_title* column records the title of each song, while the *lyrics* column contains the corresponding lyrics. The dataset has not undergone preprocessing to remove punctuation or non-lyric text at this stage. However, during the development of the LyricMaster project, appropriate preprocessing techniques will be applied to ensure the generated lyrics are coherent and free of irrelevant textual artifacts.
#
#
# **Source:** The lyrics were obtained from the official lyrics website azlyrics.com (https://www.azlyrics.com/d/davidguetta.html).
#
# Date: 13th February 2023
#
# **Dataset URL:** https://www.kaggle.com/datasets/priomdeb/david-guetta-lyrics-dataset

# %% [markdown]
# # Technologies Used
#
# 1. **Python**: The primary programming language used for developing the project, providing a wide range of libraries and tools for data processing, natural language processing, and machine learning.
#
# 2. **NumPy**: A fundamental library for numerical computing in Python, enabling efficient handling of multi-dimensional arrays and mathematical operations.
#
# 3. **Matplotlib**: A popular data visualization library in Python, utilized for generating visual representations of training curves, such as accuracy and loss plots.
#
# 4. **TensorFlow**: A powerful open-source framework for machine learning, employed for building and training neural network models in this project.
#
# 5. **Keras**: A high-level neural networks API that runs on top of TensorFlow, utilized for constructing and training the deep learning models.
#
# 6. **Pandas**: A versatile data manipulation and analysis library, used for reading and processing the dataset in the form of a CSV file.
#
# # Methodology
#
# The methodology employed in the David Guetta Song Lyrics generation project involves the following steps:
#
# 1. **Data Preparation**: The project begins with loading the dataset, containing the lyrics of David Guetta's songs, using the Pandas library. The data is inspected for duplicates and missing values, with appropriate preprocessing steps applied to handle empty spaces.
#
# 2. **Text Cleaning**: Regular expression (re) module is used to perform text cleaning operations on the lyrics, such as removing square brackets, replacing slashes, splitting into separate lines, and removing empty lines. The cleaned lyrics are stored in a list called "cleaned_lyrics_list".
#
# 3. **Text Preprocessing**: The lyrics are converted to lowercase and saved as a list called "corpus". Tokenization is performed using the Tokenizer class from Keras, and the total number of unique words in the corpus is determined.
#
# 4. **Generating n-gram Sequences**: The corpus is transformed into n-gram sequences, which are subsequences of consecutive words. The "n_gram_seqs" function generates these sequences, utilizing the Tokenizer and the corpus as inputs.
#
# 5. **Padding Sequences**: The generated n-gram sequences are padded to have the same length using the "pad_seqs" function. This ensures uniformity in the input dimensions required for the neural network model.
#
# 6. **Creating the Model**: The text generator model is created using the Sequential API from Keras. It consists of an embedding layer, a bidirectional LSTM layer, and a dense output layer. The model is compiled with appropriate loss and optimization functions.
#
# 7. **Training the Model**: The model is trained on the padded sequences and corresponding labels (one-hot encoded). The training is carried out for a specified number of epochs, and the accuracy and loss values are recorded.
#
# 8. **Evaluation**: The training curves, including accuracy and loss, are plotted using Matplotlib, providing insights into the model's performance during training.
#
# 9. **Text Generation**: Finally, the trained model is utilized to generate song lyrics. A seed text is provided, and the model predicts the next words based on the seed text using the trained weights. The generated lyrics are printed, completing the text generation process.
#
# # Results
#
# The model achieved promising results in generating David Guetta-inspired song lyrics. The training process involved 100 epochs, with an accuracy of approximately 82.57% and a decreasing loss over time. The accuracy metric measures the percentage of correctly predicted words in the generated lyrics.
#
# # Discussion/Interpretation of Results
#
# The training curves plotted for accuracy and loss reveal that the model steadily improves its performance throughout the training process. The increasing accuracy indicates that the model becomes more proficient at predicting the correct next words given a seed text. The decreasing loss signifies that the model minimizes its prediction errors and converges towards more accurate results.
#
# However, it is important to note that these results reflect the model's ability to generate lyrics that closely resemble David Guetta's style and themes. The quality and coherence of the generated lyrics depend on the complexity of the underlying linguistic patterns in David Guetta's songs, as well as the available training data. Further fine-tuning and experimentation may be required to optimize the model's performance and enhance the quality of the generated lyrics.
#
# # Conclusion
#
# The David Guetta Song Lyrics generation project showcases the potential of NLP AI techniques in generating song lyrics inspired by the renowned DJ and producer, David Guetta. By leveraging a comprehensive dataset of his lyrics, the project enables the creation of a text generation model that captures the essence of David Guetta's musical style.
#
# While the results obtained thus far are promising, there is room for further refinement and exploration to enhance the generated lyrics' quality and coherence. The project serves as a foundation for future developments in AI-assisted music composition and encourages collaboration and artistic growth within the music community.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/david-guetta-lyrics-dataset/David_Guetta_Lyrics_Dataset.csv

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %% [markdown]
# The following code shows loading a CSV file containing David Guetta lyrics into a pandas DataFrame and displaying the first few rows of the DataFrame.

# %%
df = pd.read_csv("/kaggle/input/david-guetta-lyrics-dataset/David_Guetta_Lyrics_Dataset.csv")
df.head()
# Out:
#                                           track_name  \
# 0                                You Can't Change Me
# 1                                  Who's That Chick?
# 2                                 What Would You Do?
# 3  Versace On The Floor (Bruno Mars Vs. David Gue...
# 4                                         Trampoline
#
#                                               lyrics
# 0  I won't change\n\nI keep on makin' all the sam...
# 1  [Verse 1]\n\nFeel the adrenaline moving under ...
# 2  What would you do?\n\nIf I told you I loved yo...
# 3  Let's take our time tonight, girl\n\nAbove us ...
# 4  [Missy Elliott:]\n\nBounce that shit, make it ...

# %% [markdown]
# **Duplicates and Null values**
#
# The code block following that provides some exploratory data analysis. It prints the number of data points in the dataset, checks for duplicates, and identifies missing values in the DataFrame. It also replaces empty values with NaN and rechecks the missing values after replacement.

# %%
# How many reviews do we have?
print('There are', df.shape[0], 'data in this dataset')

# Do we have duplicates?
print('Number of Duplicates:', len(df[df.duplicated()]))

# Do we have missing values?
missing_values = df.isnull().sum()
print('Number of Missing Values by column:\n',missing_values)

print('Number of Missing Values:', df.isnull().sum().sum())

df.replace("", np.nan, inplace=True)
missing_values = df.isnull().sum()
print('Number of Missing Values and Empty Spaces by column:\n',missing_values)
# Out:
# There are 184 data in this dataset
# Number of Duplicates: 0
# Number of Missing Values by column:
#  track_name    0
# lyrics        0
# dtype: int64
# Number of Missing Values: 0
# Number of Missing Values and Empty Spaces by column:
#  track_name    0
# lyrics        0
# dtype: int64

# %% [markdown]
# The next code segment converts the lyrics column from the DataFrame into a list called "lyrics_list".

# %%
lyrics_list = df['lyrics'].tolist()
lyrics_list[:3]
# Out:
# ["I won't change\n\nI keep on makin' all the same mistakes\n\nYou can't blame me\n\n'Cause you can't cha-cha-change me\n\n\n\nYou can try\n\nBut when the sun has got to kiss us goodbye\n\nI go crazy\n\n'Cause you can't cha-cha-change me\n\nChange me, oh\n\n\n\nI won't change\n\nI keep on makin' all the same mistakes\n\nYou can't blame me\n\n'Cause you can't cha-cha-change me\n\n\n\nOh, you can try\n\nBut when the sun has got to kiss us goodbye\n\nI go crazy\n\n'Cause you can't cha-cha-change me\n\nChange me, oh\n\n\n\nOh, woah-oh, oh-oh\n\nOh, woah-oh, oh-oh\n\nCha-cha-change me\n\nChange me\n\nChange me, oh",
# ...

# %% [markdown]
# **Clean Text**
#
# The following code imports the regular expression (re) module. It performs a series of text cleaning operations on the lyrics_list, such as removing square brackets and their contents, replacing slashes with spaces, splitting the lyrics into separate lines, and removing empty lines. The cleaned lyrics are stored in the "cleaned_lyrics_list".

# %%
import re

cleaned_lyrics_list = []
for song_lyrics in lyrics_list:
    # remove square brackets and their contents
    no_brackets = re.sub(r'\[.*?\]', '', song_lyrics)
    # replace slashes with spaces
    no_slashes = re.sub(r'/', ' ', no_brackets)
    # split the cleaned lyrics into separate lines
    lines = no_slashes.split('\n')
    # remove any remaining empty lines
    lines = [line for line in lines if line.strip() != '']
    cleaned_lyrics_list.extend(lines)


cleaned_lyrics_list[:3]
# Out:
# ["I won't change",
#  "I keep on makin' all the same mistakes",
#  "You can't blame me"]

# %% [markdown]
# The next code converts all the lyrics in the "cleaned_lyrics_list" to lowercase and saves them as a list called "corpus". It then prints the number of lines in the corpus and displays the first five lines.

# %%
# Convert to lower case and save as a list
corpus = [item.lower() for item in cleaned_lyrics_list]

print(f"There are {len(corpus)} lines of lyrics\n")
print(f"The first 5 lines look like this:\n")
for i in range(5):
  print(corpus[i])
# Out:
# There are 8066 lines of lyrics
#
# The first 5 lines look like this:
#
# i won't change
# i keep on makin' all the same mistakes
# you can't blame me
# 'cause you can't cha-cha-change me
# you can try

# %% [markdown]
# The code initializes a tokenizer object and fits it on the "corpus" to create a word-index dictionary. It also calculates the total number of unique words in the tokenizer's word index.

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
total_words = len(tokenizer.word_index) + 1
total_words
# Out:
# 3443

# %% [markdown]
# The following code demonstrates how to convert the first line of the "corpus" into a sequence of tokenized words using the tokenizer.

# %%
tokenizer.texts_to_sequences([corpus[0]])[0]
# Out:
# [1, 99, 219]

# %% [markdown]
# **Generating n_grams**
#
# The code defines a function called "n_gram_seqs" that generates n-gram sequences from a corpus of text. It takes the "corpus" and the tokenizer as inputs and returns a list of n-gram sequences.

# %%
def n_gram_seqs(corpus, tokenizer):
    """
    Generates a list of n-gram sequences

    Args:
        corpus (list of string): lines of texts to generate n-grams for
        tokenizer (object): an instance of the Tokenizer class containing the word-index dictionary

    Returns:
        input_sequences (list of int): the n-gram sequences for each line in the corpus
    """
    input_sequences = []

    for line in corpus:
      token_list = tokenizer.texts_to_sequences([line])[0]
      for i in range(1, len(token_list)):
          n_gram_sequence = token_list[:i+1]
          input_sequences.append(n_gram_sequence)

    return input_sequences

# %% [markdown]
# The function is tested with an example by generating n-gram sequences for the first line of the "corpus" and printing the result.

# %%
# Test the function with one example
first_example_sequence = n_gram_seqs([corpus[0]], tokenizer)

print("n_gram sequences for first example look like this:\n")
first_example_sequence
# Out:
# n_gram sequences for first example look like this:
# [[1, 99], [1, 99, 219]]

# %% [markdown]
# The function is further tested by generating n-gram sequences for the next three lines of the "corpus" and displaying the result.

# %%
# Test the function with a bigger corpus
next_3_examples_sequence = n_gram_seqs(corpus[1:4], tokenizer)

print("n_gram sequences for next 3 examples look like this:\n")
next_3_examples_sequence
# Out:
# n_gram sequences for next 3 examples look like this:
# [[1, 94],
#  [1, 94, 14],
#  [1, 94, 14, 428],
#  [1, 94, 14, 428, 25],
#  [1, 94, 14, 428, 25, 3],
#  [1, 94, 14, 428, 25, 3, 379],
#  [1, 94, 14, 428, 25, 3, 379, 900],
#  [2, 64],
#  [2, 64, 206],
#  [2, 64, 206, 4],
#  [68, 2],
#  [68, 2, 64],
#  [68, 2, 64, 595],
#  [68, 2, 64, 595, 595],
#  [68, 2, 64, 595, 595, 219],
#  [68, 2, 64, 595, 595, 219, 4]]

# %% [markdown]
# The code applies the "n_gram_seqs" transformation to the entire "corpus" to generate n-gram sequences for the entire corpus. It also calculates the maximum length of the sequences and prints the number of n-gram sequences and the maximum sequence length.

# %%
# Apply the n_gram_seqs transformation to the whole corpus
input_sequences = n_gram_seqs(corpus, tokenizer)

# Save max length
max_sequence_len = max([len(x) for x in input_sequences])

print(f"n_grams of input_sequences have length: {len(input_sequences)}")
print(f"maximum length of sequences is: {max_sequence_len}")
# Out:
# n_grams of input_sequences have length: 43964
# maximum length of sequences is: 28

# %% [markdown]
# The code defines a function called "pad_seqs" that pads tokenized sequences to the same length. It takes the input sequences and the maximum sequence length as inputs and returns the padded sequences.

# %%
def pad_seqs(input_sequences, maxlen):
    """
    Pads tokenized sequences to the same length

    Args:
        input_sequences (list of int): tokenized sequences to pad
        maxlen (int): maximum length of the token sequences

    Returns:
        padded_sequences (array of int): tokenized sequences padded to the same length
    """
    padded_sequences = pad_sequences(input_sequences, maxlen=maxlen, padding='pre')

    return padded_sequences

# %% [markdown]
# The function is tested with the n-gram sequence of the first example by padding it to the maximum length and printing the result.

# %%
# Test the function with the n_grams_seq of the first example
first_padded_seq = pad_seqs(first_example_sequence, max([len(x) for x in first_example_sequence]))
first_padded_seq
# Out:
# array([[  0,   1,  99],
#        [  1,  99, 219]], dtype=int32)

# %% [markdown]
# The function is further tested with the n-gram sequences of the next three examples by padding them to the maximum length and displaying the result.

# %%
# Test the function with the n_grams_seq of the next 3 examples
next_3_padded_seq = pad_seqs(next_3_examples_sequence, max([len(s) for s in next_3_examples_sequence]))
next_3_padded_seq
# Out:
# array([[  0,   0,   0,   0,   0,   0,   1,  94],
#        [  0,   0,   0,   0,   0,   1,  94,  14],
#        [  0,   0,   0,   0,   1,  94,  14, 428],
#        [  0,   0,   0,   1,  94,  14, 428,  25],
#        [  0,   0,   1,  94,  14, 428,  25,   3],
#        [  0,   1,  94,  14, 428,  25,   3, 379],
#        [  1,  94,  14, 428,  25,   3, 379, 900],
#        [  0,   0,   0,   0,   0,   0,   2,  64],
#        [  0,   0,   0,   0,   0,   2,  64, 206],
#        [  0,   0,   0,   0,   2,  64, 206,   4],
#        [  0,   0,   0,   0,   0,   0,  68,   2],
#        [  0,   0,   0,   0,   0,  68,   2,  64],
#        [  0,   0,   0,   0,  68,   2,  64, 595],
#        [  0,   0,   0,  68,   2,  64, 595, 595],
#        [  0,   0,  68,   2,  64, 595, 595, 219],
#        [  0,  68,   2,  64, 595, 595, 219,   4]], dtype=int32)

# %% [markdown]
# The code applies the "pad_seqs" function to the entire "corpus" to pad all the n-gram sequences to the maximum length. It prints the shape of the padded corpus.

# %%
# Pad the whole corpus
input_sequences = pad_seqs(input_sequences, max_sequence_len)

print(f"padded corpus has shape: {input_sequences.shape}")
# Out:
# padded corpus has shape: (43964, 28)

# %% [markdown]
# The code defines a function called "features_and_labels" that generates features and labels from n-gram sequences. It takes the input sequences and the total number of words as inputs and returns arrays of features and one-hot encoded labels.

# %%
def features_and_labels(input_sequences, total_words):
    """
    Generates features and labels from n-grams

    Args:
        input_sequences (list of int): sequences to split features and labels from
        total_words (int): vocabulary size

    Returns:
        features, one_hot_labels (array of int, array of int): arrays of features and one-hot encoded labels
    """
    input_sequences = np.array(input_sequences)
    features, labels = input_sequences[:,:-1], input_sequences[:,-1]
    one_hot_labels = to_categorical(labels, num_classes=total_words)

    return features, one_hot_labels

# %% [markdown]
# The function is tested with the padded n-gram sequence of the first example by generating features and labels and printing their shapes. It also displays the features.

# %%
# Test the function with the padded n_grams_seq of the first example
first_features, first_labels = features_and_labels(first_padded_seq, total_words)

print(f"labels have shape: {first_labels.shape}")
print("\nfeatures look like this:\n")
first_features
# Out:
# labels have shape: (2, 3443)
#
# features look like this:
# array([[ 0,  1],
#        [ 1, 99]], dtype=int32)

# %% [markdown]
# The function is further tested with the entire padded corpus by generating features and labels and printing their shapes.

# %%
# Split the whole corpus
features, labels = features_and_labels(input_sequences, total_words)

print(f"features have shape: {features.shape}")
print(f"labels have shape: {labels.shape}")
# Out:
# features have shape: (43964, 27)
# labels have shape: (43964, 3443)

# %% [markdown]
# The code defines a function called "create_model" that creates a text generator model using the Keras Sequential API. It takes the total number of words and the maximum sequence length as inputs and returns the model.

# %%
def create_model(total_words, max_sequence_len):
    """
    Creates a text generator model

    Args:
        total_words (int): size of the vocabulary for the Embedding layer input
        max_sequence_len (int): length of the input sequences

    Returns:
        model (tf.keras Model): the text generator model
    """
    model = Sequential()
    model.add(Embedding(total_words, 100, input_length=max_sequence_len-1))
    model.add(Bidirectional(LSTM(150, return_sequences=False)))
    model.add(Dense(total_words, activation='softmax'))

    # Compile the model
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

    return model

# %% [markdown]
# The code gets an untrained model by calling the "create_model" function with the total number of words and maximum sequence length as arguments. The model is trained using the features and labels generated from the entire corpus for 50 epochs. The training progress is displayed.

# %%
# Get the untrained model
model = create_model(total_words, max_sequence_len)

# Train the model
history = model.fit(features, labels, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 1374/1374 [==============================] - 85s 59ms/step - loss: 5.8537 - accuracy: 0.0602
# Epoch 2/100
# 1374/1374 [==============================] - 81s 59ms/step - loss: 4.6479 - accuracy: 0.1735
# Epoch 3/100
# 1374/1374 [==============================] - 81s 59ms/step - loss: 3.7811 - accuracy: 0.2949
# Epoch 4/100
# 1374/1374 [==============================] - 81s 59ms/step - loss: 3.1526 - accuracy: 0.3936
# Epoch 5/100
# 1374/1374 [==============================] - 81s 59ms/step - loss: 2.6811 - accuracy: 0.4690
# Epoch 6/100
# 1374/1374 [==============================] - 81s 59ms/step - loss: 2.3113 - accuracy: 0.5264
# Epoch 7/100
# 1374/1374 [==============================] - 81s 59ms/step - loss: 2.0160 - accuracy: 0.5769
# Epoch 8/100
# 1374/1374 [==============================] - 81s 59ms/step - loss: 1.7816 - accuracy: 0.6179
# Epoch 9/100
# 1374/1374 [==============================] - 81s 59ms/step - loss: 1.5884 - accuracy: 0.6529
# Epoch 10/100
# ...

# %% [markdown]
# The code visualizes the training curves of the model by plotting the training accuracy and training loss over the epochs.

# %%
# Take a look at the training curves of the model

acc = history.history['accuracy']
loss = history.history['loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.title('Training accuracy')

plt.figure()

plt.plot(epochs, loss, 'b', label='Training Loss')
plt.title('Training loss')
plt.legend()

plt.show()

# %% [markdown]
# The code sets a seed text and the number of words to generate. It uses the trained model to generate the specified number of words based on the given seed text. The generated text is then printed.

# %%
seed_text = "Sunshine makes me go"
next_words = 20

for _ in range(next_words):
    # Convert the text into sequences
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    # Pad the sequences
    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
    # Get the probabilities of predicting a word
    predicted = model.predict(token_list, verbose=0)
    # Choose the next word based on the maximum probability
    predicted = np.argmax(predicted, axis=-1).item()
    # Get the actual word from the word index
    output_word = tokenizer.index_word[predicted]
    # Append to the current text
    seed_text += " " + output_word

print(seed_text)
# Out:
# Sunshine makes me go now a dick i'm i'm the the aa i'm soy room i okay me out i out from the pinnapple
