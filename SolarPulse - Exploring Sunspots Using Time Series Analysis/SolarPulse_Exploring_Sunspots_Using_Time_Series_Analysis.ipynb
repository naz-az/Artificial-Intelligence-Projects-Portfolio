# %% [markdown]
# # **Title: SolarPulse - Exploring Sunspots/Solar Activity Patterns Using Time Series Analysis**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Overview/Introduction:
# The study of sunspots and their patterns plays a crucial role in understanding solar activity and its impact on various phenomena on Earth. Sunspots, temporary dark spots on the Sun's photosphere, are indicators of magnetic activity and are known to follow an approximately 11-year solar cycle. These regions of reduced surface temperature provide valuable insights into the behavior of the Sun and its influence on space weather, climate, and communication systems.
#
# In this project, we aim to analyze the Monthly Mean Total Sunspot Number dataset spanning from January 1749 to August 2017. By leveraging time series analysis techniques and employing artificial intelligence (AI) algorithms, we seek to uncover hidden patterns, trends, and anomalies in the sunspot data. This project presents an opportunity to delve into the fascinating realm of solar physics and contribute to our understanding of solar dynamics.
#
# ## Problem Statement:
# The dataset containing Monthly Mean Total Sunspot Numbers offers a rich source of information on solar activity spanning more than two centuries. However, analyzing such a vast and complex dataset manually is a challenging task. The problem statement of this project is to develop an AI-powered solution that can effectively analyze and extract meaningful insights from the sunspot dataset.
#
# By leveraging AI techniques, we aim to address the following challenges:
# 1. Pattern Recognition: Develop algorithms capable of identifying recurring patterns, trends, and cyclic behavior within the sunspot data.
# 2. Forecasting: Build models that can predict future sunspot activity based on historical data, aiding in the anticipation of solar events.
#
# ## Objectives:
# The primary objectives of this AI project on sunspot analysis are as follows:
#
# 1. Data Exploration: Perform comprehensive exploratory data analysis (EDA) to understand the dataset's structure, distribution, and statistical properties. Visualize the sunspot data to identify initial patterns and variations.
#
# 2. Time Series Analysis: Utilize various time series analysis techniques to uncover long-term trends, seasonal patterns, and cyclic behavior within the sunspot dataset.
#
# 3. Forecasting: Build predictive models that can forecast future sunspot activity based on historical data. Evaluate and compare different forecasting algorithms to identify the most accurate and reliable approach.
#
# 4. Visualization and Interpretation: Create interactive visualizations to communicate the findings and insights derived from the analysis effectively. Develop intuitive dashboards and reports that enable researchers and stakeholders to explore and understand the sunspot data.
#
# 5. Contribution to Solar Physics: Contribute to the field of solar physics by providing valuable insights and tools for analyzing sunspot activity. Help researchers and scientists gain a deeper understanding of solar dynamics and its implications on Earth and space-based systems.
#
# Through these objectives, we aim to demonstrate the power of AI and time series analysis in unlocking valuable information hidden within the sunspot dataset. By automating the analysis process, we can save time, enhance accuracy, and contribute to advancements in solar physics research and space weather forecasting.
#
# ## Dataset Description:
# The dataset used in this project is the Monthly Mean Total Sunspot Number, covering the period from January 1749 to August 2017. It is sourced from the Solar Influences Data Analysis Center (SIDC), the solar physics research department of the Royal Observatory of Belgium.
#
# This dataset provides a comprehensive record of sunspot activity over more than 250 years, encompassing various solar cycles. Each data point represents the monthly average total number of sunspots observed during a specific period. Sunspots are temporary phenomena on the Sun's photosphere that appear as dark spots due to magnetic field flux concentrations inhibiting convection and reducing surface temperature.
#
# **Dataset URL:** https://www.kaggle.com/datasets/robervalt/sunspots

# %% [markdown]
# ## Technologies Used:
#
# - Python: The primary programming language used for implementing the AI project.
# - TensorFlow: An open-source machine learning framework used for building and training the deep learning models.
# - NumPy: A Python library for numerical computations, used for handling arrays and mathematical operations.
# - Matplotlib: A plotting library in Python used for visualizing data and generating informative plots.
# - CSV: A built-in Python module used for reading and parsing the Sunspots dataset stored in CSV format.
#
# ## Methodology:
#
# 1. Data Preparation: The code starts by downloading the Sunspots dataset from a specified URL using the `wget` command. The dataset is then loaded into memory, and the time steps and sunspot values are extracted from the CSV file.
#
# 2. Data Exploration: The code visualizes the Monthly Mean Total Sunspot Number over time by plotting the series using the `plot_series` function. This step helps in understanding the general trends and patterns present in the dataset.
#
# 3. Data Splitting: The dataset is split into a training set and a validation set using the specified split time. This separation ensures that the model is trained on historical data and evaluated on unseen future data.
#
# 4. Windowed Dataset Generation: The code defines the `windowed_dataset` function, which creates time windows from the training and validation sets. These windows are used to train the model on a sequence of past sunspot values and predict the next sunspot value.
#
# 5. Model Building: The AI model architecture is defined using the Sequential API from TensorFlow. The model consists of Conv1D layers for feature extraction, LSTM layers for capturing temporal dependencies, and Dense layers for prediction. The model's summary provides an overview of its structure and the number of trainable parameters.
#
# 6. Model Training: The model is compiled with a loss function and an optimizer. The `fit` function is called to train the model on the training set, with validation data used for monitoring the model's performance during training. A learning rate schedule is used to adjust the learning rate over time, aiding in model convergence.
#
# 7. Model Evaluation: The code visualizes the training history by plotting the Mean Absolute Error (MAE) and Loss values over the training epochs. This analysis helps in understanding the model's learning progress and potential overfitting.
#
# 8. Model Forecasting: The trained model is used to generate predictions on the validation set. The `model_forecast` function generates predictions by feeding the model with time windows from the validation set. The predictions are then compared with the actual sunspot values.
#
# 9. Results Analysis: The code computes and prints the Mean Squared Error (MSE) and Mean Absolute Error (MAE) between the predicted sunspot values and the actual values from the validation set. These metrics provide quantitative measures of the model's performance in capturing the sunspot patterns.
#
# 10. Callback: The code demonstrates the use of a learning rate scheduler, including the `ExponentialDecay`, to dynamically adjust the learning rate during training. The model is recompiled and trained using the new learning rate schedule, and the results are compared with the previous training results.
#
#
# # Results:
#
# The evaluation of the AI project on sunspot analysis yielded the following results:
#
# - Results before exponential decay:
#   - MSE: 409.55133
#   - MAE: 13.902151
#
# - Results after exponential decay:
#   - MSE: 413.23022
#   - MAE: 13.939402
#
# # Discussion:
#
# Comparing the results before and after applying exponential decay to the learning rate schedule, we observe a slight increase in both MSE and MAE values. This suggests a potential small adverse effect on the model's predictive accuracy. However, the differences in MSE and MAE between the two scenarios are minimal, indicating that the impact of the learning rate schedule is not significant.
#
# # Conclusion:
#
# The AI project on sunspot analysis demonstrates the application of deep learning techniques and time series analysis for understanding and predicting solar activity patterns. The evaluation results, MSE and MAE, provide insights into the model's predictive accuracy.
#
# The comparison of results before and after applying exponential decay to the learning rate schedule suggests a slight impact on the model's performance. Further experimentation and fine-tuning may be necessary for improved accuracy. Overall, the project showcases the potential of AI-powered analysis in solar physics research and space weather forecasting, contributing to our understanding of solar dynamics.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import csv
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %% [markdown]
# The following code defines a function called plot_series that visualizes time series data using matplotlib. It takes input parameters such as x and y values, line style, start and end time steps, plot title, x and y axis labels, and legend. The function plots the data, labels the axes, sets the legend and title, overlays a grid, and displays the graph on the screen.

# %%
def plot_series(x, y, format="-", start=0, end=None,
                title=None, xlabel=None, ylabel=None, legend=None ):
    """
    Visualizes time series data

    Args:
      x (array of int) - contains values for the x-axis
      y (array of int or tuple of arrays) - contains the values for the y-axis
      format (string) - line style when plotting the graph
      start (int) - first time step to plot
      end (int) - last time step to plot
      title (string) - title of the plot
      xlabel (string) - label for the x-axis
      ylabel (string) - label for the y-axis
      legend (list of strings) - legend for the plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))

    # Check if there are more than two series to plot
    if type(y) is tuple:

      # Loop over the y elements
      for y_curr in y:

        # Plot the x and current y values
        plt.plot(x[start:end], y_curr[start:end], format)

    else:
      # Plot the x and y values
      plt.plot(x[start:end], y[start:end], format)

    # Label the x-axis
    plt.xlabel(xlabel)

    # Label the y-axis
    plt.ylabel(ylabel)

    # Set the legend
    if legend:
      plt.legend(legend)

    # Set the title
    plt.title(title)

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

# %% [markdown]
# The next code block downloads a dataset called "Sunspots.csv" using the wget command. It initializes two empty lists, time_step and sunspots, then opens the CSV file and reads its contents. It appends the values from the second and third columns of each row to the respective lists. Finally, it converts the lists into NumPy arrays and previews the data using the plot_series function.

# %%
# Download the Dataset
# !wget https://storage.googleapis.com/tensorflow-1-public/course4/Sunspots.csv
# Out:
# --2023-07-11 04:09:37--  https://storage.googleapis.com/tensorflow-1-public/course4/Sunspots.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.24.48, 2404:6800:4006:804::2010
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.24.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70827 (69K) [text/csv]
# Saving to: ‘Sunspots.csv’
#
# Sunspots.csv        100%[===================>]  69.17K  --.-KB/s    in 0.1s
#
# 2023-07-11 04:09:39 (497 KB/s) - ‘Sunspots.csv’ saved [70827/70827]

# %%
# Initialize lists
time_step = []
sunspots = []

# Open CSV file
with open('./Sunspots.csv') as csvfile:

  # Initialize reader
  reader = csv.reader(csvfile, delimiter=',')

  # Skip the first line
  next(reader)

  # Append row and sunspot number to lists
  for row in reader:
    time_step.append(int(row[0]))
    sunspots.append(float(row[2]))

# Convert lists to numpy arrays
time = np.array(time_step)
series = np.array(sunspots)

# Preview the data
plot_series(time, series, xlabel='Month', ylabel='Monthly Mean Total Sunspot Number')

# %% [markdown]
# The subsequent code block defines the split time for dividing the data into training and validation sets. It splits the time and series arrays based on the split time and assigns them to time_train, x_train, time_valid, and x_valid, respectively.

# %%
# Define the split time
split_time = 3000

# Get the train set
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

# %% [markdown]
# The next code block defines a function called windowed_dataset that generates dataset windows for time series data. It takes parameters such as the series data, window size, batch size, and shuffle buffer. The function creates a TensorFlow Dataset from the series, windows the data with the specified window size, flattens the windows, creates tuples of features and labels, shuffles the windows, creates batches, and returns the dataset.

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    dataset = dataset.shuffle(shuffle_buffer)

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)

    return dataset

# %% [markdown]
# In the following code block, window size, batch size, and shuffle buffer size are defined as parameters. The windowed_dataset function is then called to generate training and validation datasets (train_set and val_set) from the x_train and x_valid series.

# %%
# Parameters
window_size = 30
batch_size = 32
shuffle_buffer_size = 1000

# Generate the dataset windows
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# Generate data windows of the validation set
val_set = windowed_dataset(x_valid, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# The next code block builds a sequential model using the Keras API. The model consists of several layers, including a 1D convolutional layer, two LSTM layers, and several dense layers with different activation functions. The model's summary is printed to provide an overview of its architecture.

# %%
# Build the Model
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=64, kernel_size=3,
                      strides=1,
                      activation="relu",
                      padding='causal',
                      input_shape=[window_size, 1]),
  tf.keras.layers.LSTM(64, return_sequences=True),
  tf.keras.layers.LSTM(64),
  tf.keras.layers.Dense(30, activation="relu"),
  tf.keras.layers.Dense(10, activation="relu"),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 400)
])

 # Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 30, 64)            256
#
#  lstm (LSTM)                 (None, 30, 64)            33024
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 30)                1950
#
#  dense_1 (Dense)             (None, 10)                310
#
#  dense_2 (Dense)             (None, 1)                 11
#
#  lambda (Lambda)             (None, 1)                 0
#
# ...
# Total params: 68,575
# Trainable params: 68,575
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The subsequent code block retrieves the initial weights of the model.

# %%
# Get initial weights
init_weights = model.get_weights()

# %% [markdown]
# The next code block sets up a learning rate scheduler using a lambda function and defines an optimizer with stochastic gradient descent (SGD) and a momentum of 0.9. The model's loss function is set to the Huber loss. The model is then compiled with the specified parameters. Training is performed using the fit function, which takes the training and validation datasets, the number of epochs, and the learning rate scheduler as arguments.

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model.fit(train_set, validation_data=val_set, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 93/93 [==============================] - 12s 24ms/step - loss: 49.4593 - val_loss: 33.5496 - lr: 1.0000e-08
# Epoch 2/100
# 93/93 [==============================] - 1s 12ms/step - loss: 45.2381 - val_loss: 30.3498 - lr: 1.1220e-08
# Epoch 3/100
# 93/93 [==============================] - 1s 11ms/step - loss: 41.1524 - val_loss: 26.9827 - lr: 1.2589e-08
# Epoch 4/100
# 93/93 [==============================] - 1s 12ms/step - loss: 38.3627 - val_loss: 25.7406 - lr: 1.4125e-08
# Epoch 5/100
# 93/93 [==============================] - 1s 11ms/step - loss: 36.3927 - val_loss: 24.5694 - lr: 1.5849e-08
# Epoch 6/100
# 93/93 [==============================] - 1s 11ms/step - loss: 34.8020 - val_loss: 23.5080 - lr: 1.7783e-08
# Epoch 7/100
# 93/93 [==============================] - 1s 12ms/step - loss: 33.4235 - val_loss: 22.5960 - lr: 1.9953e-08
# Epoch 8/100
# 93/93 [==============================] - 1s 11ms/step - loss: 32.0387 - val_loss: 21.4631 - lr: 2.2387e-08
# Epoch 9/100
# ...

# %% [markdown]
# In the following code block, an array of learning rates is defined for visualization purposes. The learning rates are logarithmically spaced. A plot is created to visualize the learning rates and the corresponding loss values from the training history.

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(100) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the loss in log scale
plt.semilogx(lrs, history.history["loss"])

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-3, 0, 100])
# Out:
# (1e-08, 0.001, 0.0, 100.0)

# %% [markdown]
# The next code block resets the states generated by Keras and sets the model weights to the initial weights retrieved earlier.

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

# Reset the weights
model.set_weights(init_weights)

# %% [markdown]
# In the subsequent code block, a learning rate is set, an optimizer is defined with SGD and the specified learning rate and momentum, and the model is compiled with the Huber loss and mean absolute error (MAE) as a metric. The model is then trained using the training and validation datasets.

# %%
# Set the learning rate
learning_rate = 8e-7

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# %%
# Train the model
history = model.fit(train_set,validation_data=val_set, epochs=100)
# Out:
# Epoch 1/100
# 93/93 [==============================] - 6s 23ms/step - loss: 30.0479 - mae: 30.5433 - val_loss: 16.1830 - val_mae: 16.6727
# Epoch 2/100
# 93/93 [==============================] - 1s 11ms/step - loss: 20.9098 - mae: 21.4041 - val_loss: 13.7941 - val_mae: 14.2777
# Epoch 3/100
# 93/93 [==============================] - 1s 12ms/step - loss: 19.2102 - mae: 19.7040 - val_loss: 15.8313 - val_mae: 16.3253
# Epoch 4/100
# 93/93 [==============================] - 1s 12ms/step - loss: 19.2890 - mae: 19.7814 - val_loss: 14.5692 - val_mae: 15.0620
# Epoch 5/100
# 93/93 [==============================] - 1s 11ms/step - loss: 18.3863 - mae: 18.8786 - val_loss: 12.9057 - val_mae: 13.3974
# Epoch 6/100
# 93/93 [==============================] - 1s 11ms/step - loss: 18.4442 - mae: 18.9385 - val_loss: 12.5664 - val_mae: 13.0537
# Epoch 7/100
# 93/93 [==============================] - 1s 12ms/step - loss: 18.7669 - mae: 19.2601 - val_loss: 12.7810 - val_mae: 13.2688
# Epoch 8/100
# ...

# %% [markdown]
# The next code block extracts the MAE and loss values from the training history. The number of epochs is determined, and a plot is created to display the MAE and loss values over the epochs. A zoomed-in plot is also created to focus on the last 20% of the epochs.

# %%
# Get mae and loss from history log
mae=history.history['mae']
loss=history.history['loss']

# Get number of epochs
epochs=range(len(loss))

# Plot mae and loss
plot_series(
    x=epochs,
    y=(mae, loss),
    title='MAE and Loss',
    xlabel='MAE',
    ylabel='Loss',
    legend=['MAE', 'Loss']
    )

# Only plot the last 80% of the epochs
zoom_split = int(epochs[-1] * 0.2)
epochs_zoom = epochs[zoom_split:]
mae_zoom = mae[zoom_split:]
loss_zoom = loss[zoom_split:]

# Plot zoomed mae and loss
plot_series(
    x=epochs_zoom,
    y=(mae_zoom, loss_zoom),
    title='MAE and Loss',
    xlabel='MAE',
    ylabel='Loss',
    legend=['MAE', 'Loss']
    )

# %% [markdown]
# The following code block defines a function called model_forecast that uses the input model to generate predictions on data windows. The function takes the model, series data, window size, and batch size as input. It generates a TensorFlow Dataset from the series, windows the data with the specified window size, creates batches, and predicts the values using the model.

# %%
def model_forecast(model, series, window_size, batch_size):
    """Uses an input model to generate predictions on data windows

    Args:
      model (TF Keras Model) - model that accepts data windows
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the window
      batch_size (int) - the batch size

    Returns:
      forecast (numpy array) - array containing predictions
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda w: w.batch(window_size))

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)

    # Get predictions on the entire dataset
    forecast = model.predict(dataset)

    return forecast

# %% [markdown]
# In the subsequent code block, the original series is reduced to match the size of the validation set. The model_forecast function is used to generate predictions based on the reduced series. The results are plotted using the plot_series function, comparing the predictions with the actual validation data.

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 8/8 [==============================] - 1s 15ms/step

# %% [markdown]
# The next code block computes the mean squared error (MSE) and mean absolute error (MAE) between the validation data and the predicted results.

# %%
## Compute the MAE and MSE
print(tf.keras.metrics.mean_squared_error(x_valid, results).numpy())
print(tf.keras.metrics.mean_absolute_error(x_valid, results).numpy())
# Out:
# 409.55133
# 13.902151

# %% [markdown]
# **Callback: ExponentialDecay**
#
# In the following code block, the initial learning rate, a learning rate schedule using ExponentialDecay, an optimizer with SGD and the learning rate schedule, and the training parameters are defined. The model is compiled and trained using the training dataset for a specified number of epochs.

# %%
# Set the initial learning rate
initial_learning_rate=1e-7

# Define the scheduler
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=400,
    decay_rate=0.96,
    staircase=True)

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Train the model
history = model.fit(train_set,epochs=40)
# Out:
# Epoch 1/40
# 93/93 [==============================] - 5s 11ms/step - loss: 16.5352 - mae: 17.0242
# Epoch 2/40
# 93/93 [==============================] - 1s 10ms/step - loss: 16.4291 - mae: 16.9204
# Epoch 3/40
# 93/93 [==============================] - 1s 10ms/step - loss: 16.4835 - mae: 16.9735
# Epoch 4/40
# 93/93 [==============================] - 1s 11ms/step - loss: 16.4145 - mae: 16.9044
# Epoch 5/40
# 93/93 [==============================] - 1s 12ms/step - loss: 16.4062 - mae: 16.8960
# Epoch 6/40
# 93/93 [==============================] - 2s 15ms/step - loss: 16.4230 - mae: 16.9127
# Epoch 7/40
# 93/93 [==============================] - 1s 11ms/step - loss: 16.4577 - mae: 16.9468
# Epoch 8/40
# 93/93 [==============================] - 1s 11ms/step - loss: 16.4023 - mae: 16.8908
# Epoch 9/40
# 93/93 [==============================] - 1s 11ms/step - loss: 16.3872 - mae: 16.8770
# Epoch 10/40
# ...

# %% [markdown]
# The subsequent code block repeats the steps of generating predictions and plotting the results, similar to the previous forecast.

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 8/8 [==============================] - 1s 12ms/step

# %% [markdown]
#  The MAE and MSE between the validation data and the predicted results are computed and printed.

# %%
## Compute the MAE and MSE
print(tf.keras.metrics.mean_squared_error(x_valid, results).numpy())
print(tf.keras.metrics.mean_absolute_error(x_valid, results).numpy())
# Out:
# 413.23022
# 13.939402
