# %% [markdown]
# # **Title: WindTrack - Forecasting Wind Power Infeed in Germany: A Time Series Analysis**

# %% [markdown]
# ![Screenshot 2023-07-11 122948.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Overview/Introduction:
# Renewable energy, particularly wind power, plays a crucial role in Germany's electricity generation. With over 83,000 megawatts (MW) of installed capacity as of 2020, wind turbines are a key contributor to the country's renewable energy mix. However, wind power generation is subject to fluctuations depending on weather conditions, and these fluctuations pose challenges in matching electricity supply with demand. To address this issue, an AI project can leverage time series analysis to forecast the actual wind power infeed in Germany. By accurately predicting the future power infeed, energy grid operators can better manage the integration of wind power into the grid, optimize storage solutions, and ensure a stable and reliable electricity supply.
#
# ## Problem Statement:
# The intermittent nature of wind power generation poses significant challenges for grid operators and energy planners. The inconsistency between wind power supply and electricity demand requires efficient forecasting methods to optimize the integration and utilization of wind energy. Inaccurate predictions can lead to imbalances between supply and demand, which may result in costly energy imbalances, increased reliance on backup power sources, and potential disruptions to the power grid. Therefore, the problem at hand is to develop an AI-based forecasting model that accurately predicts the time series of actual wind power infeed in Germany, enabling effective grid management and supporting the successful integration of wind energy.
#
# ## Objectives:
# The main objectives of this AI project are as follows:
# 1. Develop a robust forecasting model: Create an AI model to accurately forecast wind power infeed in Germany by analyzing historical data, including wind power and weather conditions.
#
# 2. Improve grid management: Provide energy grid operators with accurate wind power forecasts to optimize operations, balance supply and demand, and ensure a reliable electricity supply.
#
# 3. Optimize energy storage and backup solutions: Enable efficient utilization of energy storage systems by accurately predicting wind power generation, reducing reliance on backup power sources, and facilitating the integration of wind energy into the grid.
#
# 4. Facilitate renewable energy planning: Support informed decisions on wind turbine placement and capacity, considering local demand, weather patterns, and transmission capabilities for effective long-term planning of renewable energy infrastructure.
#
# 5. Support climate change mitigation: Enhance wind energy utilization, reduce dependence on fossil fuels, and accelerate the transition to a cleaner and more sustainable energy future by improving the accuracy of wind power forecasts.
#
#
# ## Dataset Description:
# The dataset used in this AI project consists of historical records of actual wind power infeed in Germany. It encompasses a time series of wind power measurements, typically recorded at regular intervals (e.g., hourly or sub-hourly) over a specific period. The dataset also includes relevant weather data, such as wind speed, temperature, and atmospheric conditions, which influence wind power generation. Additionally, other contextual information, such as geographical location, turbine specifications, and electricity demand patterns, may be incorporated to enhance the forecasting model's accuracy.
#
# By analyzing this comprehensive dataset, the AI project aims to uncover temporal patterns, correlations, and dependencies between wind power generation and various influencing factors. The model will utilize this knowledge to make accurate predictions of wind power infeed, enabling stakeholders to make informed decisions regarding grid management, energy storage, and renewable energy planning in Germany.
#
# **Dataset URL:** https://www.kaggle.com/datasets/l3llff/wind-power

# %% [markdown]
# ## Technologies Used:
# - Python: The code is written in Python, a popular programming language for data analysis and machine learning tasks.
# - Pandas: Pandas library is used for data manipulation and analysis, providing convenient data structures and functions.
# - NumPy: NumPy is a fundamental package for scientific computing in Python, used for efficient numerical operations.
# - TensorFlow: TensorFlow is a popular open-source library for machine learning and deep learning, used to build and train neural networks.
# - Keras: Keras is a high-level API built on top of TensorFlow, providing a user-friendly interface for building and training neural networks.
# - Matplotlib: Matplotlib is a plotting library in Python used to visualize the data and generate plots.
# - CSV: The code uses the CSV module to read and parse data from a CSV file.
#
# ## Methodology:
# 1. Data Preprocessing: The code imports the necessary libraries and preprocesses the wind power dataset using Pandas. It handles missing values and duplicates, ensuring data integrity.
#
# 2. Exploratory Data Analysis: Matplotlib is employed to visualize the wind power infeed over time, gaining insights into its patterns and fluctuations.
#
# 3. Dataset Splitting: The code splits the dataset into training and validation sets, facilitating model evaluation.
#
# 4. Feature Preparation: TensorFlow is utilized to generate windowed datasets for training, enabling effective feature engineering.
#
# 5. Model Building and Training: Several models, including Dense, Simple RNN, Bi-directional LSTM, and Conv1D, are constructed using Keras on top of TensorFlow. The models are compiled with appropriate loss functions, optimizers, and metrics, and then trained using the fit method.
#
# 6. Model Evaluation and Forecasting: The trained models are evaluated by generating predictions on the validation set. The results are compared using evaluation metrics such as MAE, MSE, RMSE, MAPE, MASE, and R2.
#
# ## Results:
# The evaluation of the models yields the following metrics:
#
# | Model        | MAE       | MSE             | RMSE       | MAPE     | MASE      | R2        |
# |--------------|-----------|-----------------|------------|----------|-----------|-----------|
# | Model_Dense1 | 125.425   | 248,144.75      | 498.141    | 4.949%   | 0.792     | 0.980     |
# | Conv1D       | 149.346   | 257,434.14      | 507.380    | 5.805%   | 0.943     | 0.980     |
# | Bi-LSTM      | 159.142   | 288,008.34      | 536.664    | 5.402%   | 1.005     | 0.977     |
# | Simple RNN   | 171.480   | 319,135.84      | 564.921    | 6.310%   | 1.083     | 0.975     |
#
# ## Discussion/Interpretation of Results:
# The evaluation of the models reveals insights into their performance in forecasting wind power infeed in Germany. The Model_Dense1 achieves the lowest MAE, indicating the highest accuracy in predicting wind power values. The Conv1D model follows closely with a slightly higher MAE. The Bi-LSTM and Simple RNN models demonstrate higher MAE values, suggesting lower accuracy compared to the other models.
#
# The results emphasize the potential of the Dense and Conv1D models to provide reliable wind power forecasts, supporting grid management, energy storage optimization, and renewable energy planning. These models exhibit better performance in terms of MAE, indicating their ability to make more accurate predictions. However, all models demonstrate reasonably good performance across the evaluated metrics.
#
# ## Conclusion:
# This AI project successfully develops and trains various models for forecasting wind power infeed in Germany. The Dense and Conv1D models exhibit superior accuracy, making them particularly suitable for wind power forecasting applications. By leveraging these models, stakeholders can enhance grid management, optimize energy storage, and facilitate effective renewable energy planning. The findings contribute to the utilization of wind energy and support the transition towards a sustainable and cleaner energy future.
#
# Further research and optimization efforts can be pursued to improve the performance of the models, potentially reducing the MAE values even further. By fine-tuning the models and exploring additional architectural variations, the accuracy of wind power forecasts can be enhanced, enabling more efficient integration of wind energy into the grid and fostering a sustainable energy landscape.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/wind-power/data.csv

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# ...

# %% [markdown]
# The following code shows the import of the pandas library, which is commonly used for data manipulation and analysis. It then reads a CSV file named "data.csv" and parses the dates in the "dt" column, setting it as the index column of the DataFrame.

# %%
# Import with pandas
import pandas as pd
# Parse dates and set date column to index
df = pd.read_csv("/kaggle/input/wind-power/data.csv",
                 parse_dates=["dt"],
                 index_col=["dt"]) # parse the date column (tell pandas column 1 is a datetime)
df.head()
# Out:
#                          MW
# dt
# 2011-01-01 00:00:00  3416.0
# 2011-01-01 00:15:00  4755.0
# 2011-01-01 00:30:00  4939.0
# 2011-01-01 00:45:00  4939.0
# 2011-01-01 01:00:00  4998.0

# %%
# How many samples do we have?
len(df)
# Out:
# 385566

# %% [markdown]
# The next code calculates and prints the number of data points in the dataset. The subsequent code checks for duplicates in the dataset and prints the number of duplicates found. The code then checks for missing values in the dataset and prints the number of missing values in each column and the total number of missing values. After that, the code replaces empty strings with NaN values in the dataset and checks for missing values again, printing the updated counts.

# %%
import numpy as np

# How many data do we have?
print('There are', df.shape[0], 'data in this dataset')

# Do we have duplicates?
print('Number of Duplicates:', len(df[df.duplicated()]))

# Do we have missing values?
missing_values = df.isnull().sum()
print('Number of Missing Values by column:\n',missing_values)

print('Number of Missing Values:', df.isnull().sum().sum())

df.replace("", np.nan, inplace=True)
missing_values = df.isnull().sum()
print('Number of Missing Values by column after replacement:\n',missing_values)
print('Number of Missing Values after replacement:', df.isnull().sum().sum())
# Out:
# There are 385566 data in this dataset
# Number of Duplicates: 191101
# Number of Missing Values by column:
#  MW    0
# dtype: int64
# Number of Missing Values: 0
# Number of Missing Values by column after replacement:
#  MW    0
# dtype: int64
# Number of Missing Values after replacement: 0

# %%
# Dtypes of various columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 385566 entries, 2011-01-01 00:00:00 to 2021-12-30 07:45:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   MW      385566 non-null  float64
# dtypes: float64(1)
# memory usage: 5.9 MB

# %% [markdown]
# The next code block retrieves the first and last date from the index of the DataFrame and formats them into a single string representing the date range.

# %%
# get the first and last date from the index
first_date = df.index.min().strftime('%Y-%m-%d')
last_date = df.index.max().strftime('%Y-%m-%d')

# combine the dates into a single string
date_range = f"{first_date} to {last_date}"
date_range
# Out:
# '2011-01-01 to 2021-12-30'

# %% [markdown]
# The next code imports the matplotlib.pyplot library, which is used for data visualization. It plots the DataFrame using the plot() function, specifying the figure size and labeling the y-axis and title. The legend is also displayed.

# %%
import matplotlib.pyplot as plt
df.plot(figsize=(10, 7))
plt.ylabel("values")
plt.title(f"values from from {date_range}", fontsize=16)
plt.legend(fontsize=14);

# %% [markdown]
# The code df.describe().T computes the descriptive statistics of the DataFrame, providing information such as count, mean, standard deviation, minimum, and maximum values for each column.

# %%
df.describe().T
# Out:
#        count         mean          std  min    25%     50%        75%      max
# MW  385566.0  3183.560481  3045.941591  0.0  905.0  2164.0  4529.8775  16727.5

# %% [markdown]
# **Utilities**
#
# The next code defines a function named plot_series that visualizes time series data. It takes as input an array of time steps and an array of measurements for each time step. The function allows customization of line style, start and end time steps to plot, and handles both single and multiple series. The resulting graph is displayed.

# %%
def plot_series(time, series, format="-", start=0, end=None):
    """
    Visualizes time series data

    Args:
      time (array of int) - contains the time steps
      series (array of int) - contains the measurements for each time step
      format - line style when plotting the graph
      start - first time step to plot
      end - last time step to plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))

    if type(series) is tuple:

      for series_num in series:
        # Plot the time series data
        plt.plot(time[start:end], series_num[start:end], format)

    else:
      # Plot the time series data
      plt.plot(time[start:end], series[start:end], format)

    # Label the x-axis
    plt.xlabel("Time")

    # Label the y-axis
    plt.ylabel("Value")

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

# %% [markdown]
# **Import Data with Python**
#
# The next code block imports the csv module and opens the "data.csv" file. It creates a csv.reader object and reads the first row, which contains the column names. The indices of the "dt" and "MW" columns are identified and printed.

# %%
import csv

# Open the CSV file
with open("/kaggle/input/wind-power/data.csv", "r") as f:

    # Create a CSV reader object
    reader = csv.reader(f)

    # Read the first row (header) of the CSV file
    header = next(reader)

    # Print the column names
    print(header)

    # Find the indices of columns with names "Date" and "Close"
    date_index = header.index("dt")
    mw_index = header.index("MW")

    # Print the indices for columns "Date" and "Close"
    print("Index for column 'Date':", date_index)
    print("Index for column 'MW':", mw_index)
# Out:
# ['dt', 'MW']
# Index for column 'Date': 0
# Index for column 'MW': 1

# %% [markdown]
# The following code opens the "data.csv" file, reads the data using the csv.reader object, and appends the parsed dates and measurements to the time and series lists, respectively. The first 10 entries of both lists are displayed.

# %%
from datetime import datetime

time = []
series = []

with open("/kaggle/input/wind-power/data.csv", "r") as f:
  csv_reader = csv.reader(f, delimiter=",") # read in the target CSV
  next(csv_reader) # skip first line (this gets rid of the column titles)
  for line in csv_reader:
    time.append(datetime.strptime(line[date_index], "%Y-%m-%d %H:%M:%S")) # get the dates as dates (not strings), strptime = string parse time
    series.append(float(line[mw_index])) # get the average price as float

# View first 10 of each
time[:10], series[:10]
# Out:
# ([datetime.datetime(2011, 1, 1, 0, 0),
#   datetime.datetime(2011, 1, 1, 0, 15),
#   datetime.datetime(2011, 1, 1, 0, 30),
#   datetime.datetime(2011, 1, 1, 0, 45),
#   datetime.datetime(2011, 1, 1, 1, 0),
#   datetime.datetime(2011, 1, 1, 1, 15),
#   datetime.datetime(2011, 1, 1, 1, 30),
#   datetime.datetime(2011, 1, 1, 1, 45),
#   datetime.datetime(2011, 1, 1, 2, 0),
#   datetime.datetime(2011, 1, 1, 2, 15)],
#  [3416.0,
#   4755.0,
#   4939.0,
#   4939.0,
#   4998.0,
#   5184.0,
#   5341.0,
#   5438.0,
#   5509.0,
#   5638.0])

# %% [markdown]
# **Split the Dataset**
#
# The code block defines the split time, which determines the ratio of the training set to the total dataset. It calculates the split index based on the length of the series and the split ratio. The training and validation sets are then created by splitting the time and series data.

# %%
# Define the split time
split_ratio = 0.8  # 80% for the training set
split_time = int(len(series) * split_ratio)

# Get the train set
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

# %%
time_train[:2], x_train[:2], time_valid[:2], x_valid[:2]
# Out:
# ([datetime.datetime(2011, 1, 1, 0, 0), datetime.datetime(2011, 1, 1, 0, 15)],
#  [3416.0, 4755.0],
#  [datetime.datetime(2019, 10, 19, 2, 30),
#   datetime.datetime(2019, 10, 19, 2, 45)],
#  [5092.28, 5025.84])

# %%
len(time_train), len(x_train), len(time_valid), len(x_valid),
# Out:
# (308452, 308452, 77114, 77114)

# %% [markdown]
# The last code block displays a plot showing the train and test data split over time. The training data is plotted in orange, and the test data is plotted in purple. The x-axis represents dates, and the y-axis represents the values. The plot is labeled and displayed.

# %%
#displays a plot of the train/test split
fig = plt.figure(figsize=(15,5))
plt.plot(time_train, x_train, color='orange', label='Train Data')
plt.plot(time_valid, x_valid, color='purple', label='Test Data')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Train-Test Split')
plt.legend()
plt.show()

# %% [markdown]
# **Prepare Features and Labels**

# %% [markdown]
# The next code block defines the parameters for creating windowed datasets for time series analysis. It specifies the window size, batch size, and shuffle buffer size.

# %%
# Parameters
window_size = 7
batch_size = 32
shuffle_buffer_size = 1000

# %% [markdown]
# The windowed_dataset function generates a TensorFlow Dataset object containing time windows. It takes the series data, window size, batch size, and shuffle buffer size as inputs and returns the dataset.

# %%
import tensorflow as tf

def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    dataset = dataset.shuffle(shuffle_buffer)

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)

    return dataset

# %% [markdown]
# The code block generates the dataset windows for the training set using the windowed_dataset function.

# %%
# Generate the dataset windows
dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# The next code block generates data windows for the validation set using the windowed_dataset function.

# %%
# Generate data windows of the validation set
val_set = windowed_dataset(x_valid, window_size, batch_size, shuffle_buffer_size)

# %%
dataset, val_set
# Out:
# (<_PrefetchDataset element_spec=(TensorSpec(shape=(None, None), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>,
#  <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>)

# %% [markdown]
# The code block prints the shape of a sample batch from the training dataset, showing the shape of the input features and labels.

# %%
for a,b in dataset.take(1):
    print(a.shape)
    print(b.shape)
# Out:
# (32, 7)
# (32,)

# %% [markdown]
# The code block prints the shape of a sample batch from the validation dataset, showing the shape of the input features and labels.

# %%
for c,d in val_set.take(1):
    print(c.shape)
    print(d.shape)
# Out:
# (32, 7)
# (32,)

# %% [markdown]
# **Model: Dense**
#
# The following code block builds a baseline model using the Sequential API of TensorFlow's Keras module. The model consists of three dense layers with 32, 16, and 1 units, respectively, and ReLU activation. It then prints a summary of the model, which provides an overview of the model's architecture and the number of parameters.

# %%
tf.random.set_seed(42)

# Build the model
model_baseline = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, input_shape=[window_size], activation="relu"),
    tf.keras.layers.Dense(16, activation="relu"),
    tf.keras.layers.Dense(1)
])

# Print the model summary
model_baseline.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 32)                256
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# ...
# Total params: 801
# Trainable params: 801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The next code block imports necessary modules for defining the loss function (Huber) and optimizer (Adam). It sets the training parameters for the baseline model by specifying the loss function, optimizer, and metrics (mean absolute error).

# %%
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam

# Set the training parameters
model_baseline.compile(
    loss=Huber(),
    optimizer=Adam(),
    metrics=['mae']
)

# %% [markdown]
# The cc function creates a ModelCheckpoint callback in TensorFlow to save the best model. It specifies a filepath for saving, sets verbosity to limit output, and saves only the best model based on performance.

# %%
# Create a function to implement a ModelCheckpoint callback with a specific filename
def cc(filepath):
  return tf.keras.callbacks.ModelCheckpoint(filepath, # create filepath to save model
                                            verbose=1, # only output a limited amount of text
                                            save_best_only=True) # save only the best model to file

# %%
filepath="best_base.h5"

# %% [markdown]
# The code block trains the baseline model using the fit method, providing the training dataset (dataset) and the validation dataset (val_set) as input, and specifying the number of epochs.

# %%
# Train the model
model_baseline.fit(dataset,validation_data=val_set, epochs=10, callbacks=[cc(filepath)])
# Out:
# Epoch 1/10
#    9632/Unknown - 66s 6ms/step - loss: 111.9581 - mae: 112.4555
# Epoch 1: val_loss improved from inf to 135.87563, saving model to best_base.h5
# 9639/9639 [==============================] - 87s 9ms/step - loss: 112.0116 - mae: 112.5089 - val_loss: 135.8756 - val_mae: 136.3737
# Epoch 2/10
# 9634/9639 [============================>.] - ETA: 0s - loss: 103.9013 - mae: 104.3987
# Epoch 2: val_loss improved from 135.87563 to 131.63443, saving model to best_base.h5
# 9639/9639 [==============================] - 88s 9ms/step - loss: 103.9027 - mae: 104.4001 - val_loss: 131.6344 - val_mae: 132.1322
# Epoch 3/10
# 9626/9639 [============================>.] - ETA: 0s - loss: 102.0680 - mae: 102.5652
# Epoch 3: val_loss improved from 131.63443 to 127.20245, saving model to best_base.h5
# 9639/9639 [==============================] - 79s 8ms/step - loss: 102.1152 - mae: 102.6124 - val_loss: 127.2024 - val_mae: 127.7002
# Epoch 4/10
# ...

# %% [markdown]
# The code loads a best model from the filepath using TensorFlow's load_model function.

# %%
from tensorflow.keras.models import load_model

# Load the entire model
model_baseline = load_model(filepath)

# %% [markdown]
# After training the model, the code block evaluates the model's performance on the validation dataset using the evaluate method, which returns the loss and metrics values.

# %%
# Evaluate model on test data
model_baseline.evaluate(val_set)
# Out:
# 2410/2410 [==============================] - 13s 5ms/step - loss: 124.9360 - mae: 125.4339
# [124.9360122680664, 125.43390655517578]

# %% [markdown]
# The code uses the trained model to generate predictions on the validation dataset and assigns the predictions to the model_1_preds variable.

# %%
model_1_preds = model_baseline.predict(val_set)
model_1_preds.shape
# Out:
# 2410/2410 [==============================] - 10s 4ms/step
# (77107, 1)

# %% [markdown]
# The next code block defines the model_forecast function, which takes a trained model, a time series, window size, and batch size as inputs, and returns the model's predictions on the input data. It uses TensorFlow's Dataset API to prepare the input data and generates predictions using the trained model.

# %%
def model_forecast(model, series, window_size, batch_size):
    """Uses an input model to generate predictions on data windows

    Args:
      model (TF Keras Model) - model that accepts data windows
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the window
      batch_size (int) - the batch size

    Returns:
      forecast (numpy array) - array containing predictions
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda w: w.batch(window_size))

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)

    # Get predictions on the entire dataset
    forecast = model.predict(dataset)

    return forecast

# %% [markdown]
# The code block reduces the original series by selecting a subset of data from the validation set for forecasting. It then calls the model_forecast function to generate predictions using the baseline model and the reduced series. The predictions are stored in the forecast variable. Next, the code block drops the single-dimensional axis from the forecast and the original validation data. It then plots the results, showing the actual values (x_valid) and the predicted values (results) against time.

# %%
# Reduce the original series
forecast_series = series[split_time - window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model_baseline, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 2410/2410 [==============================] - 9s 4ms/step

# %% [markdown]
# The code block defines several evaluation metrics functions, including mean absolute scaled error (MASE), R-squared, and metrics for evaluating predictions. These functions are used to evaluate the performance of the model.

# %%
# MASE implemented courtesy of sktime - https://github.com/alan-turing-institute/sktime/blob/ee7a06843a44f4aaec7582d847e36073a9ab0566/sktime/performance_metrics/forecasting/_functions.py#L16
def mean_absolute_scaled_error(y_true, y_pred):
  """
  Implement MASE (assuming no seasonality of data).
  """
  mae = tf.reduce_mean(tf.abs(y_true - y_pred))

  # Find MAE of naive forecast (no seasonality)
  mae_naive_no_season = tf.reduce_mean(tf.abs(y_true[1:] - y_true[:-1])) # our seasonality is 1 day (hence the shifting of 1 day)

  return mae / mae_naive_no_season

def r_squared(y_true, y_pred):
    residual = tf.reduce_sum(tf.square(tf.subtract(y_true, y_pred)))
    total = tf.reduce_sum(tf.square(tf.subtract(y_true, tf.reduce_mean(y_true))))
    r2 = tf.subtract(1.0, tf.divide(residual, total))
    return r2

def evaluate_preds(y_true, y_pred):
  # Make sure float32 (for metric calculations)
  y_true = tf.cast(y_true, dtype=tf.float32)
  y_pred = tf.cast(y_pred, dtype=tf.float32)

  # Calculate various metrics
  mae = tf.keras.metrics.mean_absolute_error(y_true, y_pred)
  mse = tf.keras.metrics.mean_squared_error(y_true, y_pred)
  rmse = tf.sqrt(mse)
  mape = tf.keras.metrics.mean_absolute_percentage_error(y_true, y_pred)
  mase = mean_absolute_scaled_error(y_true, y_pred)
  r2 = r_squared(y_true, y_pred)

  # Account for different sized metrics (for longer horizons, reduce to single number)
  if mae.ndim > 0: # if mae isn't already a scalar, reduce it to one by aggregating tensors to mean
    mae = tf.reduce_mean(mae)
    mse = tf.reduce_mean(mse)
    rmse = tf.reduce_mean(rmse)
    mape = tf.reduce_mean(mape)
    mase = tf.reduce_mean(mase)

  return {"mae": mae.numpy(),
          "mse": mse.numpy(),
          "rmse": rmse.numpy(),
          "mape": mape.numpy(),
          "mase": mase.numpy(),
          "r2": r2.numpy()}  # Add R2 score

# %% [markdown]
# The code block calculates and prints the evaluation metrics for the baseline model's predictions on the validation data.

# %%
# Evaluate preds
results_baseline = evaluate_preds(y_true=x_valid, # reduce to right shape
                                 y_pred=results)
results_baseline
# Out:
# {'mae': 125.42548,
#  'mse': 248144.75,
#  'rmse': 498.1413,
#  'mape': 4.949317,
#  'mase': 0.79219645,
#  'r2': 0.98046947}

# %%
# Find average temp in test dataset
tf.reduce_mean(x_valid).numpy()
# Out:
# 4268.552

# %% [markdown]
# **Model: SimpleRNN**
#
# The next code block builds a model using a simple RNN (recurrent neural network) architecture. The model includes two layers of SimpleRNN cells with 256 and 128 units, respectively. It also includes a Dense layer with 1 unit for the output. The model is compiled with the Huber loss function, Adam optimizer, and mean absolute error (MAE) metric.

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

# Build the model
model_rn = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[window_size]),
  tf.keras.layers.SimpleRNN(256, return_sequences=True),
  tf.keras.layers.SimpleRNN(128),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100.0)
])

# Set the training parameters
model_rn.compile(loss=tf.keras.losses.Huber(), optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), metrics=['mae'])

# %% [markdown]
# The cc function creates a ModelCheckpoint callback for model simple rnn in TensorFlow to save the best model. It specifies a filepath for saving, sets verbosity to limit output, and saves only the best model based on performance.

# %%
filepath="best_rnn.h5"

# Create a function to implement a ModelCheckpoint callback with a specific filename
def cc(filepath):
  return tf.keras.callbacks.ModelCheckpoint(filepath, # create filepath to save model
                                            verbose=1, # only output a limited amount of text
                                            save_best_only=True
                                           ) # save only the best model to file

# %% [markdown]
# The code next trains the RNN model using the fit method, providing the training dataset (dataset) and the validation dataset (val_set) as input, and specifying the number of epochs.

# %%
# Train the model
history_rn = model_rn.fit(dataset,epochs=10, validation_data=val_set, callbacks=[cc(filepath)])
# Out:
# Epoch 1/10
#    9639/Unknown - 214s 22ms/step - loss: 593.9409 - mae: 594.4389
# Epoch 1: val_loss improved from inf to 557.39087, saving model to best_rnn.h5
# 9639/9639 [==============================] - 230s 23ms/step - loss: 593.9409 - mae: 594.4389 - val_loss: 557.3909 - val_mae: 557.8885
# Epoch 2/10
# 9638/9639 [============================>.] - ETA: 0s - loss: 205.3456 - mae: 205.8432
# Epoch 2: val_loss improved from 557.39087 to 374.03403, saving model to best_rnn.h5
# 9639/9639 [==============================] - 233s 24ms/step - loss: 205.3545 - mae: 205.8521 - val_loss: 374.0340 - val_mae: 374.5332
# Epoch 3/10
# 9639/9639 [==============================] - ETA: 0s - loss: 164.9026 - mae: 165.4005
# Epoch 3: val_loss improved from 374.03403 to 282.61877, saving model to best_rnn.h5
# 9639/9639 [==============================] - 252s 26ms/step - loss: 164.9026 - mae: 165.4005 - val_loss: 282.6188 - val_mae: 283.1176
# Epoch 4/10
# ...

# %% [markdown]
# The code loads a best model from the filepath using TensorFlow's load_model function.

# %%
# Load the entire model
model_rn = load_model(filepath)

# %% [markdown]
# After training the model, the code block generates predictions using the trained model and the reduced series from the validation set. It then drops the single-dimensional axis from the forecast and the original validation data. Finally, it plots the results, showing the actual values and the predicted values.

# %%
# Reduce the original series
forecast_series = series[split_time - window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model_rn, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 2410/2410 [==============================] - 13s 5ms/step

# %% [markdown]
# The code block evaluates the predictions of the RNN model using the evaluation metrics defined earlier and prints the results.

# %%
# Evaluate preds
results_rn = evaluate_preds(y_true=x_valid, # reduce to right shape
                                 y_pred=results)
results_rn
# Out:
# {'mae': 171.48009,
#  'mse': 319135.84,
#  'rmse': 564.9211,
#  'mape': 6.3101597,
#  'mase': 1.0830806,
#  'r2': 0.974882}

# %% [markdown]
# **Model: Bi-directional LSTM**
#
# The next code block builds a model using a bidirectional LSTM (long short-term memory) architecture. First, it resets the states generated by Keras to ensure a clean state for building the next model. The model includes two layers of bidirectional LSTM cells with 128 units each. It also includes a Dense layer with 256 units and a dropout layer with a rate of 0.4. The model is compiled with the Huber loss function, Adam optimizer, and mean absolute error (MAE) metric.

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

# Build the model
model_bl = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[window_size]),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True)),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128)),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(1),
#   tf.keras.layers.Lambda(lambda x: x * 100.0)
])

# Set the training parameters
model_bl.compile(loss=tf.keras.losses.Huber(), optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), metrics=['mae'])

# %% [markdown]
# The code defines a function cc that creates a ModelCheckpoint callback, specifying a filepath to save the best model during training.

# %%
filepath="best_bilstm.h5"

# Create a function to implement a ModelCheckpoint callback with a specific filename
def cc(filepath):
  return tf.keras.callbacks.ModelCheckpoint(filepath, # create filepath to save model
                                            verbose=1, # only output a limited amount of text
                                            save_best_only=True) # save only the best model to file

# %% [markdown]
# The code block trains the LSTM model using the fit method, providing the training dataset (dataset) and the validation dataset (val_set) as input, and specifying the number of epochs.

# %%
# Train the model
history_bl = model_bl.fit(dataset,epochs=10, validation_data=val_set, callbacks=[cc(filepath)])
# Out:
# Epoch 1/10
#    9638/Unknown - 137s 13ms/step - loss: 707.2991 - mae: 707.7978
# Epoch 1: val_loss improved from inf to 294.79184, saving model to best_bilstm.h5
# 9639/9639 [==============================] - 156s 15ms/step - loss: 707.2836 - mae: 707.7823 - val_loss: 294.7918 - val_mae: 295.2898
# Epoch 2/10
# 9635/9639 [============================>.] - ETA: 0s - loss: 256.3483 - mae: 256.8468
# Epoch 2: val_loss did not improve from 294.79184
# 9639/9639 [==============================] - 156s 16ms/step - loss: 256.4544 - mae: 256.9529 - val_loss: 339.9962 - val_mae: 340.4944
# Epoch 3/10
# 9639/9639 [==============================] - ETA: 0s - loss: 247.8827 - mae: 248.3811
# Epoch 3: val_loss improved from 294.79184 to 231.22812, saving model to best_bilstm.h5
# 9639/9639 [==============================] - 157s 16ms/step - loss: 247.8827 - mae: 248.3811 - val_loss: 231.2281 - val_mae: 231.7266
# Epoch 4/10
# ...

# %% [markdown]
# The code loads a best model from the filepath using TensorFlow's load_model function.

# %%
# Load the entire model
model_bl = load_model(filepath)

# %% [markdown]
# After training the model, the code block generates predictions using the trained model and the reduced series from the validation set. It then drops the single-dimensional axis from the forecast and the original validation data. Finally, it plots the results, showing the actual values and the predicted values.

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model_bl, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 2410/2410 [==============================] - 15s 6ms/step

# %% [markdown]
# The code block evaluates the predictions of the LSTM model using the evaluation metrics defined earlier and prints the results.

# %%
# Evaluate preds
results_bl = evaluate_preds(y_true=x_valid, # reduce to right shape
                                 y_pred=results)
results_bl
# Out:
# {'mae': 159.1417,
#  'mse': 288008.34,
#  'rmse': 536.66406,
#  'mape': 5.4024296,
#  'mase': 1.0051506,
#  'r2': 0.97733194}

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Lambda, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import Huber

# %% [markdown]
# **Model: Conv1D**
#
# The following code defines a CNN (Convolutional Neural Network) model using TensorFlow's Keras API. The model includes Conv1D layers, GlobalAveragePooling1D, Flatten, Dropout, and Dense layers. The Lambda layer is used to add an extra axis to the input data. The model is compiled with the Huber loss function, Adam optimizer, and mean absolute error (MAE) metric. It then prints a summary of the model, providing an overview of its architecture and the number of parameters.

# %%
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D, Flatten


cnn_model = Sequential([
    # add extra axis to input data
    Lambda(lambda x: tf.expand_dims(x, axis=-1), input_shape=[window_size]),
    Conv1D(filters=512, kernel_size=3, strides=1,
           padding='causal', activation='relu'),
    Conv1D(filters=256, kernel_size=3, strides=1,
           padding='causal', activation='relu'),
    GlobalAveragePooling1D(),
    Flatten(),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.4),
    Dense(1)
])

cnn_model.compile(
    loss=Huber(),
    optimizer=Adam(),
    metrics=['mae']
)

cnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lambda (Lambda)             (None, 7, 1)              0
#
#  conv1d_1 (Conv1D)           (None, 7, 512)            2048
#
#  conv1d_2 (Conv1D)           (None, 7, 256)            393472
#
#  global_average_pooling1d (G  (None, 256)              0
#  lobalAveragePooling1D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
# ...
# Total params: 428,545
# Trainable params: 428,545
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The code defines a function cc that creates a ModelCheckpoint callback, specifying a filepath to save the best model during training.

# %%
filepath="best_conv.h5"

# Create a function to implement a ModelCheckpoint callback with a specific filename
def cc(filepath):
  return tf.keras.callbacks.ModelCheckpoint(filepath, # create filepath to save model
                                            verbose=1, # only output a limited amount of text
                                            save_best_only=True) # save only the best model to file

# %% [markdown]
# The code block trains the CNN model using the fit method, providing the training dataset (dataset) and the validation dataset (val_set) as input, and specifying the number of epochs. The verbose=0 argument is used to suppress the progress output during training.

# %%
#Trains CNN Model
cnn_history = cnn_model.fit(dataset, epochs=10, validation_data=val_set,verbose=0, callbacks=[cc(filepath)])
# Out:
# Epoch 1: val_loss improved from inf to 401.04178, saving model to best_conv.h5
#
# Epoch 2: val_loss improved from 401.04178 to 180.22699, saving model to best_conv.h5
#
# Epoch 3: val_loss did not improve from 180.22699
#
# Epoch 4: val_loss did not improve from 180.22699
#
# Epoch 5: val_loss improved from 180.22699 to 171.66982, saving model to best_conv.h5
#
# Epoch 6: val_loss improved from 171.66982 to 154.21483, saving model to best_conv.h5
#
# Epoch 7: val_loss did not improve from 154.21483
#
# Epoch 8: val_loss did not improve from 154.21483
#
# Epoch 9: val_loss did not improve from 154.21483
#
# Epoch 10: val_loss improved from 154.21483 to 148.85800, saving model to best_conv.h5

# %% [markdown]
# The code loads a best model from the filepath using TensorFlow's load_model function.

# %%
# Load the entire model
cnn_model = load_model(filepath)

# %% [markdown]
# After training the model, the code block generates predictions using the trained CNN model and the reduced series from the validation set. It then drops the single-dimensional axes from the forecast and the original validation data. Finally, it plots the results, showing the actual values and the predicted values.

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(cnn_model, forecast_series, window_size, batch_size)

# Drop single dimensional axes
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 2410/2410 [==============================] - 9s 4ms/step

# %% [markdown]
# The code block evaluates the predictions of the CNN model using the evaluation metrics defined earlier and stores the results in the results_conv variable.

# %%
# Evaluate preds
results_cv = evaluate_preds(y_true=x_valid, # reduce to right shape
                                 y_pred=results)
results_cv
# Out:
# {'mae': 149.34563,
#  'mse': 257434.14,
#  'rmse': 507.37967,
#  'mape': 5.804972,
#  'mase': 0.94327784,
#  'r2': 0.9797383}

# %% [markdown]
# **Compare Models**
#
# The next code block creates a DataFrame, model_results, to compare the results of different models. It includes the MAE values of the baseline model, Simple RNN model, Bi-LSTM model, Conv1D + LSTM model, and the CNN model. The DataFrame is then sorted based on the MAE values.

# %%
# Compare different model results
model_results = pd.DataFrame({"Model_Dense1": results_baseline,
                              "Simple RNN": results_rn,
                              "Bi-LSTM": results_bl,
                              "Conv1D": results_cv,
                             }).T

model_results = model_results.sort_values(by="mae")

model_results.head(10)
# Out:
#                      mae            mse        rmse      mape      mase  \
# Model_Dense1  125.425484  248144.750000  498.141296  4.949317  0.792196
# Conv1D        149.345627  257434.140625  507.379669  5.804972  0.943278
# Bi-LSTM       159.141693  288008.343750  536.664062  5.402430  1.005151
# Simple RNN    171.480087  319135.843750  564.921082  6.310160  1.083081
#
#                     r2
# Model_Dense1  0.980469
# Conv1D        0.979738
# Bi-LSTM       0.977332
# Simple RNN    0.974882

# %% [markdown]
# The results of the different models show varying levels of performance. Model_Dense1 achieved the best overall results with the lowest mean absolute error (MAE) of 125.43, mean squared error (MSE) of 248,144.75, root mean squared error (RMSE) of 498.14, and mean absolute percentage error (MAPE) of 4.95%. It also had a higher R-squared (R2) value of 0.98, indicating a better fit to the data. The Conv1D model performed slightly worse with a higher MAE of 149.35 and MSE of 257,434.14, but still maintained a high R2 value of 0.98. The Bi-LSTM model showed further degradation in performance with a higher MAE of 159.14, MSE of 288,008.34, and RMSE of 536.66, along with a slightly lower R2 value of 0.98. Lastly, the Simple RNN model exhibited the highest MAE of 171.48, MSE of 319,135.84, and RMSE of 564.92, as well as a lower R2 value of 0.97. Despite these differences, all models achieved relatively high R2 values, indicating a reasonable fit to the data. Overall, the Model_Dense1 displayed the best accuracy among the models in predicting the target variable, providing the lowest errors and highest R2 value.

# %%
# Sort model results by MAE and plot them
model_results[["mae"]].sort_values(by="mae").plot(figsize=(10, 7), kind="bar");
