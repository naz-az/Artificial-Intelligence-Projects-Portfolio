# %% [markdown]
# # **Title: VinoValue - Predicting Spanish Wine Quality and Prices using Machine Learning**

# %% [markdown]
# ![Screenshot 2023-07-13 130748.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Overview/Introduction
# In the world of wine, understanding and predicting the quality and price of wines is a fascinating yet complex task. With the advancements in artificial intelligence, we have an opportunity to leverage machine learning algorithms to uncover insights and patterns hidden within vast amounts of data. In this project, we aim to explore the Spanish Wine Quality Dataset, a comprehensive collection of red wines from Spain, and develop an AI model that can accurately predict either the quality or prices of wines based on various features.
#
# ## Problem Statement
# The main challenge in the wine industry is to assess and predict the quality and price of wines accurately. Wine quality is a subjective measure influenced by various factors such as grape characteristics, winemaking processes, and consumer preferences. The intricate relationship between these factors makes it difficult for human experts to precisely predict wine quality and prices. Hence, there is a need for an AI-powered solution that can effectively analyze the characteristics of Spanish wines and provide reliable predictions.
#
# ## Objectives
# The primary objectives of this AI project are as follows:
#
# 1. **Data Exploration:** Conduct a thorough analysis of the Spanish Wine Quality Dataset to gain insights into the various features and their relationships with wine quality and prices.
# 2. **Model Development:** Develop a machine learning model capable of predicting either the quality or prices of Spanish wines based on the provided dataset.
# 3. **Feature Importance:** Identify the most influential features that significantly impact wine quality or prices, enabling wine producers to focus on key factors for improvement.
# 4. **Generalization:** Evaluate the model's generalization capabilities by testing its performance on unseen data, ensuring its reliability in real-world scenarios.
# 5. **Potential Expansion:** Explore the possibility of expanding the dataset to include wines from other countries and a wider spectrum of ratings, enhancing the applicability and scalability of the AI model.
#
# ## Dataset Description
# The Spanish Wine Quality Dataset comprises 7,500 different types of red wines sourced from Spain. The dataset provides extensive information on 11 features that describe the wines, including price, rating, flavor descriptions, and more. This dataset was meticulously collected by scraping data from various sources, ranging from wine specialized pages to supermarkets. The inclusion of multiple sources ensures a comprehensive and diverse representation of Spanish red wines, making this dataset valuable for AI projects and research in the wine industry.
#
# **Attribute Information:**
# The dataset includes the following attributes:
#
# - **winery:** The name of the winery producing the wine.
# - **wine:** The name of the wine.
# - **year:** The year in which the grapes were harvested.
# - **rating:** The average rating given to the wine by users, ranging from 1 to 5.
# - **num_reviews:** The number of users that reviewed the wine.
# - **country:** The country of origin, which is Spain for all wines in this dataset.
# - **region:** The region where the wine was produced.
# - **price:** The price of the wine in euros (€).
# - **type:** The variety of wine.
# - **body:** The body score, representing the richness and weight of the wine in the mouth, ranging from 1 to 5.
# - **acidity:** The acidity score, indicating the wine's tartness and refreshment, ranging from 1 to 5.
#
# **Citation:**
# fedesoriano. (April 2022). Spanish Wine Quality Dataset. Retrieved [11/5/2023] from https://www.kaggle.com/datasets/fedesoriano/spanish-wine-quality-dataset

# %% [markdown]
# ## Technologies Used
#
# - Python: The programming language used for writing the code.
# - pandas: A powerful data manipulation library used for reading and processing the dataset.
# - NumPy: A library for numerical computing, used for handling missing values and data preprocessing.
# - seaborn and matplotlib: Data visualization libraries used for creating plots and heatmaps.
# - scikit-learn: A machine learning library used for feature selection, data splitting, and preprocessing.
# - TensorFlow and Keras: Deep learning frameworks used for building and training neural network models.
#
# ## Methodology
# The code follows a systematic methodology to process and analyze the Spanish Wine Quality Dataset. The key steps involved are as follows:
#
# 1. Data Loading and Preprocessing:
#    - The code uses the pandas library to read the dataset from a CSV file.
#    - The 'country' column, with a single value (Spain), is dropped due to lack of variability.
#    - Duplicate rows and missing values are handled appropriately.
#    - The 'year' column is cleaned by replacing 'N.V.' with NaN and converting it to the integer data type.
#
# 2. Exploratory Data Analysis (EDA):
#    - The code employs visualizations, such as heatmaps, to examine feature correlations and gain insights into their relationships.
#    - Distribution plots and boxplots are generated to explore the distribution of the 'price' feature and its connection to the 'type' feature.
#
# 3. Feature Selection and Data Transformation:
#    - The code splits the preprocessed data into input features (X) and the target variable (y) by excluding the 'price' column.
#    - Column transformations are applied using the make_column_transformer function. Numerical features are normalized using MinMaxScaler, and categorical features are encoded using OneHotEncoder.
#    - The data is divided into training and testing sets using the train_test_split function.
#
# 4. Model Building:
#    - The code defines a neural network model using the Sequential API from TensorFlow and Keras.
#    - The model includes dense layers with dropout regularization to address overfitting.
#    - The model is compiled with a mean squared error loss function, an Adam optimizer, and metrics to track mean absolute error during training.
#
# 5. Model Training and Evaluation:
#    - The model is trained on the preprocessed training data and evaluated on the testing data.
#    - A learning rate schedule is implemented to dynamically adjust the learning rate during training.
#    - The model's training history and the learning rate versus loss plot are visualized.
#    - The best model is saved based on the validation loss using the ModelCheckpoint callback.
#
# 6. Model Tuning and Hyperparameter Search:
#    - Hyperparameter tuning is performed using the Keras Tuner library's RandomSearch method.
#    - A custom function is created to construct a model architecture based on sampled hyperparameters.
#    - The best model architecture is obtained, compiled with optimal hyperparameters, and trained.
#    - The best model's performance is evaluated and recorded.
#
#
# ## Results
# The initial evaluation of the model before hyperparameter tuning yielded the following results:
# - Validation Loss (MSE): 24,389.58
# - Validation Mean Absolute Error (MAE): 57.32
#
# After hyperparameter tuning, the best model achieved improved performance:
# - Validation loss (MSE) after tuning: 18,395.85
# - Validation MAE after tuning: 53.61
#
# ## Discussion/Interpretation of Results
# The initial evaluation of the model before hyperparameter tuning indicated relatively high values for both loss and MAE. This suggests that the model's predictions deviated significantly from the true wine prices. However, after applying hyperparameter tuning, the performance improved significantly, as evidenced by the lower validation loss (MSE) and MAE.
#
# The reduced validation loss and MAE after tuning indicate that the model's predictions align more closely with the true prices of the Spanish wines. This improvement can be attributed to fine-tuning the model's architecture and hyperparameters, allowing it to capture more accurate representations of the underlying patterns and relationships in the dataset. Consequently, the tuned model demonstrates enhanced predictive capabilities and can provide more reliable estimations of wine prices.
#
# ## Conclusion
# The implementation of hyperparameter tuning greatly enhanced the performance of the model in predicting Spanish wine prices. The initial model evaluation showed considerable room for improvement, as indicated by the high loss and MAE values. However, by conducting hyperparameter tuning, we were able to fine-tune the model's architecture and optimize its hyperparameters.
#
# The improved performance of the tuned model, with reduced validation loss and MAE, indicates its increased accuracy in predicting wine prices. This outcome has significant implications for the wine industry, as stakeholders can rely on the model's predictions to make informed decisions about pricing strategies, market positioning, and consumer preferences.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/spanish-wine-quality-dataset/wines_SPA.csv

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, LSTM, GRU, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler
import itertools
import random
import os
import csv
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Bidirectional, Dense, Lambda
from tensorflow.keras.optimizers import Adam
# !pip install keras-tuner
import keras_tuner as kt
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Requirement already satisfied: keras-tuner in /opt/conda/lib/python3.10/site-packages (1.3.5)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from keras-tuner) (21.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from keras-tuner) (2.31.0)
# Requirement already satisfied: kt-legacy in /opt/conda/lib/python3.10/site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->keras-tuner) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->keras-tuner) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->keras-tuner) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->keras-tuner) (2023.5.7)

# %% [markdown]
# The following code shows a function seed_everything() that sets the seed values for random number generators in TensorFlow, NumPy, and Python's random library, ensuring reproducibility of results for future use cases.

# %%
# Seed Everything to reproduce results for future use cases
def seed_everything(seed=42):
    # Seed value for TensorFlow
    tf.random.set_seed(seed)

    # Seed value for NumPy
    np.random.seed(seed)

    # Seed value for Python's random library
    random.seed(seed)

seed_everything()

# %% [markdown]
# The next code reads in a dataset from a CSV file and assigns it to the variable df. It then displays the first few rows of the dataset using the head() function.

# %%
df = pd.read_csv('/kaggle/input/spanish-wine-quality-dataset/wines_SPA.csv')
df.head()
# Out:
#           winery           wine  year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013     4.9           58  Espana
# 1         Artadi  Vina El Pison  2018     4.9           31  Espana
# 2   Vega Sicilia          Unico  2009     4.8         1793  Espana
# 3   Vega Sicilia          Unico  1999     4.8         1705  Espana
# 4   Vega Sicilia          Unico  1996     4.8         1309  Espana
#
#              region   price                  type  body  acidity
# 0              Toro  995.00              Toro Red   5.0      3.0
# 1    Vino de Espana  313.50           Tempranillo   4.0      2.0
# 2  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# 3  Ribera del Duero  692.96  Ribera Del Duero Red   5.0      3.0
# 4  Ribera del Duero  778.06  Ribera Del Duero Red   5.0      3.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   winery       7500 non-null   object
#  1   wine         7500 non-null   object
#  2   year         7498 non-null   object
#  3   rating       7500 non-null   float64
#  4   num_reviews  7500 non-null   int64
#  5   country      7500 non-null   object
#  6   region       7500 non-null   object
#  7   price        7500 non-null   float64
#  8   type         6955 non-null   object
#  9   body         6331 non-null   float64
#  10  acidity      6331 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 644.7+ KB

# %% [markdown]
# The following code shows the count of each unique value in the 'country' column of the DataFrame 'df'. This is useful for understanding the distribution of countries in the dataset.

# %%
df.country.value_counts()
# Out:
# Espana    7500
# Name: country, dtype: int64

# %% [markdown]
# The next code block demonstrates that the 'country' column is dropped from the DataFrame 'df'. This is done because the column only contains a single value, which suggests it may not be relevant for analysis.

# %%
df = df.drop(columns=['country'])
df.head()
# Out:
#           winery           wine  year  rating  num_reviews            region  \
# 0  Teso La Monja          Tinto  2013     4.9           58              Toro
# 1         Artadi  Vina El Pison  2018     4.9           31    Vino de Espana
# 2   Vega Sicilia          Unico  2009     4.8         1793  Ribera del Duero
# 3   Vega Sicilia          Unico  1999     4.8         1705  Ribera del Duero
# 4   Vega Sicilia          Unico  1996     4.8         1309  Ribera del Duero
#
#     price                  type  body  acidity
# 0  995.00              Toro Red   5.0      3.0
# 1  313.50           Tempranillo   4.0      2.0
# 2  324.95  Ribera Del Duero Red   5.0      3.0
# 3  692.96  Ribera Del Duero Red   5.0      3.0
# 4  778.06  Ribera Del Duero Red   5.0      3.0

# %% [markdown]
# **Duplicates and Null values**
#
# The code prints the number of data points in the dataset. The next code checks for duplicates in the dataset and prints the number of duplicates found. The code then checks for missing values in the dataset by calculating the sum of missing values for each column and prints the results. The code also replaces empty strings with NaN values in the dataset and recalculates the number of missing values.

# %%
# How many reviews do we have?
print('There are', df.shape[0], 'data in this dataset')

# Do we have duplicates?
print('Number of Duplicates:', len(df[df.duplicated()]))

# Do we have missing values?
missing_values = df.isnull().sum()
print('Number of Missing Values by column:\n',missing_values)

print('Number of Missing Values:', df.isnull().sum().sum())

df.replace("", np.nan, inplace=True)
missing_values = df.isnull().sum()
print('Number of Missing Values by column:\n',missing_values)
# Out:
# There are 7500 data in this dataset
# Number of Duplicates: 5452
# Number of Missing Values by column:
#  winery            0
# wine              0
# year              2
# rating            0
# num_reviews       0
# region            0
# price             0
# type            545
# body           1169
# acidity        1169
# dtype: int64
# Number of Missing Values: 2885
# Number of Missing Values by column:
#  winery            0
# wine              0
# year              2
# rating            0
# num_reviews       0
# region            0
# price             0
# type            545
# body           1169
# acidity        1169
# dtype: int64

# %% [markdown]
# **Review Duplicates**
#
# This code first identifies and selects all duplicate rows in the DataFrame by using the duplicated() function with the parameter keep=False. The resulting duplicate rows are then sorted based on all columns to ensure duplicates are adjacent. To display the top 5 pairs of duplicates (10 rows), the code selects the first 20 rows from the sorted duplicates.

# %%
# First, get all duplicate rows (keep=False ensures all duplicates are kept)
duplicate_rows = df[df.duplicated(keep=False)]

# Then sort the dataframe on all columns to ensure duplicates are adjacent
sorted_duplicates = duplicate_rows.sort_values(by=list(duplicate_rows.columns))

# Now, if we want to see 5 pairs of duplicates (10 rows), we can simply:
top_5_duplicate_pairs = sorted_duplicates.head(10)
top_5_duplicate_pairs
# Out:
#       winery        wine  year  rating  num_reviews          region  price  \
# 2042  Artadi  Valdegines  2016     4.2          398  Vino de Espana  48.96
# 2067  Artadi  Valdegines  2016     4.2          398  Vino de Espana  48.96
# 2092  Artadi  Valdegines  2016     4.2          398  Vino de Espana  48.96
# 2117  Artadi  Valdegines  2016     4.2          398  Vino de Espana  48.96
# 2142  Artadi  Valdegines  2016     4.2          398  Vino de Espana  48.96
# 2167  Artadi  Valdegines  2016     4.2          398  Vino de Espana  48.96
# 2192  Artadi  Valdegines  2016     4.2          398  Vino de Espana  48.96
# 2217  Artadi  Valdegines  2016     4.2          398  Vino de Espana  48.96
# 2242  Artadi  Valdegines  2016     4.2          398  Vino de Espana  48.96
# 2267  Artadi  Valdegines  2016     4.2          398  Vino de Espana  48.96
#
#              type  body  acidity
# 2042  Tempranillo   4.0      2.0
# 2067  Tempranillo   4.0      2.0
# 2092  Tempranillo   4.0      2.0
# 2117  Tempranillo   4.0      2.0
# 2142  Tempranillo   4.0      2.0
# 2167  Tempranillo   4.0      2.0
# 2192  Tempranillo   4.0      2.0
# 2217  Tempranillo   4.0      2.0
# 2242  Tempranillo   4.0      2.0
# 2267  Tempranillo   4.0      2.0

# %% [markdown]
# After that, the code removes the duplicate rows from the original DataFrame using the drop_duplicates() function. It then counts and prints the number of duplicates remaining in the DataFrame.

# %%
df = df.drop_duplicates()
print('Number of Duplicates:', len(df[df.duplicated()]))
# Out:
# Number of Duplicates: 0

# %% [markdown]
# The code snippet 'df = df.dropna()' drops any rows from the DataFrame 'df' that contain missing values. Then, the code prints the total number of missing values in the DataFrame using 'df.isnull().sum().sum()'. This helps to assess the amount of missing data present in the dataset after droping the missing values.

# %%
df = df.dropna()
print('Number of Missing Values:', df.isnull().sum().sum())
# Out:
# Number of Missing Values: 0

# %% [markdown]
# The code replaces 'N.V.' with NaN using 'replace()', removes rows with missing values using 'dropna()', and converts the 'year' column to 'int64' using 'astype()'. These steps handle missing or invalid values and ensure the 'year' values are stored as integers for analysis.

# %%
df['year'] = df['year'].replace('N.V.', np.NaN)
df = df.dropna()
df['year'] = df['year'].astype(np.int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1714 entries, 0 to 2049
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   winery       1714 non-null   object
#  1   wine         1714 non-null   object
#  2   year         1714 non-null   int64
#  3   rating       1714 non-null   float64
#  4   num_reviews  1714 non-null   int64
#  5   region       1714 non-null   object
#  6   price        1714 non-null   float64
#  7   type         1714 non-null   object
#  8   body         1714 non-null   float64
#  9   acidity      1714 non-null   float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 147.3+ KB

# %% [markdown]
# **Correlation Matrix**
#
# A heatmap is generated to visualize the correlation between the features in the DataFrame using the df.corr() function. The annot=True parameter enables displaying the correlation values on the heatmap.

# %%
sns.heatmap(df.corr(), annot=True, cmap='Blues')
# Out:
# /tmp/ipykernel_32/3512116964.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='Blues')
# <Axes: >

# %% [markdown]
# The correlation matrix of the DataFrame is calculated, and the correlation of "price" with other features is extracted and sorted in descending order.

# %%
# Calculate the correlation matrix
corr_matrix = df.corr(numeric_only=True)

# Get the correlation of 'price' with other features
corr_with_price = corr_matrix['price']

# Sort these correlations in descending order
sorted_correlations = corr_with_price.sort_values(ascending=False)

# Print out the sorted correlations
sorted_correlations
# Out:
# price          1.000000
# rating         0.509223
# body           0.165188
# acidity       -0.005123
# num_reviews   -0.079436
# year          -0.361058
# Name: price, dtype: float64

# %% [markdown]
# **EDA**
#
# The code sets the style and creates a distribution plot using sns.distplot to visualize the distribution of the "price" column.

# %%
sns.set(style='whitegrid')
f, ax = plt.subplots(1,1, figsize=(12, 8))
ax = sns.histplot(df['price'], kde = True, color = 'c')
plt.title('Distribution of Price')
# Out:
# Text(0.5, 1.0, 'Distribution of Price')

# %% [markdown]
# The code creates a figure and axes using matplotlib's 'subplots()' function. It then generates a boxplot using seaborn's 'boxplot()' function, visualizing the 'price' column grouped by the 'type' column from the DataFrame 'df'. The x-axis labels are rotated for better readability, and the plot is displayed using 'plt.show()'.

# %%
fig, ax = plt.subplots(ncols=1, figsize=(18,7))
sns.boxplot(y='price', x='type', data=df, ax=ax)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Feature Selection**
#
# Following that, the code splits the preprocessed data into input features (X) and target variable (y) by dropping the "price" column from the "data" dataframe.

# %%
X = df.drop('price', axis=1)
y = df['price']

# %% [markdown]
# The subsequent code imports the "train_test_split" function from the "sklearn.model_selection" module. This function is used to split the data into training and testing sets for model evaluation. The data is split such that 80% is used for training and 20% is used for testing, and a random seed of 42 is set for reproducibility.

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %% [markdown]
# The code then defines two lists: "num_cols" to store the names of numerical columns (excluding the target variable "price") and "cat_cols" to store the names of categorical columns in the "data" dataframe.

# %%
# Get list of numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Remove 'price' from num_cols
num_cols.remove('price')

# Get list of categorical columns
cat_cols = df.select_dtypes(include=['object']).columns.tolist()

# Print the numerical columns
print("Numerical columns are:", num_cols)

# Print the categorical columns
print("Categorical columns are:", cat_cols)
# Out:
# Numerical columns are: ['year', 'rating', 'num_reviews', 'body', 'acidity']
# Categorical columns are: ['winery', 'wine', 'region', 'type']

# %% [markdown]
# In the subsequent code, a column transformer is created using the "make_column_transformer" function from the "sklearn.compose" module. This column transformer applies scaling (MinMaxScaler) to the numerical columns and one-hot encoding (OneHotEncoder) to the categorical columns.

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# creating column transformer (this will help us normalize/preprocess our data)

ct = make_column_transformer((MinMaxScaler(), num_cols),
                             (OneHotEncoder(handle_unknown = 'ignore'), cat_cols))

# %% [markdown]
# The column transformer is then fitted on the training data, and the same transformation is applied to both the training and test data.

# %%
# fitting column transformer on training data
ct.fit(xtrain)

# transforming training and test data with normalizing (MinMaxScaler) and one hot encoding (OneHotEncoder)
xtrain = ct.transform(xtrain)
xtest = ct.transform(xtest)

# %%
xtrain
# Out:
# <1371x1046 sparse matrix of type '<class 'numpy.float64'>'
# 	with 12130 stored elements in Compressed Sparse Row format>

# %% [markdown]
# The code converts the training data 'xtrain' and the testing data 'xtest' from sparse matrix format to dense array format. This transformation is useful for certain machine learning algorithms that require dense array inputs rather than sparse matrix inputs.

# %%
xtrain = xtrain.toarray()
xtest = xtest.toarray()

# %% [markdown]
# **Model Building**
#
# Next, the code defines a neural network model called "model_1" using the Sequential API. The model consists of multiple dense layers with dropout regularization to prevent overfitting. The model is compiled with a mean squared error loss function, an Adam optimizer, and metrics to monitor mean absolute error during training.

# %%
from tensorflow.keras import regularizers

# Set random seed
tf.random.set_seed(42)

# Define the model
model_1 = tf.keras.Sequential([
  tf.keras.layers.Dense(512, activation="relu", kernel_regularizer=regularizers.l2(0.01)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=regularizers.l2(0.01)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(1)
])

# Define the optimizer
optimizer = tf.keras.optimizers.Adam()

# Compile the model
model_1.compile(loss="mean_squared_error",
                optimizer=optimizer,
                metrics=["mean_absolute_error"])

# %% [markdown]
# A learning rate schedule is defined using a learning rate scheduler callback. This allows the learning rate to change dynamically during training, potentially improving model performance. The model is then trained on the preprocessed training data, using the validation data for evaluation and the learning rate scheduler callback.

# %%
# Define the learning rate schedule
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-6 * 10**(-epoch / 20))

# Fit the model
history = model_1.fit(xtrain,
                      ytrain,
                      epochs=100,
                      batch_size=32,
                      validation_data=(xtest, ytest),
                      callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 43/43 [==============================] - 2s 12ms/step - loss: 107891.8984 - mean_absolute_error: 151.9747 - val_loss: 114342.2969 - val_mean_absolute_error: 147.7465 - lr: 1.0000e-06
# Epoch 2/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107888.8047 - mean_absolute_error: 151.9713 - val_loss: 114340.8047 - val_mean_absolute_error: 147.7416 - lr: 8.9125e-07
# Epoch 3/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107889.1875 - mean_absolute_error: 151.9659 - val_loss: 114339.4844 - val_mean_absolute_error: 147.7373 - lr: 7.9433e-07
# Epoch 4/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107886.8906 - mean_absolute_error: 151.9624 - val_loss: 114338.2891 - val_mean_absolute_error: 147.7335 - lr: 7.0795e-07
# Epoch 5/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107887.1094 - mean_absolute_error: 151.9587 - val_loss: 114337.2578 - val_mean_absolute_error: 147.7301 - lr: 6.3096e-07
# Epoch 6/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107884.9688 - mean_absolute_error: 151.9557 - val_loss: 114336.3281 - val_mean_absolute_error: 147.7270 - lr: 5.6234e-07
# Epoch 7/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107882.9219 - mean_absolute_error: 151.9489 - val_loss: 114335.5312 - val_mean_absolute_error: 147.7244 - lr: 5.0119e-07
# Epoch 8/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107883.6953 - mean_absolute_error: 151.9492 - val_loss: 114334.7969 - val_mean_absolute_error: 147.7220 - lr: 4.4668e-07
# Epoch 9/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107881.6406 - mean_absolute_error: 151.9469 - val_loss: 114334.1328 - val_mean_absolute_error: 147.7198 - lr: 3.9811e-07
# Epoch 10/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107881.3984 - mean_absolute_error: 151.9458 - val_loss: 114333.5391 - val_mean_absolute_error: 147.7179 - lr: 3.5481e-07
# Epoch 11/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107882.7734 - mean_absolute_error: 151.9419 - val_loss: 114333.0391 - val_mean_absolute_error: 147.7163 - lr: 3.1623e-07
# Epoch 12/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107880.7656 - mean_absolute_error: 151.9412 - val_loss: 114332.5938 - val_mean_absolute_error: 147.7148 - lr: 2.8184e-07
# Epoch 13/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107881.8516 - mean_absolute_error: 151.9399 - val_loss: 114332.1641 - val_mean_absolute_error: 147.7134 - lr: 2.5119e-07
# Epoch 14/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107880.0859 - mean_absolute_error: 151.9372 - val_loss: 114331.7891 - val_mean_absolute_error: 147.7122 - lr: 2.2387e-07
# Epoch 15/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107879.0000 - mean_absolute_error: 151.9364 - val_loss: 114331.4531 - val_mean_absolute_error: 147.7111 - lr: 1.9953e-07
# Epoch 16/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107880.3125 - mean_absolute_error: 151.9381 - val_loss: 114331.1875 - val_mean_absolute_error: 147.7101 - lr: 1.7783e-07
# Epoch 17/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107878.2891 - mean_absolute_error: 151.9344 - val_loss: 114330.8906 - val_mean_absolute_error: 147.7093 - lr: 1.5849e-07
# Epoch 18/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107879.4922 - mean_absolute_error: 151.9339 - val_loss: 114330.6953 - val_mean_absolute_error: 147.7085 - lr: 1.4125e-07
# Epoch 19/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107878.1250 - mean_absolute_error: 151.9346 - val_loss: 114330.4688 - val_mean_absolute_error: 147.7079 - lr: 1.2589e-07
# Epoch 20/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.5859 - mean_absolute_error: 151.9335 - val_loss: 114330.2969 - val_mean_absolute_error: 147.7072 - lr: 1.1220e-07
# Epoch 21/100
# 43/43 [==============================] - 0s 9ms/step - loss: 107877.8203 - mean_absolute_error: 151.9338 - val_loss: 114330.1328 - val_mean_absolute_error: 147.7067 - lr: 1.0000e-07
# Epoch 22/100
# 43/43 [==============================] - 0s 9ms/step - loss: 107877.7188 - mean_absolute_error: 151.9304 - val_loss: 114329.9844 - val_mean_absolute_error: 147.7063 - lr: 8.9125e-08
# Epoch 23/100
# 43/43 [==============================] - 0s 9ms/step - loss: 107877.0859 - mean_absolute_error: 151.9319 - val_loss: 114329.8438 - val_mean_absolute_error: 147.7058 - lr: 7.9433e-08
# Epoch 24/100
# 43/43 [==============================] - 0s 10ms/step - loss: 107877.3906 - mean_absolute_error: 151.9302 - val_loss: 114329.7266 - val_mean_absolute_error: 147.7054 - lr: 7.0795e-08
# Epoch 25/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107877.0156 - mean_absolute_error: 151.9314 - val_loss: 114329.6328 - val_mean_absolute_error: 147.7051 - lr: 6.3096e-08
# Epoch 26/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107878.5234 - mean_absolute_error: 151.9321 - val_loss: 114329.5391 - val_mean_absolute_error: 147.7048 - lr: 5.6234e-08
# Epoch 27/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107878.2656 - mean_absolute_error: 151.9319 - val_loss: 114329.4453 - val_mean_absolute_error: 147.7045 - lr: 5.0119e-08
# Epoch 28/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.4141 - mean_absolute_error: 151.9302 - val_loss: 114329.3750 - val_mean_absolute_error: 147.7043 - lr: 4.4668e-08
# Epoch 29/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.4219 - mean_absolute_error: 151.9271 - val_loss: 114329.3203 - val_mean_absolute_error: 147.7041 - lr: 3.9811e-08
# Epoch 30/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.7578 - mean_absolute_error: 151.9311 - val_loss: 114329.2578 - val_mean_absolute_error: 147.7039 - lr: 3.5481e-08
# Epoch 31/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.3438 - mean_absolute_error: 151.9306 - val_loss: 114329.2031 - val_mean_absolute_error: 147.7037 - lr: 3.1623e-08
# Epoch 32/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.0625 - mean_absolute_error: 151.9310 - val_loss: 114329.1641 - val_mean_absolute_error: 147.7035 - lr: 2.8184e-08
# Epoch 33/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.7266 - mean_absolute_error: 151.9303 - val_loss: 114329.1172 - val_mean_absolute_error: 147.7034 - lr: 2.5119e-08
# Epoch 34/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.5625 - mean_absolute_error: 151.9275 - val_loss: 114329.0625 - val_mean_absolute_error: 147.7033 - lr: 2.2387e-08
# Epoch 35/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107878.5938 - mean_absolute_error: 151.9313 - val_loss: 114329.0469 - val_mean_absolute_error: 147.7032 - lr: 1.9953e-08
# Epoch 36/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.8828 - mean_absolute_error: 151.9296 - val_loss: 114329.0234 - val_mean_absolute_error: 147.7031 - lr: 1.7783e-08
# Epoch 37/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.9297 - mean_absolute_error: 151.9318 - val_loss: 114328.9766 - val_mean_absolute_error: 147.7030 - lr: 1.5849e-08
# Epoch 38/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.1953 - mean_absolute_error: 151.9288 - val_loss: 114328.9531 - val_mean_absolute_error: 147.7029 - lr: 1.4125e-08
# Epoch 39/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107876.3672 - mean_absolute_error: 151.9287 - val_loss: 114328.9453 - val_mean_absolute_error: 147.7029 - lr: 1.2589e-08
# Epoch 40/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.7344 - mean_absolute_error: 151.9294 - val_loss: 114328.9297 - val_mean_absolute_error: 147.7028 - lr: 1.1220e-08
# Epoch 41/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.1328 - mean_absolute_error: 151.9292 - val_loss: 114328.9219 - val_mean_absolute_error: 147.7027 - lr: 1.0000e-08
# Epoch 42/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.0469 - mean_absolute_error: 151.9290 - val_loss: 114328.8984 - val_mean_absolute_error: 147.7027 - lr: 8.9125e-09
# Epoch 43/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.2891 - mean_absolute_error: 151.9292 - val_loss: 114328.8750 - val_mean_absolute_error: 147.7026 - lr: 7.9433e-09
# Epoch 44/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.4922 - mean_absolute_error: 151.9267 - val_loss: 114328.8750 - val_mean_absolute_error: 147.7026 - lr: 7.0795e-09
# Epoch 45/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107875.9297 - mean_absolute_error: 151.9268 - val_loss: 114328.8594 - val_mean_absolute_error: 147.7026 - lr: 6.3096e-09
# Epoch 46/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.9688 - mean_absolute_error: 151.9266 - val_loss: 114328.8359 - val_mean_absolute_error: 147.7026 - lr: 5.6234e-09
# Epoch 47/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107874.7344 - mean_absolute_error: 151.9256 - val_loss: 114328.8359 - val_mean_absolute_error: 147.7025 - lr: 5.0119e-09
# Epoch 48/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107875.9219 - mean_absolute_error: 151.9302 - val_loss: 114328.8281 - val_mean_absolute_error: 147.7025 - lr: 4.4668e-09
# Epoch 49/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107876.3438 - mean_absolute_error: 151.9297 - val_loss: 114328.8281 - val_mean_absolute_error: 147.7025 - lr: 3.9811e-09
# Epoch 50/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.6016 - mean_absolute_error: 151.9280 - val_loss: 114328.8125 - val_mean_absolute_error: 147.7025 - lr: 3.5481e-09
# Epoch 51/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.3438 - mean_absolute_error: 151.9273 - val_loss: 114328.8125 - val_mean_absolute_error: 147.7025 - lr: 3.1623e-09
# Epoch 52/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.2031 - mean_absolute_error: 151.9288 - val_loss: 114328.8047 - val_mean_absolute_error: 147.7024 - lr: 2.8184e-09
# Epoch 53/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107875.4922 - mean_absolute_error: 151.9268 - val_loss: 114328.8047 - val_mean_absolute_error: 147.7024 - lr: 2.5119e-09
# Epoch 54/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.5625 - mean_absolute_error: 151.9280 - val_loss: 114328.8047 - val_mean_absolute_error: 147.7024 - lr: 2.2387e-09
# Epoch 55/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.3750 - mean_absolute_error: 151.9305 - val_loss: 114328.8047 - val_mean_absolute_error: 147.7024 - lr: 1.9953e-09
# Epoch 56/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107877.5781 - mean_absolute_error: 151.9312 - val_loss: 114328.8047 - val_mean_absolute_error: 147.7024 - lr: 1.7783e-09
# Epoch 57/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107878.9062 - mean_absolute_error: 151.9288 - val_loss: 114328.8047 - val_mean_absolute_error: 147.7024 - lr: 1.5849e-09
# Epoch 58/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107875.1250 - mean_absolute_error: 151.9256 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 1.4125e-09
# Epoch 59/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107878.9766 - mean_absolute_error: 151.9313 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 1.2589e-09
# Epoch 60/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.1719 - mean_absolute_error: 151.9268 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 1.1220e-09
# Epoch 61/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.1250 - mean_absolute_error: 151.9280 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 1.0000e-09
# Epoch 62/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107878.4688 - mean_absolute_error: 151.9305 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 8.9125e-10
# Epoch 63/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.7578 - mean_absolute_error: 151.9285 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 7.9433e-10
# Epoch 64/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107877.1250 - mean_absolute_error: 151.9297 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 7.0795e-10
# Epoch 65/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.3594 - mean_absolute_error: 151.9278 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 6.3096e-10
# Epoch 66/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107875.4219 - mean_absolute_error: 151.9289 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 5.6234e-10
# Epoch 67/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107877.5469 - mean_absolute_error: 151.9272 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 5.0119e-10
# Epoch 68/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107875.1484 - mean_absolute_error: 151.9264 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 4.4668e-10
# Epoch 69/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.5859 - mean_absolute_error: 151.9287 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 3.9811e-10
# Epoch 70/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.2891 - mean_absolute_error: 151.9268 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 3.5481e-10
# Epoch 71/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.3125 - mean_absolute_error: 151.9274 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 3.1623e-10
# Epoch 72/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.1016 - mean_absolute_error: 151.9290 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 2.8184e-10
# Epoch 73/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.6016 - mean_absolute_error: 151.9256 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 2.5119e-10
# Epoch 74/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107875.9062 - mean_absolute_error: 151.9281 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 2.2387e-10
# Epoch 75/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.2734 - mean_absolute_error: 151.9283 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 1.9953e-10
# Epoch 76/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107876.6719 - mean_absolute_error: 151.9274 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 1.7783e-10
# Epoch 77/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107878.7188 - mean_absolute_error: 151.9285 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 1.5849e-10
# Epoch 78/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107875.3828 - mean_absolute_error: 151.9275 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 1.4125e-10
# Epoch 79/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.2422 - mean_absolute_error: 151.9280 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 1.2589e-10
# Epoch 80/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.1953 - mean_absolute_error: 151.9269 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 1.1220e-10
# Epoch 81/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107876.2500 - mean_absolute_error: 151.9265 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 1.0000e-10
# Epoch 82/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107875.2578 - mean_absolute_error: 151.9275 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 8.9125e-11
# Epoch 83/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107875.9922 - mean_absolute_error: 151.9274 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 7.9433e-11
# Epoch 84/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.6797 - mean_absolute_error: 151.9279 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 7.0795e-11
# Epoch 85/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107877.1719 - mean_absolute_error: 151.9279 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 6.3096e-11
# Epoch 86/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.3906 - mean_absolute_error: 151.9294 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 5.6234e-11
# Epoch 87/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107879.1328 - mean_absolute_error: 151.9288 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 5.0119e-11
# Epoch 88/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.3594 - mean_absolute_error: 151.9264 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 4.4668e-11
# Epoch 89/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.0547 - mean_absolute_error: 151.9263 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 3.9811e-11
# Epoch 90/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107878.2188 - mean_absolute_error: 151.9274 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 3.5481e-11
# Epoch 91/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107878.0234 - mean_absolute_error: 151.9273 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 3.1623e-11
# Epoch 92/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107877.1328 - mean_absolute_error: 151.9292 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 2.8184e-11
# Epoch 93/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107875.3828 - mean_absolute_error: 151.9257 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 2.5119e-11
# Epoch 94/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.4609 - mean_absolute_error: 151.9262 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 2.2387e-11
# Epoch 95/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.5547 - mean_absolute_error: 151.9276 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 1.9953e-11
# Epoch 96/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107876.1797 - mean_absolute_error: 151.9261 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 1.7783e-11
# Epoch 97/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107876.2266 - mean_absolute_error: 151.9254 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 1.5849e-11
# Epoch 98/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107878.2109 - mean_absolute_error: 151.9291 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 1.4125e-11
# Epoch 99/100
# 43/43 [==============================] - 0s 8ms/step - loss: 107877.7031 - mean_absolute_error: 151.9292 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 1.2589e-11
# Epoch 100/100
# 43/43 [==============================] - 0s 7ms/step - loss: 107874.8594 - mean_absolute_error: 151.9277 - val_loss: 114328.7969 - val_mean_absolute_error: 147.7024 - lr: 1.1220e-11

# %% [markdown]
# The subsequent code plots the learning rate versus the loss to visualize the relationship between the learning rate and the model's performance. This can help in choosing an appropriate learning rate for training the model.

# %%
# Plot the learning rate versus the loss
lrs = 1e-6 * (10 ** (np.arange(100)/20))
plt.figure(figsize=(10, 7))
plt.semilogx(lrs, history.history["loss"]) # we want the x-axis (learning rate) to be log scale
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Learning rate vs. loss");

# %% [markdown]
# After that, the code resets the TensorFlow session and the weights of the model to ensure a clean state for further experiments or model retraining. A learning rate value (lrx) is also assigned.

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

lrx=1e-4
lrx
# Out:
# 0.0001

# %% [markdown]
# The code recompiles the model with the specified learning rate and fits it on the preprocessed training data again, this time using the early stopping callback and model checkpoint.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)

# Define the optimizer
optimizer = tf.keras.optimizers.Adam(lr=lrx)

# Compile the model
model_1.compile(loss="mean_squared_error",
                optimizer=optimizer,
                metrics=["mean_absolute_error"])

# Fit the model
history = model_1.fit(xtrain,
                      ytrain,
                      epochs=100,
                      batch_size=32,
                      validation_data=(xtest, ytest),
                      callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 35/43 [=======================>......] - ETA: 0s - loss: 103545.5625 - mean_absolute_error: 144.9363
# Epoch 1: val_loss improved from inf to 103303.36719, saving model to best_model.h5
# 43/43 [==============================] - 1s 12ms/step - loss: 104610.8047 - mean_absolute_error: 142.0062 - val_loss: 103303.3672 - val_mean_absolute_error: 116.4151
# Epoch 2/100
# 35/43 [=======================>......] - ETA: 0s - loss: 84654.9141 - mean_absolute_error: 127.2924
# Epoch 2: val_loss improved from 103303.36719 to 83756.37500, saving model to best_model.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 84197.7188 - mean_absolute_error: 131.3102 - val_loss: 83756.3750 - val_mean_absolute_error: 145.5533
# Epoch 3/100
# 37/43 [========================>.....] - ETA: 0s - loss: 69244.9375 - mean_absolute_error: 144.3388
# Epoch 3: val_loss improved from 83756.37500 to 75613.07031, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 72742.1406 - mean_absolute_error: 144.5124 - val_loss: 75613.0703 - val_mean_absolute_error: 124.7837
# Epoch 4/100
# 35/43 [=======================>......] - ETA: 0s - loss: 59552.0039 - mean_absolute_error: 123.2655
# Epoch 4: val_loss improved from 75613.07031 to 67148.90625, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 63228.3750 - mean_absolute_error: 125.1616 - val_loss: 67148.9062 - val_mean_absolute_error: 119.3164
# Epoch 5/100
# 43/43 [==============================] - ETA: 0s - loss: 53302.2148 - mean_absolute_error: 114.2309
# Epoch 5: val_loss improved from 67148.90625 to 57485.97656, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 53302.2148 - mean_absolute_error: 114.2309 - val_loss: 57485.9766 - val_mean_absolute_error: 106.2651
# Epoch 6/100
# 36/43 [========================>.....] - ETA: 0s - loss: 45566.7617 - mean_absolute_error: 100.0373
# Epoch 6: val_loss improved from 57485.97656 to 48501.43750, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 43148.2031 - mean_absolute_error: 96.8843 - val_loss: 48501.4375 - val_mean_absolute_error: 89.7189
# Epoch 7/100
# 43/43 [==============================] - ETA: 0s - loss: 35304.6523 - mean_absolute_error: 78.8604
# Epoch 7: val_loss improved from 48501.43750 to 42192.74219, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 35304.6523 - mean_absolute_error: 78.8604 - val_loss: 42192.7422 - val_mean_absolute_error: 89.3985
# Epoch 8/100
# 42/43 [============================>.] - ETA: 0s - loss: 30431.0039 - mean_absolute_error: 71.2816
# Epoch 8: val_loss improved from 42192.74219 to 37699.37109, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 29933.3418 - mean_absolute_error: 70.7756 - val_loss: 37699.3711 - val_mean_absolute_error: 80.6549
# Epoch 9/100
# 37/43 [========================>.....] - ETA: 0s - loss: 27654.6914 - mean_absolute_error: 67.3000
# Epoch 9: val_loss improved from 37699.37109 to 34174.69922, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 25634.9199 - mean_absolute_error: 65.4584 - val_loss: 34174.6992 - val_mean_absolute_error: 72.7171
# Epoch 10/100
# 38/43 [=========================>....] - ETA: 0s - loss: 21240.6016 - mean_absolute_error: 58.0092
# Epoch 10: val_loss improved from 34174.69922 to 33210.69922, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 23673.7246 - mean_absolute_error: 58.1220 - val_loss: 33210.6992 - val_mean_absolute_error: 66.6148
# Epoch 11/100
# 40/43 [==========================>...] - ETA: 0s - loss: 19119.1367 - mean_absolute_error: 51.4366
# Epoch 11: val_loss improved from 33210.69922 to 32204.88672, saving model to best_model.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 21017.7383 - mean_absolute_error: 53.3278 - val_loss: 32204.8867 - val_mean_absolute_error: 72.5305
# Epoch 12/100
# 41/43 [===========================>..] - ETA: 0s - loss: 18540.3672 - mean_absolute_error: 52.5952
# Epoch 12: val_loss improved from 32204.88672 to 31654.75195, saving model to best_model.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 20379.5352 - mean_absolute_error: 53.6845 - val_loss: 31654.7520 - val_mean_absolute_error: 66.3197
# Epoch 13/100
# 36/43 [========================>.....] - ETA: 0s - loss: 20262.3223 - mean_absolute_error: 51.5966
# Epoch 13: val_loss improved from 31654.75195 to 31187.42578, saving model to best_model.h5
# 43/43 [==============================] - 0s 10ms/step - loss: 18428.9277 - mean_absolute_error: 49.6176 - val_loss: 31187.4258 - val_mean_absolute_error: 67.3058
# Epoch 14/100
# 39/43 [==========================>...] - ETA: 0s - loss: 17052.5762 - mean_absolute_error: 45.8246
# Epoch 14: val_loss improved from 31187.42578 to 30778.87109, saving model to best_model.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 17764.7637 - mean_absolute_error: 45.9181 - val_loss: 30778.8711 - val_mean_absolute_error: 71.0192
# Epoch 15/100
# 42/43 [============================>.] - ETA: 0s - loss: 18213.2461 - mean_absolute_error: 47.7697
# Epoch 15: val_loss improved from 30778.87109 to 30775.63281, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 17884.3262 - mean_absolute_error: 47.2692 - val_loss: 30775.6328 - val_mean_absolute_error: 72.6009
# Epoch 16/100
# 43/43 [==============================] - ETA: 0s - loss: 16759.1035 - mean_absolute_error: 44.9896
# Epoch 16: val_loss improved from 30775.63281 to 30601.57227, saving model to best_model.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 16759.1035 - mean_absolute_error: 44.9896 - val_loss: 30601.5723 - val_mean_absolute_error: 64.9350
# Epoch 17/100
# 37/43 [========================>.....] - ETA: 0s - loss: 18153.3164 - mean_absolute_error: 44.7911
# Epoch 17: val_loss improved from 30601.57227 to 30280.06445, saving model to best_model.h5
# 43/43 [==============================] - 0s 7ms/step - loss: 16737.2402 - mean_absolute_error: 44.4778 - val_loss: 30280.0645 - val_mean_absolute_error: 69.6645
# Epoch 18/100
# 37/43 [========================>.....] - ETA: 0s - loss: 17119.9961 - mean_absolute_error: 43.2556
# Epoch 18: val_loss did not improve from 30280.06445
# 43/43 [==============================] - 0s 7ms/step - loss: 16254.1982 - mean_absolute_error: 43.9233 - val_loss: 30552.0059 - val_mean_absolute_error: 64.8354
# Epoch 19/100
# 37/43 [========================>.....] - ETA: 0s - loss: 18119.3086 - mean_absolute_error: 46.3885
# Epoch 19: val_loss did not improve from 30280.06445
# 43/43 [==============================] - 0s 7ms/step - loss: 16384.5039 - mean_absolute_error: 44.4235 - val_loss: 30611.8301 - val_mean_absolute_error: 62.3810
# Epoch 20/100
# 38/43 [=========================>....] - ETA: 0s - loss: 15511.9717 - mean_absolute_error: 42.3153
# Epoch 20: val_loss improved from 30280.06445 to 29772.52539, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 15862.8945 - mean_absolute_error: 42.3612 - val_loss: 29772.5254 - val_mean_absolute_error: 65.2377
# Epoch 21/100
# 37/43 [========================>.....] - ETA: 0s - loss: 17263.5977 - mean_absolute_error: 42.2475
# Epoch 21: val_loss did not improve from 29772.52539
# 43/43 [==============================] - 0s 7ms/step - loss: 16048.8457 - mean_absolute_error: 41.9153 - val_loss: 30053.9473 - val_mean_absolute_error: 61.8498
# Epoch 22/100
# 36/43 [========================>.....] - ETA: 0s - loss: 13314.9639 - mean_absolute_error: 40.9498
# Epoch 22: val_loss improved from 29772.52539 to 29599.25000, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 15397.8848 - mean_absolute_error: 41.1912 - val_loss: 29599.2500 - val_mean_absolute_error: 64.0660
# Epoch 23/100
# 39/43 [==========================>...] - ETA: 0s - loss: 15985.4355 - mean_absolute_error: 41.8891
# Epoch 23: val_loss did not improve from 29599.25000
# 43/43 [==============================] - 0s 7ms/step - loss: 15439.1631 - mean_absolute_error: 42.0779 - val_loss: 30072.7812 - val_mean_absolute_error: 62.4119
# Epoch 24/100
# 37/43 [========================>.....] - ETA: 0s - loss: 17131.5723 - mean_absolute_error: 43.8860
# Epoch 24: val_loss did not improve from 29599.25000
# 43/43 [==============================] - 0s 7ms/step - loss: 15671.3613 - mean_absolute_error: 42.4419 - val_loss: 30309.9219 - val_mean_absolute_error: 61.8622
# Epoch 25/100
# 38/43 [=========================>....] - ETA: 0s - loss: 15482.2666 - mean_absolute_error: 40.1720
# Epoch 25: val_loss improved from 29599.25000 to 29289.63867, saving model to best_model.h5
# 43/43 [==============================] - 0s 7ms/step - loss: 15089.4355 - mean_absolute_error: 41.2248 - val_loss: 29289.6387 - val_mean_absolute_error: 63.4133
# Epoch 26/100
# 36/43 [========================>.....] - ETA: 0s - loss: 16182.3955 - mean_absolute_error: 38.9524
# Epoch 26: val_loss did not improve from 29289.63867
# 43/43 [==============================] - 0s 7ms/step - loss: 14968.7998 - mean_absolute_error: 39.4940 - val_loss: 29596.6387 - val_mean_absolute_error: 64.2785
# Epoch 27/100
# 36/43 [========================>.....] - ETA: 0s - loss: 13522.1602 - mean_absolute_error: 39.6490
# Epoch 27: val_loss improved from 29289.63867 to 29176.76367, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 16480.1172 - mean_absolute_error: 40.7669 - val_loss: 29176.7637 - val_mean_absolute_error: 64.3860
# Epoch 28/100
# 37/43 [========================>.....] - ETA: 0s - loss: 14394.8652 - mean_absolute_error: 38.3952
# Epoch 28: val_loss improved from 29176.76367 to 29109.07227, saving model to best_model.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 15151.4766 - mean_absolute_error: 38.9795 - val_loss: 29109.0723 - val_mean_absolute_error: 64.7732
# Epoch 29/100
# 42/43 [============================>.] - ETA: 0s - loss: 16052.8301 - mean_absolute_error: 42.4876
# Epoch 29: val_loss did not improve from 29109.07227
# 43/43 [==============================] - 0s 8ms/step - loss: 15797.6045 - mean_absolute_error: 42.1403 - val_loss: 29377.3848 - val_mean_absolute_error: 60.9737
# Epoch 30/100
# 36/43 [========================>.....] - ETA: 0s - loss: 14993.7275 - mean_absolute_error: 40.5621
# Epoch 30: val_loss did not improve from 29109.07227
# 43/43 [==============================] - 0s 7ms/step - loss: 15433.0244 - mean_absolute_error: 39.9816 - val_loss: 29374.2891 - val_mean_absolute_error: 61.5387
# Epoch 31/100
# 37/43 [========================>.....] - ETA: 0s - loss: 15144.1807 - mean_absolute_error: 39.7206
# Epoch 31: val_loss improved from 29109.07227 to 28874.59961, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 14657.6729 - mean_absolute_error: 40.0890 - val_loss: 28874.5996 - val_mean_absolute_error: 61.1387
# Epoch 32/100
# 43/43 [==============================] - ETA: 0s - loss: 14438.2266 - mean_absolute_error: 38.7941
# Epoch 32: val_loss improved from 28874.59961 to 28759.96289, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 14438.2266 - mean_absolute_error: 38.7941 - val_loss: 28759.9629 - val_mean_absolute_error: 61.0094
# Epoch 33/100
# 43/43 [==============================] - ETA: 0s - loss: 15257.2812 - mean_absolute_error: 38.5368
# Epoch 33: val_loss improved from 28759.96289 to 28495.60938, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 15257.2812 - mean_absolute_error: 38.5368 - val_loss: 28495.6094 - val_mean_absolute_error: 62.6711
# Epoch 34/100
# 42/43 [============================>.] - ETA: 0s - loss: 13181.9121 - mean_absolute_error: 37.8833
# Epoch 34: val_loss did not improve from 28495.60938
# 43/43 [==============================] - 0s 8ms/step - loss: 14305.2373 - mean_absolute_error: 38.9873 - val_loss: 29174.6152 - val_mean_absolute_error: 59.9411
# Epoch 35/100
# 43/43 [==============================] - ETA: 0s - loss: 15951.2285 - mean_absolute_error: 39.6293
# Epoch 35: val_loss did not improve from 28495.60938
# 43/43 [==============================] - 0s 8ms/step - loss: 15951.2285 - mean_absolute_error: 39.6293 - val_loss: 28875.0000 - val_mean_absolute_error: 62.5407
# Epoch 36/100
# 35/43 [=======================>......] - ETA: 0s - loss: 10983.7383 - mean_absolute_error: 36.0274
# Epoch 36: val_loss did not improve from 28495.60938
# 43/43 [==============================] - 0s 7ms/step - loss: 14243.8604 - mean_absolute_error: 37.8472 - val_loss: 28618.9453 - val_mean_absolute_error: 59.6410
# Epoch 37/100
# 36/43 [========================>.....] - ETA: 0s - loss: 15941.2773 - mean_absolute_error: 39.0841
# Epoch 37: val_loss improved from 28495.60938 to 28352.23828, saving model to best_model.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 15312.5088 - mean_absolute_error: 38.8978 - val_loss: 28352.2383 - val_mean_absolute_error: 61.4549
# Epoch 38/100
# 36/43 [========================>.....] - ETA: 0s - loss: 16361.8574 - mean_absolute_error: 41.6766
# Epoch 38: val_loss improved from 28352.23828 to 28055.94531, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 14731.9941 - mean_absolute_error: 39.8609 - val_loss: 28055.9453 - val_mean_absolute_error: 60.0614
# Epoch 39/100
# 37/43 [========================>.....] - ETA: 0s - loss: 15622.5186 - mean_absolute_error: 39.1482
# Epoch 39: val_loss did not improve from 28055.94531
# 43/43 [==============================] - 0s 7ms/step - loss: 14264.3721 - mean_absolute_error: 38.0862 - val_loss: 28640.7500 - val_mean_absolute_error: 59.2518
# Epoch 40/100
# 36/43 [========================>.....] - ETA: 0s - loss: 11640.5088 - mean_absolute_error: 36.0236
# Epoch 40: val_loss did not improve from 28055.94531
# 43/43 [==============================] - 0s 7ms/step - loss: 14359.3945 - mean_absolute_error: 37.9378 - val_loss: 28231.7520 - val_mean_absolute_error: 58.5645
# Epoch 41/100
# 41/43 [===========================>..] - ETA: 0s - loss: 15575.8398 - mean_absolute_error: 37.5851
# Epoch 41: val_loss improved from 28055.94531 to 27990.43164, saving model to best_model.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 15464.2461 - mean_absolute_error: 37.9533 - val_loss: 27990.4316 - val_mean_absolute_error: 60.1358
# Epoch 42/100
# 37/43 [========================>.....] - ETA: 0s - loss: 13436.4541 - mean_absolute_error: 36.0951
# Epoch 42: val_loss did not improve from 27990.43164
# 43/43 [==============================] - 0s 7ms/step - loss: 14187.8848 - mean_absolute_error: 37.7250 - val_loss: 28754.4746 - val_mean_absolute_error: 58.5901
# Epoch 43/100
# 36/43 [========================>.....] - ETA: 0s - loss: 14830.6230 - mean_absolute_error: 36.9221
# Epoch 43: val_loss improved from 27990.43164 to 27502.53906, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 14821.7422 - mean_absolute_error: 37.2001 - val_loss: 27502.5391 - val_mean_absolute_error: 61.8973
# Epoch 44/100
# 35/43 [=======================>......] - ETA: 0s - loss: 16098.2871 - mean_absolute_error: 39.3519
# Epoch 44: val_loss did not improve from 27502.53906
# 43/43 [==============================] - 0s 7ms/step - loss: 15193.5713 - mean_absolute_error: 39.4143 - val_loss: 27690.8945 - val_mean_absolute_error: 58.4929
# Epoch 45/100
# 36/43 [========================>.....] - ETA: 0s - loss: 10091.7900 - mean_absolute_error: 34.4702
# Epoch 45: val_loss improved from 27502.53906 to 27427.63867, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 15047.7188 - mean_absolute_error: 37.8903 - val_loss: 27427.6387 - val_mean_absolute_error: 59.2232
# Epoch 46/100
# 35/43 [=======================>......] - ETA: 0s - loss: 16259.4180 - mean_absolute_error: 40.1140
# Epoch 46: val_loss did not improve from 27427.63867
# 43/43 [==============================] - 0s 7ms/step - loss: 14487.4219 - mean_absolute_error: 39.0628 - val_loss: 28167.5605 - val_mean_absolute_error: 58.1844
# Epoch 47/100
# 36/43 [========================>.....] - ETA: 0s - loss: 16239.3926 - mean_absolute_error: 39.1312
# Epoch 47: val_loss did not improve from 27427.63867
# 43/43 [==============================] - 0s 7ms/step - loss: 14904.4512 - mean_absolute_error: 38.7010 - val_loss: 27877.3945 - val_mean_absolute_error: 58.2365
# Epoch 48/100
# 35/43 [=======================>......] - ETA: 0s - loss: 13512.6543 - mean_absolute_error: 35.4366
# Epoch 48: val_loss did not improve from 27427.63867
# 43/43 [==============================] - 0s 8ms/step - loss: 13556.8516 - mean_absolute_error: 36.0641 - val_loss: 27550.1016 - val_mean_absolute_error: 58.4490
# Epoch 49/100
# 37/43 [========================>.....] - ETA: 0s - loss: 15801.8701 - mean_absolute_error: 39.8049
# Epoch 49: val_loss did not improve from 27427.63867
# 43/43 [==============================] - 0s 7ms/step - loss: 14811.5635 - mean_absolute_error: 38.8136 - val_loss: 28439.6992 - val_mean_absolute_error: 57.4649
# Epoch 50/100
# 36/43 [========================>.....] - ETA: 0s - loss: 13402.6641 - mean_absolute_error: 36.5029
# Epoch 50: val_loss improved from 27427.63867 to 27309.75781, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 15249.3994 - mean_absolute_error: 38.7485 - val_loss: 27309.7578 - val_mean_absolute_error: 61.2295
# Epoch 51/100
# 35/43 [=======================>......] - ETA: 0s - loss: 14826.7656 - mean_absolute_error: 37.2732
# Epoch 51: val_loss improved from 27309.75781 to 27053.38477, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 14843.5752 - mean_absolute_error: 38.1655 - val_loss: 27053.3848 - val_mean_absolute_error: 60.6907
# Epoch 52/100
# 35/43 [=======================>......] - ETA: 0s - loss: 16512.3750 - mean_absolute_error: 37.6016
# Epoch 52: val_loss did not improve from 27053.38477
# 43/43 [==============================] - 0s 7ms/step - loss: 15201.3672 - mean_absolute_error: 38.3735 - val_loss: 27197.9863 - val_mean_absolute_error: 58.2341
# Epoch 53/100
# 36/43 [========================>.....] - ETA: 0s - loss: 16661.9590 - mean_absolute_error: 38.7217
# Epoch 53: val_loss did not improve from 27053.38477
# 43/43 [==============================] - 0s 7ms/step - loss: 14919.1348 - mean_absolute_error: 38.1789 - val_loss: 27598.3477 - val_mean_absolute_error: 56.9570
# Epoch 54/100
# 37/43 [========================>.....] - ETA: 0s - loss: 13508.8682 - mean_absolute_error: 36.7379
# Epoch 54: val_loss did not improve from 27053.38477
# 43/43 [==============================] - 0s 8ms/step - loss: 14048.1602 - mean_absolute_error: 36.9367 - val_loss: 27497.6523 - val_mean_absolute_error: 58.0853
# Epoch 55/100
# 37/43 [========================>.....] - ETA: 0s - loss: 11268.0078 - mean_absolute_error: 35.5948
# Epoch 55: val_loss did not improve from 27053.38477
# 43/43 [==============================] - 0s 7ms/step - loss: 14437.5771 - mean_absolute_error: 37.0192 - val_loss: 27726.9707 - val_mean_absolute_error: 56.5464
# Epoch 56/100
# 35/43 [=======================>......] - ETA: 0s - loss: 16086.9502 - mean_absolute_error: 38.6541
# Epoch 56: val_loss did not improve from 27053.38477
# 43/43 [==============================] - 0s 7ms/step - loss: 14321.2119 - mean_absolute_error: 37.4265 - val_loss: 28765.3125 - val_mean_absolute_error: 57.5385
# Epoch 57/100
# 37/43 [========================>.....] - ETA: 0s - loss: 10764.7959 - mean_absolute_error: 35.2175
# Epoch 57: val_loss improved from 27053.38477 to 26720.94727, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 14786.1084 - mean_absolute_error: 37.0388 - val_loss: 26720.9473 - val_mean_absolute_error: 59.7065
# Epoch 58/100
# 42/43 [============================>.] - ETA: 0s - loss: 15072.6455 - mean_absolute_error: 38.6456
# Epoch 58: val_loss did not improve from 26720.94727
# 43/43 [==============================] - 0s 8ms/step - loss: 14796.4229 - mean_absolute_error: 38.2899 - val_loss: 27005.1992 - val_mean_absolute_error: 58.2060
# Epoch 59/100
# 37/43 [========================>.....] - ETA: 0s - loss: 16055.5576 - mean_absolute_error: 38.2061
# Epoch 59: val_loss did not improve from 26720.94727
# 43/43 [==============================] - 0s 7ms/step - loss: 14666.1680 - mean_absolute_error: 37.4470 - val_loss: 27057.8047 - val_mean_absolute_error: 56.6269
# Epoch 60/100
# 36/43 [========================>.....] - ETA: 0s - loss: 10651.5166 - mean_absolute_error: 34.4162
# Epoch 60: val_loss did not improve from 26720.94727
# 43/43 [==============================] - 0s 7ms/step - loss: 13500.1719 - mean_absolute_error: 35.7740 - val_loss: 26963.6055 - val_mean_absolute_error: 56.1066
# Epoch 61/100
# 42/43 [============================>.] - ETA: 0s - loss: 14371.8838 - mean_absolute_error: 36.7318
# Epoch 61: val_loss did not improve from 26720.94727
# 43/43 [==============================] - 0s 8ms/step - loss: 14116.3193 - mean_absolute_error: 36.3687 - val_loss: 26829.3848 - val_mean_absolute_error: 57.2287
# Epoch 62/100
# 37/43 [========================>.....] - ETA: 0s - loss: 14268.7412 - mean_absolute_error: 37.7711
# Epoch 62: val_loss did not improve from 26720.94727
# 43/43 [==============================] - 0s 8ms/step - loss: 14269.0820 - mean_absolute_error: 37.8224 - val_loss: 27168.4453 - val_mean_absolute_error: 56.3480
# Epoch 63/100
# 37/43 [========================>.....] - ETA: 0s - loss: 10645.0186 - mean_absolute_error: 33.7238
# Epoch 63: val_loss improved from 26720.94727 to 26421.61719, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 13473.3564 - mean_absolute_error: 35.7659 - val_loss: 26421.6172 - val_mean_absolute_error: 56.0825
# Epoch 64/100
# 36/43 [========================>.....] - ETA: 0s - loss: 14449.9111 - mean_absolute_error: 37.3275
# Epoch 64: val_loss did not improve from 26421.61719
# 43/43 [==============================] - 0s 7ms/step - loss: 14006.2490 - mean_absolute_error: 37.0873 - val_loss: 27260.2207 - val_mean_absolute_error: 56.9031
# Epoch 65/100
# 37/43 [========================>.....] - ETA: 0s - loss: 15770.3057 - mean_absolute_error: 36.9242
# Epoch 65: val_loss did not improve from 26421.61719
# 43/43 [==============================] - 0s 7ms/step - loss: 14710.9102 - mean_absolute_error: 36.7375 - val_loss: 26491.5977 - val_mean_absolute_error: 56.7499
# Epoch 66/100
# 37/43 [========================>.....] - ETA: 0s - loss: 12742.2178 - mean_absolute_error: 35.8791
# Epoch 66: val_loss improved from 26421.61719 to 26343.77930, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 13816.2949 - mean_absolute_error: 36.8386 - val_loss: 26343.7793 - val_mean_absolute_error: 60.0743
# Epoch 67/100
# 35/43 [=======================>......] - ETA: 0s - loss: 15509.4854 - mean_absolute_error: 36.7168
# Epoch 67: val_loss did not improve from 26343.77930
# 43/43 [==============================] - 0s 7ms/step - loss: 14008.0420 - mean_absolute_error: 36.6991 - val_loss: 26463.0078 - val_mean_absolute_error: 56.2842
# Epoch 68/100
# 37/43 [========================>.....] - ETA: 0s - loss: 15328.7471 - mean_absolute_error: 36.9117
# Epoch 68: val_loss did not improve from 26343.77930
# 43/43 [==============================] - 0s 7ms/step - loss: 14149.8525 - mean_absolute_error: 36.3807 - val_loss: 26381.9941 - val_mean_absolute_error: 57.4108
# Epoch 69/100
# 37/43 [========================>.....] - ETA: 0s - loss: 14564.8291 - mean_absolute_error: 36.3238
# Epoch 69: val_loss did not improve from 26343.77930
# 43/43 [==============================] - 0s 7ms/step - loss: 13772.2158 - mean_absolute_error: 36.4121 - val_loss: 26628.1133 - val_mean_absolute_error: 56.1044
# Epoch 70/100
# 37/43 [========================>.....] - ETA: 0s - loss: 14756.4443 - mean_absolute_error: 35.7114
# Epoch 70: val_loss did not improve from 26343.77930
# 43/43 [==============================] - 0s 7ms/step - loss: 13956.5908 - mean_absolute_error: 35.9436 - val_loss: 27050.0000 - val_mean_absolute_error: 55.9829
# Epoch 71/100
# 43/43 [==============================] - ETA: 0s - loss: 13463.9668 - mean_absolute_error: 35.6431
# Epoch 71: val_loss did not improve from 26343.77930
# 43/43 [==============================] - 0s 9ms/step - loss: 13463.9668 - mean_absolute_error: 35.6431 - val_loss: 26414.2480 - val_mean_absolute_error: 56.7952
# Epoch 72/100
# 36/43 [========================>.....] - ETA: 0s - loss: 11510.2773 - mean_absolute_error: 33.7988
# Epoch 72: val_loss did not improve from 26343.77930
# 43/43 [==============================] - 0s 8ms/step - loss: 13540.6611 - mean_absolute_error: 36.1260 - val_loss: 26518.3477 - val_mean_absolute_error: 55.3357
# Epoch 73/100
# 36/43 [========================>.....] - ETA: 0s - loss: 14537.4229 - mean_absolute_error: 36.0287
# Epoch 73: val_loss improved from 26343.77930 to 26131.63281, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 13131.8018 - mean_absolute_error: 35.2213 - val_loss: 26131.6328 - val_mean_absolute_error: 55.6221
# Epoch 74/100
# 36/43 [========================>.....] - ETA: 0s - loss: 14867.2744 - mean_absolute_error: 35.3715
# Epoch 74: val_loss did not improve from 26131.63281
# 43/43 [==============================] - 0s 8ms/step - loss: 14475.2617 - mean_absolute_error: 36.0043 - val_loss: 26247.1426 - val_mean_absolute_error: 56.8056
# Epoch 75/100
# 43/43 [==============================] - ETA: 0s - loss: 13962.6025 - mean_absolute_error: 35.9864
# Epoch 75: val_loss improved from 26131.63281 to 26083.08789, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 13962.6025 - mean_absolute_error: 35.9864 - val_loss: 26083.0879 - val_mean_absolute_error: 55.6443
# Epoch 76/100
# 37/43 [========================>.....] - ETA: 0s - loss: 11454.1719 - mean_absolute_error: 36.0443
# Epoch 76: val_loss did not improve from 26083.08789
# 43/43 [==============================] - 0s 7ms/step - loss: 13689.6953 - mean_absolute_error: 36.2855 - val_loss: 26327.1992 - val_mean_absolute_error: 55.1256
# Epoch 77/100
# 36/43 [========================>.....] - ETA: 0s - loss: 14351.5146 - mean_absolute_error: 34.7241
# Epoch 77: val_loss improved from 26083.08789 to 25903.59961, saving model to best_model.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 13460.6816 - mean_absolute_error: 34.9359 - val_loss: 25903.5996 - val_mean_absolute_error: 57.9957
# Epoch 78/100
# 34/43 [======================>.......] - ETA: 0s - loss: 13289.3369 - mean_absolute_error: 34.3372
# Epoch 78: val_loss did not improve from 25903.59961
# 43/43 [==============================] - 0s 7ms/step - loss: 13775.0371 - mean_absolute_error: 36.4440 - val_loss: 26623.4316 - val_mean_absolute_error: 55.3002
# Epoch 79/100
# 36/43 [========================>.....] - ETA: 0s - loss: 12458.5703 - mean_absolute_error: 34.1966
# Epoch 79: val_loss improved from 25903.59961 to 25830.91016, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 13295.2793 - mean_absolute_error: 35.8845 - val_loss: 25830.9102 - val_mean_absolute_error: 59.4462
# Epoch 80/100
# 36/43 [========================>.....] - ETA: 0s - loss: 12626.7275 - mean_absolute_error: 36.6075
# Epoch 80: val_loss did not improve from 25830.91016
# 43/43 [==============================] - 0s 7ms/step - loss: 13105.1973 - mean_absolute_error: 36.5256 - val_loss: 26521.3770 - val_mean_absolute_error: 55.1282
# Epoch 81/100
# 38/43 [=========================>....] - ETA: 0s - loss: 12795.0898 - mean_absolute_error: 34.2536
# Epoch 81: val_loss improved from 25830.91016 to 25614.22656, saving model to best_model.h5
# 43/43 [==============================] - 0s 7ms/step - loss: 13523.4053 - mean_absolute_error: 35.5739 - val_loss: 25614.2266 - val_mean_absolute_error: 56.9872
# Epoch 82/100
# 36/43 [========================>.....] - ETA: 0s - loss: 12110.0088 - mean_absolute_error: 34.6795
# Epoch 82: val_loss improved from 25614.22656 to 25549.02930, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 13772.1836 - mean_absolute_error: 36.6566 - val_loss: 25549.0293 - val_mean_absolute_error: 56.3845
# Epoch 83/100
# 43/43 [==============================] - ETA: 0s - loss: 13488.1650 - mean_absolute_error: 35.8905
# Epoch 83: val_loss did not improve from 25549.02930
# 43/43 [==============================] - 0s 8ms/step - loss: 13488.1650 - mean_absolute_error: 35.8905 - val_loss: 25828.2910 - val_mean_absolute_error: 54.7120
# Epoch 84/100
# 36/43 [========================>.....] - ETA: 0s - loss: 10491.1201 - mean_absolute_error: 34.6360
# Epoch 84: val_loss did not improve from 25549.02930
# 43/43 [==============================] - 0s 7ms/step - loss: 13235.4238 - mean_absolute_error: 35.2796 - val_loss: 26072.6797 - val_mean_absolute_error: 54.2314
# Epoch 85/100
# 36/43 [========================>.....] - ETA: 0s - loss: 14241.2285 - mean_absolute_error: 35.6014
# Epoch 85: val_loss did not improve from 25549.02930
# 43/43 [==============================] - 0s 7ms/step - loss: 12703.1689 - mean_absolute_error: 34.8545 - val_loss: 25823.0762 - val_mean_absolute_error: 54.4241
# Epoch 86/100
# 38/43 [=========================>....] - ETA: 0s - loss: 13106.2236 - mean_absolute_error: 35.2528
# Epoch 86: val_loss improved from 25549.02930 to 25338.09375, saving model to best_model.h5
# 43/43 [==============================] - 0s 7ms/step - loss: 13622.4902 - mean_absolute_error: 35.8801 - val_loss: 25338.0938 - val_mean_absolute_error: 55.9478
# Epoch 87/100
# 35/43 [=======================>......] - ETA: 0s - loss: 17077.6055 - mean_absolute_error: 38.3550
# Epoch 87: val_loss did not improve from 25338.09375
# 43/43 [==============================] - 0s 7ms/step - loss: 14629.3389 - mean_absolute_error: 36.1510 - val_loss: 25787.8652 - val_mean_absolute_error: 55.0532
# Epoch 88/100
# 43/43 [==============================] - ETA: 0s - loss: 13939.1631 - mean_absolute_error: 36.8095
# Epoch 88: val_loss improved from 25338.09375 to 25258.29102, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 13939.1631 - mean_absolute_error: 36.8095 - val_loss: 25258.2910 - val_mean_absolute_error: 55.7836
# Epoch 89/100
# 35/43 [=======================>......] - ETA: 0s - loss: 14923.5635 - mean_absolute_error: 36.7774
# Epoch 89: val_loss did not improve from 25258.29102
# 43/43 [==============================] - 0s 7ms/step - loss: 13539.2764 - mean_absolute_error: 36.4555 - val_loss: 25638.2539 - val_mean_absolute_error: 54.8172
# Epoch 90/100
# 43/43 [==============================] - ETA: 0s - loss: 13850.8301 - mean_absolute_error: 35.6483
# Epoch 90: val_loss did not improve from 25258.29102
# 43/43 [==============================] - 0s 8ms/step - loss: 13850.8301 - mean_absolute_error: 35.6483 - val_loss: 26001.1660 - val_mean_absolute_error: 54.5796
# Epoch 91/100
# 36/43 [========================>.....] - ETA: 0s - loss: 8584.3408 - mean_absolute_error: 32.6557
# Epoch 91: val_loss did not improve from 25258.29102
# 43/43 [==============================] - 0s 7ms/step - loss: 13269.6992 - mean_absolute_error: 34.1397 - val_loss: 25513.7266 - val_mean_absolute_error: 55.2670
# Epoch 92/100
# 41/43 [===========================>..] - ETA: 0s - loss: 13800.1611 - mean_absolute_error: 35.0350
# Epoch 92: val_loss did not improve from 25258.29102
# 43/43 [==============================] - 0s 8ms/step - loss: 13683.2842 - mean_absolute_error: 35.2250 - val_loss: 25378.1113 - val_mean_absolute_error: 54.4954
# Epoch 93/100
# 37/43 [========================>.....] - ETA: 0s - loss: 15288.8213 - mean_absolute_error: 37.3833
# Epoch 93: val_loss did not improve from 25258.29102
# 43/43 [==============================] - 0s 7ms/step - loss: 13571.2637 - mean_absolute_error: 34.9998 - val_loss: 26980.2207 - val_mean_absolute_error: 54.5780
# Epoch 94/100
# 35/43 [=======================>......] - ETA: 0s - loss: 14750.6182 - mean_absolute_error: 36.3066
# Epoch 94: val_loss did not improve from 25258.29102
# 43/43 [==============================] - 0s 7ms/step - loss: 13506.5576 - mean_absolute_error: 35.2090 - val_loss: 25593.9062 - val_mean_absolute_error: 54.0176
# Epoch 95/100
# 35/43 [=======================>......] - ETA: 0s - loss: 9138.5107 - mean_absolute_error: 31.1830
# Epoch 95: val_loss did not improve from 25258.29102
# 43/43 [==============================] - 0s 8ms/step - loss: 13003.8057 - mean_absolute_error: 33.5552 - val_loss: 25658.2656 - val_mean_absolute_error: 53.6680
# Epoch 96/100
# 36/43 [========================>.....] - ETA: 0s - loss: 7568.8984 - mean_absolute_error: 30.2453
# Epoch 96: val_loss improved from 25258.29102 to 25241.58398, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 12569.8965 - mean_absolute_error: 33.2476 - val_loss: 25241.5840 - val_mean_absolute_error: 55.4832
# Epoch 97/100
# 38/43 [=========================>....] - ETA: 0s - loss: 10548.3477 - mean_absolute_error: 34.4176
# Epoch 97: val_loss did not improve from 25241.58398
# 43/43 [==============================] - 0s 7ms/step - loss: 14164.0156 - mean_absolute_error: 36.7573 - val_loss: 26707.7930 - val_mean_absolute_error: 54.1955
# Epoch 98/100
# 37/43 [========================>.....] - ETA: 0s - loss: 15416.6787 - mean_absolute_error: 36.1757
# Epoch 98: val_loss did not improve from 25241.58398
# 43/43 [==============================] - 0s 7ms/step - loss: 14155.8643 - mean_absolute_error: 35.8374 - val_loss: 25429.5508 - val_mean_absolute_error: 53.7363
# Epoch 99/100
# 36/43 [========================>.....] - ETA: 0s - loss: 14977.2881 - mean_absolute_error: 37.4869
# Epoch 99: val_loss did not improve from 25241.58398
# 43/43 [==============================] - 0s 7ms/step - loss: 14082.8516 - mean_absolute_error: 35.7735 - val_loss: 25279.1582 - val_mean_absolute_error: 53.6456
# Epoch 100/100
# 42/43 [============================>.] - ETA: 0s - loss: 14077.7188 - mean_absolute_error: 36.0183
# Epoch 100: val_loss improved from 25241.58398 to 24389.57617, saving model to best_model.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 13989.0928 - mean_absolute_error: 36.1774 - val_loss: 24389.5762 - val_mean_absolute_error: 57.3183

# %% [markdown]
# A function called "plot_losses" is defined to plot the losses (training and validation) from the history object returned by the model training process.

# %%
def plot_losses(history):
    losses = pd.DataFrame(history.history)
    losses.plot()

# %%
plot_losses(history)

# %% [markdown]
# The next code loads the best saved model from the model checkpoint file ("best_model.h5").

# %%
from tensorflow.keras.models import load_model

# Load the best saved model
model = load_model('best_model.h5')

# %%
model.evaluate(xtest, ytest)
# Out:
# 11/11 [==============================] - 0s 2ms/step - loss: 24389.5762 - mean_absolute_error: 57.3183
# [24389.576171875, 57.31826400756836]

# %%
# Predictions
testPredict = model.predict(xtest)
# Out:
# 11/11 [==============================] - 0s 2ms/step

# %% [markdown]
# Test predictions are made using the loaded model, and an evaluation function is defined to calculate and print the mean absolute error (MAE) and mean squared error (MSE) between the true target values (ytest) and the predicted values (testPredict).

# %%
# Evaluate model
def evaluate_model(y_true, y_pred):
    mae = tf.keras.metrics.mean_absolute_error(y_true, y_pred)
    mse = tf.keras.metrics.mean_squared_error(y_true, y_pred)

    print('Mean Absolute Error: ', mae.numpy())
    print('Mean Squared Error: ', mse.numpy())

# %% [markdown]
# The code then evaluates the model's performance by calling the evaluation function with the true target values and the predicted values. The MAE and MSE are printed, providing an assessment of the model's predictive accuracy.

# %%
evaluate_model(ytest, tf.squeeze(testPredict))  # Flatten the prediction array to match the shape
# Out:
# Mean Absolute Error:  57.318264
# Mean Squared Error:  24343.408

# %% [markdown]
# **Hyperparameter Tuning**
#
# The following code defines a function called "build_model" that constructs a neural network model with customizable hyperparameters. The model includes multiple layers, dropout regularization, and batch normalization. It is compiled with an Adam optimizer and mean squared error loss.

# %%
def build_model(hp):
    from keras.layers import BatchNormalization
    from keras.regularizers import l1_l2

    # Define all hyperparameters
    n_layers = hp.Choice('n_layers', [2, 4, 6])
    dropout_rate = hp.Choice('rate', [0.2, 0.4, 0.5, 0.7])
    n_units = hp.Choice('units', [64, 128, 256, 512])
    l1_reg = hp.Choice('l1', [0.0, 0.01, 0.001, 0.0001])
    l2_reg = hp.Choice('l2', [0.0, 0.01, 0.001, 0.0001])

    # Model architecture
    model = Sequential()

    # Input layer
    model.add(Dense(n_units, input_dim=xtrain.shape[1], activation='relu', kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)))
    model.add(BatchNormalization())

    # Add hidden layers
    for _ in range(n_layers):
        model.add(Dense(n_units, activation='relu', kernel_initializer='he_normal', kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)))
        model.add(BatchNormalization())

    # Add Dropout Layer
    model.add(Dropout(dropout_rate))

    # Output Layer
    model.add(Dense(1))

    # Define the optimizer
    optimizer = tf.keras.optimizers.Adam(lr=lrx)

    # Compile the model
    model.compile(loss="mean_squared_error",
                    optimizer=optimizer,
                    metrics=["mean_absolute_error"])

    # Return model
    return model

# %% [markdown]
# In the next code block, a random search is initialized to find the best model architecture. The search explores different hyperparameter combinations and aims to minimize validation loss. This approach helps in identifying the optimal model configuration.

# %%
# Initialize Random Searcher
random_searcher = kt.RandomSearch(
    hypermodel=build_model,
    objective='val_loss',
    max_trials=30,
    seed=42,
    project_name="Plt-Search"
)

# Start Searching
search = random_searcher.search(
    xtrain, ytrain,
    validation_data=(xtest, ytest),
    epochs = 20,
    batch_size = 64
)
# Out:
# Trial 30 Complete [00h 00m 07s]
# val_loss: 99608.3828125
#
# Best val_loss So Far: 65298.921875
# Total elapsed time: 00h 04m 31s

# %%
BATCH_SIZE=64

# %% [markdown]
# The code then imports necessary modules for callbacks and collects the best model architecture from the random search. The model is compiled and trained on the preprocessed data, with early stopping and model checkpoint implemented to prevent overfitting and save the best model based on validation loss.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Collect the best model Architecture obtained by Random Searcher
best_model = build_model(random_searcher.get_best_hyperparameters(num_trials=1)[0])

# Model Architecture
best_model.summary()

optimizer = tf.keras.optimizers.Adam(lr=lrx)

# Compile Model
best_model.compile(loss="mean_squared_error",
                    optimizer=optimizer,
                    metrics=["mean_absolute_error"])
# Model Training
best_model_history = best_model.fit(
    xtrain, ytrain,
    validation_data=(xtest, ytest),
    epochs = 500,
    batch_size = BATCH_SIZE*2,
    callbacks = [
  EarlyStopping(patience=150, restore_best_weights=True),
  ModelCheckpoint('best-model.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)]
)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 512)               536064
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_7 (Dense)             (None, 512)               262656
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_8 (Dense)             (None, 512)               262656
#
#  batch_normalization_7 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_9 (Dense)             (None, 512)               262656
#
#  batch_normalization_8 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_10 (Dense)            (None, 512)               262656
#
#  batch_normalization_9 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_11 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 1,597,441
# Trainable params: 1,592,321
# Non-trainable params: 5,120
# _________________________________________________________________
# Epoch 1/500
#  9/11 [=======================>......] - ETA: 0s - loss: 104571.9688 - mean_absolute_error: 152.4324
# Epoch 1: val_loss improved from inf to 113984.51562, saving model to best-model.h5
# 11/11 [==============================] - 4s 69ms/step - loss: 104405.0781 - mean_absolute_error: 151.8255 - val_loss: 113984.5156 - val_mean_absolute_error: 147.6296
# Epoch 2/500
# 11/11 [==============================] - ETA: 0s - loss: 98882.5781 - mean_absolute_error: 151.4678
# Epoch 2: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 31ms/step - loss: 98882.5781 - mean_absolute_error: 151.4678 - val_loss: 114237.1094 - val_mean_absolute_error: 150.9769
# Epoch 3/500
#  9/11 [=======================>......] - ETA: 0s - loss: 93334.4766 - mean_absolute_error: 151.3893
# Epoch 3: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 31ms/step - loss: 95114.0156 - mean_absolute_error: 150.9390 - val_loss: 117220.7578 - val_mean_absolute_error: 162.5891
# Epoch 4/500
# 11/11 [==============================] - ETA: 0s - loss: 91228.1953 - mean_absolute_error: 150.2645
# Epoch 4: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 32ms/step - loss: 91228.1953 - mean_absolute_error: 150.2645 - val_loss: 123129.1328 - val_mean_absolute_error: 181.5957
# Epoch 5/500
#  9/11 [=======================>......] - ETA: 0s - loss: 90203.3281 - mean_absolute_error: 149.4101
# Epoch 5: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 31ms/step - loss: 87057.3750 - mean_absolute_error: 149.3040 - val_loss: 133319.7031 - val_mean_absolute_error: 207.5276
# Epoch 6/500
# 11/11 [==============================] - ETA: 0s - loss: 83277.9609 - mean_absolute_error: 148.3727
# Epoch 6: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 32ms/step - loss: 83277.9609 - mean_absolute_error: 148.3727 - val_loss: 144018.5938 - val_mean_absolute_error: 229.6815
# Epoch 7/500
#  9/11 [=======================>......] - ETA: 0s - loss: 78366.5391 - mean_absolute_error: 146.6234
# Epoch 7: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 31ms/step - loss: 78813.2109 - mean_absolute_error: 146.9402 - val_loss: 152072.0156 - val_mean_absolute_error: 245.8804
# Epoch 8/500
# 11/11 [==============================] - ETA: 0s - loss: 76434.1328 - mean_absolute_error: 145.5888
# Epoch 8: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 32ms/step - loss: 76434.1328 - mean_absolute_error: 145.5888 - val_loss: 156833.4062 - val_mean_absolute_error: 254.6143
# Epoch 9/500
# 11/11 [==============================] - ETA: 0s - loss: 72608.7344 - mean_absolute_error: 143.8461
# Epoch 9: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 32ms/step - loss: 72608.7344 - mean_absolute_error: 143.8461 - val_loss: 158480.6250 - val_mean_absolute_error: 258.2273
# Epoch 10/500
#  9/11 [=======================>......] - ETA: 0s - loss: 68873.2344 - mean_absolute_error: 144.3511
# Epoch 10: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 31ms/step - loss: 70060.0859 - mean_absolute_error: 142.8076 - val_loss: 157602.4062 - val_mean_absolute_error: 256.9014
# Epoch 11/500
#  9/11 [=======================>......] - ETA: 0s - loss: 61891.8125 - mean_absolute_error: 138.6070
# Epoch 11: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 31ms/step - loss: 65302.6797 - mean_absolute_error: 139.9056 - val_loss: 158413.8125 - val_mean_absolute_error: 259.2857
# Epoch 12/500
#  9/11 [=======================>......] - ETA: 0s - loss: 57919.8867 - mean_absolute_error: 132.5409
# Epoch 12: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 35ms/step - loss: 63444.0742 - mean_absolute_error: 138.6303 - val_loss: 158477.2812 - val_mean_absolute_error: 261.4914
# Epoch 13/500
#  9/11 [=======================>......] - ETA: 0s - loss: 62375.8281 - mean_absolute_error: 138.0378
# Epoch 13: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 32ms/step - loss: 59835.1797 - mean_absolute_error: 136.5038 - val_loss: 160457.7500 - val_mean_absolute_error: 266.0129
# Epoch 14/500
# 11/11 [==============================] - ETA: 0s - loss: 57006.1797 - mean_absolute_error: 133.9341
# Epoch 14: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 34ms/step - loss: 57006.1797 - mean_absolute_error: 133.9341 - val_loss: 160879.5625 - val_mean_absolute_error: 267.1807
# Epoch 15/500
# 11/11 [==============================] - ETA: 0s - loss: 53136.3516 - mean_absolute_error: 131.7216
# Epoch 15: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 32ms/step - loss: 53136.3516 - mean_absolute_error: 131.7216 - val_loss: 165040.3594 - val_mean_absolute_error: 275.2249
# Epoch 16/500
# 11/11 [==============================] - ETA: 0s - loss: 51010.7031 - mean_absolute_error: 128.2842
# Epoch 16: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 35ms/step - loss: 51010.7031 - mean_absolute_error: 128.2842 - val_loss: 156713.0000 - val_mean_absolute_error: 263.4600
# Epoch 17/500
#  9/11 [=======================>......] - ETA: 0s - loss: 48184.5547 - mean_absolute_error: 125.1568
# Epoch 17: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 31ms/step - loss: 46630.1758 - mean_absolute_error: 125.1329 - val_loss: 163389.7188 - val_mean_absolute_error: 280.3797
# Epoch 18/500
#  9/11 [=======================>......] - ETA: 0s - loss: 42299.6133 - mean_absolute_error: 120.9344
# Epoch 18: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 31ms/step - loss: 44155.4180 - mean_absolute_error: 123.5649 - val_loss: 161720.7188 - val_mean_absolute_error: 278.3445
# Epoch 19/500
# 11/11 [==============================] - ETA: 0s - loss: 41292.1406 - mean_absolute_error: 120.0039
# Epoch 19: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 31ms/step - loss: 41292.1406 - mean_absolute_error: 120.0039 - val_loss: 177775.5000 - val_mean_absolute_error: 302.3944
# Epoch 20/500
#  9/11 [=======================>......] - ETA: 0s - loss: 37596.1758 - mean_absolute_error: 115.9466
# Epoch 20: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 31ms/step - loss: 38190.2070 - mean_absolute_error: 116.0872 - val_loss: 161582.4531 - val_mean_absolute_error: 282.0770
# Epoch 21/500
# 11/11 [==============================] - ETA: 0s - loss: 37835.3477 - mean_absolute_error: 115.8452
# Epoch 21: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 32ms/step - loss: 37835.3477 - mean_absolute_error: 115.8452 - val_loss: 163258.7812 - val_mean_absolute_error: 283.6104
# Epoch 22/500
# 11/11 [==============================] - ETA: 0s - loss: 34647.2227 - mean_absolute_error: 110.7247
# Epoch 22: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 35ms/step - loss: 34647.2227 - mean_absolute_error: 110.7247 - val_loss: 162976.8438 - val_mean_absolute_error: 283.3125
# Epoch 23/500
#  9/11 [=======================>......] - ETA: 0s - loss: 32046.7773 - mean_absolute_error: 107.8539
# Epoch 23: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 31ms/step - loss: 31512.5371 - mean_absolute_error: 108.3742 - val_loss: 149293.5469 - val_mean_absolute_error: 270.0348
# Epoch 24/500
# 11/11 [==============================] - ETA: 0s - loss: 31522.8164 - mean_absolute_error: 109.1910
# Epoch 24: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 32ms/step - loss: 31522.8164 - mean_absolute_error: 109.1910 - val_loss: 149071.1719 - val_mean_absolute_error: 269.5106
# Epoch 25/500
# 11/11 [==============================] - ETA: 0s - loss: 31015.0234 - mean_absolute_error: 102.4076
# Epoch 25: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 35ms/step - loss: 31015.0234 - mean_absolute_error: 102.4076 - val_loss: 130483.9219 - val_mean_absolute_error: 238.4817
# Epoch 26/500
# 11/11 [==============================] - ETA: 0s - loss: 27673.6230 - mean_absolute_error: 98.5616
# Epoch 26: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 40ms/step - loss: 27673.6230 - mean_absolute_error: 98.5616 - val_loss: 120686.7656 - val_mean_absolute_error: 225.2707
# Epoch 27/500
# 11/11 [==============================] - ETA: 0s - loss: 27181.0684 - mean_absolute_error: 97.0333
# Epoch 27: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 35ms/step - loss: 27181.0684 - mean_absolute_error: 97.0333 - val_loss: 125950.2656 - val_mean_absolute_error: 235.9992
# Epoch 28/500
# 11/11 [==============================] - ETA: 0s - loss: 26162.8887 - mean_absolute_error: 94.8023
# Epoch 28: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 35ms/step - loss: 26162.8887 - mean_absolute_error: 94.8023 - val_loss: 122050.7500 - val_mean_absolute_error: 236.2542
# Epoch 29/500
# 11/11 [==============================] - ETA: 0s - loss: 26210.9590 - mean_absolute_error: 94.2311
# Epoch 29: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 31ms/step - loss: 26210.9590 - mean_absolute_error: 94.2311 - val_loss: 127080.2188 - val_mean_absolute_error: 245.3875
# Epoch 30/500
#  9/11 [=======================>......] - ETA: 0s - loss: 22474.2969 - mean_absolute_error: 89.2393
# Epoch 30: val_loss did not improve from 113984.51562
# 11/11 [==============================] - 0s 31ms/step - loss: 22474.9023 - mean_absolute_error: 87.7654 - val_loss: 116699.1719 - val_mean_absolute_error: 227.2681
# Epoch 31/500
#  9/11 [=======================>......] - ETA: 0s - loss: 26163.9531 - mean_absolute_error: 91.0447
# Epoch 31: val_loss improved from 113984.51562 to 110116.59375, saving model to best-model.h5
# 11/11 [==============================] - 0s 40ms/step - loss: 24919.4277 - mean_absolute_error: 91.1305 - val_loss: 110116.5938 - val_mean_absolute_error: 210.0679
# Epoch 32/500
#  9/11 [=======================>......] - ETA: 0s - loss: 26785.0293 - mean_absolute_error: 88.9639
# Epoch 32: val_loss improved from 110116.59375 to 89134.25000, saving model to best-model.h5
# 11/11 [==============================] - 0s 39ms/step - loss: 23737.6035 - mean_absolute_error: 86.8904 - val_loss: 89134.2500 - val_mean_absolute_error: 177.5563
# Epoch 33/500
#  9/11 [=======================>......] - ETA: 0s - loss: 18514.7168 - mean_absolute_error: 82.7752
# Epoch 33: val_loss did not improve from 89134.25000
# 11/11 [==============================] - 0s 31ms/step - loss: 21293.6230 - mean_absolute_error: 83.3858 - val_loss: 96890.5625 - val_mean_absolute_error: 192.5155
# Epoch 34/500
#  9/11 [=======================>......] - ETA: 0s - loss: 16062.1582 - mean_absolute_error: 78.7596
# Epoch 34: val_loss improved from 89134.25000 to 80929.32812, saving model to best-model.h5
# 11/11 [==============================] - 0s 41ms/step - loss: 17947.2480 - mean_absolute_error: 78.6049 - val_loss: 80929.3281 - val_mean_absolute_error: 181.4477
# Epoch 35/500
# 11/11 [==============================] - ETA: 0s - loss: 21059.9531 - mean_absolute_error: 78.2284
# Epoch 35: val_loss did not improve from 80929.32812
# 11/11 [==============================] - 0s 32ms/step - loss: 21059.9531 - mean_absolute_error: 78.2284 - val_loss: 84707.0781 - val_mean_absolute_error: 189.3219
# Epoch 36/500
#  9/11 [=======================>......] - ETA: 0s - loss: 14764.1963 - mean_absolute_error: 72.8463
# Epoch 36: val_loss improved from 80929.32812 to 71651.71094, saving model to best-model.h5
# 11/11 [==============================] - 0s 38ms/step - loss: 17464.6387 - mean_absolute_error: 74.5187 - val_loss: 71651.7109 - val_mean_absolute_error: 161.4907
# Epoch 37/500
# 11/11 [==============================] - ETA: 0s - loss: 17421.4258 - mean_absolute_error: 73.5476
# Epoch 37: val_loss did not improve from 71651.71094
# 11/11 [==============================] - 0s 32ms/step - loss: 17421.4258 - mean_absolute_error: 73.5476 - val_loss: 80809.2422 - val_mean_absolute_error: 180.5424
# Epoch 38/500
#  9/11 [=======================>......] - ETA: 0s - loss: 21321.4453 - mean_absolute_error: 77.0408
# Epoch 38: val_loss improved from 71651.71094 to 54687.07422, saving model to best-model.h5
# 11/11 [==============================] - 0s 42ms/step - loss: 19545.2207 - mean_absolute_error: 74.8281 - val_loss: 54687.0742 - val_mean_absolute_error: 130.0565
# Epoch 39/500
#  9/11 [=======================>......] - ETA: 0s - loss: 19415.4238 - mean_absolute_error: 74.7098
# Epoch 39: val_loss did not improve from 54687.07422
# 11/11 [==============================] - 0s 31ms/step - loss: 17601.5137 - mean_absolute_error: 71.9431 - val_loss: 59080.6250 - val_mean_absolute_error: 140.6000
# Epoch 40/500
#  9/11 [=======================>......] - ETA: 0s - loss: 14010.3906 - mean_absolute_error: 65.7760
# Epoch 40: val_loss improved from 54687.07422 to 53411.88281, saving model to best-model.h5
# 11/11 [==============================] - 0s 40ms/step - loss: 17504.7812 - mean_absolute_error: 69.1556 - val_loss: 53411.8828 - val_mean_absolute_error: 132.4008
# Epoch 41/500
# 11/11 [==============================] - ETA: 0s - loss: 17449.3164 - mean_absolute_error: 68.9013
# Epoch 41: val_loss did not improve from 53411.88281
# 11/11 [==============================] - 0s 36ms/step - loss: 17449.3164 - mean_absolute_error: 68.9013 - val_loss: 53490.8984 - val_mean_absolute_error: 128.8853
# Epoch 42/500
#  9/11 [=======================>......] - ETA: 0s - loss: 15274.6338 - mean_absolute_error: 59.8873
# Epoch 42: val_loss did not improve from 53411.88281
# 11/11 [==============================] - 0s 32ms/step - loss: 15489.5371 - mean_absolute_error: 62.2929 - val_loss: 55422.2812 - val_mean_absolute_error: 137.2653
# Epoch 43/500
#  9/11 [=======================>......] - ETA: 0s - loss: 15272.5557 - mean_absolute_error: 62.7635
# Epoch 43: val_loss improved from 53411.88281 to 45157.24609, saving model to best-model.h5
# 11/11 [==============================] - 0s 39ms/step - loss: 16062.7393 - mean_absolute_error: 63.6021 - val_loss: 45157.2461 - val_mean_absolute_error: 108.6412
# Epoch 44/500
#  9/11 [=======================>......] - ETA: 0s - loss: 16059.1182 - mean_absolute_error: 59.3614
# Epoch 44: val_loss did not improve from 45157.24609
# 11/11 [==============================] - 0s 34ms/step - loss: 14432.2432 - mean_absolute_error: 57.9460 - val_loss: 50339.0508 - val_mean_absolute_error: 123.4713
# Epoch 45/500
# 11/11 [==============================] - ETA: 0s - loss: 15496.3301 - mean_absolute_error: 58.4780
# Epoch 45: val_loss improved from 45157.24609 to 40428.58203, saving model to best-model.h5
# 11/11 [==============================] - 0s 43ms/step - loss: 15496.3301 - mean_absolute_error: 58.4780 - val_loss: 40428.5820 - val_mean_absolute_error: 100.3324
# Epoch 46/500
# 11/11 [==============================] - ETA: 0s - loss: 13293.7725 - mean_absolute_error: 56.3397
# Epoch 46: val_loss did not improve from 40428.58203
# 11/11 [==============================] - 0s 32ms/step - loss: 13293.7725 - mean_absolute_error: 56.3397 - val_loss: 44843.6172 - val_mean_absolute_error: 115.4107
# Epoch 47/500
#  9/11 [=======================>......] - ETA: 0s - loss: 16720.7812 - mean_absolute_error: 54.1764
# Epoch 47: val_loss improved from 40428.58203 to 36509.70703, saving model to best-model.h5
# 11/11 [==============================] - 0s 43ms/step - loss: 15015.3213 - mean_absolute_error: 52.9116 - val_loss: 36509.7070 - val_mean_absolute_error: 97.9485
# Epoch 48/500
#  9/11 [=======================>......] - ETA: 0s - loss: 13596.2920 - mean_absolute_error: 52.2986
# Epoch 48: val_loss did not improve from 36509.70703
# 11/11 [==============================] - 0s 31ms/step - loss: 13544.9629 - mean_absolute_error: 53.8103 - val_loss: 38769.2109 - val_mean_absolute_error: 100.0619
# Epoch 49/500
#  9/11 [=======================>......] - ETA: 0s - loss: 17042.1797 - mean_absolute_error: 57.3834
# Epoch 49: val_loss did not improve from 36509.70703
# 11/11 [==============================] - 0s 31ms/step - loss: 16071.3643 - mean_absolute_error: 56.8020 - val_loss: 38346.0078 - val_mean_absolute_error: 106.9376
# Epoch 50/500
#  9/11 [=======================>......] - ETA: 0s - loss: 12608.6963 - mean_absolute_error: 46.8104
# Epoch 50: val_loss improved from 36509.70703 to 33829.52344, saving model to best-model.h5
# 11/11 [==============================] - 0s 39ms/step - loss: 14094.6201 - mean_absolute_error: 49.4901 - val_loss: 33829.5234 - val_mean_absolute_error: 88.5856
# Epoch 51/500
#  9/11 [=======================>......] - ETA: 0s - loss: 15491.2119 - mean_absolute_error: 46.6666
# Epoch 51: val_loss improved from 33829.52344 to 33508.61719, saving model to best-model.h5
# 11/11 [==============================] - 0s 42ms/step - loss: 14823.6582 - mean_absolute_error: 47.4004 - val_loss: 33508.6172 - val_mean_absolute_error: 96.3196
# Epoch 52/500
# 11/11 [==============================] - ETA: 0s - loss: 12766.6357 - mean_absolute_error: 50.3616
# Epoch 52: val_loss did not improve from 33508.61719
# 11/11 [==============================] - 0s 32ms/step - loss: 12766.6357 - mean_absolute_error: 50.3616 - val_loss: 40264.7695 - val_mean_absolute_error: 114.9574
# Epoch 53/500
#  9/11 [=======================>......] - ETA: 0s - loss: 13329.3330 - mean_absolute_error: 45.4821
# Epoch 53: val_loss did not improve from 33508.61719
# 11/11 [==============================] - 0s 30ms/step - loss: 12697.1787 - mean_absolute_error: 46.9510 - val_loss: 38298.2773 - val_mean_absolute_error: 112.1286
# Epoch 54/500
# 10/11 [==========================>...] - ETA: 0s - loss: 14551.6738 - mean_absolute_error: 49.3864
# Epoch 54: val_loss improved from 33508.61719 to 32192.99805, saving model to best-model.h5
# 11/11 [==============================] - 0s 37ms/step - loss: 15527.1455 - mean_absolute_error: 49.4998 - val_loss: 32192.9980 - val_mean_absolute_error: 87.9127
# Epoch 55/500
# 11/11 [==============================] - ETA: 0s - loss: 15183.5264 - mean_absolute_error: 47.3641
# Epoch 55: val_loss did not improve from 32192.99805
# 11/11 [==============================] - 0s 31ms/step - loss: 15183.5264 - mean_absolute_error: 47.3641 - val_loss: 33272.8789 - val_mean_absolute_error: 96.6334
# Epoch 56/500
#  9/11 [=======================>......] - ETA: 0s - loss: 15416.7725 - mean_absolute_error: 43.9681
# Epoch 56: val_loss improved from 32192.99805 to 31738.70312, saving model to best-model.h5
# 11/11 [==============================] - 0s 39ms/step - loss: 13744.9551 - mean_absolute_error: 44.1174 - val_loss: 31738.7031 - val_mean_absolute_error: 93.0706
# Epoch 57/500
#  9/11 [=======================>......] - ETA: 0s - loss: 9736.5117 - mean_absolute_error: 41.6642
# Epoch 57: val_loss improved from 31738.70312 to 30783.67578, saving model to best-model.h5
# 11/11 [==============================] - 0s 38ms/step - loss: 14073.3848 - mean_absolute_error: 43.6131 - val_loss: 30783.6758 - val_mean_absolute_error: 87.6124
# Epoch 58/500
#  9/11 [=======================>......] - ETA: 0s - loss: 15249.9131 - mean_absolute_error: 42.8310
# Epoch 58: val_loss improved from 30783.67578 to 30346.69727, saving model to best-model.h5
# 11/11 [==============================] - 0s 38ms/step - loss: 14010.3848 - mean_absolute_error: 41.9472 - val_loss: 30346.6973 - val_mean_absolute_error: 84.0699
# Epoch 59/500
# 11/11 [==============================] - ETA: 0s - loss: 14679.5576 - mean_absolute_error: 46.2552
# Epoch 59: val_loss did not improve from 30346.69727
# 11/11 [==============================] - 0s 32ms/step - loss: 14679.5576 - mean_absolute_error: 46.2552 - val_loss: 30395.6992 - val_mean_absolute_error: 77.1765
# Epoch 60/500
#  9/11 [=======================>......] - ETA: 0s - loss: 11366.7783 - mean_absolute_error: 38.9797
# Epoch 60: val_loss improved from 30346.69727 to 29179.02344, saving model to best-model.h5
# 11/11 [==============================] - 0s 43ms/step - loss: 13038.4111 - mean_absolute_error: 40.5461 - val_loss: 29179.0234 - val_mean_absolute_error: 75.3973
# Epoch 61/500
#  9/11 [=======================>......] - ETA: 0s - loss: 14184.8633 - mean_absolute_error: 41.9123
# Epoch 61: val_loss did not improve from 29179.02344
# 11/11 [==============================] - 0s 31ms/step - loss: 12520.6230 - mean_absolute_error: 40.0153 - val_loss: 30545.6230 - val_mean_absolute_error: 77.9065
# Epoch 62/500
# 11/11 [==============================] - ETA: 0s - loss: 13505.1494 - mean_absolute_error: 42.7659
# Epoch 62: val_loss did not improve from 29179.02344
# 11/11 [==============================] - 0s 31ms/step - loss: 13505.1494 - mean_absolute_error: 42.7659 - val_loss: 29824.6172 - val_mean_absolute_error: 76.8245
# Epoch 63/500
#  9/11 [=======================>......] - ETA: 0s - loss: 8766.9922 - mean_absolute_error: 37.2473
# Epoch 63: val_loss did not improve from 29179.02344
# 11/11 [==============================] - 0s 31ms/step - loss: 11646.4102 - mean_absolute_error: 40.8279 - val_loss: 33559.5586 - val_mean_absolute_error: 80.4497
# Epoch 64/500
#  9/11 [=======================>......] - ETA: 0s - loss: 11519.8398 - mean_absolute_error: 37.3854
# Epoch 64: val_loss did not improve from 29179.02344
# 11/11 [==============================] - 0s 35ms/step - loss: 11646.3838 - mean_absolute_error: 37.5255 - val_loss: 31571.4863 - val_mean_absolute_error: 79.0769
# Epoch 65/500
# 11/11 [==============================] - ETA: 0s - loss: 13532.2480 - mean_absolute_error: 43.2483
# Epoch 65: val_loss improved from 29179.02344 to 28381.98242, saving model to best-model.h5
# 11/11 [==============================] - 0s 42ms/step - loss: 13532.2480 - mean_absolute_error: 43.2483 - val_loss: 28381.9824 - val_mean_absolute_error: 74.3223
# Epoch 66/500
# 11/11 [==============================] - ETA: 0s - loss: 12516.0010 - mean_absolute_error: 40.6290
# Epoch 66: val_loss improved from 28381.98242 to 26520.59961, saving model to best-model.h5
# 11/11 [==============================] - 0s 46ms/step - loss: 12516.0010 - mean_absolute_error: 40.6290 - val_loss: 26520.5996 - val_mean_absolute_error: 60.3243
# Epoch 67/500
#  9/11 [=======================>......] - ETA: 0s - loss: 12721.8281 - mean_absolute_error: 36.9444
# Epoch 67: val_loss did not improve from 26520.59961
# 11/11 [==============================] - 0s 31ms/step - loss: 11361.3125 - mean_absolute_error: 36.1029 - val_loss: 32090.9863 - val_mean_absolute_error: 75.5938
# Epoch 68/500
#  9/11 [=======================>......] - ETA: 0s - loss: 11908.2422 - mean_absolute_error: 37.4700
# Epoch 68: val_loss did not improve from 26520.59961
# 11/11 [==============================] - 0s 31ms/step - loss: 12254.4668 - mean_absolute_error: 39.1494 - val_loss: 30268.8887 - val_mean_absolute_error: 79.0492
# Epoch 69/500
#  9/11 [=======================>......] - ETA: 0s - loss: 13866.4512 - mean_absolute_error: 42.9675
# Epoch 69: val_loss did not improve from 26520.59961
# 11/11 [==============================] - 0s 30ms/step - loss: 12933.1875 - mean_absolute_error: 43.2305 - val_loss: 27626.1895 - val_mean_absolute_error: 75.3790
# Epoch 70/500
# 11/11 [==============================] - ETA: 0s - loss: 14663.9580 - mean_absolute_error: 37.9981
# Epoch 70: val_loss did not improve from 26520.59961
# 11/11 [==============================] - 0s 32ms/step - loss: 14663.9580 - mean_absolute_error: 37.9981 - val_loss: 28329.0137 - val_mean_absolute_error: 68.0961
# Epoch 71/500
#  9/11 [=======================>......] - ETA: 0s - loss: 15878.0137 - mean_absolute_error: 41.0609
# Epoch 71: val_loss did not improve from 26520.59961
# 11/11 [==============================] - 0s 31ms/step - loss: 14665.8633 - mean_absolute_error: 42.0033 - val_loss: 27571.1289 - val_mean_absolute_error: 71.0198
# Epoch 72/500
# 11/11 [==============================] - ETA: 0s - loss: 12433.6016 - mean_absolute_error: 38.4451
# Epoch 72: val_loss did not improve from 26520.59961
# 11/11 [==============================] - 0s 32ms/step - loss: 12433.6016 - mean_absolute_error: 38.4451 - val_loss: 29882.2656 - val_mean_absolute_error: 82.5243
# Epoch 73/500
#  9/11 [=======================>......] - ETA: 0s - loss: 12485.7559 - mean_absolute_error: 37.6762
# Epoch 73: val_loss did not improve from 26520.59961
# 11/11 [==============================] - 0s 31ms/step - loss: 11310.1104 - mean_absolute_error: 37.0401 - val_loss: 32846.6953 - val_mean_absolute_error: 90.9687
# Epoch 74/500
# 10/11 [==========================>...] - ETA: 0s - loss: 10729.9121 - mean_absolute_error: 36.0708
# Epoch 74: val_loss did not improve from 26520.59961
# 11/11 [==============================] - 0s 30ms/step - loss: 10924.5117 - mean_absolute_error: 36.9572 - val_loss: 30064.2188 - val_mean_absolute_error: 85.1339
# Epoch 75/500
# 11/11 [==============================] - ETA: 0s - loss: 13507.3623 - mean_absolute_error: 39.0341
# Epoch 75: val_loss did not improve from 26520.59961
# 11/11 [==============================] - 0s 32ms/step - loss: 13507.3623 - mean_absolute_error: 39.0341 - val_loss: 28970.1777 - val_mean_absolute_error: 74.5036
# Epoch 76/500
# 11/11 [==============================] - ETA: 0s - loss: 12390.2373 - mean_absolute_error: 36.2239
# Epoch 76: val_loss improved from 26520.59961 to 24362.05273, saving model to best-model.h5
# 11/11 [==============================] - 0s 40ms/step - loss: 12390.2373 - mean_absolute_error: 36.2239 - val_loss: 24362.0527 - val_mean_absolute_error: 63.2109
# Epoch 77/500
#  9/11 [=======================>......] - ETA: 0s - loss: 13834.9160 - mean_absolute_error: 39.4328
# Epoch 77: val_loss did not improve from 24362.05273
# 11/11 [==============================] - 0s 31ms/step - loss: 12973.3418 - mean_absolute_error: 38.5941 - val_loss: 25580.1016 - val_mean_absolute_error: 65.1749
# Epoch 78/500
# 10/11 [==========================>...] - ETA: 0s - loss: 13116.1816 - mean_absolute_error: 43.3632
# Epoch 78: val_loss improved from 24362.05273 to 23393.51953, saving model to best-model.h5
# 11/11 [==============================] - 0s 38ms/step - loss: 13765.0303 - mean_absolute_error: 44.4696 - val_loss: 23393.5195 - val_mean_absolute_error: 56.5879
# Epoch 79/500
# 11/11 [==============================] - ETA: 0s - loss: 13503.0537 - mean_absolute_error: 41.6067
# Epoch 79: val_loss improved from 23393.51953 to 21027.35352, saving model to best-model.h5
# 11/11 [==============================] - 0s 38ms/step - loss: 13503.0537 - mean_absolute_error: 41.6067 - val_loss: 21027.3535 - val_mean_absolute_error: 53.1646
# Epoch 80/500
#  9/11 [=======================>......] - ETA: 0s - loss: 13785.3750 - mean_absolute_error: 40.1409
# Epoch 80: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 14209.4111 - mean_absolute_error: 40.3991 - val_loss: 23380.2754 - val_mean_absolute_error: 58.7440
# Epoch 81/500
# 11/11 [==============================] - ETA: 0s - loss: 12421.0225 - mean_absolute_error: 43.1621
# Epoch 81: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 35ms/step - loss: 12421.0225 - mean_absolute_error: 43.1621 - val_loss: 23296.4766 - val_mean_absolute_error: 56.9871
# Epoch 82/500
#  9/11 [=======================>......] - ETA: 0s - loss: 9193.6113 - mean_absolute_error: 33.9802
# Epoch 82: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 34ms/step - loss: 12459.4951 - mean_absolute_error: 36.6908 - val_loss: 25208.0547 - val_mean_absolute_error: 59.8967
# Epoch 83/500
# 10/11 [==========================>...] - ETA: 0s - loss: 13908.5254 - mean_absolute_error: 42.4190
# Epoch 83: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 13392.2871 - mean_absolute_error: 41.8200 - val_loss: 25565.9297 - val_mean_absolute_error: 60.2564
# Epoch 84/500
# 11/11 [==============================] - ETA: 0s - loss: 10791.6270 - mean_absolute_error: 33.7110
# Epoch 84: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 10791.6270 - mean_absolute_error: 33.7110 - val_loss: 24128.0605 - val_mean_absolute_error: 57.5828
# Epoch 85/500
#  9/11 [=======================>......] - ETA: 0s - loss: 14046.0430 - mean_absolute_error: 39.0028
# Epoch 85: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 30ms/step - loss: 12876.0449 - mean_absolute_error: 38.1531 - val_loss: 25118.2070 - val_mean_absolute_error: 60.7801
# Epoch 86/500
#  9/11 [=======================>......] - ETA: 0s - loss: 11371.5508 - mean_absolute_error: 38.5099
# Epoch 86: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 34ms/step - loss: 13483.2842 - mean_absolute_error: 40.4099 - val_loss: 22896.4629 - val_mean_absolute_error: 54.5145
# Epoch 87/500
#  9/11 [=======================>......] - ETA: 0s - loss: 16958.3047 - mean_absolute_error: 45.0872
# Epoch 87: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 14803.0908 - mean_absolute_error: 43.0856 - val_loss: 24257.2852 - val_mean_absolute_error: 54.7391
# Epoch 88/500
#  9/11 [=======================>......] - ETA: 0s - loss: 11437.6133 - mean_absolute_error: 35.9730
# Epoch 88: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 34ms/step - loss: 10610.9639 - mean_absolute_error: 36.9009 - val_loss: 25501.0254 - val_mean_absolute_error: 56.8436
# Epoch 89/500
#  9/11 [=======================>......] - ETA: 0s - loss: 11417.4961 - mean_absolute_error: 35.5418
# Epoch 89: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 35ms/step - loss: 10573.5820 - mean_absolute_error: 35.8066 - val_loss: 24448.5586 - val_mean_absolute_error: 55.5958
# Epoch 90/500
#  9/11 [=======================>......] - ETA: 0s - loss: 14917.5693 - mean_absolute_error: 38.4309
# Epoch 90: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 13837.1855 - mean_absolute_error: 38.3466 - val_loss: 24176.4336 - val_mean_absolute_error: 54.9279
# Epoch 91/500
# 11/11 [==============================] - ETA: 0s - loss: 12036.7139 - mean_absolute_error: 40.3051
# Epoch 91: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 32ms/step - loss: 12036.7139 - mean_absolute_error: 40.3051 - val_loss: 23904.2285 - val_mean_absolute_error: 57.1027
# Epoch 92/500
#  9/11 [=======================>......] - ETA: 0s - loss: 12043.8350 - mean_absolute_error: 37.5009
# Epoch 92: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 11720.3086 - mean_absolute_error: 36.9821 - val_loss: 24316.4238 - val_mean_absolute_error: 57.8736
# Epoch 93/500
#  9/11 [=======================>......] - ETA: 0s - loss: 13065.6416 - mean_absolute_error: 40.0281
# Epoch 93: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 12990.1182 - mean_absolute_error: 41.7615 - val_loss: 24187.0605 - val_mean_absolute_error: 56.2754
# Epoch 94/500
#  9/11 [=======================>......] - ETA: 0s - loss: 15027.7412 - mean_absolute_error: 39.6024
# Epoch 94: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 33ms/step - loss: 13189.8809 - mean_absolute_error: 37.7099 - val_loss: 24922.2891 - val_mean_absolute_error: 53.9442
# Epoch 95/500
# 11/11 [==============================] - ETA: 0s - loss: 10968.9277 - mean_absolute_error: 36.4187
# Epoch 95: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 33ms/step - loss: 10968.9277 - mean_absolute_error: 36.4187 - val_loss: 23350.6992 - val_mean_absolute_error: 52.4681
# Epoch 96/500
# 10/11 [==========================>...] - ETA: 0s - loss: 10735.2559 - mean_absolute_error: 39.8385
# Epoch 96: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 13570.3848 - mean_absolute_error: 42.1807 - val_loss: 24174.3945 - val_mean_absolute_error: 55.2553
# Epoch 97/500
# 11/11 [==============================] - ETA: 0s - loss: 11716.9268 - mean_absolute_error: 38.0202
# Epoch 97: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 35ms/step - loss: 11716.9268 - mean_absolute_error: 38.0202 - val_loss: 24402.1055 - val_mean_absolute_error: 57.9265
# Epoch 98/500
# 11/11 [==============================] - ETA: 0s - loss: 12145.3760 - mean_absolute_error: 40.2310
# Epoch 98: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 35ms/step - loss: 12145.3760 - mean_absolute_error: 40.2310 - val_loss: 25805.4844 - val_mean_absolute_error: 56.7625
# Epoch 99/500
# 11/11 [==============================] - ETA: 0s - loss: 12049.0615 - mean_absolute_error: 35.9580
# Epoch 99: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 32ms/step - loss: 12049.0615 - mean_absolute_error: 35.9580 - val_loss: 22986.0137 - val_mean_absolute_error: 54.8991
# Epoch 100/500
# 11/11 [==============================] - ETA: 0s - loss: 12555.0068 - mean_absolute_error: 40.0022
# Epoch 100: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 12555.0068 - mean_absolute_error: 40.0022 - val_loss: 24081.8047 - val_mean_absolute_error: 67.4171
# Epoch 101/500
# 11/11 [==============================] - ETA: 0s - loss: 11654.3711 - mean_absolute_error: 40.7748
# Epoch 101: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 33ms/step - loss: 11654.3711 - mean_absolute_error: 40.7748 - val_loss: 23665.1504 - val_mean_absolute_error: 58.4399
# Epoch 102/500
# 11/11 [==============================] - ETA: 0s - loss: 12116.8877 - mean_absolute_error: 37.8806
# Epoch 102: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 12116.8877 - mean_absolute_error: 37.8806 - val_loss: 24422.6758 - val_mean_absolute_error: 54.2133
# Epoch 103/500
# 11/11 [==============================] - ETA: 0s - loss: 10709.1377 - mean_absolute_error: 37.5661
# Epoch 103: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 32ms/step - loss: 10709.1377 - mean_absolute_error: 37.5661 - val_loss: 25382.6855 - val_mean_absolute_error: 58.9822
# Epoch 104/500
# 11/11 [==============================] - ETA: 0s - loss: 9734.5332 - mean_absolute_error: 36.4988
# Epoch 104: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 32ms/step - loss: 9734.5332 - mean_absolute_error: 36.4988 - val_loss: 24916.4785 - val_mean_absolute_error: 57.0859
# Epoch 105/500
#  9/11 [=======================>......] - ETA: 0s - loss: 11241.0918 - mean_absolute_error: 38.6770
# Epoch 105: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 11714.2500 - mean_absolute_error: 41.0097 - val_loss: 24926.1133 - val_mean_absolute_error: 59.5370
# Epoch 106/500
#  9/11 [=======================>......] - ETA: 0s - loss: 10483.9512 - mean_absolute_error: 41.0780
# Epoch 106: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 11242.6055 - mean_absolute_error: 41.5427 - val_loss: 23445.2988 - val_mean_absolute_error: 58.2386
# Epoch 107/500
#  9/11 [=======================>......] - ETA: 0s - loss: 10554.5000 - mean_absolute_error: 38.3705
# Epoch 107: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 9502.3281 - mean_absolute_error: 37.8087 - val_loss: 22889.9824 - val_mean_absolute_error: 54.3250
# Epoch 108/500
#  9/11 [=======================>......] - ETA: 0s - loss: 8440.1914 - mean_absolute_error: 36.4927
# Epoch 108: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 10393.9014 - mean_absolute_error: 37.1129 - val_loss: 23966.3008 - val_mean_absolute_error: 55.6845
# Epoch 109/500
#  9/11 [=======================>......] - ETA: 0s - loss: 8599.9551 - mean_absolute_error: 33.2041
# Epoch 109: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 10783.3711 - mean_absolute_error: 35.8585 - val_loss: 24768.4258 - val_mean_absolute_error: 56.4853
# Epoch 110/500
# 10/11 [==========================>...] - ETA: 0s - loss: 8153.7734 - mean_absolute_error: 34.7158
# Epoch 110: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 41ms/step - loss: 11110.0059 - mean_absolute_error: 36.6297 - val_loss: 25205.3379 - val_mean_absolute_error: 57.7668
# Epoch 111/500
# 11/11 [==============================] - ETA: 0s - loss: 12652.0703 - mean_absolute_error: 40.2564
# Epoch 111: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 37ms/step - loss: 12652.0703 - mean_absolute_error: 40.2564 - val_loss: 24214.0430 - val_mean_absolute_error: 56.6446
# Epoch 112/500
# 11/11 [==============================] - ETA: 0s - loss: 12446.7920 - mean_absolute_error: 42.4654
# Epoch 112: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 36ms/step - loss: 12446.7920 - mean_absolute_error: 42.4654 - val_loss: 24300.2910 - val_mean_absolute_error: 63.5172
# Epoch 113/500
# 11/11 [==============================] - ETA: 0s - loss: 12725.2676 - mean_absolute_error: 41.7438
# Epoch 113: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 33ms/step - loss: 12725.2676 - mean_absolute_error: 41.7438 - val_loss: 23453.5469 - val_mean_absolute_error: 59.1973
# Epoch 114/500
#  9/11 [=======================>......] - ETA: 0s - loss: 11504.0918 - mean_absolute_error: 38.0650
# Epoch 114: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 37ms/step - loss: 10296.6494 - mean_absolute_error: 36.6454 - val_loss: 22708.6074 - val_mean_absolute_error: 53.2959
# Epoch 115/500
# 11/11 [==============================] - ETA: 0s - loss: 8895.7246 - mean_absolute_error: 31.6986
# Epoch 115: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 32ms/step - loss: 8895.7246 - mean_absolute_error: 31.6986 - val_loss: 23908.7617 - val_mean_absolute_error: 55.2964
# Epoch 116/500
# 11/11 [==============================] - ETA: 0s - loss: 12414.4316 - mean_absolute_error: 37.9111
# Epoch 116: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 32ms/step - loss: 12414.4316 - mean_absolute_error: 37.9111 - val_loss: 24984.4746 - val_mean_absolute_error: 52.4367
# Epoch 117/500
# 11/11 [==============================] - ETA: 0s - loss: 10416.5811 - mean_absolute_error: 35.7831
# Epoch 117: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 32ms/step - loss: 10416.5811 - mean_absolute_error: 35.7831 - val_loss: 24396.2734 - val_mean_absolute_error: 54.4600
# Epoch 118/500
# 11/11 [==============================] - ETA: 0s - loss: 11003.5576 - mean_absolute_error: 37.3934
# Epoch 118: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 32ms/step - loss: 11003.5576 - mean_absolute_error: 37.3934 - val_loss: 24613.3555 - val_mean_absolute_error: 60.3050
# Epoch 119/500
# 11/11 [==============================] - ETA: 0s - loss: 11967.6445 - mean_absolute_error: 38.5882
# Epoch 119: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 32ms/step - loss: 11967.6445 - mean_absolute_error: 38.5882 - val_loss: 24519.0957 - val_mean_absolute_error: 56.1436
# Epoch 120/500
# 11/11 [==============================] - ETA: 0s - loss: 10326.0752 - mean_absolute_error: 32.7910
# Epoch 120: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 10326.0752 - mean_absolute_error: 32.7910 - val_loss: 26448.2676 - val_mean_absolute_error: 61.0396
# Epoch 121/500
# 11/11 [==============================] - ETA: 0s - loss: 9383.4775 - mean_absolute_error: 33.0388
# Epoch 121: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 9383.4775 - mean_absolute_error: 33.0388 - val_loss: 25710.1934 - val_mean_absolute_error: 59.0047
# Epoch 122/500
#  9/11 [=======================>......] - ETA: 0s - loss: 11017.9434 - mean_absolute_error: 35.1098
# Epoch 122: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 34ms/step - loss: 9763.7549 - mean_absolute_error: 34.1638 - val_loss: 24615.5840 - val_mean_absolute_error: 55.7079
# Epoch 123/500
#  9/11 [=======================>......] - ETA: 0s - loss: 9037.9541 - mean_absolute_error: 34.7118
# Epoch 123: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 10152.6611 - mean_absolute_error: 36.5356 - val_loss: 24198.9688 - val_mean_absolute_error: 55.5036
# Epoch 124/500
# 11/11 [==============================] - ETA: 0s - loss: 9156.7988 - mean_absolute_error: 33.5918
# Epoch 124: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 30ms/step - loss: 9156.7988 - mean_absolute_error: 33.5918 - val_loss: 24331.8164 - val_mean_absolute_error: 58.5348
# Epoch 125/500
# 10/11 [==========================>...] - ETA: 0s - loss: 10029.1250 - mean_absolute_error: 37.7928
# Epoch 125: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 30ms/step - loss: 9763.5752 - mean_absolute_error: 37.3375 - val_loss: 23601.1152 - val_mean_absolute_error: 53.6690
# Epoch 126/500
# 11/11 [==============================] - ETA: 0s - loss: 7391.9014 - mean_absolute_error: 33.0225
# Epoch 126: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 32ms/step - loss: 7391.9014 - mean_absolute_error: 33.0225 - val_loss: 25063.0605 - val_mean_absolute_error: 58.3935
# Epoch 127/500
#  9/11 [=======================>......] - ETA: 0s - loss: 9750.9668 - mean_absolute_error: 37.3991
# Epoch 127: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 13494.7207 - mean_absolute_error: 39.0976 - val_loss: 24012.3418 - val_mean_absolute_error: 54.1096
# Epoch 128/500
#  9/11 [=======================>......] - ETA: 0s - loss: 10015.4932 - mean_absolute_error: 36.6759
# Epoch 128: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 8985.7051 - mean_absolute_error: 34.7925 - val_loss: 25705.3906 - val_mean_absolute_error: 59.2090
# Epoch 129/500
#  9/11 [=======================>......] - ETA: 0s - loss: 8619.7783 - mean_absolute_error: 34.2572
# Epoch 129: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 10953.2422 - mean_absolute_error: 36.7275 - val_loss: 24099.9531 - val_mean_absolute_error: 55.0728
# Epoch 130/500
# 11/11 [==============================] - ETA: 0s - loss: 10525.0820 - mean_absolute_error: 32.7353
# Epoch 130: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 10525.0820 - mean_absolute_error: 32.7353 - val_loss: 24588.2891 - val_mean_absolute_error: 56.2352
# Epoch 131/500
# 11/11 [==============================] - ETA: 0s - loss: 10243.4912 - mean_absolute_error: 39.7409
# Epoch 131: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 10243.4912 - mean_absolute_error: 39.7409 - val_loss: 28051.1602 - val_mean_absolute_error: 60.7694
# Epoch 132/500
#  9/11 [=======================>......] - ETA: 0s - loss: 12439.4980 - mean_absolute_error: 39.3744
# Epoch 132: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 32ms/step - loss: 11056.4170 - mean_absolute_error: 37.8692 - val_loss: 22926.7012 - val_mean_absolute_error: 53.6836
# Epoch 133/500
#  9/11 [=======================>......] - ETA: 0s - loss: 10523.9941 - mean_absolute_error: 36.2402
# Epoch 133: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 30ms/step - loss: 9479.7080 - mean_absolute_error: 36.4040 - val_loss: 23186.3496 - val_mean_absolute_error: 54.9414
# Epoch 134/500
#  9/11 [=======================>......] - ETA: 0s - loss: 10889.0605 - mean_absolute_error: 35.8962
# Epoch 134: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 9898.5156 - mean_absolute_error: 35.9367 - val_loss: 23323.2324 - val_mean_absolute_error: 57.1133
# Epoch 135/500
# 11/11 [==============================] - ETA: 0s - loss: 8001.0669 - mean_absolute_error: 31.5707
# Epoch 135: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 32ms/step - loss: 8001.0669 - mean_absolute_error: 31.5707 - val_loss: 24268.0605 - val_mean_absolute_error: 63.7862
# Epoch 136/500
#  9/11 [=======================>......] - ETA: 0s - loss: 6819.4302 - mean_absolute_error: 31.4961
# Epoch 136: val_loss did not improve from 21027.35352
# 11/11 [==============================] - 0s 31ms/step - loss: 9892.2744 - mean_absolute_error: 33.9111 - val_loss: 23234.3066 - val_mean_absolute_error: 55.2995
# Epoch 137/500
# 10/11 [==========================>...] - ETA: 0s - loss: 7986.2803 - mean_absolute_error: 32.0930
# Epoch 137: val_loss did not improve from 21027.35352
# ...
# Epoch 452/500
# 11/11 [==============================] - ETA: 0s - loss: 6515.0854 - mean_absolute_error: 40.4723
# Epoch 452: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 6515.0854 - mean_absolute_error: 40.4723 - val_loss: 20898.4336 - val_mean_absolute_error: 53.8650
# Epoch 453/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5832.0566 - mean_absolute_error: 35.8984
# Epoch 453: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 30ms/step - loss: 5188.9707 - mean_absolute_error: 34.6440 - val_loss: 23005.8711 - val_mean_absolute_error: 56.8215
# Epoch 454/500
# 11/11 [==============================] - ETA: 0s - loss: 4982.0957 - mean_absolute_error: 31.2690
# Epoch 454: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 32ms/step - loss: 4982.0957 - mean_absolute_error: 31.2690 - val_loss: 23660.7188 - val_mean_absolute_error: 57.7290
# Epoch 455/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5932.4224 - mean_absolute_error: 31.5926
# Epoch 455: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 30ms/step - loss: 5381.5229 - mean_absolute_error: 33.2278 - val_loss: 22916.4375 - val_mean_absolute_error: 55.2157
# Epoch 456/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5835.0317 - mean_absolute_error: 30.6341
# Epoch 456: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 30ms/step - loss: 5335.0400 - mean_absolute_error: 29.3901 - val_loss: 24854.9238 - val_mean_absolute_error: 55.7612
# Epoch 457/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5682.8613 - mean_absolute_error: 32.0258
# Epoch 457: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 5313.5078 - mean_absolute_error: 30.6821 - val_loss: 23748.0508 - val_mean_absolute_error: 54.5403
# Epoch 458/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5698.0234 - mean_absolute_error: 25.7719
# Epoch 458: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 32ms/step - loss: 5015.4404 - mean_absolute_error: 25.6220 - val_loss: 22956.2090 - val_mean_absolute_error: 58.1205
# Epoch 459/500
#  9/11 [=======================>......] - ETA: 0s - loss: 4443.4375 - mean_absolute_error: 30.8180
# Epoch 459: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 5641.1680 - mean_absolute_error: 31.6999 - val_loss: 24738.6094 - val_mean_absolute_error: 57.2595
# Epoch 460/500
# 10/11 [==========================>...] - ETA: 0s - loss: 5309.5825 - mean_absolute_error: 36.9979
# Epoch 460: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 5075.2588 - mean_absolute_error: 35.8626 - val_loss: 24955.5020 - val_mean_absolute_error: 59.6675
# Epoch 461/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5596.0317 - mean_absolute_error: 35.8126
# Epoch 461: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 30ms/step - loss: 4891.8774 - mean_absolute_error: 33.9803 - val_loss: 24433.1758 - val_mean_absolute_error: 55.0163
# Epoch 462/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5063.9443 - mean_absolute_error: 36.0526
# Epoch 462: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 4502.2554 - mean_absolute_error: 34.7228 - val_loss: 24621.4688 - val_mean_absolute_error: 57.4096
# Epoch 463/500
#  9/11 [=======================>......] - ETA: 0s - loss: 3053.7202 - mean_absolute_error: 28.1492
# Epoch 463: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 4137.2627 - mean_absolute_error: 29.1888 - val_loss: 23208.9922 - val_mean_absolute_error: 53.9915
# Epoch 464/500
# 11/11 [==============================] - ETA: 0s - loss: 4305.0474 - mean_absolute_error: 26.4611
# Epoch 464: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 37ms/step - loss: 4305.0474 - mean_absolute_error: 26.4611 - val_loss: 22048.3652 - val_mean_absolute_error: 53.6687
# Epoch 465/500
# 11/11 [==============================] - ETA: 0s - loss: 5497.2354 - mean_absolute_error: 24.4520
# Epoch 465: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 5497.2354 - mean_absolute_error: 24.4520 - val_loss: 22305.2559 - val_mean_absolute_error: 53.5715
# Epoch 466/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5451.5703 - mean_absolute_error: 32.3159
# Epoch 466: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 4902.0889 - mean_absolute_error: 32.0353 - val_loss: 21816.9766 - val_mean_absolute_error: 53.1332
# Epoch 467/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5083.5576 - mean_absolute_error: 29.4250
# Epoch 467: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 35ms/step - loss: 4448.2231 - mean_absolute_error: 27.5653 - val_loss: 23929.0742 - val_mean_absolute_error: 58.9608
# Epoch 468/500
# 10/11 [==========================>...] - ETA: 0s - loss: 5287.5918 - mean_absolute_error: 30.1069
# Epoch 468: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 5090.4443 - mean_absolute_error: 30.9329 - val_loss: 23542.0684 - val_mean_absolute_error: 56.9537
# Epoch 469/500
# 11/11 [==============================] - ETA: 0s - loss: 4823.8369 - mean_absolute_error: 29.9941
# Epoch 469: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 37ms/step - loss: 4823.8369 - mean_absolute_error: 29.9941 - val_loss: 23838.2637 - val_mean_absolute_error: 55.9075
# Epoch 470/500
# 11/11 [==============================] - ETA: 0s - loss: 4491.1704 - mean_absolute_error: 27.6336
# Epoch 470: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 40ms/step - loss: 4491.1704 - mean_absolute_error: 27.6336 - val_loss: 22771.6289 - val_mean_absolute_error: 54.6361
# Epoch 471/500
# 11/11 [==============================] - ETA: 0s - loss: 5432.4326 - mean_absolute_error: 29.4980
# Epoch 471: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 35ms/step - loss: 5432.4326 - mean_absolute_error: 29.4980 - val_loss: 22176.0742 - val_mean_absolute_error: 56.9719
# Epoch 472/500
#  9/11 [=======================>......] - ETA: 0s - loss: 4065.1311 - mean_absolute_error: 27.5099
# Epoch 472: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 5574.1206 - mean_absolute_error: 30.7923 - val_loss: 22502.5312 - val_mean_absolute_error: 53.9425
# Epoch 473/500
#  9/11 [=======================>......] - ETA: 0s - loss: 7991.5347 - mean_absolute_error: 34.9533
# Epoch 473: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 7048.5269 - mean_absolute_error: 32.7641 - val_loss: 24046.0020 - val_mean_absolute_error: 55.7271
# Epoch 474/500
#  9/11 [=======================>......] - ETA: 0s - loss: 8089.2188 - mean_absolute_error: 31.5651
# Epoch 474: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 7475.6821 - mean_absolute_error: 34.9117 - val_loss: 23633.6367 - val_mean_absolute_error: 56.7718
# Epoch 475/500
# 11/11 [==============================] - ETA: 0s - loss: 5667.5493 - mean_absolute_error: 28.4743
# Epoch 475: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 32ms/step - loss: 5667.5493 - mean_absolute_error: 28.4743 - val_loss: 21426.1055 - val_mean_absolute_error: 53.7698
# Epoch 476/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5575.9707 - mean_absolute_error: 30.3271
# Epoch 476: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 30ms/step - loss: 5045.9746 - mean_absolute_error: 29.4175 - val_loss: 22914.9219 - val_mean_absolute_error: 55.2044
# Epoch 477/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5637.5122 - mean_absolute_error: 24.3061
# Epoch 477: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 30ms/step - loss: 4969.1611 - mean_absolute_error: 24.0403 - val_loss: 22914.3711 - val_mean_absolute_error: 55.8939
# Epoch 478/500
# 10/11 [==========================>...] - ETA: 0s - loss: 5809.8105 - mean_absolute_error: 30.2970
# Epoch 478: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 30ms/step - loss: 5624.8823 - mean_absolute_error: 31.2917 - val_loss: 21985.8887 - val_mean_absolute_error: 54.7928
# Epoch 479/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5753.9043 - mean_absolute_error: 28.3622
# Epoch 479: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 5486.0762 - mean_absolute_error: 29.2434 - val_loss: 22866.1699 - val_mean_absolute_error: 57.8100
# Epoch 480/500
# 11/11 [==============================] - ETA: 0s - loss: 5715.8843 - mean_absolute_error: 38.2810
# Epoch 480: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 32ms/step - loss: 5715.8843 - mean_absolute_error: 38.2810 - val_loss: 23048.2324 - val_mean_absolute_error: 57.9650
# Epoch 481/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5133.3188 - mean_absolute_error: 29.2867
# Epoch 481: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 6028.8535 - mean_absolute_error: 29.7629 - val_loss: 23058.4922 - val_mean_absolute_error: 56.0233
# Epoch 482/500
#  9/11 [=======================>......] - ETA: 0s - loss: 4972.2520 - mean_absolute_error: 29.9782
# Epoch 482: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 35ms/step - loss: 6057.2183 - mean_absolute_error: 30.7383 - val_loss: 25405.6094 - val_mean_absolute_error: 56.7417
# Epoch 483/500
# 11/11 [==============================] - ETA: 0s - loss: 5845.7422 - mean_absolute_error: 36.6310
# Epoch 483: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 5845.7422 - mean_absolute_error: 36.6310 - val_loss: 23911.4199 - val_mean_absolute_error: 61.6790
# Epoch 484/500
#  9/11 [=======================>......] - ETA: 0s - loss: 6034.3813 - mean_absolute_error: 27.2044
# Epoch 484: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 34ms/step - loss: 5333.0293 - mean_absolute_error: 26.9282 - val_loss: 21687.4980 - val_mean_absolute_error: 55.9843
# Epoch 485/500
# 11/11 [==============================] - ETA: 0s - loss: 4967.3931 - mean_absolute_error: 32.6348
# Epoch 485: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 4967.3931 - mean_absolute_error: 32.6348 - val_loss: 23243.0430 - val_mean_absolute_error: 55.8497
# Epoch 486/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5492.7129 - mean_absolute_error: 33.4119
# Epoch 486: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 35ms/step - loss: 5182.0059 - mean_absolute_error: 32.4038 - val_loss: 22961.2773 - val_mean_absolute_error: 56.0728
# Epoch 487/500
# 11/11 [==============================] - ETA: 0s - loss: 5699.2095 - mean_absolute_error: 34.4573
# Epoch 487: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 36ms/step - loss: 5699.2095 - mean_absolute_error: 34.4573 - val_loss: 26198.4375 - val_mean_absolute_error: 62.4807
# Epoch 488/500
# 11/11 [==============================] - ETA: 0s - loss: 6463.0293 - mean_absolute_error: 32.7476
# Epoch 488: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 6463.0293 - mean_absolute_error: 32.7476 - val_loss: 21057.7383 - val_mean_absolute_error: 55.2071
# Epoch 489/500
# 11/11 [==============================] - ETA: 0s - loss: 4923.6709 - mean_absolute_error: 28.8088
# Epoch 489: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 4923.6709 - mean_absolute_error: 28.8088 - val_loss: 22220.3594 - val_mean_absolute_error: 55.9750
# Epoch 490/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5111.4858 - mean_absolute_error: 27.6505
# Epoch 490: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 4965.3945 - mean_absolute_error: 27.9501 - val_loss: 22280.1016 - val_mean_absolute_error: 55.7576
# Epoch 491/500
#  9/11 [=======================>......] - ETA: 0s - loss: 6080.5273 - mean_absolute_error: 33.8154
# Epoch 491: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 5657.5889 - mean_absolute_error: 34.6075 - val_loss: 25490.4004 - val_mean_absolute_error: 57.5867
# Epoch 492/500
# 10/11 [==========================>...] - ETA: 0s - loss: 5826.1772 - mean_absolute_error: 31.5217
# Epoch 492: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 33ms/step - loss: 5562.6680 - mean_absolute_error: 30.6909 - val_loss: 23265.5801 - val_mean_absolute_error: 56.4544
# Epoch 493/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5912.7202 - mean_absolute_error: 32.8030
# Epoch 493: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 5289.3853 - mean_absolute_error: 31.4605 - val_loss: 21004.2070 - val_mean_absolute_error: 53.5166
# Epoch 494/500
# 10/11 [==========================>...] - ETA: 0s - loss: 5336.6279 - mean_absolute_error: 26.8552
# Epoch 494: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 30ms/step - loss: 5123.6226 - mean_absolute_error: 27.4566 - val_loss: 25221.5918 - val_mean_absolute_error: 58.7655
# Epoch 495/500
# 10/11 [==========================>...] - ETA: 0s - loss: 5747.5649 - mean_absolute_error: 34.2907
# Epoch 495: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 30ms/step - loss: 5468.4258 - mean_absolute_error: 34.1932 - val_loss: 23332.3652 - val_mean_absolute_error: 55.9574
# Epoch 496/500
# 10/11 [==========================>...] - ETA: 0s - loss: 6121.0996 - mean_absolute_error: 34.8508
# Epoch 496: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 6167.0654 - mean_absolute_error: 36.7188 - val_loss: 19403.9863 - val_mean_absolute_error: 53.6377
# Epoch 497/500
# 11/11 [==============================] - ETA: 0s - loss: 5867.0688 - mean_absolute_error: 32.4881
# Epoch 497: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 5867.0688 - mean_absolute_error: 32.4881 - val_loss: 21710.7891 - val_mean_absolute_error: 53.9220
# Epoch 498/500
# 11/11 [==============================] - ETA: 0s - loss: 5452.0679 - mean_absolute_error: 30.7745
# Epoch 498: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 5452.0679 - mean_absolute_error: 30.7745 - val_loss: 24722.0547 - val_mean_absolute_error: 58.5656
# Epoch 499/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5545.9458 - mean_absolute_error: 38.8493
# Epoch 499: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 30ms/step - loss: 6009.5859 - mean_absolute_error: 37.6309 - val_loss: 22115.2832 - val_mean_absolute_error: 55.5818
# Epoch 500/500
#  9/11 [=======================>......] - ETA: 0s - loss: 5392.2129 - mean_absolute_error: 30.0197
# Epoch 500: val_loss did not improve from 18395.84766
# 11/11 [==============================] - 0s 31ms/step - loss: 5812.6650 - mean_absolute_error: 29.6280 - val_loss: 19921.5820 - val_mean_absolute_error: 55.1160

# %% [markdown]
# After training, the best model is loaded and its architecture summary is printed.

# %%
#  Load model
best_model = tf.keras.models.load_model('best-model.h5')
best_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 512)               536064
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_7 (Dense)             (None, 512)               262656
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_8 (Dense)             (None, 512)               262656
#
#  batch_normalization_7 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_9 (Dense)             (None, 512)               262656
#
#  batch_normalization_8 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_10 (Dense)            (None, 512)               262656
#
#  batch_normalization_9 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_11 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 1,597,441
# Trainable params: 1,592,321
# Non-trainable params: 5,120
# _________________________________________________________________

# %% [markdown]
# Next, the best model's performance is evaluated by calculating mean squared error and mean absolute error on the test data. This assessment provides insights into the model's predictive accuracy.

# %%
# Evaluate the best model
best_test_loss, best_test_acc = best_model.evaluate(xtest, ytest)
print(f"Validation loss (MSE) after Tuning     : {best_test_loss} ")
print(f"Validation MAE after Tuning : {best_test_acc}  ")
# Out:
# 11/11 [==============================] - 0s 5ms/step - loss: 18395.8496 - mean_absolute_error: 53.6051
# Validation loss (MSE) after Tuning     : 18395.849609375
# Validation MAE after Tuning : 53.605072021484375

# %% [markdown]
# The subsequent code extracts training and validation metrics from the best model's training history. These metrics, including mean absolute error and loss, are plotted over epochs. This visualization helps in understanding the model's learning progress.

# %%
# Extract the history from the best model
accuracy = best_model_history.history['mean_absolute_error']
val_accuracy = best_model_history.history['val_mean_absolute_error']

loss = best_model_history.history['loss']
val_loss = best_model_history.history['val_loss']

epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'b', label='Training mean_absolute_error')
plt.plot(epochs, val_accuracy, 'r', label='Validation mean_absolute_error')

plt.title('Training and validation mean_absolute_error')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')

plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# A function called "make_sample_prediction" is defined to make predictions on individual test samples using the best model. It calculates differences and percentage differences between true and predicted prices.

# %%
def make_sample_prediction(index, xtest, ytest, model, transformed_cols):
    # Select the corresponding test sample and true price
    sample, true_price = xtest[index], ytest.iloc[index]

    # Reshape the sample to be a batch of size 1
    sample = sample.reshape(1, -1)

    # Make a prediction
    predicted_price = model.predict(sample)[0][0]

    # Calculate the difference
    difference = true_price - predicted_price

    # Calculate the percentage difference
    pct_difference = (difference / true_price) * 100

    # Create a data frame for the scaled sample
    sample_df = pd.DataFrame(sample, columns=transformed_cols)

    # Print out the sample, the true price, and the predicted price
    print(f"Prediction {index+1}")
#     print("Features (scaled):")
#     print(sample_df)
    print("True Price: ", true_price)
    print("Predicted Price: ", predicted_price)
    print("Difference: ", difference)
    print("Percentage Difference: ", pct_difference, "%")
    print("\n---------------------\n")

# %%
# Get feature names after transformation
transformed_feature_names = (ct.named_transformers_['onehotencoder']
                                .get_feature_names_out(cat_cols))
transformed_cols = num_cols + list(transformed_feature_names)

# %% [markdown]
# Then, the code calls the "make_sample_prediction" function for the first 10 samples in the test data, providing predictions, true prices, differences, and percentage differences. This step aids in understanding the model's predictive capabilities on specific samples.

# %%
# Call the function for the first 10 samples
for i in range(10):
    make_sample_prediction(i, xtest, ytest, best_model, transformed_cols)
# Out:
# 1/1 [==============================] - 0s 151ms/step
# Prediction 1
# True Price:  85.9
# Predicted Price:  71.71312
# Difference:  14.186880493164068
# Percentage Difference:  16.515576825569344 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 20ms/step
# Prediction 2
# True Price:  23.43
# Predicted Price:  17.2268
# Difference:  6.203199081420898
# Percentage Difference:  26.47545489296158 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 20ms/step
# Prediction 3
# True Price:  113.0
# Predicted Price:  170.01901
# Difference:  -57.019012451171875
# Percentage Difference:  -50.45930305413441 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 21ms/step
# Prediction 4
# True Price:  29.0132184621944
# Predicted Price:  90.97307
# Difference:  -61.959849775110285
# Percentage Difference:  -213.55731304283566 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 20ms/step
# Prediction 5
# True Price:  49.75
# Predicted Price:  62.399437
# Difference:  -12.649436950683594
# Percentage Difference:  -25.426003920972047 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 20ms/step
# Prediction 6
# True Price:  26.2902950466486
# Predicted Price:  10.646686
# Difference:  15.643609446367837
# Percentage Difference:  59.50336205284251 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 20ms/step
# Prediction 7
# True Price:  174.91
# Predicted Price:  47.73014
# Difference:  127.17985931396484
# Percentage Difference:  72.71159985933615 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 20ms/step
# Prediction 8
# True Price:  81.35
# Predicted Price:  71.346855
# Difference:  10.003144836425776
# Percentage Difference:  12.296428809374033 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 22ms/step
# Prediction 9
# True Price:  59.95
# Predicted Price:  44.75922
# Difference:  15.190779876708987
# Percentage Difference:  25.33908236315094 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 23ms/step
# Prediction 10
# True Price:  95.0
# Predicted Price:  142.15413
# Difference:  -47.15412902832031
# Percentage Difference:  -49.63592529296875 %
#
# ---------------------
