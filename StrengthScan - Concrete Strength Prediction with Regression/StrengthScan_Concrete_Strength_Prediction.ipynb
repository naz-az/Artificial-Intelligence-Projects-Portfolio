# %% [markdown]
# # **Title: StrengthScan - Revisiting Concrete Strength Prediction with Regression**

# %% [markdown]
# ![Screenshot 2023-07-13 082349.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Overview/Introduction:
# In the field of civil engineering, concrete is considered the most essential material. The compressive strength of concrete plays a vital role in determining its performance and durability. Predicting concrete strength accurately can assist engineers in optimizing structural designs, ensuring safety, and reducing costs. To address this challenge, we present an AI project that utilizes regression techniques to revisit the prediction of concrete strength based on various factors, such as age and ingredient composition. By analyzing a comprehensive dataset and employing artificial intelligence algorithms, we aim to develop a reliable model that can estimate concrete compressive strength with high accuracy.
#
# ## Problem Statement:
# The prediction of concrete compressive strength poses a significant challenge due to its highly nonlinear relationship with age and ingredient composition. Traditional methods of estimating concrete strength often rely on time-consuming and expensive experimental testing. Therefore, there is a need for an efficient and accurate approach that can leverage historical data to predict concrete strength reliably. By harnessing the power of artificial intelligence and regression techniques, this project aims to tackle this problem and provide a valuable tool for engineers and researchers in the field of civil engineering.
#
# ## Objectives:
# 1. Develop a regression model to predict the compressive strength of concrete based on input variables such as the composition of different components (cement, blast furnace slag, fly ash, water, superplasticizer, coarse aggregate, fine aggregate) and age.
# 2. Explore and analyze the dataset to identify patterns and relationships between the input variables and concrete strength.
# 3. Optimize the regression model to improve its accuracy and generalization capabilities.
# 4. Evaluate the performance of the model using appropriate metrics and compare it with existing methods for concrete strength prediction.
# 5. Provide valuable insights and recommendations based on the model's predictions, assisting engineers in optimizing concrete mixtures for desired strength requirements.
#
# ## Dataset Description:
# The dataset utilized in this project is the Concrete Compressive Strength Data Set. It consists of 1,030 instances with nine attributes, including eight quantitative input variables and one quantitative output variable. Each row in the dataset corresponds to a specific concrete mixture, with the order of attributes following the order of numerals along the rows. The dataset provides information on various components of the mixture, such as cement, blast furnace slag, fly ash, water, superplasticizer, coarse aggregate, fine aggregate, and age. The output variable is the concrete compressive strength, measured in megapascals (MPa).
#
# **Acknowledgements:**
# The original owner and donor of the dataset is Prof. I-Cheng Yeh from the Department of Information Management at Chung-Hua University, Hsin Chu, Taiwan. The dataset was donated in August 2007 and is made available with unlimited reuse, while retaining the copyright notice for Prof. I-Cheng Yeh. The dataset was originally used in the research paper titled "Modeling of strength of high-performance concrete using artificial neural networks" by I-Cheng Yeh, published in Cement and Concrete Research, Vol. 28, No. 12, pp. 1797-1808 (1998).
#
# **Dataset Source:**
# Prof. I-Cheng Yeh
# Department of Information Management
# Chung-Hua University,
# Hsin Chu, Taiwan 30067, R.O.C.
# Email: icyeh '@' chu.edu.tw
# TEL: 886-3-5186511
#
# Date Donated: August 3, 2007
#
# **Dataset URL:** [Concrete Compressive Strength Data Set](https://archive.ics.uci.edu/ml/datasets/Concrete+Compressive+Strength)
#
# **Citation:**
# I-Cheng Yeh, "Modeling of strength of high-performance concrete using artificial neural networks," Cement and Concrete Research, Vol. 28, No. 12, pp. 1797-1808 (1998).

# %% [markdown]
# # Technologies Used
#
# 1. Python: The project is implemented using Python, which provides a wide range of libraries and tools for data analysis, machine learning, and deep learning.
#
# 2. Pandas: Pandas is used for data manipulation and analysis, including dataset reading, preprocessing, handling missing values, and exploratory data analysis.
#
# 3. NumPy: NumPy is employed for efficient numerical operations and multi-dimensional array handling in data calculations.
#
# 4. Matplotlib and Seaborn: Matplotlib and Seaborn are used for data visualization, offering various plotting functionalities and visually appealing statistical graphics.
#
# 5. Scikit-learn: Scikit-learn provides tools for data preprocessing, model selection, evaluation, and performance metrics. It is used for train-test splitting and evaluating the models in this project.
#
# 6. TensorFlow and Keras: TensorFlow is used for building and training neural networks, while Keras simplifies the process of defining and training the neural network models for concrete strength prediction.
#
# 7. RandomSearch: RandomSearch is employed for hyperparameter optimization. It explores a predefined search space to discover the best hyperparameters for the neural network model.
#
# # Methodology
#
# The project follows the following methodology to tackle the concrete strength prediction problem:
#
# 1. Data Loading and Preprocessing: The dataset, obtained from Prof. I-Cheng Yeh, is loaded using the Pandas library. The dataset is then examined for duplicates and missing values. Missing values are replaced, and duplicates are removed to ensure data quality.
#
# 2. Exploratory Data Analysis (EDA): Exploratory data analysis is performed to gain insights into the dataset and understand the relationships between variables. Correlation analysis and visualization techniques, such as heatmaps and distribution plots, are used to identify the key factors influencing concrete compressive strength.
#
# 3. Outlier Handling: Outliers, which are data points deviating significantly from the normal range, can impact model performance. The Interquartile Range (IQR) method is employed to detect and handle outliers effectively. Boxplots are generated to visualize the outliers in different numerical features.
#
# 4. Model Building and Evaluation: The dataset is split into training and testing sets using the train_test_split function from Scikit-learn. A neural network model using the Keras API is defined, compiled, and trained on the training data. The model is evaluated using various evaluation metrics, including mean absolute error (MAE), mean squared error (MSE), root mean squared error (RMSE), mean absolute percentage error (MAPE), mean absolute scaled error (MASE), and R-squared score.
#
# 5. Hyperparameter Tuning: Hyperparameter tuning is performed using RandomSearch, which explores a predefined search space to find the best combination of hyperparameters for the neural network model. The best model architecture obtained from RandomSearch is further trained and evaluated.
#
# 6. Residual Analysis and Visualization: Residual analysis is conducted to examine the difference between the actual and predicted values. Scatter plots and residual plots are generated to assess the linearity and distribution of the residuals.
#
# 7. Model Comparison: Different model results, including the baseline model, hyperparameter-tuned model, and dense model, are compared based on evaluation metrics. The results are stored in a DataFrame and sorted based on MAE to identify the best-performing model.
#
#
# # Results:
#
# The project evaluated two models: Model_hp and Model_Dense1+Lr. The results of the evaluation metrics for both models are as follows:
#
# - Model_hp:
#   - Mean Absolute Error (MAE): 2.420572
#   - Mean Squared Error (MSE): 12.798655
#   - Root Mean Squared Error (RMSE): 2.420572
#   - Mean Absolute Percentage Error (MAPE): 9.2600355%
#   - Mean Absolute Scaled Error (MASE): 0.126525
#   - R-squared (R2) Score: 0.950936
#
# - Model_Dense1+Lr:
#   - Mean Absolute Error (MAE): 3.22834
#   - Mean Squared Error (MSE): 19.793867
#   - Root Mean Squared Error (RMSE): 3.22834
#   - Mean Absolute Percentage Error (MAPE): 11.692483%
#   - Mean Absolute Scaled Error (MASE): 0.168748
#   - R-squared (R2) Score: 0.92412
#
# # Discussion:
#
# The results indicate that Model_hp outperformed Model_Dense1+Lr in terms of several evaluation metrics. Model_hp achieved a lower MAE (2.420572) compared to Model_Dense1+Lr (3.22834), indicating that it made predictions that were, on average, closer to the actual values. Additionally, Model_hp exhibited a lower MSE and RMSE, indicating better overall accuracy.
#
# Both models achieved high R-squared (R2) scores, indicating that they captured a significant portion of the variance in the concrete strength data. However, Model_hp had a slightly higher R2 score (0.950936) compared to Model_Dense1+Lr (0.92412), indicating a better fit to the data.
#
# # Conclusion:
#
# Based on the evaluation results, Model_hp emerges as the superior model for concrete strength prediction. It demonstrated better performance across multiple evaluation metrics, including lower MAE, MSE, RMSE, MAPE, and MASE, as well as a higher R-squared score. The success of Model_hp can be attributed to the optimal hyperparameters obtained through the hyperparameter tuning process. By leveraging RandomSearch, the project identified the best combination of hyperparameters for the neural network model, leading to improved prediction accuracy.
#
# The findings of this project have significant implications for the field of civil engineering. Accurate prediction of concrete strength is crucial for optimizing structural designs, ensuring safety, and reducing costs. By leveraging machine learning techniques, engineers can make informed decisions about concrete mixtures, component compositions, and age considerations to achieve desired strength requirements.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Import series of helper functions for the notebook
# Download helper functions script
# !wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
from helper_functions import unzip_data, create_tensorboard_callback, plot_loss_curves, compare_historys
# Out:
# --2023-07-12 05:36:08--  https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10246 (10K) [text/plain]
# Saving to: ‘helper_functions.py’
#
# helper_functions.py 100%[===================>]  10.01K  --.-KB/s    in 0s
#
# 2023-07-12 05:36:09 (44.7 MB/s) - ‘helper_functions.py’ saved [10246/10246]

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf

# %% [markdown]
# The following code shows a function called seed_everything() that sets the seed value for random number generators in TensorFlow, NumPy, and Python's random library. This is done to ensure reproducibility of results in future use cases.

# %%
import random

# Seed Everything to reproduce results for future use cases
def seed_everything(seed=42):
    # Seed value for TensorFlow
    tf.random.set_seed(seed)
    # Seed value for NumPy
    np.random.seed(seed)
    # Seed value for Python's random library
    random.seed(seed)

seed_everything()

# %% [markdown]
# The following code reads in the  dataset and displays the first few rows of the data.

# %%
# Read in the dataset
df = pd.read_csv("./Concrete_Data_Yeh.csv")
df.head()
# Out:
#    cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0   540.0    0.0     0.0  162.0               2.5           1040.0
# 1   540.0    0.0     0.0  162.0               2.5           1055.0
# 2   332.5  142.5     0.0  228.0               0.0            932.0
# 3   332.5  142.5     0.0  228.0               0.0            932.0
# 4   198.6  132.4     0.0  192.0               0.0            978.4
#
#    fineaggregate  age  csMPa
# 0          676.0   28  79.99
# 1          676.0   28  61.89
# 2          594.0  270  40.27
# 3          594.0  365  41.05
# 4          825.5  360  44.30

# %% [markdown]
# The next code calculates descriptive statistics for the dataset and transposes the result.

# %%
df.describe().T
# Out:
#                    count        mean         std     min      25%      50%  \
# cement            1030.0  281.167864  104.506364  102.00  192.375  272.900
# slag              1030.0   73.895825   86.279342    0.00    0.000   22.000
# flyash            1030.0   54.188350   63.997004    0.00    0.000    0.000
# water             1030.0  181.567282   21.354219  121.80  164.900  185.000
# superplasticizer  1030.0    6.204660    5.973841    0.00    0.000    6.400
# coarseaggregate   1030.0  972.918932   77.753954  801.00  932.000  968.000
# fineaggregate     1030.0  773.580485   80.175980  594.00  730.950  779.500
# age               1030.0   45.662136   63.169912    1.00    7.000   28.000
# csMPa             1030.0   35.817961   16.705742    2.33   23.710   34.445
#
#                        75%     max
# cement             350.000   540.0
# slag               142.950   359.4
# flyash             118.300   200.1
# water              192.000   247.0
# superplasticizer    10.200    32.2
# ...

# %%
df.shape
# Out:
# (1030, 9)

# %% [markdown]
# In the next code, the target variable is defined as "csMPa".

# %%
target="csMPa"
target
# Out:
# 'csMPa'

# %% [markdown]
# **Duplicates and Null values**
#
# The code block following that provides some exploratory data analysis. It prints the number of data points in the dataset, checks for duplicates, and identifies missing values in the DataFrame. It also replaces empty values with NaN and rechecks the missing values after replacement.

# %%
import numpy as np

# Remove columns

# How many reviews do we have?
print('There are', df.shape[0], 'data in this dataset')

# Do we have duplicates?
print('Number of Duplicates:', len(df[df.duplicated()]))

# Do we have missing values?
missing_values = df.isnull().sum()
print('Number of Missing Values by column:\n',missing_values)

print('Number of Missing Values:', df.isnull().sum().sum())

df.replace("", np.nan, inplace=True)
missing_values = df.isnull().sum()
print('Number of Missing Values by column after replacement:\n',missing_values)
print('Number of Missing Values after replacement:', df.isnull().sum().sum())
# Out:
# There are 1030 data in this dataset
# Number of Duplicates: 25
# Number of Missing Values by column:
#  cement              0
# slag                0
# flyash              0
# water               0
# superplasticizer    0
# coarseaggregate     0
# fineaggregate       0
# age                 0
# csMPa               0
# dtype: int64
# Number of Missing Values: 0
# Number of Missing Values by column after replacement:
#  cement              0
# slag                0
# flyash              0
# water               0
# superplasticizer    0
# coarseaggregate     0
# fineaggregate       0
# age                 0
# csMPa               0
# dtype: int64
# Number of Missing Values after replacement: 0

# %% [markdown]
# **Review Duplicates**
#
# Now, we want to identify and display duplicate rows in the dataset. The code finds and sorts all duplicate rows, then shows the top 5 pairs of duplicate rows.

# %%
# First, get all duplicate rows (keep=False ensures all duplicates are kept)
duplicate_rows = df[df.duplicated(keep=False)]

# Then sort the dataframe on all columns to ensure duplicates are adjacent
sorted_duplicates = duplicate_rows.sort_values(by=list(duplicate_rows.columns))

# Now, if we want to see 5 pairs of duplicates (10 rows), we can simply:
top_5_duplicate_pairs = sorted_duplicates.head(20)
top_5_duplicate_pairs
# Out:
#      cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 801   252.0    0.0     0.0  185.0               0.0           1111.0
# 809   252.0    0.0     0.0  185.0               0.0           1111.0
# 83    362.6  189.0     0.0  164.9              11.6            944.7
# 86    362.6  189.0     0.0  164.9              11.6            944.7
# 88    362.6  189.0     0.0  164.9              11.6            944.7
# 91    362.6  189.0     0.0  164.9              11.6            944.7
# 106   362.6  189.0     0.0  164.9              11.6            944.7
# 109   362.6  189.0     0.0  164.9              11.6            944.7
# 111   362.6  189.0     0.0  164.9              11.6            944.7
# 129   362.6  189.0     0.0  164.9              11.6            944.7
# 132   362.6  189.0     0.0  164.9              11.6            944.7
# 134   362.6  189.0     0.0  164.9              11.6            944.7
# 137   362.6  189.0     0.0  164.9              11.6            944.7
# ...

# %% [markdown]
# To remove duplicate rows from the dataset, we can use the next code. It drops the duplicate rows and prints the number of remaining duplicates.

# %%
df = df.drop_duplicates()
print('Number of Duplicates:', len(df[df.duplicated()]))
# Out:
# Number of Duplicates: 0

# %% [markdown]
# **Correlation Matrix**
#
# The code plots a heatmap of the correlation matrix for the dataset, providing insights into the relationships between different features.

# %%
plt.subplots(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, fmt='.2f')
pass

# %% [markdown]
# To analyze the correlation of a specific target variable, we use the target variable "csMPa." The code calculates the correlation of "csMPa" with other features and sorts them in descending order.

# %%
# Calculate the correlation matrix
corr_matrix = df.corr(numeric_only=True)

# Get the correlation of 'price' with other features
corr_with_price = corr_matrix[target]

# Sort these correlations in descending order
sorted_correlations = corr_with_price.sort_values(ascending=False)
sorted_correlations
# Out:
# csMPa               1.000000
# cement              0.488283
# superplasticizer    0.344209
# age                 0.337367
# slag                0.103374
# flyash             -0.080648
# coarseaggregate    -0.144717
# fineaggregate      -0.186448
# water              -0.269624
# Name: csMPa, dtype: float64

# %% [markdown]
# The sorted correlations are visualized as a bar plot using the next code. This helps to identify the most positively correlated features with the target variable.

# %%
sorted_correlations.sort_values(ascending=0).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# **EDA**
#
# Next, a distribution plot is created using seaborn to visualize the distribution of the target variable ("csMPa").

# %%
sns.set(style='whitegrid')
f, ax = plt.subplots(1,1, figsize=(12, 8))
ax = sns.distplot(df[target], kde = True, color = 'c')
plt.title(f'Distribution of {target}')
# Out:
# Text(0.5, 1.0, 'Distribution of csMPa')

# %% [markdown]
# Next, we analyze the statistical summary of the "csMPa" variable, including measures like mean, standard deviation, minimum, maximum, and quartiles.

# %%
df['csMPa'].describe()
# Out:
# count    1005.000000
# mean       35.250378
# std        16.284815
# min         2.330000
# 25%        23.520000
# 50%        33.800000
# 75%        44.870000
# max        82.600000
# Name: csMPa, dtype: float64

# %% [markdown]
# **Handling Outliers**

# %% [markdown]
# > **Interquartile Range Method**
#
#
# The Interquartile Range (IQR) is a statistical measure used to calculate data variability and visualize it through boxplot graphs. Simply put, the IQR divides a dataset into four distinct intervals, known as quartiles, based on their comparative values.
#
# The quartiles themselves are points that split the data into four equal parts. IQR is determined by subtracting the first quartile (Q1) from the third quartile (Q3). So, IQR = Q3 - Q1.
#
# Outliers are data points that lie outside the typical range of the data set. They are specifically defined as observations falling below the lower whisker of the boxplot, calculated as (Q1 - 1.5x IQR), or above the upper whisker, calculated as (Q3 + 1.5x IQR). These outliers can be easily identified in a boxplot, which provides a visual representation of data dispersion and variability.

# %% [markdown]
# To perform outlier analysis on numerical features, we select the columns with numerical data types and plot boxplots for each feature. This helps identify potential outliers.

# %%
numerical_features = df.select_dtypes(include=['float64','int64']).columns
numerical_features
# Out:
# Index(['cement', 'slag', 'flyash', 'water', 'superplasticizer',
#        'coarseaggregate', 'fineaggregate', 'age', 'csMPa'],
#       dtype='object')

# %%
import math

# Selecting the numerical features
numerical_features = df.select_dtypes(include=['float64','int64']).columns

rounded_up_value = math.ceil(len(numerical_features)/3)

# Plotting boxplots for all numerical features
fig, axes = plt.subplots(rounded_up_value, 3, figsize=(12, 12))
fig.subplots_adjust(wspace=0.1, hspace=0.3)
fig.suptitle('Outlier Analysis using Boxplot', fontsize=30)
axes = axes.ravel()
font = {
    'family': 'serif',
    'color':  'darkred',
    'weight': 'normal',
    'size': 16,
}
for i, col in enumerate(numerical_features):
    sns.boxplot(df[col], ax=axes[i])
    axes[i].set_title(col, fontdict=font, fontsize=25)

# %% [markdown]
# The code defines a function to detect outliers based on the interquartile range (IQR) method. It returns the indices and values of outliers for a given feature.

# %%
# Function to detect outliers
def detect_outliers(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_limit = Q1 - (1.5 * IQR)
    upper_limit = Q3 + (1.5 * IQR)
    outliers = df[(df[col] < lower_limit) | (df[col] > upper_limit)]

    if len(outliers) == 0:
        return [], 'No Outliers Present'
    else:
        return outliers.index.tolist(), outliers

# %% [markdown]
# We collect and print all outlier indices and their corresponding values for each numerical feature in the dataset.

# %%
# Collect all outlier indices
all_outlier_indices = []

# Outliers values are --
for col in numerical_features:
    print('-' * 27, col,'-' * 26)
    outlier_indices, outliers = detect_outliers(df, col)
    all_outlier_indices.extend(outlier_indices)
    print(outliers)
    print('\n')
# Out:
# --------------------------- cement --------------------------
# No Outliers Present
#
#
# --------------------------- slag --------------------------
#      cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 553   239.6  359.4     0.0  185.7               0.0            941.6
# 559   239.6  359.4     0.0  185.7               0.0            941.6
#
#      fineaggregate  age  csMPa
# 553          664.3    7  25.42
# 559          664.3   28  39.44
#
#
# --------------------------- flyash --------------------------
# No Outliers Present
#
#
# --------------------------- water --------------------------
#       cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 74     375.0   93.8     0.0  126.6              23.4            852.1
# 97     375.0   93.8     0.0  126.6              23.4            852.1
# 120    375.0   93.8     0.0  126.6              23.4            852.1
# 143    375.0   93.8     0.0  126.6              23.4            852.1
# ...

# %% [markdown]
# The unique outlier indices are obtained from the collected outlier indices, and the total count of unique outlier indices is printed.

# %%
# Get unique outlier indices
unique_outlier_indices = list(set(all_outlier_indices))

# Print the unique indices and their count
print("Unique outlier indices:", unique_outlier_indices)
print("Number of unique outlier indices:", len(unique_outlier_indices))
# Out:
# Unique outlier indices: [0, 2, 3, 4, 6, 12, 17, 19, 20, 23, 24, 25, 26, 27, 30, 31, 32, 33, 34, 35, 39, 553, 41, 42, 43, 559, 47, 50, 51, 56, 58, 60, 61, 63, 64, 65, 66, 74, 76, 79, 603, 604, 97, 609, 99, 610, 102, 615, 616, 619, 620, 621, 622, 120, 122, 125, 143, 145, 148, 152, 153, 159, 166, 168, 171, 175, 181, 224, 225, 226, 227, 228, 755, 756, 762, 768, 769, 791, 792, 794, 795, 797, 798, 813, 814, 820, 823, 862, 873, 381, 383, 908, 936, 1019]
# Number of unique outlier indices: 94

# %% [markdown]
# The next code drops the rows with unique outlier indices from the dataset, removing the outliers.

# %%
df = df.drop(unique_outlier_indices)

# %% [markdown]
# **Evaluation Metrics**
#
# The next code block defines two utility functions: mean_absolute_scaled_error() and evaluate_preds(). The mean_absolute_scaled_error() function calculates the Mean Absolute Scaled Error (MASE), assuming no seasonality of the data. The evaluate_preds() function calculates various metrics, including MAE, MSE, RMSE, MAPE, MASE, and R-squared score, for evaluating the predictions.

# %%
# MASE implemented courtesy of sktime - https://github.com/alan-turing-institute/sktime/blob/ee7a06843a44f4aaec7582d847e36073a9ab0566/sktime/performance_metrics/forecasting/_functions.py#L16
def mean_absolute_scaled_error(y_true, y_pred):
  """
  Implement MASE (assuming no seasonality of data).
  """
  mae = tf.reduce_mean(tf.abs(y_true - y_pred))

  # Find MAE of naive forecast (no seasonality)
  mae_naive_no_season = tf.reduce_mean(tf.abs(y_true[1:] - y_true[:-1])) # our seasonality is 1 day (hence the shifting of 1 day)

  return mae / mae_naive_no_season

def evaluate_preds(y_true, y_pred):
    # Make sure float32 (for metric calculations)
    y_true = tf.cast(y_true, dtype=tf.float32)
    y_pred = tf.cast(y_pred, dtype=tf.float32)

    # Calculate various metrics
    mae = tf.keras.metrics.mean_absolute_error(y_true, y_pred)
    mse = tf.keras.metrics.mean_squared_error(y_true, y_pred)
    rmse = tf.sqrt(mse)
    mape = tf.keras.metrics.mean_absolute_percentage_error(y_true, y_pred)
    mase = mean_absolute_scaled_error(y_true, y_pred)

    # Calculate R-squared score
    ss_res = tf.reduce_sum((y_true - y_pred)**2)
    ss_tot = tf.reduce_sum((y_true - tf.reduce_mean(y_true))**2)
    r2 = 1 - (ss_res / ss_tot)

    # Account for different sized metrics
    if mae.ndim > 0:
        mae = tf.reduce_mean(mae)
        mse = tf.reduce_mean(mse)
        rmse = tf.reduce_mean(rmse)
        mape = tf.reduce_mean(mape)
        mase = tf.reduce_mean(mase)
        r2 = tf.reduce_mean(r2)

    return {"mae": mae.numpy(),
            "mse": mse.numpy(),
            "rmse": rmse.numpy(),
            "mape": str(mape.numpy()) + "%",
            "mase": mase.numpy(),
            "r2": r2.numpy()}

# %% [markdown]
# **Define Features and Labels**
#
# We split the dataset into input features (X) and the target variable (y) using the next code.

# %%
X=df.drop([target],axis=1)
y=df[[target]]
X,y
# Out:
# (      cement   slag  flyash  water  superplasticizer  coarseaggregate  \
#  1      540.0    0.0     0.0  162.0               2.5           1055.0
#  5      266.0  114.0     0.0  228.0               0.0            932.0
#  7      380.0   95.0     0.0  228.0               0.0            932.0
#  8      266.0  114.0     0.0  228.0               0.0            932.0
#  9      475.0    0.0     0.0  228.0               0.0            932.0
#  ...      ...    ...     ...    ...               ...              ...
#  1025   276.4  116.0    90.3  179.6               8.9            870.1
#  1026   322.2    0.0   115.6  196.0              10.4            817.9
#  1027   148.5  139.4   108.6  192.7               6.1            892.4
#  1028   159.1  186.7     0.0  175.6              11.3            989.6
#  1029   260.9  100.5    78.3  200.6               8.6            864.5
#
#        fineaggregate  age
#  1             676.0   28
#  5             670.0   90
#  7             594.0   28
# ...

# %% [markdown]
# **Train-Test Split**
#
# The train_test_split function from scikit-learn is used to split the dataset into training and testing sets, with 80% of the data used for training and 20% for testing.

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %% [markdown]
# The code identifies and prints the list of numerical and categorical columns in the dataset.

# %%
# Get list of numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Remove 'price' from num_cols
num_cols.remove(target)

# Get list of categorical columns
cat_cols = df.select_dtypes(include=['object']).columns.tolist()

# Print the numerical columns
print("Numerical columns are:", num_cols)

# Print the categorical columns
print("Categorical columns are:", cat_cols)
# Out:
# Numerical columns are: ['cement', 'slag', 'flyash', 'water', 'superplasticizer', 'coarseaggregate', 'fineaggregate', 'age']
# Categorical columns are: []

# %% [markdown]
# To preprocess the numerical data, we create a column transformer using MinMaxScaler for normalization.

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# creating column transformer (this will help us normalize/preprocess our data)
ct = make_column_transformer((MinMaxScaler(), num_cols))

# %% [markdown]
# The column transformer is fitted on the training data, and then the transformation is applied to both the training and test data.

# %%
# fitting column transformer on training data
ct.fit(xtrain)

# transforming training and test data with normalizing (MinMaxScaler) and one hot encoding (OneHotEncoder)
xtrain = ct.transform(xtrain)
xtest = ct.transform(xtest)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Bidirectional, LSTM, Dropout, Dense, Lambda
from tensorflow.keras.optimizers import Adam
# !pip install keras-tuner
import keras_tuner as kt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 15.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Model: Dense**
#
# The next code defines a neural network model using TensorFlow's Keras API. It consists of multiple dense layers with dropout regularization. The model is compiled with the mean squared error loss function and the Adam optimizer. Mean absolute error is used as an additional metric. A learning rate schedule is defined to adjust the learning rate during training. The model is then trained on the training data with the specified parameters.

# %%
from tensorflow.keras import regularizers

# Set random seed
tf.random.set_seed(42)

# Define the model
model_1 = tf.keras.Sequential([
  tf.keras.layers.Dense(512, activation="relu", kernel_regularizer=regularizers.l2(0.01)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=regularizers.l2(0.01)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(1)
])

# Define the optimizer
optimizer = tf.keras.optimizers.Adam()

# Compile the model
model_1.compile(loss="mean_squared_error",
                optimizer=optimizer,
                metrics=["mean_absolute_error"])

# Define the learning rate schedule
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-6 * 10**(-epoch / 20))

# Fit the model
history = model_1.fit(xtrain,
                      ytrain,
                      epochs=100,
                      batch_size=32,
                      validation_data=(xtest, ytest),
                      callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 23/23 [==============================] - 10s 45ms/step - loss: 1439.7881 - mean_absolute_error: 34.4945 - val_loss: 1301.5111 - val_mean_absolute_error: 32.2205 - lr: 1.0000e-06
# Epoch 2/100
# 23/23 [==============================] - 0s 15ms/step - loss: 1439.8538 - mean_absolute_error: 34.4938 - val_loss: 1301.3132 - val_mean_absolute_error: 32.2175 - lr: 8.9125e-07
# Epoch 3/100
# 23/23 [==============================] - 0s 15ms/step - loss: 1439.5247 - mean_absolute_error: 34.4915 - val_loss: 1301.1387 - val_mean_absolute_error: 32.2148 - lr: 7.9433e-07
# Epoch 4/100
# 23/23 [==============================] - 0s 11ms/step - loss: 1439.1119 - mean_absolute_error: 34.4848 - val_loss: 1300.9832 - val_mean_absolute_error: 32.2125 - lr: 7.0795e-07
# Epoch 5/100
# 23/23 [==============================] - 0s 11ms/step - loss: 1439.3943 - mean_absolute_error: 34.4881 - val_loss: 1300.8439 - val_mean_absolute_error: 32.2103 - lr: 6.3096e-07
# Epoch 6/100
# ...

# %% [markdown]
# The learning rate versus the loss is plotted to visualize the relationship between the learning rate and the model's loss.

# %%
# Plot the learning rate versus the loss
lrs = 1e-6 * (10 ** (np.arange(100)/20))
plt.figure(figsize=(10, 7))
plt.semilogx(lrs, history.history["loss"]) # we want the x-axis (learning rate) to be log scale
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Learning rate vs. loss");

# %% [markdown]
# After training the model, the states generated by Keras are reset to ensure a clean state for subsequent computations. And a new learning rate is set.

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

lrx=1e-3
lrx
# Out:
# 0.001

# %% [markdown]
# The code imports the EarlyStopping and ModelCheckpoint callbacks from TensorFlow's Keras API. A checkpoint is set to save the best model based on the validation loss. Early stopping is used with a patience of 100 epochs to prevent overfitting.
#
# The model is compiled and trained with the specified parameters, including the learning rate, early stopping, and model checkpoint callbacks.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
ES=EarlyStopping(patience=100, restore_best_weights=True),

# Define the optimizer
optimizer = tf.keras.optimizers.Adam(lr=lrx)

# Compile the model
model_1.compile(loss="mean_squared_error",
                optimizer=optimizer,
                metrics=["mean_absolute_error"])

# Fit the model
history = model_1.fit(xtrain,
                      ytrain,
                      epochs=500,
                      batch_size=32,
                      validation_data=(xtest, ytest),
                      callbacks=[ES,checkpoint])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/500
# 21/23 [==========================>...] - ETA: 0s - loss: 1286.0334 - mean_absolute_error: 32.2369
# Epoch 1: val_loss improved from inf to 908.94775, saving model to best_model.h5
# 23/23 [==============================] - 3s 25ms/step - loss: 1281.1118 - mean_absolute_error: 32.1666 - val_loss: 908.9478 - val_mean_absolute_error: 25.5945
# Epoch 2/500
# 18/23 [======================>.......] - ETA: 0s - loss: 695.5128 - mean_absolute_error: 21.3256
# Epoch 2: val_loss improved from 908.94775 to 221.29951, saving model to best_model.h5
# 23/23 [==============================] - 0s 17ms/step - loss: 603.0091 - mean_absolute_error: 19.4925 - val_loss: 221.2995 - val_mean_absolute_error: 12.1103
# Epoch 3/500
# 22/23 [===========================>..] - ETA: 0s - loss: 225.1796 - mean_absolute_error: 12.2233
# ...

# %% [markdown]
# The next code block defines a function called plot_losses() that takes the training history as input and plots the losses (loss function values) over the epochs.

# %%
def plot_losses(history):
    losses = pd.DataFrame(history.history)
    losses.plot()

# %%
plot_losses(history)

# %% [markdown]
# The model with the best validation loss is loaded from the saved checkpoint file using the load_model() function.

# %%
from tensorflow.keras.models import load_model

# Load the best saved model
model_1 = load_model('best_model.h5')

# %% [markdown]
# The model is evaluated on the test data using the evaluate() method, and the results are printed.

# %%
model_1.evaluate(xtest, ytest)
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 23.0990 - mean_absolute_error: 3.2283
# [23.098979949951172, 3.228339910507202]

# %%
# Make predictions
train_pred = model_1.predict(xtrain)
test_pred = model_1.predict(xtest)
# Out:
# ...
# 6/6 [==============================] - 0s 2ms/step

# %% [markdown]
# The evaluate_preds function is then used to evaluate the predictions on the test data.

# %%
res1=evaluate_preds(ytest,test_pred)
res1
# Out:
# {'mae': 3.22834,
#  'mse': 19.793867,
#  'rmse': 3.22834,
#  'mape': '11.692483%',
#  'mase': 0.16874778,
#  'r2': 0.9241199}

# %% [markdown]
# **Prediction Visualization**

# %% [markdown]
# **Residuals plot**
#
# Residual analysis is performed by plotting the predicted values against the residuals (difference between predicted and actual values) for both the train and test data.

# %%
plt.figure(figsize=(10,6))
plt.scatter(train_pred, train_pred - ytrain, c='black', marker='o', s=35, alpha=0.5, label='Train data')
plt.scatter(test_pred, test_pred - ytest, c='c', marker='o', s=35, alpha=0.7, label='Test data')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.legend(loc='upper left')
plt.hlines(y=0, xmin=-10, xmax=50, lw=2, color='red')
plt.show()

# %% [markdown]
# **Checking for linearity: Actual vs Predicted values**
#
# A scatter plot is created to visualize the linearity between the actual and predicted values.

# %%
plt.figure(figsize=(14,5))
plt.scatter(ytest, test_pred, color='r')
plt.title('Check for Linearity:\n Actual vs Predicted values')
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.show()

# %% [markdown]
# **Hyperparameter Tuning: RandomSearch**
#
# The code defines a function to build a neural network model with customizable hyperparameters, including the number of layers, dropout rate, number of units, and regularization parameters. The model architecture consists of input and hidden layers, a dropout layer, and an output layer. It is compiled with an optimizer, loss function, and metrics.

# %%
def build_model(hp):
    from keras.layers import BatchNormalization
    from keras.regularizers import l1_l2

    # Define all hyperparameters
    n_layers = hp.Choice('n_layers', [2, 4, 6])
    dropout_rate = hp.Choice('rate', [0.2, 0.4, 0.5, 0.7])
    n_units = hp.Choice('units', [64, 128, 256, 512])
    l1_reg = hp.Choice('l1', [0.0, 0.01, 0.001, 0.0001])
    l2_reg = hp.Choice('l2', [0.0, 0.01, 0.001, 0.0001])

    # Model architecture
    model = Sequential()

    # Input layer
    model.add(Dense(n_units, input_dim=xtrain.shape[1], activation='relu', kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)))
    model.add(BatchNormalization())

    # Add hidden layers
    for _ in range(n_layers):
        model.add(Dense(n_units, activation='relu', kernel_initializer='he_normal', kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)))
        model.add(BatchNormalization())

    # Add Dropout Layer
    model.add(Dropout(dropout_rate))

    # Output Layer
    model.add(Dense(1))

    # Define the optimizer
    optimizer = tf.keras.optimizers.Adam(lr=lrx)

    # Compile the model
    model.compile(loss="mean_squared_error",
                    optimizer=optimizer,
                    metrics=["mean_absolute_error"])

    # Return model
    return model

# %% [markdown]
# The code initializes a random search algorithm using Keras Tuner to find the best model architecture. It searches for the optimal hyperparameters by minimizing validation loss. The search is performed on the training data with specified parameters.

# %%
# Initialize Random Searcher
random_searcher = kt.RandomSearch(
    hypermodel=build_model,
    objective='val_loss',
    max_trials=30,
    seed=42,
    project_name="Pgt-Search"
)

# Start Searching
search = random_searcher.search(
    xtrain, ytrain,
    validation_data=(xtest, ytest),
    epochs = 30,
    batch_size = 64
)
# Out:
# Trial 30 Complete [00h 00m 13s]
# val_loss: 276.6974792480469
#
# Best val_loss So Far: 119.31571960449219
# Total elapsed time: 00h 06m 16s

# %%
BATCH_SIZE=64

# %% [markdown]
# In the next code block, the best model architecture obtained from the random search is collected and its summary is printed. The model is compiled with an optimizer, loss function, and metrics. The code trains the best model on the training data, using specified training and validation sets, epochs, batch size, and callbacks for early stopping and model checkpointing. The model aims to minimize the loss function.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Collect the best model Architecture obtained by Random Searcher
best_model = build_model(random_searcher.get_best_hyperparameters(num_trials=1)[0])

# Model Architecture
best_model.summary()

optimizer = tf.keras.optimizers.Adam(lr=lrx)

# Compile Model
best_model.compile(loss="mean_squared_error",
                    optimizer=optimizer,
                    metrics=["mean_absolute_error"])
# Model Training
best_model_history = best_model.fit(
    xtrain, ytrain,
    validation_data=(xtest, ytest),
    epochs = 1000,
    batch_size = BATCH_SIZE*2,
    callbacks = [
  EarlyStopping(patience=300, restore_best_weights=True),
  ModelCheckpoint('best-model.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)]
)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 256)               2304
#
#  batch_normalization_5 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_7 (Dense)             (None, 256)               65792
#
#  batch_normalization_6 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_8 (Dense)             (None, 256)               65792
#
#  batch_normalization_7 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 1)                 257
#
# ...
# Total params: 137,217
# Trainable params: 135,681
# Non-trainable params: 1,536
# ...

# %% [markdown]
# After training, the best model is loaded from a saved file and its summary is printed.

# %%
#  Load model
best_model = tf.keras.models.load_model('best-model.h5')
best_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 256)               2304
#
#  batch_normalization_5 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_7 (Dense)             (None, 256)               65792
#
#  batch_normalization_6 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_8 (Dense)             (None, 256)               65792
#
#  batch_normalization_7 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 1)                 257
#
# ...
# Total params: 137,217
# Trainable params: 135,681
# Non-trainable params: 1,536
# _________________________________________________________________

# %% [markdown]
# The code evaluates the performance of the best model on the test data by calculating mean squared error (MSE) and mean absolute error (MAE).

# %%
# Evaluate the best model
best_test_loss, best_test_acc = best_model.evaluate(xtest, ytest)
print(f"Validation loss (MSE) after Tuning     : {best_test_loss} ")
print(f"Validation MAE after Tuning : {best_test_acc}  ")
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 12.9225 - mean_absolute_error: 2.4206
# Validation loss (MSE) after Tuning     : 12.922456741333008
# Validation MAE after Tuning : 2.4205715656280518

# %% [markdown]
# The code extracts the training and validation history from the best model and plots the mean absolute error and loss over epochs. This visualization helps understand the training progress and the model's performance.

# %%
# Extract the history from the best model
accuracy = best_model_history.history['mean_absolute_error']
val_accuracy = best_model_history.history['val_mean_absolute_error']

loss = best_model_history.history['loss']
val_loss = best_model_history.history['val_loss']

epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'b', label='Training mean_absolute_error')
plt.plot(epochs, val_accuracy, 'r', label='Validation mean_absolute_error')

plt.title('Training and validation mean_absolute_error')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')

plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
# Make predictions
train_pred = best_model.predict(xtrain)
test_pred = best_model.predict(xtest)
# Out:
# ...
# 6/6 [==============================] - 0s 2ms/step

# %% [markdown]
# The evaluate_preds function is then used to evaluate the predictions on the test data.

# %%
res2=evaluate_preds(ytest,test_pred)
res2
# Out:
# {'mae': 2.4205716,
#  'mse': 12.798655,
#  'rmse': 2.4205716,
#  'mape': '9.2600355%',
#  'mase': 0.12652512,
#  'r2': 0.95093614}

# %% [markdown]
# To analyze the model's predictions, the code prepares a DataFrame with actual and predicted values, as well as the difference and percentage difference between them. This allows for the comparison and analysis of predictions.

# %%
# Ensure 'ytest' and 'test_pred' are 1D
ytest_1D = tf.squeeze(ytest)
test_pred_1D = tf.squeeze(test_pred)

# Now create the DataFrame
dr = pd.DataFrame({'Actual': ytest_1D, 'Predicted': test_pred_1D})

# Calculate the difference
dr['Difference'] = dr['Predicted'] - dr['Actual']

# Calculate the percentage difference
dr['Percentage Difference'] = (dr['Difference'] / dr['Actual']) * 100

dr = dr.round(2)
dr.head(30)
# Out:
#     Actual  Predicted  Difference  Percentage Difference
# 0    42.42  40.060001       -2.36                  -5.56
# 1    33.06  33.520000        0.46                   1.40
# 2    20.28  21.010000        0.73                   3.58
# 3    31.72  36.160000        4.44                  14.01
# 4    48.59  48.549999       -0.04                  -0.09
# 5    12.46  13.220000        0.76                   6.13
# 6    67.87  71.220001        3.35                   4.93
# 7    22.53  24.740000        2.21                   9.82
# 8    58.61  58.980000        0.37                   0.62
# 9    33.02  34.889999        1.87                   5.67
# 10   24.00  23.950001       -0.05                  -0.19
# 11   26.14  25.809999       -0.33                  -1.24
# 12   39.58  33.000000       -6.58                 -16.61
# 13   59.09  50.320000       -8.77                 -14.84
# 14   10.22  11.060000        0.84                   8.24
# ...

# %% [markdown]
# Then, the code selects the last 200 records from the data and plots the predicted and actual values. This visualization enables a graphical comparison between predicted and actual values.

# %%
# Get last 200 records from your data
y_pred_sub = test_pred[-200:]
y_test_sub = ytest[-200:]

plt.figure(figsize=(10, 5))
plt.plot(range(len(y_pred_sub)), y_pred_sub, label='Predicted')
plt.plot(range(len(y_test_sub)), y_test_sub, label='Actual')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.title("Actual vs Predicted")
plt.show()

# %% [markdown]
# **Compare Models**
#
# The results of different models, including Model_Dense1+Lr, Model_Dense2, and Model_Ensemble, are compared and stored in the model_results DataFrame. The DataFrame is sorted based on the mean absolute error (MAE).

# %%
# Compare different model results
model_results = pd.DataFrame({"Model_Dense1+Lr": res1,
                              "Model_hp": res2,
                             }).T

model_results = model_results.sort_values(by="mae")

model_results.head(10)
# Out:
#                       mae        mse      rmse        mape      mase        r2
# Model_hp         2.420572  12.798655  2.420572  9.2600355%  0.126525  0.950936
# Model_Dense1+Lr   3.22834  19.793867   3.22834  11.692483%  0.168748   0.92412

# %% [markdown]
# The table above compares two machine learning models, "Model_Dense1+Lr" and "Model_hp", using various performance metrics. "Model_Dense1+Lr" is a Dense model optimized for a specific learning rate. "Model_hp" is the same model but further improved through hyperparameter tuning. The hyperparameter-tuned model "Model_hp" outperforms "Model_Dense1+Lr" in every metric. It shows lower error values (MAE, MSE, RMSE, MAPE, MASE), indicating better prediction accuracy and precision, and a higher R2 value, signifying a superior explanation of the variance in the dependent variable (95% versus 92.41%).
#
# These results highlight the significant role of hyperparameter tuning in enhancing model performance. Despite the extra computational resources and time required, the improvements it brings to predictive power justify the investment. This comparison emphasizes the value of comprehensive model optimization, where learning rate adjustment and hyperparameter tuning are combined.

# %% [markdown]
# A bar plot is then created to visualize and compare the MAE values of different models stored in the model_results DataFrame.

# %%
# Sort model results by MAE and plot them
model_results[["mae"]].sort_values(by="mae").plot(figsize=(10, 7), kind="bar");
