# %% [markdown]
# # **Title: LaptopLogic - Predicting Laptop Prices with Regression Analysis**

# %% [markdown]
# ![Screenshot 2023-07-12 151047.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Overview/Introduction:
# This project aims to utilize a comprehensive dataset of laptop specifications and prices to develop a regression model capable of predicting laptop prices accurately. The dataset contains information on various features of laptops, including the brand, processor type, RAM size, storage capacity, operating system, graphics card, weight, warranty, and more. By leveraging this dataset, data scientists, machine learning enthusiasts, and researchers can gain valuable insights into the factors that influence laptop prices and create powerful regression models for price prediction.
#
# ## Problem Statement:
# The price of a laptop is influenced by numerous factors, making it challenging for consumers, manufacturers, and retailers to accurately determine a fair and competitive price. Moreover, with the vast array of laptop models available in the market, understanding the relationship between laptop features and their prices becomes crucial for informed decision-making. Therefore, the problem statement revolves around developing an AI model capable of predicting laptop prices based on their specifications, providing valuable insights to buyers, manufacturers, and retailers alike.
#
# ## Objectives:
# 1. **Price Prediction**: Develop a regression model that accurately predicts the prices of laptops based on their specifications.
# 2. **Feature Importance**: Identify the most influential features that impact laptop prices, allowing consumers and manufacturers to prioritize essential specifications.
# 3. **Market Analysis**: Gain insights into market trends and consumer preferences by analyzing the relationships between laptop features, prices, and customer ratings/reviews.
# 4. **Competitive Pricing**: Assist manufacturers and retailers in setting competitive prices for their laptop models, considering their features, competitors, and target market.
# 5. **Decision Support**: Empower consumers with a tool to make informed purchasing decisions by providing price estimates for laptops with desired specifications.
#
# ## Dataset Description:
# The dataset comprises data on approximately 800 laptops, with each laptop represented by multiple features and its corresponding price. Here is a breakdown of the dataset attributes:
#
# - **Brand**: The company that manufactures the laptop.
# - **Processor Brand**: The brand name of the processor.
# - **Processor Name**: The model or name of the processor.
# - **Processor Generation**: The generation of the processor.
# - **RAM (GB)**: The size of the laptop's RAM (Random Access Memory) in gigabytes.
# - **RAM Type**: The type of RAM used in the laptop.
# - **SSD**: The size of the laptop's solid-state drive.
# - **HDD**: The size of the laptop's hard disk drive.
# - **OS**: The type of operating system installed on the laptop.
# - **OS Bit**: The bit architecture of the operating system.
# - **Graphic Card (GB)**: The size of the laptop's graphics card memory.
# - **Weight**: The weight of the laptop in a standard unit of measurement.
# - **Warranty**: The duration of the laptop's warranty coverage.
# - **Touchscreen**: Indicates whether the laptop has a touchscreen feature or not.
# - **MS Office**: Indicates the presence of Microsoft Office software.
# - **Price**: The price of the laptop in Indian Rupees.
# - **Rating**: The number of ratings received by the laptop.
# - **Number of Reviews**: The number of reviews given by users.
#
# This dataset provides a wealth of information for analyzing the relationships between laptop specifications and prices. By leveraging this data, we can develop an AI model that enhances decision-making in the laptop market, benefiting both consumers and manufacturers.
#
# **Dataset URL:** https://www.kaggle.com/datasets/anubhavgoyal10/laptop-prices-dataset

# %% [markdown]
# # Technologies Used
#
# The following technologies were utilized in this AI project:
#
# - Python: The code is implemented using the Python programming language, a versatile and widely used language for data analysis and machine learning.
# - Pandas: The Pandas library is used for data manipulation and analysis. It provides powerful data structures and data analysis tools.
# - NumPy: NumPy is used for numerical computations and array operations. It provides efficient data structures for handling large datasets.
# - Matplotlib: Matplotlib is a popular plotting library in Python used for creating visualizations, including line plots, scatter plots, and histograms.
# - Seaborn: Seaborn is a data visualization library built on top of Matplotlib. It provides a high-level interface for creating attractive statistical graphics.
# - Scikit-learn: Scikit-learn is a machine learning library in Python that provides various algorithms for regression, classification, and clustering tasks. It also includes utilities for data preprocessing and model evaluation.
# - TensorFlow: TensorFlow is an open-source deep learning framework. It is used for building and training neural network models.
# - Keras: Keras is a high-level API for building neural networks. It is implemented on top of TensorFlow and simplifies the process of designing and training deep learning models.
#
# # Methodology
#
# The AI project follows a systematic methodology to predict laptop prices based on the given dataset:
#
# 1. **Data Loading and Preprocessing**: The dataset, stored in the "laptopPrice.csv" file, is loaded into a Pandas DataFrame. Data cleaning steps are performed to handle missing values and duplicates. The dataset is then examined to understand its structure and characteristics.
#
# 2. **Exploratory Data Analysis**: Descriptive statistics and visualizations are used to gain insights into the dataset. A correlation matrix heatmap is plotted to understand the relationships between different features. The distribution of the target variable, "Price," is visualized to understand its variability.
#
# 3. **Data Preprocessing**: Outliers are removed using the Interquartile Range (IQR) method to ensure data quality. The dataset is split into input features (X) and the target variable (y). Column transformation is applied to normalize numeric features and perform one-hot encoding on categorical features.
#
# 4. **Model Building**: Two neural network models, model_1 and model_dense2, are constructed using TensorFlow and Keras. These models consist of multiple dense layers with ReLU activation functions. The models are compiled with suitable loss functions and optimizers. The learning rate is adjusted during training using learning rate schedules. Early stopping is implemented to prevent overfitting.
#
# 5. **Model Training and Evaluation**: The models are trained using the training data and evaluated using evaluation metrics such as Mean Absolute Error (MAE), Mean Squared Error (MSE), Root Mean Squared Error (RMSE), Mean Absolute Percentage Error (MAPE), Mean Absolute Scaled Error (MASE), and R-squared score. The training progress and learning rate are visualized using plots.
#
# 6. **Model Comparison**: The performance of different models, including model_dense1+Lr and model_dense2, is compared based on evaluation metrics. The results are stored in a DataFrame and sorted based on MAE.
#
# 7. **Machine Learning Models**: Additional machine learning models, including KNeighborsRegressor, LinearRegression, XGBRegressor, and CatBoostRegressor, are applied and evaluated using cross-validation. The models' performance is assessed using the R-squared score.
#
# # Results
#
# The AI project yields the following results for the regression models and machine learning models:
#
# **Neural Network Models:**
#
# 1. Model_Dense2:
#    - Mean Absolute Error (MAE): 8777.64
#    - Mean Squared Error (MSE): 207099584.0
#    - Root Mean Squared Error (RMSE): 8777.64
#    - Mean Absolute Percentage Error (MAPE): 11.79%
#    - Mean Absolute Scaled Error (MASE): 0.283
#    - R-squared Score (R2): 0.747
#
# 2. Model_Dense1+Lr:
#    - Mean Absolute Error (MAE): 9505.37
#    - Mean Squared Error (MSE): 205565904.0
#    - Root Mean Squared Error (RMSE): 9505.37
#    - Mean Absolute Percentage Error (MAPE): 12.68%
#    - Mean Absolute Scaled Error (MASE): 0.307
#    - R-squared Score (R2): 0.749
#
# **Machine Learning Models:**
#
# - KNeighborsRegressor:
#   - R-squared Score (R2): 0.526
#
# - LinearRegression:
#   - R-squared Score (R2): -8.59e+21
#
# - XGBRegressor:
#   - R-squared Score (R2): 0.801
#
# - CatBoostRegressor:
#   - R-squared Score (R2): 0.828
#
# # Discussion/Interpretation of Results
#
# In the analysis of laptop prices based on their features, different models yield varied results. Among Neural Network models, Model_Dense2 outperforms Model_Dense1+Lr across multiple metrics, including MAE, MSE, RMSE, MAPE, and MASE, thereby demonstrating superior accuracy and precision in predicting prices. While both models show similar performance in terms of R-squared scores, Model_Dense1+Lr scores slightly higher, indicating a marginally stronger correlation between predicted and actual prices.
#
# For the Machine Learning models evaluated, CatBoostRegressor exhibits the highest R-squared score, reflecting a strong correlation between predicted and actual prices. The XGBRegressor also performs effectively, demonstrating a robust understanding of the relationship between laptop features and prices. However, KNeighborsRegressor only shows moderate performance, and LinearRegression presents a remarkably low and negative R-squared score, implying that it may not be the best fit for predicting laptop prices due to the task's complexity.
#
# # Summary
#
# In summary, the project successfully develops and evaluates regression models and machine learning models for laptop price prediction. The neural network models, Model_Dense2 and Model_Dense1+Lr, demonstrate good accuracy and precision in estimating laptop prices, with Model_Dense2 performing slightly better. The machine learning models, particularly CatBoostRegressor and XGBRegressor, exhibit strong correlations between predicted and actual prices. However, LinearRegression shows poor performance in this context.
#
# The results provide valuable insights for consumers, manufacturers, and retailers in understanding laptop pricing dynamics. Consumers can utilize the models to estimate laptop prices based on desired specifications, enabling informed purchasing decisions. Manufacturers and retailers can optimize pricing strategies and align prices with market demand. The project also contributes to market analysis by uncovering relationships between laptop features, prices, and customer preferences.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Import series of helper functions for the notebook
# Download helper functions script
# !wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
from helper_functions import unzip_data, create_tensorboard_callback, plot_loss_curves, compare_historys
# Out:
# --2023-07-12 05:46:49--  https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10246 (10K) [text/plain]
# Saving to: ‘helper_functions.py.1’
#
# helper_functions.py 100%[===================>]  10.01K  --.-KB/s    in 0s
#
# 2023-07-12 05:46:49 (57.4 MB/s) - ‘helper_functions.py.1’ saved [10246/10246]

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf

# %% [markdown]
# The following code shows a function called seed_everything() that sets the seed value for random number generators in TensorFlow, NumPy, and Python's random library. This is done to ensure reproducibility of results in future use cases.

# %%
import random

# Seed Everything to reproduce results for future use cases
def seed_everything(seed=42):
    # Seed value for TensorFlow
    tf.random.set_seed(seed)
    # Seed value for NumPy
    np.random.seed(seed)
    # Seed value for Python's random library
    random.seed(seed)

seed_everything()

# %% [markdown]
# The following code shows how to read a dataset from a CSV file and display the first few rows of the data. This is done to understand the structure and content of the dataset.

# %%
# Read in the dataset
df = pd.read_csv("./laptopPrice.csv")
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %% [markdown]
# The next code calculates descriptive statistics for each column of the dataset and transposes the result.

# %%
df.describe().T
# Out:
#                    count          mean           std      min      25%  \
# Price              823.0  76745.177400  45101.790525  16990.0  46095.0
# Number of Ratings  823.0    315.301337   1047.382654      0.0      0.0
# Number of Reviews  823.0     37.609964    121.728017      0.0      0.0
#
#                        50%      75%       max
# Price              64990.0  89636.0  441990.0
# Number of Ratings     17.0    139.5   15279.0
# Number of Reviews      2.0     18.0    1947.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %% [markdown]
# **Duplicates and Null values**
#
# The code block following that provides some exploratory data analysis. It prints the number of data points in the dataset, checks for duplicates, and identifies missing values in the DataFrame. It also replaces empty values with NaN and rechecks the missing values after replacement.

# %%
import numpy as np

# Remove columns

# How many reviews do we have?
print('There are', df.shape[0], 'data in this dataset')

# Do we have duplicates?
print('Number of Duplicates:', len(df[df.duplicated()]))

# Do we have missing values?
missing_values = df.isnull().sum()
print('Number of Missing Values by column:\n',missing_values)

print('Number of Missing Values:', df.isnull().sum().sum())

df.replace("", np.nan, inplace=True)
missing_values = df.isnull().sum()
print('Number of Missing Values by column after replacement:\n',missing_values)
print('Number of Missing Values after replacement:', df.isnull().sum().sum())
# Out:
# There are 823 data in this dataset
# Number of Duplicates: 21
# Number of Missing Values by column:
#  brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64
# Number of Missing Values: 0
# Number of Missing Values by column after replacement:
#  brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# ...

# %% [markdown]
# **Review Duplicates**
#
# Now, we want to identify and display duplicate rows in the dataset. The code finds and sorts all duplicate rows, then shows the top 5 pairs of duplicate rows.

# %%
# First, get all duplicate rows (keep=False ensures all duplicates are kept)
duplicate_rows = df[df.duplicated(keep=False)]

# Then sort the dataframe on all columns to ensure duplicates are adjacent
sorted_duplicates = duplicate_rows.sort_values(by=list(duplicate_rows.columns))

# Now, if we want to see 5 pairs of duplicates (10 rows), we can simply:
top_5_duplicate_pairs = sorted_duplicates.head(20)
top_5_duplicate_pairs
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 619  APPLE              M1             M1            10th  16 GB     DDR4
# 622  APPLE              M1             M1            10th  16 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 610  APPLE              M1             M1            10th   8 GB     DDR4
# 616  APPLE              M1             M1            10th   8 GB     DDR4
# 5     ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 13    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ...

# %% [markdown]
# To remove duplicate rows from the dataset, we can use the next code. It drops the duplicate rows and prints the number of remaining duplicates.

# %%
df = df.drop_duplicates()
print('Number of Duplicates:', len(df[df.duplicated()]))
# Out:
# Number of Duplicates: 0

# %% [markdown]
# **Correlation Matrix**
#
# The code plots a heatmap of the correlation matrix for the dataset, providing insights into the relationships between different features.

# %%
plt.subplots(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, fmt='.2f')
pass

# %% [markdown]
# In the next code, the target variable is defined as "Price".

# %%
target="Price"
target
# Out:
# 'Price'

# %% [markdown]
# To analyze the correlation of a specific target variable, we use the target variable. The code calculates the correlation of target variable with other features and sorts them in descending order.

# %%
# Calculate the correlation matrix
corr_matrix = df.corr(numeric_only=True)

# Get the correlation of 'price' with other features
corr_with_price = corr_matrix[target]

# Sort these correlations in descending order
sorted_correlations = corr_with_price.sort_values(ascending=False)
sorted_correlations
# Out:
# Price                1.000000
# Number of Ratings   -0.152553
# Number of Reviews   -0.156791
# Name: Price, dtype: float64

# %% [markdown]
# The sorted correlations are visualized as a bar plot using the next code. This helps to identify the most positively correlated features with the target variable.

# %%
sorted_correlations.sort_values(ascending=0).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# **EDA**
#
# Next, a distribution plot is created using seaborn to visualize the distribution of the target variable ("Price").

# %%
sns.set(style='whitegrid')
f, ax = plt.subplots(1,1, figsize=(12, 8))
ax = sns.distplot(df[target], kde = True, color = 'c')
plt.title(f'Distribution of {target}')
# Out:
# Text(0.5, 1.0, 'Distribution of Price')

# %%
df[target].describe()
# Out:
# count       802.000000
# mean      76625.543641
# std       45232.984422
# min       16990.000000
# 25%       45990.000000
# 50%       63990.000000
# 75%       89525.000000
# max      441990.000000
# Name: Price, dtype: float64

# %% [markdown]
# **Handling Outliers**

# %% [markdown]
# > **Interquartile Range Method**
#
#
# The Interquartile Range (IQR) is a statistical measure used to calculate data variability and visualize it through boxplot graphs. Simply put, the IQR divides a dataset into four distinct intervals, known as quartiles, based on their comparative values.
#
# The quartiles themselves are points that split the data into four equal parts. IQR is determined by subtracting the first quartile (Q1) from the third quartile (Q3). So, IQR = Q3 - Q1.
#
# Outliers are data points that lie outside the typical range of the data set. They are specifically defined as observations falling below the lower whisker of the boxplot, calculated as (Q1 - 1.5x IQR), or above the upper whisker, calculated as (Q3 + 1.5x IQR). These outliers can be easily identified in a boxplot, which provides a visual representation of data dispersion and variability.

# %% [markdown]
# Now, we will define a function called remove_outliers that takes a DataFrame and a column name as input. This function removes outliers from the specified column using the interquartile range (IQR) method. Removing outliers helps to ensure that extreme values do not skew the analysis or modeling.

# %%
def remove_outliers(df, column):
    percentile25 = df[column].quantile(0.25)
    percentile75 = df[column].quantile(0.75)
    iqr = percentile75-percentile25
    upper_limit = percentile75 + 1.5 * iqr
    lower_limit = percentile25 - 1.5 * iqr
    df = df[(df[column] < upper_limit) & (df[column] > lower_limit)]
    return df

# %% [markdown]
# The following code applies the remove_outliers function to the 'Price' column of the DataFrame, effectively removing any outliers from the dataset.

# %%
df = remove_outliers(df, 'Price')

# %% [markdown]
# **Evaluation Metrics**
#
# The next code block defines two utility functions: mean_absolute_scaled_error() and evaluate_preds(). The mean_absolute_scaled_error() function calculates the Mean Absolute Scaled Error (MASE), assuming no seasonality of the data. The evaluate_preds() function calculates various metrics, including MAE, MSE, RMSE, MAPE, MASE, and R-squared score, for evaluating the predictions.

# %%
# MASE implemented courtesy of sktime - https://github.com/alan-turing-institute/sktime/blob/ee7a06843a44f4aaec7582d847e36073a9ab0566/sktime/performance_metrics/forecasting/_functions.py#L16
def mean_absolute_scaled_error(y_true, y_pred):
  """
  Implement MASE (assuming no seasonality of data).
  """
  mae = tf.reduce_mean(tf.abs(y_true - y_pred))

  # Find MAE of naive forecast (no seasonality)
  mae_naive_no_season = tf.reduce_mean(tf.abs(y_true[1:] - y_true[:-1])) # our seasonality is 1 day (hence the shifting of 1 day)

  return mae / mae_naive_no_season

def evaluate_preds(y_true, y_pred):
    # Make sure float32 (for metric calculations)
    y_true = tf.cast(y_true, dtype=tf.float32)
    y_pred = tf.cast(y_pred, dtype=tf.float32)

    # Calculate various metrics
    mae = tf.keras.metrics.mean_absolute_error(y_true, y_pred)
    mse = tf.keras.metrics.mean_squared_error(y_true, y_pred)
    rmse = tf.sqrt(mse)
    mape = tf.keras.metrics.mean_absolute_percentage_error(y_true, y_pred)
    mase = mean_absolute_scaled_error(y_true, y_pred)

    # Calculate R-squared score
    ss_res = tf.reduce_sum((y_true - y_pred)**2)
    ss_tot = tf.reduce_sum((y_true - tf.reduce_mean(y_true))**2)
    r2 = 1 - (ss_res / ss_tot)

    # Account for different sized metrics
    if mae.ndim > 0:
        mae = tf.reduce_mean(mae)
        mse = tf.reduce_mean(mse)
        rmse = tf.reduce_mean(rmse)
        mape = tf.reduce_mean(mape)
        mase = tf.reduce_mean(mase)
        r2 = tf.reduce_mean(r2)

    return {"mae": mae.numpy(),
            "mse": mse.numpy(),
            "rmse": rmse.numpy(),
            "mape": str(mape.numpy()) + "%",
            "mase": mase.numpy(),
            "r2": r2.numpy()}

# %%
len(df)
# Out:
# 753

# %% [markdown]
# **Define Features and Labels**
#
# We split the dataset into input features (X) and the target variable (y) using the next code.

# %%
X=df.drop([target],axis=1)
y=df[[target]]
X,y
# Out:
# (      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
#  0      ASUS           Intel        Core i3            10th   4 GB     DDR4
#  1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
#  2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
#  3      ASUS           Intel        Core i5            10th   8 GB     DDR4
#  4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#  ..      ...             ...            ...             ...    ...      ...
#  818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
#  819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
#  820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
#  821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
#  822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %% [markdown]
# **Train-Test Split**
#
# The train_test_split function from scikit-learn is used to split the dataset into training and testing sets, with 80% of the data used for training and 20% for testing.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %% [markdown]
# The code identifies and prints the list of numerical and categorical columns in the dataset.

# %%
# Get list of numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Remove 'price' from num_cols
num_cols.remove(target)

# Get list of categorical columns
cat_cols = df.select_dtypes(include=['object']).columns.tolist()

# Print the numerical columns
print("Numerical columns are:", num_cols)

# Print the categorical columns
print("Categorical columns are:", cat_cols)
# Out:
# Numerical columns are: ['Number of Ratings', 'Number of Reviews']
# Categorical columns are: ['brand', 'processor_brand', 'processor_name', 'processor_gnrtn', 'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb', 'weight', 'warranty', 'Touchscreen', 'msoffice', 'rating']

# %% [markdown]
# Next, a column transformer is created using the make_column_transformer function. This transformer applies specific preprocessing steps to different columns of the dataset. In this case, it uses MinMaxScaler to normalize numerical columns and OneHotEncoder to perform one-hot encoding on categorical columns.

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# creating column transformer
ct = make_column_transformer((MinMaxScaler(), num_cols),
                             (OneHotEncoder(handle_unknown = 'ignore'), cat_cols))

# %% [markdown]
# The column transformer is then fitted on the training data, learning the scaling and encoding parameters. After fitting the column transformer, the training and test data are transformed using the learned transformations.

# %%
# fitting column transformer on training data
ct.fit(X_train)

# transforming training and test data with normalizing (MinMaxScaler) and one hot encoding (OneHotEncoder)
X_train = ct.transform(X_train)
X_test = ct.transform(X_test)

# %%
X_train
# Out:
# <602x75 sparse matrix of type '<class 'numpy.float64'>'
# 	with 10458 stored elements in Compressed Sparse Row format>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Bidirectional, LSTM, Dropout, Dense, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

# %% [markdown]
# The next two lines convert the transformed training and test data to arrays and the target variables to arrays as well. This conversion is done to ensure compatibility with the TensorFlow machine learning framework.

# %%
X_train=X_train.toarray()
X_test=X_test.toarray()

y_train=y_train.values
y_test=y_test.values

# %% [markdown]
# Now, we set a random seed to ensure reproducibility of the results. The model is defined as a sequential neural network using the Keras API. It consists of three dense layers with ReLU activation functions and a dropout layer to prevent overfitting.

# %%
# Set random seed
tf.random.set_seed(42)

# Define the model
model_1 = tf.keras.Sequential([
  tf.keras.layers.Dense(512, activation="relu", kernel_regularizer=regularizers.l2(0.01)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=regularizers.l2(0.01)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(1)
])

# %% [markdown]
# The optimizer is defined as Adam, a popular optimization algorithm used in deep learning.
# The model is compiled with the mean squared error (MSE) loss function and mean absolute error (MAE) as the evaluation metric.
#
# A learning rate schedule is defined using a learning rate scheduler callback. This schedule adjusts the learning rate during training based on the epoch number.
#
# The model is then trained using the fit method, providing the training data, target variables, and other training parameters. The validation data is used to monitor the model's performance on unseen data during training.

# %%
# Define the optimizer
optimizer = tf.keras.optimizers.Adam()

# Compile the model
model_1.compile(loss="mean_squared_error",
                optimizer=optimizer,
                metrics=["mean_absolute_error"])

# Define the learning rate schedule
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-6 * 10**(-epoch / 20))

# Fit the model
history = model_1.fit(X_train,
                      y_train,
                      epochs=100,
                      batch_size=32,
                      validation_data=(X_test, y_test),
                      callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 19/19 [==============================] - 4s 47ms/step - loss: 5441514496.0000 - mean_absolute_error: 67907.3359 - val_loss: 5657228288.0000 - val_mean_absolute_error: 69550.8047 - lr: 1.0000e-06
# Epoch 2/100
# 19/19 [==============================] - 0s 15ms/step - loss: 5441515520.0000 - mean_absolute_error: 67907.3438 - val_loss: 5657227264.0000 - val_mean_absolute_error: 69550.8047 - lr: 8.9125e-07
# Epoch 3/100
# 19/19 [==============================] - 0s 13ms/step - loss: 5441515520.0000 - mean_absolute_error: 67907.3359 - val_loss: 5657226240.0000 - val_mean_absolute_error: 69550.7969 - lr: 7.9433e-07
# Epoch 4/100
# 19/19 [==============================] - 0s 15ms/step - loss: 5441513984.0000 - mean_absolute_error: 67907.3203 - val_loss: 5657225216.0000 - val_mean_absolute_error: 69550.7969 - lr: 7.0795e-07
# Epoch 5/100
# ...

# %% [markdown]
# After training the model, the learning rate versus the loss is plotted to visualize the relationship between the learning rate and the model's performance. This plot helps in selecting an appropriate learning rate for training.

# %%
# Plot the learning rate versus the loss
lrs = 1e-6 * (10 ** (np.arange(100)/20))
plt.figure(figsize=(10, 7))
plt.semilogx(lrs, history.history["loss"]) # we want the x-axis (learning rate) to be log scale
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Learning rate vs. loss");

# %% [markdown]
# The next code block resets the states generated by Keras. This ensures a clean start for subsequent model evaluations or training runs.
#
# A learning rate (lrx) is defined for further training optimization. This value is used to adjust the learning rate of the optimizer

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

lrx=1e-3
lrx
# Out:
# 0.001

# %% [markdown]
# The Early Stopping and Model Checkpoint callbacks are imported from Keras. The Early Stopping callback stops the training process if the validation loss does not improve for a certain number of epochs, helping to prevent overfitting. The Model Checkpoint callback saves the best model during training based on the validation loss.
#
# The optimizer is redefined with the specified learning rate (lrx). The model is compiled again with the updated optimizer and loss function. The model is trained again, this time with additional callbacks (Early Stopping and Model Checkpoint) to monitor the training process and save the best model.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
ES=EarlyStopping(patience=150, restore_best_weights=True),

# Define the optimizer
optimizer = tf.keras.optimizers.Adam(lr=lrx)

# Compile the model
model_1.compile(loss="mean_squared_error",
                optimizer=optimizer,
                metrics=["mean_absolute_error"])

# Fit the model
history = model_1.fit(X_train,
                      y_train,
                      epochs=300,
                      batch_size=32,
                      validation_data=(X_test, y_test),
                      callbacks=[ES,checkpoint])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/300
# 12/19 [=================>............] - ETA: 0s - loss: 5518433280.0000 - mean_absolute_error: 68232.6328
# Epoch 1: val_loss improved from inf to 5655007744.00000, saving model to best_model.h5
# 19/19 [==============================] - 1s 20ms/step - loss: 5440784896.0000 - mean_absolute_error: 67901.9297 - val_loss: 5655007744.0000 - val_mean_absolute_error: 69534.7734
# Epoch 2/300
#  8/19 [===========>..................] - ETA: 0s - loss: 5500677120.0000 - mean_absolute_error: 68181.0000
# Epoch 2: val_loss improved from 5655007744.00000 to 5644625408.00000, saving model to best_model.h5
# 19/19 [==============================] - 0s 10ms/step - loss: 5435673088.0000 - mean_absolute_error: 67864.1250 - val_loss: 5644625408.0000 - val_mean_absolute_error: 69459.7109
# Epoch 3/300
# ...

# %% [markdown]
# A function called plot_losses is defined to plot the loss curves from the training history.

# %%
def plot_losses(history):
    losses = pd.DataFrame(history.history)
    losses.plot()

# %% [markdown]
# The plot_losses function is then called to plot the losses from the training history.

# %%
plot_losses(history)

# %% [markdown]
# The load_model function is imported from Keras to load the best saved model from the previous training run.

# %%
from tensorflow.keras.models import load_model

# Load the best saved model
model_1 = load_model('best_model.h5')

# %% [markdown]
# The loaded model is evaluated on the test data to assess its performance.

# %%
model_1.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 5ms/step - loss: 205566208.0000 - mean_absolute_error: 9505.3672
# [205566208.0, 9505.3671875]

# %%
# Make predictions
train_pred = model_1.predict(X_train)
test_pred = model_1.predict(X_test)
# Out:
# ...
# 5/5 [==============================] - 0s 3ms/step

# %% [markdown]
# The evaluate_preds function is called with the true test target values and the predicted test values to calculate evaluation metrics. The result is stored in the variable res1.

# %%
res1=evaluate_preds(y_test,test_pred)
res1
# Out:
# {'mae': 9505.367,
#  'mse': 205565900.0,
#  'rmse': 9505.367,
#  'mape': '12.681346%',
#  'mase': 0.30680093,
#  'r2': 0.7492837}

# %% [markdown]
# **Prediction Visualization**

# %% [markdown]
# **Residuals plot**
#
# Residual analysis is performed by plotting the predicted values against the residuals (difference between predicted and actual values) for both the train and test data.

# %%
plt.figure(figsize=(10,6))
plt.scatter(train_pred, train_pred - y_train, c='black', marker='o', s=35, alpha=0.5, label='Train data')
plt.scatter(test_pred, test_pred - y_test, c='c', marker='o', s=35, alpha=0.7, label='Test data')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.legend(loc='upper left')
plt.hlines(y=0, xmin=-10, xmax=50, lw=2, color='red')
plt.show()

# %% [markdown]
# **Checking for linearity: Actual vs Predicted values**
#
# A scatter plot is created to visualize the linearity between the actual and predicted values.

# %%
plt.figure(figsize=(14,5))
plt.scatter(y_test, test_pred, color='r')
plt.title('Check for Linearity:\n Actual vs Predicted values')
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.show()

# %% [markdown]
# To analyze the model's predictions, the code prepares a DataFrame with actual and predicted values, as well as the difference and percentage difference between them. This allows for the comparison and analysis of predictions.

# %%
# Ensure 'y_test' and 'test_pred' are 1D
ytest_1D = tf.squeeze(y_test)
test_pred_1D = tf.squeeze(test_pred)

# Now create the DataFrame
dr = pd.DataFrame({'Actual': ytest_1D, 'Predicted': test_pred_1D})

# Calculate the difference
dr['Difference'] = dr['Predicted'] - dr['Actual']

# Calculate the percentage difference
dr['Percentage Difference'] = (dr['Difference'] / dr['Actual']) * 100

dr = dr.round(2)
dr.head(30)
# Out:
#     Actual      Predicted  Difference  Percentage Difference
# 0    95990   83980.406250   -12009.59                 -12.51
# 1    49990   49023.089844     -966.91                  -1.93
# 2    86990   68894.617188   -18095.38                 -20.80
# 3    39990   40283.281250      293.28                   0.73
# 4    53990   64844.640625    10854.64                  20.10
# 5    34990   40789.621094     5799.62                  16.58
# 6    25990   30738.259766     4748.26                  18.27
# 7    59990   60684.039062      694.04                   1.16
# 8    64990   63703.621094    -1286.38                  -1.98
# 9    60990   67070.101562     6080.10                   9.97
# 10  129990   93976.609375   -36013.39                 -27.70
# 11   81490   74405.281250    -7084.72                  -8.69
# 12   79990   85516.203125     5526.20                   6.91
# 13   99990   84917.898438   -15072.10                 -15.07
# ...

# %% [markdown]
# Then, the code selects the last 200 records from the data and plots the predicted and actual values. This visualization enables a graphical comparison between predicted and actual values.

# %%
# Get last 150 records from your data
y_pred_sub = test_pred[-200:]
y_test_sub = y_test[-200:]

plt.figure(figsize=(10, 5))
plt.plot(range(len(y_pred_sub)), y_pred_sub, label='Predicted')
plt.plot(range(len(y_test_sub)), y_test_sub, label='Actual')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.title("Actual vs Predicted")
plt.show()

# %% [markdown]
# **Model: Dense2**
#
# A new neural network model called model_dense2 is defined using the TensorFlow Keras Sequential API. It consists of multiple dense layers with ReLU activation. The model is compiled with the mean absolute error (MAE) loss function and the RMSprop optimizer with a specific learning rate. MAE is chosen as the loss function because it provides a more robust measure of error compared to MSE in the presence of outliers. The model is trained on the training data for a specified number of epochs, with validation performed on the test data. The cc callback is passed to the callbacks parameter to save the best model based on the validation loss.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

cc = ModelCheckpoint('best_model_dense2.h5',
                             monitor='val_loss',
                             mode='min',
                             save_best_only=True,
                             verbose=1)

# %%
# Set random seed
tf.random.set_seed(42)

# Build the model
model_dense2 = tf.keras.Sequential([
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(1)
])

# Compile the model
model_dense2.compile(loss=tf.keras.losses.mae,
                    optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),
                    metrics=['mae'])

# Fit the model
model_dense2.fit(X_train, y_train, epochs=1000, validation_data=(X_test, y_test), verbose=1, callbacks=[cc])
# Out:
# Epoch 1/1000
# 14/19 [=====================>........] - ETA: 0s - loss: 67779.7031 - mae: 67779.7031
# Epoch 1: val_loss improved from inf to 68235.46875, saving model to best_model_dense2.h5
# 19/19 [==============================] - 1s 22ms/step - loss: 67651.2422 - mae: 67651.2422 - val_loss: 68235.4688 - val_mae: 68235.4688
# Epoch 2/1000
# 17/19 [=========================>....] - ETA: 0s - loss: 62581.4922 - mae: 62581.4922
# Epoch 2: val_loss improved from 68235.46875 to 56203.96094, saving model to best_model_dense2.h5
# 19/19 [==============================] - 0s 10ms/step - loss: 62421.9922 - mae: 62421.9922 - val_loss: 56203.9609 - val_mae: 56203.9609
# Epoch 3/1000
# 19/19 [==============================] - ETA: 0s - loss: 40767.2461 - mae: 40767.2461
# Epoch 3: val_loss improved from 56203.96094 to 26431.42383, saving model to best_model_dense2.h5
# ...

# %% [markdown]
# The code block loads the best saved model from the file "best_model_dense2.h5" using the load_model() function.

# %%
from tensorflow.keras.models import load_model

# Load the best saved model
model_dense2 = load_model('best_model_dense2.h5')

# %% [markdown]
# The model is evaluated on the test data using the evaluate() method, and the results are printed.

# %%
model_dense2.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 6ms/step - loss: 8777.6416 - mae: 8777.6416
# [8777.6416015625, 8777.6416015625]

# %%
# Make predictions
train_pred = model_dense2.predict(X_train)
test_pred = model_dense2.predict(X_test)
# Out:
# ...
# 5/5 [==============================] - 0s 3ms/step

# %% [markdown]
# The evaluate_preds() function is used to evaluate the predictions of the model on the test data, and the results are stored in the res2 variable.

# %%
res2=evaluate_preds(y_test,test_pred)
res2
# Out:
# {'mae': 8777.641,
#  'mse': 207099580.0,
#  'rmse': 8777.641,
#  'mape': '11.787648%',
#  'mase': 0.28331238,
#  'r2': 0.74741316}

# %% [markdown]
# The code block ensures that the target variable y_test and the corresponding predicted values test_pred are 1-dimensional arrays. A DataFrame is created to compare the actual and predicted values, as well as the difference and percentage difference between them. The DataFrame is rounded to two decimal places.

# %%
# Ensure 'y_test' and 'test_pred' are 1D
y_test_1D = tf.squeeze(y_test)
test_pred_1D = tf.squeeze(test_pred)

# Now create the DataFrame
df = pd.DataFrame({'Actual': y_test_1D, 'Predicted': test_pred_1D})

# Calculate the difference
df['Difference'] = df['Predicted'] - df['Actual']

# Calculate the percentage difference
df['Percentage Difference'] = (df['Difference'] / df['Actual']) * 100

df = df.round(2)
df.head(30)
# Out:
#     Actual      Predicted  Difference  Percentage Difference
# 0    95990   77943.039062   -18046.95                 -18.80
# 1    49990   62390.539062    12400.54                  24.81
# 2    86990   80139.062500    -6850.94                  -7.88
# 3    39990   41690.789062     1700.79                   4.25
# 4    53990   58511.718750     4521.72                   8.38
# 5    34990   40294.390625     5304.39                  15.16
# 6    25990   28694.929688     2704.93                  10.41
# 7    59990   57023.671875    -2966.33                  -4.94
# 8    64990   64095.160156     -894.84                  -1.38
# 9    60990   69281.507812     8291.51                  13.59
# 10  129990   95955.593750   -34034.41                 -26.18
# 11   81490   68338.343750   -13151.66                 -16.14
# 12   79990   81540.828125     1550.83                   1.94
# 13   99990   94016.882812    -5973.12                  -5.97
# ...

# %% [markdown]
# The last 200 records of the predicted and actual values are plotted to visualize the model's performance over time.

# %%
# Get last 150 records from your data
y_pred_sub = test_pred[-200:]
y_test_sub = y_test[-200:]

plt.figure(figsize=(10, 5))
plt.plot(range(len(y_pred_sub)), y_pred_sub, label='Predicted')
plt.plot(range(len(y_test_sub)), y_test_sub, label='Actual')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.title("Actual vs Predicted")
plt.show()

# %% [markdown]
# The plot_predictions() function is defined to plot the input data against the actual output values in blue and the predictions in red. This can help visualize how well the model's predictions align with the actual values. The function is then used to plot the predictions and actual values for the test data using the model_dense2 model.

# %%
def plot_predictions(model, X_test, y_test):
    plt.figure(figsize=(10, 7))
    # Plot input data vs actual output in blue
    y_test = tf.squeeze(y_test)

    plt.scatter(X_test[:, 0], y_test, c="b", label="Actual")  # change here
    # Calculate and plot predictions in red
    predictions = model.predict(X_test)
    predictions = tf.squeeze(predictions)
    plt.scatter(X_test[:, 0], predictions, c="r", label="Predictions")  # change here
    # Show the legend
    plt.legend()

# Plot predictions and actual values for the new x values
plot_predictions(model_dense2, X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %% [markdown]
# **Compare Models**
#
# The results of different models, including Model_Dense1+Lr, Model_Dense2, and Model_Ensemble, are compared and stored in the model_results DataFrame. The DataFrame is sorted based on the mean absolute error (MAE).

# %%
# Compare different model results
model_results = pd.DataFrame({"Model_Dense1+Lr": res1,
                              "Model_Dense2": res2,
                             }).T

model_results = model_results.sort_values(by="mae")

model_results.head(10)
# Out:
#                          mae          mse         rmse        mape      mase  \
# Model_Dense2     8777.640625  207099584.0  8777.640625  11.787648%  0.283312
# Model_Dense1+Lr  9505.367188  205565904.0  9505.367188  12.681346%  0.306801
#
#                        r2
# Model_Dense2     0.747413
# Model_Dense1+Lr  0.749284

# %% [markdown]
# The results of two models, Model_Dense2 and Model_Dense1+Lr, are compared in terms of various evaluation metrics. Model_Dense2 achieved a mean absolute error (MAE) of 8777.64, a mean squared error (MSE) of 207099584.0, a root mean squared error (RMSE) of 8777.64, a mean absolute percentage error (MAPE) of 11.79%, a mean absolute scaled error (MASE) of 0.283312, and an R-squared (r2) value of 0.747413. On the other hand, Model_Dense1+Lr resulted in a slightly higher MAE of 9505.37, a slightly lower MSE of 205565904.0, the same RMSE of 9505.37, a higher MAPE of 12.68%, a higher MASE of 0.306801, but a slightly higher r2 value of 0.749284. Overall, both models perform similarly, but Model_Dense2 tends to have slightly better MAE, MAPE, MASE, and RMSE scores, while Model_Dense1+Lr has a slightly higher r2 value.

# %% [markdown]
# A bar plot is created to visualize and compare the MAE values of different models stored in the model_results DataFrame.

# %%
# Sort model results by MAE and plot them
model_results[["mae"]].sort_values(by="mae").plot(figsize=(10, 7), kind="bar");

# %% [markdown]
# **Machine Learning Models**

# %% [markdown]
# The code block creates a DataFrame (X_df) from the training data (X_train) and performs label encoding for categorical columns. This is done to convert categorical variables into numeric format so that they can be used as input for certain models that require numerical data.

# %%
X_df = pd.DataFrame(X_train)

# Now you can use `select_dtypes`:
for colname in X_df.select_dtypes(["category"]):
    X_df[colname] = X_df[colname].cat.codes

# %% [markdown]
# The code block imports various regressor models from scikit-learn and creates a dictionary (models) to store the models.

# %%
# !pip install catboost
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 9.3 MB/s eta 0:00:00
# ...

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

models = {}

models["KNeighborsRegressor"] = {"model": KNeighborsRegressor(n_neighbors=50)}
models["LinearRegression"] = {"model": LinearRegression()}
models["XGBRegressor"] = {"model": XGBRegressor(n_jobs=5, learning_rate=0.1, max_depth=10, random_state=1)}
models["CatBoostRegressor"]={"model":CatBoostRegressor(logging_level ='Silent',iterations=500,random_state=1)}

# %% [markdown]
# The score_dataset() function is defined to evaluate a model's performance using cross-validation and return the R-squared score. The function converts categorical variables to numeric codes before scoring.

# %%
def score_dataset(X, y, model=XGBRegressor()):
    for colname in X.select_dtypes(["category"]):
        X[colname] = X[colname].cat.codes

    score_r2 = cross_val_score(model, X, y, cv=5, scoring="r2")
    score_r2 = score_r2.mean()

    return score_r2

# %% [markdown]
# The get_scores() function is defined to iterate over the models in the models dictionary, fit each model on the training data, and evaluate its performance using the score_dataset() function.

# %%
from sklearn.model_selection import cross_val_score
def get_scores(models,xtrain,ytrain):
    for name,model in models.items():
        model["model"].fit(xtrain,ytrain)

        score_r2 = score_dataset(xtrain, ytrain, model=model["model"])
        score = {'model':"Linear regression", 'score_r2':score_r2}
        print("--- "+name+" ---")
        print("Score r2: {}".format(score_r2))
        print("\n")

# %% [markdown]
# The get_scores() function is called to evaluate and print the R-squared scores of the models.

# %%
get_scores(models,X_df,y_train)
# Out:
# --- KNeighborsRegressor ---
# Score r2: 0.5257725849978379
#
#
# --- LinearRegression ---
# Score r2: -8.591634835120553e+21
#
#
# --- XGBRegressor ---
# Score r2: 0.800945932308502
#
#
# --- CatBoostRegressor ---
# Score r2: 0.827833045852435

# %% [markdown]
# The results of four different regression models, KNeighborsRegressor, LinearRegression, XGBRegressor, and CatBoostRegressor, are compared based on the R-squared (r2) score. The KNeighborsRegressor model achieved an r2 score of 0.5258, indicating moderate predictive performance. In contrast, the LinearRegression model obtained an extremely low and negative r2 score of -8.5916e+21, suggesting a poor fit for the data. The XGBRegressor model performed better with an r2 score of 0.8009, indicating a good level of prediction. The CatBoostRegressor model had the highest r2 score of 0.8278, implying a strong predictive capability. Overall, the CatBoostRegressor model demonstrated the best performance, followed by the XGBRegressor model, while the KNeighborsRegressor model had a moderate performance and the LinearRegression model performed poorly.
