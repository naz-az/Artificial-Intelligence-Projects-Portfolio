# %% [markdown]
# # **Title: JewelQuest - Exploring the Diamond Prices and Attributes using Regression**

# %% [markdown]
# ![Screenshot 2023-07-13 125347.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Overview/Introduction
#
# Welcome to the Diamonds Prices project! In this AI project, we will delve into a fascinating dataset that contains prices and attributes for approximately 54,000 round-cut diamonds. Diamonds have long been associated with beauty, luxury, and elegance. Understanding the factors that influence their prices can be of great value to various stakeholders, including diamond sellers, buyers, and enthusiasts.
#
# By exploring this dataset, we aim to uncover valuable insights and patterns that can help us better understand diamond pricing dynamics. Leveraging the power of artificial intelligence and data analysis techniques, this project offers an exciting opportunity to gain in-depth knowledge about the characteristics that drive diamond prices.
#
# ## Problem Statement
#
# The diamond industry is inherently complex, with numerous factors contributing to the pricing of diamonds. Traditionally, diamond evaluation has relied on the expertise of gemologists and subjective assessments. However, this approach can be time-consuming, expensive, and prone to human error.
#
# The problem we aim to address with this AI project is the need for an accurate and efficient diamond pricing system. By leveraging machine learning algorithms and predictive modeling techniques, we can develop a reliable pricing model based on objective features and attributes of diamonds. This model can assist jewelers, diamond traders, and customers in making informed decisions and transactions.
#
# ## Objectives
#
# The primary objectives of this project are as follows:
#
# 1. **Data Exploration**: Conduct a comprehensive analysis of the diamonds dataset, uncovering insights, trends, and relationships between various attributes and their impact on diamond prices.
#
# 2. **Feature Engineering**: Extract meaningful features from the dataset that capture the essential characteristics of diamonds and their potential influence on pricing.
#
# 3. **Machine Learning Modeling**: Develop and train a predictive model using machine learning algorithms to accurately estimate diamond prices based on their attributes.
#
# 4. **Model Evaluation**: Assess the performance of the trained model by measuring its accuracy, precision, and recall. Identify areas for improvement and fine-tuning.
#
# 5. **Deployment and Application**: Deploy the trained model as a practical tool that can be used to predict diamond prices. Demonstrate its value in real-world scenarios, such as assisting jewelers in pricing their inventory or helping customers make informed purchasing decisions.
#
# By achieving these objectives, this AI project will contribute to a more transparent, efficient, and objective approach to diamond pricing, benefiting various stakeholders in the diamond industry.
#
# ## Dataset Description
#
# The Diamonds Prices dataset comprises 53,940 round-cut diamonds, each associated with ten distinct features. These features include carat (diamond weight), cut (quality of the cut), color (diamond color grade), clarity (diamond clarity grade), depth (total depth percentage), table (width of top facet relative to the widest point), price (diamond price in currency), and the diamond measurements x (length), y (width), and z (depth) in millimeters.
#
# The price column represents the diamond price in the currency indicated (USD). The columns x, y, and z denote specific measurements of the diamonds, providing valuable physical dimensions for further analysis.
#
#
# **Acknowledgments:**
# We extend our gratitude to the authors of this dataset for their contribution. The dataset is published under the CC BY 4.0 license and is made available for reuse, including in Google Research datasets.
#
# **Dataset URL:** https://www.kaggle.com/datasets/nancyalaswad90/diamonds-prices

# %% [markdown]
# ## Technologies Used
#
# 1. **Python**: The code is written in the Python programming language, which provides a rich ecosystem of libraries and tools for data analysis and machine learning.
#
# 2. **Pandas**: Pandas is a powerful library used for data manipulation and analysis. It is employed to read the dataset from a CSV file, handle missing values, and perform exploratory data analysis.
#
# 3. **NumPy**: NumPy is a fundamental library for numerical computations in Python. It is used to handle numerical operations and perform calculations on the dataset.
#
# 4. **Matplotlib and Seaborn**: These libraries are used for data visualization. Matplotlib is a versatile plotting library, while Seaborn provides high-level interfaces for creating informative and visually appealing statistical graphics.
#
# 5. **Scikit-learn**: Scikit-learn is a popular machine learning library that provides various tools and algorithms for data preprocessing, model training, and evaluation. It is used in this code for preprocessing data, splitting the dataset, and scaling features.
#
# 6. **TensorFlow and Keras**: TensorFlow is an open-source deep learning framework, and Keras is a user-friendly API built on top of TensorFlow. They are utilized for building, training, and evaluating neural network models for diamond price prediction.
#
# 7. **Keras Tuner**: Keras Tuner is a library used for hyperparameter tuning. It facilitates the automated search for optimal hyperparameters in the neural network model.
#
# ## Methodology
#
# The code follows a structured methodology to explore the diamonds dataset, preprocess the data, build a neural network model, and tune the hyperparameters. The key steps involved are:
#
# 1. **Data Loading and Exploration**: The code reads the diamonds dataset from a CSV file and performs initial exploratory data analysis. It checks the number of data points, identifies duplicates, and examines missing values in the dataset.
#
# 2. **Correlation Matrix**: A correlation matrix is generated using a heatmap visualization to understand the relationships between different features in the dataset. This helps identify potential correlations with diamond prices.
#
# 3. **EDA (Exploratory Data Analysis)**: Exploratory data analysis techniques are applied to gain insights into the distribution of the diamond prices. A distribution plot is created to visualize the distribution of prices.
#
# 4. **Handling Outliers**: The code selects numerical features from the dataset and creates boxplots to visualize their distributions. Outliers are detected using a defined function, and the corresponding indices are collected. The outliers are removed from the dataset for further analysis.
#
# 5. **Data Preprocessing**: The dataset is split into input features (X) and target variable (y). The input features are normalized using MinMaxScaler and categorical features are one-hot encoded using OneHotEncoder. The preprocessed data is then split into training and testing sets.
#
# 6. **Model Building**: A neural network model is constructed using the TensorFlow and Keras libraries. The model architecture consists of multiple dense layers with dropout regularization. The model is compiled with an optimizer, loss function, and metrics for evaluation.
#
# 7. **Model Training and Evaluation**: The model is trained on the training set and evaluated on the testing set. The learning rate schedule is defined to optimize the learning process. The training history is visualized to analyze the learning progress and determine the optimal learning rate.
#
# 8. **Hyperparameter Tuning**: A hyperparameter tuning process is performed using the Keras Tuner library. A function is defined to build a neural network model with customizable hyperparameters. Random Search is conducted to find the best hyperparameters for the model.
#
# 9. **Model Evaluation with Tuned Hyperparameters**: The model with the best hyperparameters obtained from the tuning process is compiled and trained again. The model's performance is evaluated on the testing set, and the validation loss (MSE) and mean absolute error (MAE) are calculated and displayed.
#
#
# ## Results
#
# The code provides insightful results for evaluating the model's performance before and after hyperparameter tuning. Key results include:
#
# **Before Hyperparameter Tuning:**
# - Mean Absolute Error (MAE): 228.0766
# - Mean Squared Error (MSE): 154,207.06
#
# **After Hyperparameter Tuning:**
# - Validation loss (MSE): 128,453.68
# - Validation MAE: 204.46
#
# The hyperparameter tuning process significantly improves the model's performance, leading to a reduction in both MSE and MAE. The lower MSE and MAE values indicate improved accuracy and better prediction capabilities of the model.
#
# ## Discussion/Interpretation of Results
#
# The performance improvement achieved through hyperparameter tuning emphasizes the importance of selecting optimal hyperparameters. Fine-tuning the model's architecture and other parameters enhances its ability to capture complex patterns and make accurate predictions.
#
# The reduced MSE and MAE values demonstrate the model's improved ability to estimate diamond prices. This contributes to better decision-making and pricing strategies in the diamond industry. The achieved MAE value of 204.46 indicates the model's average prediction deviation from actual diamond prices. This level of accuracy is satisfactory considering the inherent complexities in diamond pricing.
#
#
#
# ## Conclusion
#
# In conclusion, the AI project on diamond price prediction shows promising results. Through data exploration, preprocessing, model building, and hyperparameter tuning, significant improvements in performance are achieved.
#
# By applying AI and machine learning to diamond pricing, transparency, efficiency, and objectivity are enhanced. The trained model serves as a valuable tool for diamond stakeholders, providing reliable price estimations.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/diamonds-prices/Diamonds Prices2022.csv

# %%
# Import required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# The following code shows a function seed_everything() that sets the seed values for random number generators in TensorFlow, NumPy, and Python's random library, ensuring reproducibility of results for future use cases.

# %%
import random
import tensorflow as tf

# Seed Everything to reproduce results for future use cases
def seed_everything(seed=42):
    # Seed value for TensorFlow
    tf.random.set_seed(seed)

    # Seed value for NumPy
    np.random.seed(seed)

    # Seed value for Python's random library
    random.seed(seed)

seed_everything()

# %% [markdown]
# The next code reads in a dataset from a CSV file and assigns it to the variable df. It then displays the first few rows of the dataset using the head() function.

# %%
# Read in the dataset
df = pd.read_csv("/kaggle/input/diamonds-prices/Diamonds Prices2022.csv")
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %% [markdown]
# In the next code, the "Unnamed: 0" column is dropped from the dataset df.

# %%
df=df.drop("Unnamed: 0", axis=1)

# %%
df.shape
# Out:
# (53943, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53943 entries, 0 to 53942
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53943 non-null  float64
#  1   cut      53943 non-null  object
#  2   color    53943 non-null  object
#  3   clarity  53943 non-null  object
#  4   depth    53943 non-null  float64
#  5   table    53943 non-null  float64
#  6   price    53943 non-null  int64
#  7   x        53943 non-null  float64
#  8   y        53943 non-null  float64
#  9   z        53943 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# This code computes descriptive statistics for each column in the DataFrame and transposes the result.

# %%
df.describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  53943.0     0.797935     0.473999    0.2    0.40     0.70     1.04
# depth  53943.0    61.749322     1.432626   43.0   61.00    61.80    62.50
# table  53943.0    57.457251     2.234549   43.0   56.00    57.00    59.00
# price  53943.0  3932.734294  3989.338447  326.0  950.00  2401.00  5324.00
# x      53943.0     5.731158     1.121730    0.0    4.71     5.70     6.54
# y      53943.0     5.734526     1.142103    0.0    4.72     5.71     6.54
# z      53943.0     3.538730     0.705679    0.0    2.91     3.53     4.04
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# price  18823.00
# x         10.74
# y         58.90
# z         31.80

# %% [markdown]
# **Duplicates and Null values**
#
# The code prints the number of data points in the dataset. The next code checks for duplicates in the dataset and prints the number of duplicates found. The code then checks for missing values in the dataset by calculating the sum of missing values for each column and prints the results. The code also replaces empty strings with NaN values in the dataset and recalculates the number of missing values.

# %%
# How many reviews do we have?
print('There are', df.shape[0], 'data in this dataset')

# Do we have duplicates?
print('Number of Duplicates:', len(df[df.duplicated()]))

# Do we have missing values?
missing_values = df.isnull().sum()
print('Number of Missing Values by column:\n',missing_values)

print('Number of Missing Values:', df.isnull().sum().sum())

df.replace("", np.nan, inplace=True)
missing_values = df.isnull().sum()
print('Number of Missing Values by column:\n',missing_values)
# Out:
# There are 53943 data in this dataset
# Number of Duplicates: 149
# Number of Missing Values by column:
#  carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64
# Number of Missing Values: 0
# Number of Missing Values by column:
#  carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %% [markdown]
# **Review Duplicates**
#
# This code first identifies and selects all duplicate rows in the DataFrame by using the duplicated() function with the parameter keep=False. The resulting duplicate rows are then sorted based on all columns to ensure duplicates are adjacent. To display the top 5 pairs of duplicates (10 rows), the code selects the first 20 rows from the sorted duplicates.

# %%
# First, get all duplicate rows (keep=False ensures all duplicates are kept)
duplicate_rows = df[df.duplicated(keep=False)]

# Then sort the dataframe on all columns to ensure duplicates are adjacent
sorted_duplicates = duplicate_rows.sort_values(by=list(duplicate_rows.columns))

# Now, if we want to see 5 pairs of duplicates (10 rows), we can simply:
top_5_duplicate_pairs = sorted_duplicates.head(20)
top_5_duplicate_pairs
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 43995   0.30       Good     J     VS1   63.4   57.0    394  4.23  4.26  2.69
# 47296   0.30       Good     J     VS1   63.4   57.0    394  4.23  4.26  2.69
# 34408   0.30      Ideal     G      IF   62.1   55.0    863  4.32  4.35  2.69
# 34422   0.30      Ideal     G      IF   62.1   55.0    863  4.32  4.35  2.69
# 28592   0.30      Ideal     G     VS2   63.0   55.0    675  4.31  4.29  2.71
# 28593   0.30      Ideal     G     VS2   63.0   55.0    675  4.31  4.29  2.71
# 31624   0.30      Ideal     H     SI1   62.2   57.0    450  4.26  4.29  2.66
# 31627   0.30      Ideal     H     SI1   62.2   57.0    450  4.26  4.29  2.66
# 31626   0.30      Ideal     H     SI1   62.2   57.0    450  4.27  4.28  2.66
# 31629   0.30      Ideal     H     SI1   62.2   57.0    450  4.27  4.28  2.66
# 29801   0.30    Premium     D     SI1   62.2   58.0    709  4.31  4.28  2.67
# ...

# %% [markdown]
# After that, the code removes the duplicate rows from the original DataFrame using the drop_duplicates() function. It then counts and prints the number of duplicates remaining in the DataFrame.

# %%
df = df.drop_duplicates()
print('Number of Duplicates:', len(df[df.duplicated()]))
# Out:
# Number of Duplicates: 0

# %% [markdown]
# **Correlation Matrix**
#
# A heatmap is generated to visualize the correlation between the features in the DataFrame using the df.corr() function. The annot=True parameter enables displaying the correlation values on the heatmap.

# %%
plt.subplots(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, fmt='.2f')
pass

# %% [markdown]
# The correlation matrix of the DataFrame is calculated, and the correlation of "price" with other features is extracted and sorted in descending order.

# %%
# Calculate the correlation matrix
corr_matrix = df.corr(numeric_only=True)

# Get the correlation of 'price' with other features
corr_with_price = corr_matrix['price']

# Sort these correlations in descending order
sorted_correlations = corr_with_price.sort_values(ascending=False)

# Print out the sorted correlations
sorted_correlations
# Out:
# price    1.000000
# carat    0.921548
# x        0.884504
# y        0.865395
# z        0.861208
# table    0.126566
# depth   -0.011048
# Name: price, dtype: float64

# %% [markdown]
# **EDA**
#
# The code sets the style and creates a distribution plot using sns.distplot to visualize the distribution of the "price" column.

# %%
sns.set(style='whitegrid')
f, ax = plt.subplots(1,1, figsize=(12, 8))
ax = sns.distplot(df['price'], kde = True, color = 'c')
plt.title('Distribution of Price')
# Out:
# Text(0.5, 1.0, 'Distribution of Price')

# %%
len(df)
# Out:
# 53794

# %% [markdown]
# **Handling Outliers**
#
# The following code shows the selection of numerical features from a dataframe and the subsequent plotting of boxplots for each of those features. This code is important for visualizing and analyzing the distribution of numerical data, identifying potential outliers in the data.

# %%
# Selecting the numerical features
numerical_features = df.select_dtypes(include=['float64','int64']).columns

# Plotting boxplots for all numerical features
fig, axes = plt.subplots(10, 3, figsize=(25, 50))
fig.subplots_adjust(wspace=0.1, hspace=0.3)
fig.suptitle('Outlier Analysis using Boxplot', fontsize=30)
axes = axes.ravel()
font = {
    'family': 'serif',
    'color':  'darkred',
    'weight': 'normal',
    'size': 16,
}
for i, col in enumerate(numerical_features):
    sns.boxplot(df[col], ax=axes[i])
    axes[i].set_title(col, fontdict=font, fontsize=25)

# %% [markdown]
# The next code defines a function called "detect_outliers" that takes a dataframe and a column as input. It calculates the lower and upper limits for outlier detection using the interquartile range (IQR) method and identifies outliers in the specified column. If no outliers are present, it returns an empty list; otherwise, it returns the indices and values of the outliers.

# %%
# Function to detect outliers
def detect_outliers(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_limit = Q1 - (1.5 * IQR)
    upper_limit = Q3 + (1.5 * IQR)
    outliers = df[(df[col] < lower_limit) | (df[col] > upper_limit)]

    if len(outliers) == 0:
        return [], 'No Outliers Present'
    else:
        return outliers.index.tolist(), outliers

# %% [markdown]
# In the following code, all the outlier indices are collected by iterating over the numerical features and applying the "detect_outliers" function. The outliers and their indices are printed for each feature.

# %%
# Collect all outlier indices
all_outlier_indices = []

# Outliers values are --
for col in numerical_features:
    print('-' * 27, col,'-' * 26)
    outlier_indices, outliers = detect_outliers(df, col)
    all_outlier_indices.extend(outlier_indices)
    print(outliers)
    print('\n')
# Out:
# --------------------------- carat --------------------------
#        carat      cut color clarity  depth  table  price     x     y     z
# 12246   2.06  Premium     J      I1   61.2   58.0   5203  8.10  8.07  4.95
# 13002   2.14     Fair     J      I1   69.4   57.0   5405  7.74  7.70  5.36
# 13118   2.15     Fair     J      I1   65.5   57.0   5430  8.01  7.95  5.23
# 13757   2.22     Fair     J      I1   66.7   56.0   5607  8.04  8.02  5.36
# 13991   2.01     Fair     I      I1   67.4   58.0   5696  7.71  7.64  5.17
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27741   2.15    Ideal     G     SI2   62.6   54.0  18791  8.29  8.35  5.21
# 27742   2.04  Premium     H     SI1   58.1   60.0  18795  8.37  8.28  4.84
# 27744   2.29  Premium     I     SI1   61.8   59.0  18797  8.52  8.45  5.24
# 27746   2.07    Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27749   2.29  Premium     I     VS2   60.8   60.0  18823  8.50  8.47  5.16
#
# ...

# %% [markdown]
# The code then gets the unique outlier indices by removing any duplicates from the previously collected outlier indices. The unique outlier indices and their count are printed, providing information about the overall number of unique outliers in the dataset.

# %%
# Get unique outlier indices
unique_outlier_indices = list(set(all_outlier_indices))

# Print the unique indices and their count
print("Unique outlier indices:", unique_outlier_indices)
print("Number of unique outlier indices:", len(unique_outlier_indices))
# Out:
# Unique outlier indices: [2, 8, 24, 35, 42, 43, 84, 91, 95, 97, 124, 129, 32901, 145, 171, 190, 204, 219, 221, 227, 239, 33008, 33015, 33016, 255, 282, 284, 296, 298, 301, 33078, 314, 33084, 320, 333, 33102, 335, 33111, 352, 356, 359, 369, 384, 385, 33170, 33171, 33172, 415, 423, 424, 433, 439, 440, 442, 443, 33224, 461, 472, 33269, 504, 514, 526, 528, 33301, 33329, 581, 595, 33401, 635, 640, 651, 663, 704, 706, 707, 712, 713, 714, 719, 723, 750, 33523, 771, 777, 33554, 797, 801, 33586, 832, 839, 868, 872, 874, 879, 880, 883, 884, 895, 897, 898, 899, 33666, 919, 921, 929, 930, 932, 933, 934, 938, 939, 967, 985, 1002, 1028, 33804, 1061, 1088, 1093, 1096, 1097, 1098, 1140, 33919, 1155, 1156, 1158, 1182, 1183, 33953, 1195, 1196, 1199, 1206, 1227, 1228, 1235, 1238, 1246, 1255, 34024, 1267, 1270, 1275, 34069, 1312, 1318, 1319, 1324, 1350, 1357, 1359, 1361, 1362, 1412, 1413, 1422, 1423, 1438, 34217, 1463, 1467, 1469, 34251, 1493, 1498, 1506, 1515, 34283, 1523, 1524, 34300, 1552, 34354, 1597
# ...

# %%
len(df)
# Out:
# 53794

# %% [markdown]
# Next, the code drops the rows with unique outlier indices from the original dataframe, creating a new dataframe called "data" that excludes those outliers.

# %%
data = df.drop(unique_outlier_indices)

# %%
len(data)
# Out:
# 47416

# %% [markdown]
# **Feature Selection**
#
# Following that, the code splits the preprocessed data into input features (X) and target variable (y) by dropping the "price" column from the "data" dataframe.

# %%
X = data.drop('price', axis=1)
y = data['price']

# %% [markdown]
# The subsequent code imports the "train_test_split" function from the "sklearn.model_selection" module. This function is used to split the data into training and testing sets for model evaluation. The data is split such that 80% is used for training and 20% is used for testing, and a random seed of 42 is set for reproducibility.

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %% [markdown]
# The code then defines two lists: "num_cols" to store the names of numerical columns (excluding the target variable "price") and "cat_cols" to store the names of categorical columns in the "data" dataframe.

# %%
# Get list of numerical columns
num_cols = data.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Remove 'price' from num_cols
num_cols.remove('price')

# Get list of categorical columns
cat_cols = data.select_dtypes(include=['object']).columns.tolist()

# Print the numerical columns
print("Numerical columns are:", num_cols)

# Print the categorical columns
print("Categorical columns are:", cat_cols)
# Out:
# Numerical columns are: ['carat', 'depth', 'table', 'x', 'y', 'z']
# Categorical columns are: ['cut', 'color', 'clarity']

# %% [markdown]
# In the subsequent code, a column transformer is created using the "make_column_transformer" function from the "sklearn.compose" module. This column transformer applies scaling (MinMaxScaler) to the numerical columns and one-hot encoding (OneHotEncoder) to the categorical columns.

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# creating column transformer (this will help us normalize/preprocess our data)

ct = make_column_transformer((MinMaxScaler(), num_cols),
                             (OneHotEncoder(handle_unknown = 'ignore'), cat_cols))

# %% [markdown]
# The column transformer is then fitted on the training data, and the same transformation is applied to both the training and test data.

# %%
# fitting column transformer on training data
ct.fit(xtrain)

# transforming training and test data with normalizing (MinMaxScaler) and one hot encoding (OneHotEncoder)
xtrain = ct.transform(xtrain)
xtest = ct.transform(xtest)

# %% [markdown]
# **Model Building**
#
# Next, the code imports necessary modules from TensorFlow and defines a neural network model called "model_1" using the Sequential API. The model consists of multiple dense layers with dropout regularization to prevent overfitting. The model is compiled with a mean squared error loss function, an Adam optimizer, and metrics to monitor mean absolute error during training.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Bidirectional, LSTM, Dropout, Dense, Lambda
from tensorflow.keras.optimizers import Adam
# !pip install keras-tuner
import keras_tuner as kt

# %%
from tensorflow.keras import regularizers

# Set random seed
tf.random.set_seed(42)

# Define the model
model_1 = tf.keras.Sequential([
  tf.keras.layers.Dense(512, activation="relu", kernel_regularizer=regularizers.l2(0.01)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=regularizers.l2(0.01)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(1)
])

# Define the optimizer
optimizer = tf.keras.optimizers.Adam()

# Compile the model
model_1.compile(loss="mean_squared_error",
                optimizer=optimizer,
                metrics=["mean_absolute_error"])

# %% [markdown]
# A learning rate schedule is defined using a learning rate scheduler callback. This allows the learning rate to change dynamically during training, potentially improving model performance. The model is then trained on the preprocessed training data, using the validation data for evaluation and the learning rate scheduler callback.

# %%
# Define the learning rate schedule
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-6 * 10**(-epoch / 20))

# Fit the model
history = model_1.fit(xtrain,
                      ytrain,
                      epochs=100,
                      batch_size=32,
                      validation_data=(xtest, ytest),
                      callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 1186/1186 [==============================] - 5s 3ms/step - loss: 17284732.0000 - mean_absolute_error: 3118.7917 - val_loss: 17132982.0000 - val_mean_absolute_error: 3085.5767 - lr: 1.0000e-06
# Epoch 2/100
# 1186/1186 [==============================] - 3s 3ms/step - loss: 17283236.0000 - mean_absolute_error: 3118.5693 - val_loss: 17131504.0000 - val_mean_absolute_error: 3085.3552 - lr: 8.9125e-07
# Epoch 3/100
# 1186/1186 [==============================] - 3s 3ms/step - loss: 17281780.0000 - mean_absolute_error: 3118.3542 - val_loss: 17130072.0000 - val_mean_absolute_error: 3085.1396 - lr: 7.9433e-07
# Epoch 4/100
# 1186/1186 [==============================] - 4s 3ms/step - loss: 17280382.0000 - mean_absolute_error: 3118.1450 - val_loss: 17128722.0000 - val_mean_absolute_error: 3084.9382 - lr: 7.0795e-07
# Epoch 5/100
# ...

# %% [markdown]
# The subsequent code plots the learning rate versus the loss to visualize the relationship between the learning rate and the model's performance. This can help in choosing an appropriate learning rate for training the model.

# %%
# Plot the learning rate versus the loss
lrs = 1e-6 * (10 ** (np.arange(100)/20))
plt.figure(figsize=(10, 7))
plt.semilogx(lrs, history.history["loss"]) # we want the x-axis (learning rate) to be log scale
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Learning rate vs. loss");

# %% [markdown]
# After that, the code resets the TensorFlow session and the weights of the model to ensure a clean state for further experiments or model retraining. A learning rate value (lrx) is also assigned.

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

lrx=5e-4
lrx
# Out:
# 0.0005

# %% [markdown]
# The code recompiles the model with the specified learning rate and fits it on the preprocessed training data again, this time using the early stopping callback and model checkpoint.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)

# Define the optimizer
optimizer = tf.keras.optimizers.Adam(lr=lrx)

# Compile the model
model_1.compile(loss="mean_squared_error",
                optimizer=optimizer,
                metrics=["mean_absolute_error"])

# Fit the model
history = model_1.fit(xtrain,
                      ytrain,
                      epochs=100,
                      batch_size=32,
                      validation_data=(xtest, ytest),
                      callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 1170/1186 [============================>.] - ETA: 0s - loss: 4041253.7500 - mean_absolute_error: 1348.6863
# Epoch 1: val_loss improved from inf to 567140.93750, saving model to best_model.h5
# 1186/1186 [==============================] - 4s 3ms/step - loss: 3998273.5000 - mean_absolute_error: 1338.6387 - val_loss: 567140.9375 - val_mean_absolute_error: 507.2323
# Epoch 2/100
# 1177/1186 [============================>.] - ETA: 0s - loss: 424778.9062 - mean_absolute_error: 417.5267
# Epoch 2: val_loss improved from 567140.93750 to 259165.26562, saving model to best_model.h5
# 1186/1186 [==============================] - 4s 3ms/step - loss: 423791.5000 - mean_absolute_error: 416.9869 - val_loss: 259165.2656 - val_mean_absolute_error: 305.9894
# Epoch 3/100
# 1170/1186 [============================>.] - ETA: 0s - loss: 303319.1250 - mean_absolute_error: 340.4363
# Epoch 3: val_loss improved from 259165.26562 to 215104.54688, saving model to best_model.h5
# ...

# %% [markdown]
# A function called "plot_losses" is defined to plot the losses (training and validation) from the history object returned by the model training process.

# %%
def plot_losses(history):
    losses = pd.DataFrame(history.history)
    losses.plot()

# %%
plot_losses(history)

# %% [markdown]
# The next code loads the best saved model from the model checkpoint file ("best_model.h5").

# %%
from tensorflow.keras.models import load_model

# Load the best saved model
model = load_model('best_model.h5')

# %%
# Predictions
testPredict = model.predict(xtest)
# Out:
# 297/297 [==============================] - 0s 1ms/step

# %% [markdown]
# Test predictions are made using the loaded model, and an evaluation function is defined to calculate and print the mean absolute error (MAE) and mean squared error (MSE) between the true target values (ytest) and the predicted values (testPredict).

# %%
# Evaluate model
def evaluate_model(y_true, y_pred):
    mae = tf.keras.metrics.mean_absolute_error(y_true, y_pred)
    mse = tf.keras.metrics.mean_squared_error(y_true, y_pred)

    print('Mean Absolute Error: ', mae.numpy())
    print('Mean Squared Error: ', mse.numpy())

# %% [markdown]
# The code then evaluates the model's performance by calling the evaluation function with the true target values and the predicted values. The MAE and MSE are printed, providing an assessment of the model's predictive accuracy.

# %%
evaluate_model(ytest, tf.squeeze(testPredict))  # Flatten the prediction array to match the shape
# Out:
# Mean Absolute Error:  228.0766
# Mean Squared Error:  154207.06

# %% [markdown]
# **Hyperparameter Tuning**

# %%
xtrain.shape[1]
# Out:
# 26

# %%
xtrain.shape
# Out:
# (37932, 26)

# %% [markdown]
# **Hyperparameter Tuning**
#
# The following code defines a function called "build_model" that constructs a neural network model with customizable hyperparameters. The model includes multiple layers, dropout regularization, and batch normalization. It is compiled with an Adam optimizer and mean squared error loss.

# %%
def build_model(hp):
    from keras.layers import BatchNormalization
    from keras.regularizers import l1_l2

    # Define all hyperparameters
    n_layers = hp.Choice('n_layers', [2, 4, 6])
    dropout_rate = hp.Choice('rate', [0.2, 0.4, 0.5, 0.7])
    n_units = hp.Choice('units', [64, 128, 256, 512])
    l1_reg = hp.Choice('l1', [0.0, 0.01, 0.001, 0.0001])
    l2_reg = hp.Choice('l2', [0.0, 0.01, 0.001, 0.0001])

    # Model architecture
    model = Sequential()

    # Input layer
    model.add(Dense(n_units, input_dim=xtrain.shape[1], activation='relu', kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)))
    model.add(BatchNormalization())

    # Add hidden layers
    for _ in range(n_layers):
        model.add(Dense(n_units, activation='relu', kernel_initializer='he_normal', kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)))
        model.add(BatchNormalization())

    # Add Dropout Layer
    model.add(Dropout(dropout_rate))

    # Output Layer
    model.add(Dense(1))

    # Define the optimizer
    optimizer = tf.keras.optimizers.Adam(lr=lrx)

    # Compile the model
    model.compile(loss="mean_squared_error",
                    optimizer=optimizer,
                    metrics=["mean_absolute_error"])

    # Return model
    return model

# %% [markdown]
# In the next code block, a random search is initialized to find the best model architecture. The search explores different hyperparameter combinations and aims to minimize validation loss. This approach helps in identifying the optimal model configuration.

# %%
# Initialize Random Searcher
random_searcher = kt.RandomSearch(
    hypermodel=build_model,
    objective='val_loss',
    max_trials=30,
    seed=42,
    project_name="PlSearch"
)

# Start Searching
search = random_searcher.search(
    xtrain, ytrain,
    validation_data=(xtest, ytest),
    epochs = 20,
    batch_size = 64
)
# Out:
# Trial 30 Complete [00h 00m 59s]
# val_loss: 148894.984375
#
# Best val_loss So Far: 142439.171875
# Total elapsed time: 00h 50m 47s

# %%
BATCH_SIZE=64

# %% [markdown]
# The code then imports necessary modules for callbacks and collects the best model architecture from the random search. The model is compiled and trained on the preprocessed data, with early stopping and model checkpoint implemented to prevent overfitting and save the best model based on validation loss.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Collect the best model Architecture obtained by Random Searcher
best_model = build_model(random_searcher.get_best_hyperparameters(num_trials=1)[0])

# Model Architecture
best_model.summary()

optimizer = tf.keras.optimizers.Adam(lr=lrx)

# Compile Model
best_model.compile(loss="mean_squared_error",
                    optimizer=optimizer,
                    metrics=["mean_absolute_error"])
# Model Training
best_model_history = best_model.fit(
    xtrain, ytrain,
    validation_data=(xtest, ytest),
    epochs = 500,
    batch_size = BATCH_SIZE*2,
    callbacks = [
  EarlyStopping(patience=150, restore_best_weights=True),
  ModelCheckpoint('best-model.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)]
)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 512)               13824
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_7 (Dense)             (None, 512)               262656
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_8 (Dense)             (None, 512)               262656
#
#  batch_normalization_7 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_9 (Dense)             (None, 1)                 513
#
# ...
# Total params: 545,793
# Trainable params: 542,721
# Non-trainable params: 3,072
# _________________________________________________________________
# Epoch 1/500
# 294/297 [============================>.] - ETA: 0s - loss: 16458688.0000 - mean_absolute_error: 3091.0950
# ...

# %% [markdown]
# After training, the best model is loaded and its architecture summary is printed.

# %%
#  Load model
best_model = tf.keras.models.load_model('best-model.h5')
best_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 512)               13824
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_7 (Dense)             (None, 512)               262656
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_8 (Dense)             (None, 512)               262656
#
#  batch_normalization_7 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_9 (Dense)             (None, 1)                 513
#
# ...
# Total params: 545,793
# Trainable params: 542,721
# Non-trainable params: 3,072
# _________________________________________________________________

# %% [markdown]
# Next, the best model's performance is evaluated by calculating mean squared error and mean absolute error on the test data. This assessment provides insights into the model's predictive accuracy.

# %%
# Evaluate the best model
best_test_loss, best_test_acc = best_model.evaluate(xtest, ytest)
print(f"Validation loss (MSE) after Tuning     : {best_test_loss} ")
print(f"Validation MAE after Tuning : {best_test_acc}  ")
# Out:
# 297/297 [==============================] - 1s 3ms/step - loss: 128453.6797 - mean_absolute_error: 204.4567
# Validation loss (MSE) after Tuning     : 128453.6796875
# Validation MAE after Tuning : 204.4567108154297

# %% [markdown]
# The subsequent code extracts training and validation metrics from the best model's training history. These metrics, including mean absolute error and loss, are plotted over epochs. This visualization helps in understanding the model's learning progress.

# %%
# Extract the history from the best model
accuracy = best_model_history.history['mean_absolute_error']
val_accuracy = best_model_history.history['val_mean_absolute_error']

loss = best_model_history.history['loss']
val_loss = best_model_history.history['val_loss']

epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'b', label='Training mean_absolute_error')
plt.plot(epochs, val_accuracy, 'r', label='Validation mean_absolute_error')

plt.title('Training and validation mean_absolute_error')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')

plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# A function called "make_sample_prediction" is defined to make predictions on individual test samples using the best model. It calculates differences and percentage differences between true and predicted prices.

# %%
def make_sample_prediction(index, xtest, ytest, model):
    # Select the corresponding test sample and true price
    sample, true_price = xtest[index], ytest.iloc[index]

    # Reshape the sample to be a batch of size 1
    sample = sample.reshape(1, -1)

    # Make a prediction
    predicted_price = model.predict(sample)[0][0]

    # Calculate the difference
    difference = true_price - predicted_price

    # Calculate the percentage difference
    pct_difference = (difference / true_price) * 100

    # Create a data frame for the scaled sample
#     sample_df = pd.DataFrame(sample, columns=transformed_cols)

    # Print out the sample, the true price, and the predicted price
    print(f"Prediction {index+1}")
#     print("Features (scaled):")
#     print(sample_df)
    print("True Price: ", true_price)
    print("Predicted Price: ", predicted_price)
    print("Difference: ", difference)
    print("Percentage Difference: ", pct_difference, "%")
    print("\n---------------------\n")

# %% [markdown]
# Then, the code calls the "make_sample_prediction" function for the first 10 samples in the test data, providing predictions, true prices, differences, and percentage differences. This step aids in understanding the model's predictive capabilities on specific samples.

# %%
# Call the function for the first 10 samples
for i in range(10):
    make_sample_prediction(i, xtest, ytest, best_model)
# Out:
# 1/1 [==============================] - 0s 122ms/step
# Prediction 1
# True Price:  1800
# Predicted Price:  1459.2579
# Difference:  340.7420654296875
# Percentage Difference:  18.93011474609375 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 21ms/step
# Prediction 2
# True Price:  4900
# Predicted Price:  5658.515
# Difference:  -758.51513671875
# Percentage Difference:  -15.479900749362244 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 20ms/step
# Prediction 3
# True Price:  432
# Predicted Price:  462.80408
# Difference:  -30.8040771484375
# Percentage Difference:  -7.130573413990161 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 21ms/step
# Prediction 4
# True Price:  666
# Predicted Price:  761.8357
# Difference:  -95.835693359375
# Percentage Difference:  -14.389743747653904 %
#
# ---------------------
#
# 1/1 [==============================] - 0s 20ms/step
# Prediction 5
# True Price:  571
# ...
