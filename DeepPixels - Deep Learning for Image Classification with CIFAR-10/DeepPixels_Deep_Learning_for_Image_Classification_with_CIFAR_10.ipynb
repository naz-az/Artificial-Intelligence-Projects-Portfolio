# %% [markdown]
# # **Title: DeepPixels - Deep Learning for Image Classification with CIFAR-10**

# %% [markdown]
# ![Screenshot 2023-07-11 125347.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Overview/Introduction
# This project aims to develop an Artificial Intelligence (AI) system for image classification using the CIFAR-10 dataset. Image classification is a fundamental task in computer vision, and the CIFAR-10 dataset provides a diverse collection of 60,000 color images across ten different classes. By building an AI model capable of accurately classifying these images, we can demonstrate the potential of AI in various applications such as object recognition, autonomous vehicles, medical imaging, and more.
#
# ### Problem Statement
# The problem at hand is to develop a robust AI model that can accurately classify images from the CIFAR-10 dataset into their respective classes. Each image in the dataset belongs to one of the ten categories, including airplanes, automobiles, birds, cats, deer, dogs, frogs, horses, ships, and trucks. However, due to the complexity and variability of real-world images, accurately distinguishing between these classes presents a significant challenge.
#
# ### Objectives
# The objectives of this project are as follows:
#
# 1. **Develop a Convolutional Neural Network (CNN)**: Build a deep learning model using a Convolutional Neural Network architecture to effectively extract features and learn discriminative representations from the CIFAR-10 images. CNNs are well-suited for image classification tasks due to their ability to automatically learn hierarchical features.
#
# 2. **Achieve High Accuracy**: Train the CNN model to achieve high accuracy in classifying the CIFAR-10 images. The goal is to develop a model that can accurately predict the correct class label for a given image, thereby demonstrating the potential of AI for real-world image recognition tasks.
#
# 3. **Evaluate Performance**: Evaluate the performance of the trained model using appropriate metrics such as accuracy, precision, recall, and F1 score. This analysis will provide insights into the model's strengths and weaknesses and help identify areas for improvement.
#
# 4. **Publish on GitHub**: Share the developed AI project on GitHub as part of the portfolio to showcase proficiency in image classification and deep learning techniques. The GitHub repository will include the complete source code, documentation, and instructions for reproducing the results.
#
# ### Dataset Description
# The CIFAR-10 dataset is a widely used benchmark dataset for image classification tasks. It consists of 60,000 32x32 color images, equally divided into ten classes, with 6,000 images per class. The dataset is further split into a training set of 50,000 images and a test set of 10,000 images.
#
# The images in the CIFAR-10 dataset are collected from various sources and cover a wide range of real-world scenarios. The ten different classes represent common objects, animals, and vehicles encountered in everyday life. The classes include airplanes, automobiles, birds, cats, deer, dogs, frogs, horses, ships, and trucks.
#
# By leveraging the CIFAR-10 dataset, this AI project aims to create an image classification model that can effectively categorize images into these ten classes. The trained model can be used in a variety of applications, including automated image tagging, content-based image retrieval, and intelligent image recognition systems. The project's successful implementation will contribute to advancing the field of computer vision and provide a foundation for future research and development in AI-based image classification techniques.

# %% [markdown]
# ## Technologies Used
#
# The AI project utilizes the following technologies and libraries:
#
# - TensorFlow: A popular open-source deep learning framework for building and training neural networks.
# - Keras: A high-level neural networks API that runs on top of TensorFlow, providing a user-friendly interface for building and training models.
# - Pandas: A powerful data manipulation library used for handling and analyzing structured data.
# - Matplotlib: A plotting library that provides a wide range of visualization capabilities for creating graphs, charts, and images.
# - NumPy: A fundamental package for scientific computing in Python, used for efficient numerical operations and array manipulation.
# - Scikit-learn: A machine learning library that offers various tools and algorithms for tasks such as evaluation, preprocessing, and model selection.
#
# ## Methodology
#
# The AI project follows the following methodology:
#
# 1. **Data Loading and Exploration**: The CIFAR-10 dataset, containing training and test sets, is loaded using the TensorFlow Keras API. Basic exploratory analysis is performed to understand the dataset's structure and visualize example images.
#
# 2. **Data Preprocessing**: The training and test images are normalized by dividing them by 255.0 to bring the pixel values into the range of [0, 1]. The label arrays are flattened for further processing, and new labels with corresponding class names are created.
#
# 3. **Data Visualization**: Various visualizations, including bar charts and pie charts, are created to examine the label distribution within the dataset.
#
# 4. **Model Creation**: A Convolutional Neural Network (CNN) model is developed using the TensorFlow Sequential API. The model consists of convolutional layers, max-pooling layers, and dense layers with activation functions. It is compiled with appropriate loss function, optimizer, and evaluation metrics.
#
# 5. **Model Training and Evaluation**: The model is trained on the preprocessed training data, with a learning rate scheduler callback to adjust the learning rate during training. The training progress, including loss and accuracy, is visualized over the epochs. The best model is saved based on validation accuracy. Finally, the model is evaluated on the test set to assess its performance.
#
# 6. **Results Analysis**: The evaluation results, including loss and accuracy, are presented. Additionally, a confusion matrix is generated to visualize the model's performance in predicting different classes. Random images from the test set are plotted along with their predicted labels for qualitative analysis.
#
# ## Results
#
# The evaluation of the model on the test set yields the following results:
# - Loss: 0.6514
# - Accuracy: 0.8593
#
# These metrics indicate that the trained model achieves a relatively low loss and a high accuracy in classifying the CIFAR-10 images.
#
# ## Discussion/Interpretation of Results
#
# The results demonstrate that the implemented CNN model can effectively classify the CIFAR-10 images, achieving a high level of accuracy. The model's accuracy of 85.93% indicates that it can correctly predict the class labels for a significant portion of the test images. This level of performance is quite impressive considering the complexity and variability of the CIFAR-10 dataset, which contains diverse images of different objects, animals, and vehicles.
#
#
# ## Conclusion
#
# In conclusion, this AI project demonstrates the application of deep learning techniques for fine-grained image classification using the CIFAR-10 dataset. By training a CNN model, we achieved a high level of accuracy in classifying CIFAR-10 images, showcasing the effectiveness of the implemented approach. The project's successful implementation highlights the significance of AI-based image classification methods in various domains, including object recognition, content-based image retrieval, and intelligent image recognition systems.
#
# In future work, several areas can be explored to further improve the image classification AI project using the CIFAR-10 dataset. These include optimizing the model architecture by experimenting with deeper or more complex CNN models and leveraging techniques like transfer learning. Hyperparameter tuning can be performed to find the best combination of parameters for improved performance. Data augmentation can also be applied to increase the diversity of the training data.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# The following code shows how to import TensorFlow and load the CIFAR-10 dataset, which consists of labeled images of various objects.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10

# The data has already been sorted into training and test sets for us
(train_data, train_labels), (test_data, test_labels) = cifar10.load_data()
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %% [markdown]
# The next code snippet displays the first training example from the CIFAR-10 dataset, including the image data and its corresponding label.

# %%
# Show the first training example
print(f"Training sample:\n{train_data[0]}\n")
print(f"Training label: {train_labels[0]}")
# Out:
# Training sample:
# [[[ 59  62  63]
#   [ 43  46  45]
#   [ 50  48  43]
#   ...
#   [158 132 108]
#   [152 125 102]
#   [148 124 103]]
#
#  [[ 16  20  20]
#   [  0   0   0]
#   [ 18   8   0]
#   ...
#   [123  88  55]
#   [119  83  50]
#   [122  87  57]]
#
#  [[ 25  24  21]
#   [ 16   7   0]
#   [ 49  27   8]
#   ...
#   [118  84  50]
#   [120  84  50]
#   [109  73  42]]
#
#  ...
#
#  [[208 170  96]
#   [201 153  34]
#   [198 161  26]
#   ...
#   [160 133  70]
#   [ 56  31   7]
#   [ 53  34  20]]
#
#  [[180 139  96]
#   [173 123  42]
#   [186 144  30]
#   ...
#   [184 148  94]
#   [ 97  62  34]
#   [ 83  53  34]]
#
#  [[177 144 116]
#   [168 129  94]
#   [179 142  87]
#   ...
#   [216 184 140]
#   [151 118  84]
#   [123  92  72]]]
#
# Training label: [6]

# %%
# Check the shape of our data
train_data.shape, train_labels.shape, test_data.shape, test_labels.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
# Check shape of a single example
train_data[0].shape, train_labels[0].shape
# Out:
# ((32, 32, 3), (1,))

# %% [markdown]
# Now we will find the minimum and maximum values of the labels in the training set. This information can be useful for further analysis or preprocessing.

# %%
min_value = min(train_labels)
max_value = max(train_labels)

print("Minimum value:", min_value)
print("Maximum value:", max_value)
# Out:
# Minimum value: [0]
# Maximum value: [9]

# %% [markdown]
# The code imports the matplotlib library and plots a single example from the training data using the imshow function.

# %%
# Plot a single example
import matplotlib.pyplot as plt
plt.imshow(train_data[56]);

# %% [markdown]
# In this code, pandas is imported, and a label dictionary is created to map label values to their corresponding names. The dictionary is then converted into a DataFrame for easy manipulation and exploration.

# %%
import pandas as pd

label_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Create a dictionary with label values and names
label_dict = {'label_value': range(len(label_names)), 'label_name': label_names}

# Convert the dictionary into a DataFrame
label_df = pd.DataFrame(label_dict)

label_df
# Out:
#    label_value  label_name
# 0            0    airplane
# 1            1  automobile
# 2            2        bird
# 3            3         cat
# 4            4        deer
# 5            5         dog
# 6            6        frog
# 7            7       horse
# 8            8        ship
# 9            9       truck

# %% [markdown]
# Next, the code randomly selects five indices from the training data, plots the corresponding images, and displays their labels. This helps visualize a random sample of the data.

# %%
import numpy as np

# Randomly select 5 indices from train_data
indices = np.random.choice(len(train_data), size=5, replace=False)

# Plot the 5 random samples and their labels
fig, axes = plt.subplots(1, 5, figsize=(15, 3))

for i, idx in enumerate(indices):
    axes[i].imshow(train_data[idx])
    label_value = train_labels[idx]
    axes[i].set_title(label_names[label_value[0]])
    axes[i].axis('off')

plt.show()

# %% [markdown]
# In the next code block, the labels in the training and test sets are modified by flattening them and appending the corresponding label names in parentheses. This is done to make the labels more informative and human-readable. The code creates unique IDs for each image in the training and test sets. It then constructs two DataFrames, one for the training data and one for the test data, with columns for ID, image data, and modified labels. The first 10 rows of the training DataFrame are printed.

# %%
# Make copies and then flatten the labels arrays
train_labels_mod = np.copy(train_labels).flatten()
test_labels_mod = np.copy(test_labels).flatten()

# Create a list for new labels
label_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
train_labels_mod = [f'{label} ({label_names[label]})' for label in train_labels_mod]
test_labels_mod = [f'{label} ({label_names[label]})' for label in test_labels_mod]

# Create IDs
train_ids = [f'train_{str(i).zfill(5)}' for i in range(len(train_data))]
test_ids = [f'test_{str(i).zfill(5)}' for i in range(len(test_data))]

# Create dataframes
train_df = pd.DataFrame({'id': train_ids, 'image': list(train_data), 'label': train_labels_mod})
test_df = pd.DataFrame({'id': test_ids, 'image': list(test_data), 'label': test_labels_mod})

# Print the first 10 rows
train_df.head(10)
# Out:
#             id                                              image  \
# 0  train_00000  [[[59, 62, 63], [43, 46, 45], [50, 48, 43], [6...
# 1  train_00001  [[[154, 177, 187], [126, 137, 136], [105, 104,...
# 2  train_00002  [[[255, 255, 255], [253, 253, 253], [253, 253,...
# 3  train_00003  [[[28, 25, 10], [37, 34, 19], [38, 35, 20], [4...
# 4  train_00004  [[[170, 180, 198], [168, 178, 196], [177, 185,...
# 5  train_00005  [[[159, 102, 101], [150, 91, 95], [153, 95, 97...
# 6  train_00006  [[[164, 206, 84], [105, 140, 61], [118, 148, 1...
# 7  train_00007  [[[28, 35, 39], [30, 34, 44], [33, 44, 47], [6...
# 8  train_00008  [[[134, 186, 223], [131, 184, 220], [128, 182,...
# 9  train_00009  [[[125, 125, 116], [110, 101, 91], [102, 90, 8...
#
#             label
# 0        6 (frog)
# 1       9 (truck)
# 2       9 (truck)
# 3        4 (deer)
# 4  1 (automobile)
# 5  1 (automobile)
# 6        2 (bird)
# 7       7 (horse)
# 8        8 (ship)
# 9         3 (cat)

# %% [markdown]
# The following code calculates the count of each label in the training DataFrame and plots a bar chart to visualize the label distribution. Similarly, a pie chart is plotted to provide a visual representation of the label distribution.

# %%
# Get count of each label
label_counts = train_df['label'].value_counts()

# Plot bar chart
plt.figure(figsize=(10, 6))
label_counts.plot(kind='bar', color='blue', alpha=0.7)
plt.title('Label Counts - Bar Chart')
plt.xlabel('Labels')
plt.ylabel('Counts')
plt.grid(True)
plt.show()

# Plot pie chart
plt.figure(figsize=(10, 6))
label_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('Label Counts - Pie Chart')
plt.ylabel('')
plt.show()

# %%
label_names
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %% [markdown]
# The next code block sets the number of classes based on the number of label names.

# %%
n_classes=len(label_names)

# %% [markdown]
# The code normalizes the pixel values of the images in the training and test sets by dividing them by 255.0. This step is commonly performed to ensure that the pixel values are within the range of 0 to 1.

# %%
# Divide train and test images by the maximum value (normalize it)
train_data = train_data / 255.0
test_data = test_data / 255.0

# Check the min and max values of the training data
train_data.min(), train_data.max()
# Out:
# (0.0, 1.0)

# %% [markdown]
# **Model**
#
# Now we set the random seed and create a simple Convolutional Neural Network (CNN) model using TensorFlow's Sequential API. The model consists of convolutional layers, max-pooling layers, and dense layers with activation functions. The model is compiled with a loss function, optimizer, and metrics. A learning rate scheduler callback is created to adjust the learning rate during training. The model is then fitted to the training data, and the learning rate scheduler is included as a callback.

# %%
# Set random seed
tf.random.set_seed(42)

# Create the model (simple Convolutional Neural Network)
model = tf.keras.Sequential([
  tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
  tf.keras.layers.MaxPooling2D((2, 2)),
  tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D((2, 2)),
  tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D((2, 2)),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                 optimizer=tf.keras.optimizers.Adam(),
                 metrics=["accuracy"])

# Create the learning rate callback
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-3 * 10**(epoch/20))

# Fit the model (without the learning rate scheduler for now)
find_lr_history = model.fit(train_data,
                               train_labels,
                               epochs=15,
                               validation_data=(test_data, test_labels),
                               callbacks=[lr_scheduler])
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 16s 5ms/step - loss: 1.5418 - accuracy: 0.4378 - val_loss: 1.2539 - val_accuracy: 0.5534 - lr: 0.0010
# Epoch 2/15
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.1805 - accuracy: 0.5820 - val_loss: 1.1396 - val_accuracy: 0.5989 - lr: 0.0011
# Epoch 3/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0448 - accuracy: 0.6320 - val_loss: 1.0110 - val_accuracy: 0.6501 - lr: 0.0013
# Epoch 4/15
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.9541 - accuracy: 0.6660 - val_loss: 0.9995 - val_accuracy: 0.6579 - lr: 0.0014
# Epoch 5/15
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.8849 - accuracy: 0.6888 - val_loss: 0.9165 - val_accuracy: 0.6817 - lr: 0.0016
# Epoch 6/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8425 - accuracy: 0.7032 - val_loss: 0.9189 - val_accuracy: 0.6838 - lr: 0.0018
# Epoch 7/15
# ...

# %% [markdown]
# The code plots the learning rate decay curve, showing the relationship between the learning rate and the loss. This visualization helps in finding an ideal learning rate.

# %%
# Plot the learning rate decay curve
lrs = 1e-3 * (10**(np.arange(15)/20))
plt.semilogx(lrs, find_lr_history.history["loss"]) # want the x-axis to be log-scale
plt.xlabel("Learning rate")
plt.ylabel("Loss")
plt.title("Finding the ideal learning rate");

# %% [markdown]
# By analyzing the plot, one can identify the learning rate at the point where the loss begins to stabilize or reach a minimum. This learning rate is often considered the "ideal" or optimal learning rate for the given model and dataset. In this case, around 2e-3.

# %% [markdown]
# Now we set the learning rate for the next model.

# %%
lrp=2e-3

# %% [markdown]
# A more complex CNN model is defined with additional layers, such as batch normalization and dropout, to improve performance and prevent overfitting. The model is compiled with the chosen learning rate and metrics. A model checkpoint callback is created to save the best model based on validation accuracy. The model is fitted to the training data with increased epochs, and the checkpoint callback is included.

# %%
tf.random.set_seed(42)

# Create the model
model = tf.keras.Sequential([
  tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D((2, 2)),
  tf.keras.layers.Dropout(0.2),

  tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D((2, 2)),
  tf.keras.layers.Dropout(0.3),

  tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D((2, 2)),
  tf.keras.layers.Dropout(0.4),

  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                 optimizer=tf.keras.optimizers.Adam(lr=lrp),
                 metrics=["accuracy"])

# Create a model checkpoint
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("best_model.h5",
                                                   save_best_only=True,
                                                   monitor='val_accuracy',
                                                   mode='max',
                                                   verbose=1)
# Fit the model
find_lr_history = model.fit(train_data,
                               train_labels,
                               epochs=100, # increased number of epochs
                               validation_data=(test_data, test_labels),
                               callbacks=[checkpoint_cb])
# Out:
# Epoch 1/100
# 2023-07-11 10:10:01.520555: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1563/1563 [==============================] - ETA: 0s - loss: 1.5472 - accuracy: 0.4652
# Epoch 1: val_accuracy improved from -inf to 0.58190, saving model to best_model.h5
# 1563/1563 [==============================] - 23s 11ms/step - loss: 1.5472 - accuracy: 0.4652 - val_loss: 1.2074 - val_accuracy: 0.5819
# Epoch 2/100
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.0130 - accuracy: 0.6446
# Epoch 2: val_accuracy improved from 0.58190 to 0.69360, saving model to best_model.h5
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.0130 - accuracy: 0.6446 - val_loss: 0.9806 - val_accuracy: 0.6936
# Epoch 3/100
# ...

# %% [markdown]
# The saved model is loaded for further evaluation and predictions.

# %%
# Load the saved model
best_model = tf.keras.models.load_model('best_model.h5')

# %% [markdown]
# The best model is evaluated on the test data, providing the loss and accuracy metrics.

# %%
best_model.evaluate(test_data, test_labels)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.6514 - accuracy: 0.8593
# [0.6514029502868652, 0.8593000173568726]

# %% [markdown]
# The code plots the training curves, displaying the loss and accuracy values over the epochs.

# %%
# Plot the loss curves
pd.DataFrame(find_lr_history.history).plot()
plt.title("Training curves")
# Out:
# Text(0.5, 1.0, 'Training curves')

# %% [markdown]
# Using the best model, predictions are made on the test data, resulting in predicted probabilities for each class. The first five predictions are displayed.

# %%
# Make predictions with the best model
y_probs = best_model.predict(test_data) # "probs" is short for probabilities

# View the first 5 predictions
y_probs[:5]
# Out:
# 313/313 [==============================] - 1s 3ms/step
# array([[2.1620299e-07, 2.0047357e-06, 1.5340420e-07, 9.9910837e-01,
#         7.0090795e-09, 8.6248567e-04, 2.2459826e-05, 8.3834113e-09,
#         4.0895789e-06, 2.3881876e-07],
#        [4.3873629e-09, 2.0014104e-06, 5.8411506e-13, 6.6844733e-12,
#         8.8824824e-13, 7.2491731e-13, 5.0227565e-12, 2.1672260e-13,
#         9.9999797e-01, 1.1951428e-09],
#        [4.3508103e-07, 3.5867519e-03, 2.8775194e-08, 1.2808846e-08,
#         2.2897246e-09, 6.1169160e-08, 4.7479006e-07, 6.5775518e-09,
#         9.9639040e-01, 2.1867783e-05],
#        [9.8835993e-01, 2.7910583e-05, 1.8713055e-03, 2.0473257e-03,
#         3.6738187e-05, 5.1668763e-07, 3.6335857e-06, 3.5656940e-05,
#         7.5673261e-03, 4.9660284e-05],
#        [5.0095924e-11, 2.4743037e-09, 9.1582041e-07, 3.2223600e-06,
#         4.8995465e-09, 5.9588050e-11, 9.9999583e-01, 2.0464090e-12,
#         5.5755831e-11, 8.1133272e-10]], dtype=float32)

# %% [markdown]
# The predicted probabilities are converted to labels by selecting the class with the highest probability. The first ten predicted labels are shown.

# %%
# Convert all of the predictions from probabilities to labels
y_preds = y_probs.argmax(axis=1)

# View the first 10 prediction labels
y_preds[:10]
# Out:
# array([3, 8, 8, 0, 6, 6, 1, 6, 3, 1])

# %% [markdown]
# A confusion matrix is generated using the true labels and the predicted labels. This matrix provides insight into the model's performance for each class.

# %%
# Check out the non-prettified confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_true=test_labels,
                 y_pred=y_preds)
# Out:
# array([[864,  11,  40,  12,  14,   4,   6,   4,  29,  16],
#        [  8, 933,   1,   5,   2,   1,   3,   1,   9,  37],
#        [ 30,   1, 781,  43,  47,  37,  39,  15,   3,   4],
#        [ 13,   5,  29, 714,  47, 109,  48,  19,   8,   8],
#        [  3,   2,  29,  29, 868,   9,  26,  30,   3,   1],
#        [  5,   3,  17, 111,  29, 791,  10,  28,   3,   3],
#        [  3,   2,  16,  27,  16,   9, 921,   2,   3,   1],
#        [  7,   2,  11,  26,  25,  30,   2, 891,   3,   3],
#        [ 22,  11,   4,  13,   2,   0,   7,   1, 926,  14],
#        [ 21,  38,   2,   9,   0,   2,   2,   7,  15, 904]])

# %% [markdown]
# A prettier confusion matrix is created using a custom function, which includes class labels and adjusts the visualization's appearance.

# %%
# Note: The following confusion matrix code is a remix of Scikit-Learn's
# plot_confusion_matrix function - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.plot_confusion_matrix.html
# and Made with ML's introductory notebook - https://github.com/GokuMohandas/MadeWithML/blob/main/notebooks/08_Neural_Networks.ipynb
import itertools
from sklearn.metrics import confusion_matrix

# Our function needs a different name to sklearn's plot_confusion_matrix
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15):
  """Makes a labelled confusion matrix comparing predictions and ground truth labels.

  If classes is passed, confusion matrix will be labelled, if not, integer class values
  will be used.

  Args:
    y_true: Array of truth labels (must be same shape as y_pred).
    y_pred: Array of predicted labels (must be same shape as y_true).
    classes: Array of class labels (e.g. string form). If `None`, integer labels are used.
    figsize: Size of output figure (default=(10, 10)).
    text_size: Size of output figure text (default=15).

  Returns:
    A labelled confusion matrix plot comparing y_true and y_pred.

  Example usage:
    make_confusion_matrix(y_true=test_labels, # ground truth test labels
                          y_pred=y_preds, # predicted labels
                          classes=class_names, # array of class label names
                          figsize=(15, 15),
                          text_size=10)
  """
  # Create the confustion matrix
  cm = confusion_matrix(y_true, y_pred)
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
  n_classes = cm.shape[0] # find the number of classes we're dealing with

  # Plot the figure and make it pretty
  fig, ax = plt.subplots(figsize=figsize)
  cax = ax.matshow(cm, cmap=plt.cm.Blues) # colors will represent how 'correct' a class is, darker == better
  fig.colorbar(cax)

  # Are there a list of classes?
  if classes:
    labels = classes
  else:
    labels = np.arange(cm.shape[0])

  # Label the axes
  ax.set(title="Confusion Matrix",
         xlabel="Predicted label",
         ylabel="True label",
         xticks=np.arange(n_classes), # create enough axis slots for each class
         yticks=np.arange(n_classes),
         xticklabels=labels, # axes will labeled with class names (if they exist) or ints
         yticklabels=labels)

  # Make x-axis labels appear on bottom
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()

  # Set the threshold for different colors
  threshold = (cm.max() + cm.min()) / 2.

  # Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
             horizontalalignment="center",
             color="white" if cm[i, j] > threshold else "black",
             size=text_size)

# %%
# Make a prettier confusion matrix
make_confusion_matrix(y_true=test_labels,
                      y_pred=y_preds,
                      classes=label_names,
                      figsize=(15, 15),
                      text_size=10)

# %% [markdown]
# The code defines a function to plot a random image from the dataset with the model's prediction and the true label. The color of the label is green if the prediction is correct and red if incorrect.

# %%
import random

def plot_random_image(model, images, true_labels, classes):
    i = random.randint(0, len(images))

    target_image = images[i]
    pred_probs = model.predict(target_image.reshape(1, 32, 32, 3))
    pred_label = classes[pred_probs.argmax()]
    true_label = classes[true_labels[i][0]]

    plt.imshow(target_image, cmap=plt.cm.binary)

    if pred_label == true_label:
        color = "green"
    else:
        color = "red"

    plt.xlabel("Pred: {} {:2.0f}% (True: {})".format(pred_label,
                                                   100*tf.reduce_max(pred_probs),
                                                   true_label),
             color=color)

# %% [markdown]
# Another function is defined to plot multiple random images using the previously defined function. The specified number of images is displayed, each with its prediction and true label.

# %%
def plot_random_images(model, images, true_labels, classes, num_images=10):
    for _ in range(num_images):
        plot_random_image(model, images, true_labels, classes)
        plt.figure()  # create a new figure for the next image

# %% [markdown]
# Then, the functions are utilized to plot multiple random images using the best model, test data, true labels, and label names.

# %%
# Now use the modified function
plot_random_images(best_model, test_data, test_labels, label_names)
# Out:
# ...
# 1/1 [==============================] - 0s 18ms/step
