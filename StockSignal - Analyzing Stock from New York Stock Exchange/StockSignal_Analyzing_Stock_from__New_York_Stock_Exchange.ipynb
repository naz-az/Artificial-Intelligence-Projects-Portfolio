# %% [markdown]
# # **Title: StockSignal - Analyzing XRAY Stock from the New York Stock Exchange with Time Series Analysis**

# %% [markdown]
# ![Screenshot 2023-07-13 085133.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Overview/Introduction:
# In this AI project, we aim to develop a powerful stock prediction model specifically focused on analyzing the historical prices and fundamental data of the XRAY stock from the New York Stock Exchange. By leveraging machine learning techniques, our objective is to create a robust system that can assist investors, traders, and financial analysts in making informed decisions regarding XRAY stock investments.
#
# ## Problem Statement:
# As the financial markets become increasingly complex and dynamic, there is a growing need for automated systems that can efficiently process and analyze vast amounts of historical stock data. The challenge lies in developing an AI-based solution capable of accurately predicting the future performance of individual stocks, such as XRAY, while considering the influence of fundamental factors. By addressing this challenge, we can enhance our understanding of market trends, optimize investment strategies, and potentially maximize returns for stakeholders.
#
# ## Objectives:
# The primary objectives of this project are as follows:
#
# 1. **Develop an AI-driven stock prediction model:** Utilize advanced machine learning algorithms and techniques to train a model that can accurately forecast the future price movements of XRAY stock. By analyzing historical prices and fundamental data, we aim to capture patterns, trends, and market indicators that contribute to reliable predictions.
#
# 2. **Evaluate model performance:** Assess the effectiveness of the developed stock prediction model through comprehensive performance evaluation metrics. By measuring accuracy, precision, recall, and other relevant indicators, we can gauge the model's ability to generate reliable predictions for XRAY stock.
#
# 3. **Provide actionable insights:** Present the predictions and analysis generated by the model in a clear and understandable manner. Create visualizations and reports that highlight key trends, significant events, and potential trading opportunities related to XRAY stock. This will enable investors and financial professionals to make informed decisions based on the AI-driven insights.
#
# ## Dataset Description:
# The dataset for this project consists of the following files:
#
# 1. **prices.csv:** This file contains the raw daily prices of various stocks, including XRAY. The data spans from 2010 to the end of 2016, with a shorter date range for companies that entered the stock market later. It is important to note that the dataset does not account for approximately 140 stock splits that occurred during this period.
#
# 2. **prices-split-adjusted.csv:** Similar to the prices.csv file, this dataset includes daily prices but incorporates adjustments for stock splits. These adjustments ensure that the data accurately reflects the stock's price movements even after accounting for the impact of stock splits.
#
# 3. **securities.csv:** This file provides a general description of each company, including XRAY, listed on the New York Stock Exchange. It also classifies the companies into different sectors, enabling sector-wise analysis and comparison.
#
# 4. **fundamentals.csv:** Extracted from annual SEC 10K filings between 2012 and 2016, this dataset includes various metrics that serve as fundamental indicators for companies. These metrics encompass key financial information, such as revenue, earnings, and other relevant data, which can provide valuable insights into the financial health and stability of XRAY.
#
# ## Acknowledgements:
# The prices data in this dataset was sourced from Yahoo Finance, while the fundamental data was obtained from Nasdaq Financials, supplemented with additional fields from the EDGAR SEC databases. We acknowledge the invaluable contributions of these platforms and databases in providing comprehensive financial information that underpins this AI project.
#
# **Dataset URL:** https://www.kaggle.com/datasets/dgawlik/nyse

# %% [markdown]
# # Technologies Used:
# - Python: The code provided is written in Python, a widely-used programming language for data analysis and machine learning tasks.
# - Pandas: The pandas library is utilized for data manipulation and analysis. It provides powerful data structures and data analysis tools.
# - NumPy: NumPy is used for numerical computing and handling multi-dimensional arrays in Python.
# - Matplotlib: The Matplotlib library is employed for data visualization and creating plots.
# - TensorFlow: TensorFlow is an open-source deep learning framework that provides tools and functionalities for building and training neural networks.
# - Keras Tuner: Keras Tuner is a hyperparameter optimization library used for finding the best hyperparameters for machine learning models.
#
# # Methodology:
# The code follows a systematic methodology for stock prediction using LSTM (Long Short-Term Memory) neural networks. The process involves several steps, including data preprocessing, model building, training, and evaluation. Here is an overview of the methodology employed:
#
# 1. **Data Preprocessing:** The code begins by importing the necessary libraries, including pandas, and loading the stock price data from the provided CSV file. It performs data cleaning and filtering to extract the historical prices for a specific stock symbol (randomly chosen). It also scales the input features using MinMaxScaler to ensure the data is within a specific range.
#
# 2. **Data Visualization:** The code segment utilizes Matplotlib to visualize the stock price data. It plots the open, close, low, and high prices from the DataFrame to provide a graphical representation of the stock's historical performance.
#
# 3. **Model Building:** The code defines an LSTM model using the Sequential API from TensorFlow. The model architecture includes multiple LSTM layers with dropout regularization to prevent overfitting. It also incorporates dense output layers. The model is compiled with an Adam optimizer and mean squared error loss.
#
# 4. **Model Training:** The LSTM model is trained on the preprocessed data using the fit() function. The training data is split into a training set and a validation set. The model is trained for a specified number of epochs, with early stopping and model checkpointing used as callbacks to ensure the best model is saved.
#
# 5. **Model Prediction:** After training, the trained LSTM model is used to make predictions on both the training and testing data. The predicted stock prices are transformed back to their original scale using inverse_transform(), allowing for meaningful interpretation and comparison with the actual stock prices.
#
# 6. **Model Evaluation:** The code calculates the root mean squared error (RMSE) for both the training and testing data. The RMSE is a metric that measures the difference between predicted and actual values, providing an indication of the model's performance. The lower the RMSE, the better the model's accuracy.
#
# 7. **Hyperparameter Tuning:** In an effort to optimize the model's performance, the code employs hyperparameter tuning using Keras Tuner. It defines a function to build a neural network model with hyperparameters to be tuned. The hyperparameters considered include the number of layers, dropout rate, number of units, number of filters, and kernel size. Random search is performed to explore different hyperparameter combinations and find the best model architecture. The best model obtained through hyperparameter tuning is then compiled and trained.
#
# # Results:
# The code provides the results of the trained LSTM models on both the training and testing data. The results are presented in terms of the root mean squared error (RMSE) metric, which measures the accuracy of the predicted stock prices compared to the actual prices. The lower the RMSE, the better the model's performance. The code displays the RMSE values for the training and testing data, allowing for an assessment of the models' effectiveness.
#
# - Results of the LSTM model without hyperparameter tuning:
#   - Train Score: 0.96 RMSE
#   - Test Score: 1.50 RMSE
#
# - Results of the LSTM model after hyperparameter tuning:
#   - Train Score: 1.58 RMSE
#   - Test Score: 1.14 RMSE
#
# # Discussion/Interpretation of Results:
#
# Comparing the results of the LSTM model without hyperparameter tuning to the model after hyperparameter tuning, we observe that the initial model achieved a lower RMSE on the test set (1.50 RMSE) compared to the tuned model (1.14 RMSE). This suggests that the initial model performed slightly better in capturing the underlying patterns and trends in the stock price data.
#
# It is important to note that the performance of the stock prediction models can vary depending on several factors, including the specific stock being analyzed, the available features, and the length of the training period. Further experimentation and fine-tuning may be required to achieve even more accurate predictions.
#
#
# # Conclusion:
# In conclusion, this AI project focuses on stock prediction for the XRAY stock from the New York Stock Exchange using historical price data. The implementation utilizes the LSTM neural network model, along with data preprocessing, model building, training, and evaluation techniques. By leveraging machine learning algorithms and techniques, the project aims to predict future price movements of the XRAY stock based on historical data and fundamental indicators.
#
# The results obtained from the LSTM models demonstrate their capability to forecast stock prices. The implementation serves as a valuable tool for investors, traders, and financial analysts in making informed decisions regarding XRAY stock investments. However, it is crucial to acknowledge that stock market prediction is inherently challenging and subject to various uncertainties. Continuous research and development are required to enhance the accuracy and reliability of the predictions, ensuring that the models remain effective in dynamic market conditions.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, LSTM, GRU, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler
import itertools
import random
import os
import csv

# %% [markdown]
# The following code shows a function called seed_everything() which sets random seeds for TensorFlow, NumPy, and Python's random library. This is done to ensure reproducibility of results in future use cases.

# %%
# Seed Everything to reproduce results for future use cases
def seed_everything(seed=42):
    # Seed value for TensorFlow
    tf.random.set_seed(seed)

    # Seed value for NumPy
    np.random.seed(seed)

    # Seed value for Python's random library
    random.seed(seed)

seed_everything()

# %% [markdown]
# The next code imports the pandas library and reads a CSV file called "prices.csv". It parses the dates in the "date" column and sets it as the index of the DataFrame. The first few rows of the DataFrame are then displayed.

# %%
# Import with pandas
import pandas as pd
# Parse dates and set date column to index
df = pd.read_csv("./prices.csv",
                 parse_dates=["date"],
                 index_col=["date"]) # parse the date column (tell pandas column 1 is a datetime)
df.head()
# Out:
#            symbol        open       close         low        high     volume
# date
# 2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000  2163600.0
# 2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001  2386400.0
# 2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998  2489500.0
# 2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002  2006300.0
# 2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002  1408600.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 53244 entries, 2016-01-05 to 2010-06-16
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   symbol  53244 non-null  object
#  1   open    53244 non-null  float64
#  2   close   53244 non-null  float64
#  3   low     53244 non-null  float64
#  4   high    53243 non-null  float64
#  5   volume  53243 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 2.8+ MB

# %% [markdown]
# The code df.symbol.unique() accesses the 'symbol' column of the DataFrame and returns the unique values.

# %%
df.symbol.unique()
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALK', 'ALL',
#        'ALXN', 'AMAT', 'AME', 'AMG', 'AMGN', 'AMP', 'AMT', 'AMZN', 'AN',
#        'ANTM', 'AON', 'APA', 'APC', 'APD', 'APH', 'ARNC', 'ATVI', 'AVB',
#        'AVGO', 'AVY', 'AWK', 'AXP', 'AYI', 'AZO', 'BA', 'BAC', 'BAX',
#        'BBBY', 'BBT', 'BBY', 'BCR', 'BDX', 'BEN', 'BHI', 'BIIB', 'BK',
#        'BLK', 'BLL', 'BMY', 'BSX', 'BWA', 'BXP', 'C', 'CA', 'CAG', 'CAH',
#        'CAT', 'CB', 'CBG', 'CBS', 'CCI', 'CCL', 'CELG', 'CERN', 'CF',
#        'CHD', 'CHK', 'CHRW', 'CI', 'CINF', 'CL', 'CLX', 'CMA', 'CMCSA',
#        'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COH',
#        'COL', 'COO', 'COP', 'COST', 'CPB', 'CRM', 'CSCO', 'CSX', 'CTAS',
#        'CTL', 'CTSH', 'CTXS', 'CVS', 'CVX', 'CXO', 'D', 'DAL', 'DD', 'DE',
# ...

# %%
len(df)
# Out:
# 53244

# %% [markdown]
# In the next code, the 'symbol' column is converted to a list called symbol_list. Then, a random symbol is chosen from the list using the random.choice() function, and it is printed out.

# %%
# Access the 'symbol' column and convert it to a list
symbol_list = df['symbol'].tolist()

# Pick a random symbol from the list
random_symbol = random.choice(symbol_list)

print("Random symbol:", random_symbol)
# Out:
# Random symbol: XRAY

# %% [markdown]
# The code df_price = df[df['symbol'] == random_symbol] filters the DataFrame to create a new DataFrame called df_price containing only rows where the symbol is equal to the randomly chosen symbol.

# %%
# Recreate DataFrame with rows
df_price = df[df['symbol'] == random_symbol]

# Print information about the new DataFrame
df_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 113 entries, 2010-01-04 to 2010-06-15
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   symbol  113 non-null    object
#  1   open    113 non-null    float64
#  2   close   113 non-null    float64
#  3   low     113 non-null    float64
#  4   high    113 non-null    float64
#  5   volume  113 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 6.2+ KB

# %%
len(df_price)
# Out:
# 113

# %% [markdown]
# The following code creates a new DataFrame called df_prices with only the "close" column from the df_price DataFrame. The column name is then renamed to "Price".

# %%
# Only want closing price for each day
df_prices = pd.DataFrame(df_price["close"]).rename(columns={"close": "Price"})
df_prices.head()
# Out:
#                 Price
# date
# 2010-01-04  35.330002
# 2010-01-05  34.910000
# 2010-01-06  35.139999
# 2010-01-07  35.599998
# 2010-01-08  35.599998

# %% [markdown]
# The next code plots the stock prices from the df_prices DataFrame using the plot() method, and sets the figure size, y-label, and title based on the randomly chosen symbol.

# %%
df_prices.plot(figsize=(10, 7))
plt.ylabel("Stock Price")
plt.title(f"Price of {random_symbol} stock from 2010-01-04 to 2016-12-30", fontsize=16)
plt.legend(fontsize=14);

# %%
# Open the CSV file
with open("./prices.csv", "r") as f:
    # Create a CSV reader object
    reader = csv.reader(f)

    # Read the first row (header) of the CSV file
    header = next(reader)

    # Print the column names
    print(header)
# Out:
# ['date', 'symbol', 'open', 'close', 'low', 'high', 'volume']

# %%
from datetime import datetime

timesteps = []
stock_price = []
with open("./prices.csv", "r") as f:
    csv_reader = csv.reader(f, delimiter=",") # read in the target CSV
    next(csv_reader) # skip first line (this gets rid of the column titles)
    for line in csv_reader:
        if line[1] == random_symbol: # check if the symbol is KSU
            timesteps.append(datetime.strptime(line[0], "%Y-%m-%d")) # get the dates as dates (not strings), strptime = string parse time
            stock_price.append(float(line[3])) # get the closing price as float

# View first 10 of each
timesteps[:10], stock_price[:10]
# Out:
# ([datetime.datetime(2010, 1, 4, 0, 0),
#   datetime.datetime(2010, 1, 5, 0, 0),
#   datetime.datetime(2010, 1, 6, 0, 0),
#   datetime.datetime(2010, 1, 7, 0, 0),
#   datetime.datetime(2010, 1, 8, 0, 0),
#   datetime.datetime(2010, 1, 11, 0, 0),
#   datetime.datetime(2010, 1, 12, 0, 0),
#   datetime.datetime(2010, 1, 13, 0, 0),
#   datetime.datetime(2010, 1, 14, 0, 0),
#   datetime.datetime(2010, 1, 15, 0, 0)],
#  [35.330002,
#   34.91,
#   35.139999,
#   35.599998,
#   35.599998,
#   36.060001,
#   35.799999,
#   36.299999,
#   36.57,
#   35.950001])

# %% [markdown]
# The following code plots the stock price data from the timesteps and stock_price variables. It creates a figure with a specified size, plots the data using the plot() function from matplotlib.pyplot, and sets the title, x-label, and y-label.

# %%
# Plot from CSV
plt.figure(figsize=(10, 7))
plt.plot(timesteps, stock_price)
plt.title(f"Price of {random_symbol} stock from 2010-01-04 to 2016-12-30", fontsize=16)
plt.xlabel("Date")
plt.ylabel("Stock Price");

# %%
df_price.head()
# Out:
#            symbol       open      close        low       high     volume
# date
# 2010-01-04   XRAY  35.529999  35.330002  35.270000  35.650002  1051400.0
# 2010-01-05   XRAY  35.240002  34.910000  34.730000  35.360001   763400.0
# 2010-01-06   XRAY  35.020000  35.139999  34.750000  35.340000  1595100.0
# 2010-01-07   XRAY  35.080002  35.599998  34.880001  35.639999  1096100.0
# 2010-01-08   XRAY  35.560001  35.599998  35.450001  35.770000   803600.0

# %% [markdown]
# The next code creates a figure with a size of 15x5 and plots multiple subplots. The first subplot displays the 'open', 'close', 'low', and 'high' prices from the df_price DataFrame. The second subplot displays the 'volume' data. The code provides titles and labels for each subplot and includes a legend.

# %%
plt.figure(figsize=(15, 5));
plt.subplot(1,2,1);
plt.plot(df_price.open.values, color='red', label='open')
plt.plot(df_price.close.values, color='green', label='close')
plt.plot(df_price.low.values, color='blue', label='low')
plt.plot(df_price.high.values, color='black', label='high')
plt.title('stock price')
plt.xlabel('time [days]')
plt.ylabel('price')
plt.legend(loc='best')
#plt.show()

plt.subplot(1,2,2);
plt.plot(df_price.volume.values, color='black', label='volume')
plt.title('stock volume')
plt.xlabel('time [days]')
plt.ylabel('volume')
plt.legend(loc='best');

# %% [markdown]
# The code segment applies scaling to the 'open', 'low', 'high', and 'volume' columns of the df_price DataFrame using MinMaxScaler() from sklearn.preprocessing. The 'close' column is scaled separately. The scaled values are then stored in the x and y variables.

# %%
# Scalling
x_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()
data = df_price.copy()
data.drop(['symbol'], axis=1, inplace=True)
x = data[['open', 'low', 'high', 'volume']].copy()
y = data['close'].copy()

x[['open', 'low', 'high', 'volume']] = x_scaler.fit_transform(x)
y = y_scaler.fit_transform(y.values.reshape(-1, 1))

# %%
x.shape, y.shape
# Out:
# ((113, 4), (113, 1))

# %%
x, y
# Out:
# (                open       low      high    volume
#  date
#  2010-01-04  0.672199  0.785603  0.650838  0.252291
#  2010-01-05  0.632089  0.701096  0.610335  0.140918
#  2010-01-06  0.601660  0.704225  0.607542  0.462547
#  2010-01-07  0.609959  0.724570  0.649441  0.269577
#  2010-01-08  0.676348  0.813772  0.667598  0.156464
#  ...              ...       ...       ...       ...
#  2010-06-09  0.009682  0.035994  0.019553  0.328667
#  2010-06-10  0.049793  0.062598  0.034916  0.357941
#  2010-06-11  0.000000  0.035994  0.030726  0.191925
#  2010-06-14  0.078838  0.150235  0.107542  0.202019
#  2010-06-15  0.121715  0.136150  0.078212  0.459221
#
#  [113 rows x 4 columns],
#  array([[0.64314826],
#         [0.58616019],
#         [0.61736766],
#         [0.67978272],
#         [0.67978272],
#         [0.74219834],
#         [0.70691991],
#         [0.77476252],
#         [0.81139767],
#         [0.72727296],
#         [0.80461341],
#         [0.7516963 ],
#         [0.57530564],
# ...

# %% [markdown]
# The next code defines a function called load_data() to split the data into training and testing sets. It takes the input data X, sequence length seq_len, and train size as arguments. The function reshapes the data and splits it into training and testing sets based on the sequence length.

# %%
def load_data(X, seq_len, train_size=0.9):
    amount_of_features = X.shape[1]
    X_mat = X.values
    sequence_length = seq_len + 1
    data = []

    for index in range(len(X_mat) - sequence_length):
        data.append(X_mat[index: index + sequence_length])

    data = np.array(data)
    train_split = int(round(train_size * data.shape[0]))
    train_data = data[:train_split, :]

    x_train = train_data[:, :-1]
    y_train = train_data[:, -1][:,-1]

    x_test = data[train_split:, :-1]
    y_test = data[train_split:, -1][:,-1]

    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], amount_of_features))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], amount_of_features))

    return x_train, y_train, x_test, y_test

# %% [markdown]
# The code segment applies the load_data() function to the x and window variables to obtain the training and testing sets (X_train, y_train, X_test, y_test).

# %%
window = 7
x['close'] = y
X_train, y_train, X_test, y_test = load_data(x, window)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (94, 7, 5) (94,) (11, 7, 5) (11,)

# %% [markdown]
# The code plots the 'open', 'close', 'low', and 'high' prices from the df_price DataFrame using the plot() function. It sets the figure size, title, x-label, and y-label.

# %%
plt.figure(figsize=(15, 5));
plt.plot(df_price.open.values, color='red', label='open')
plt.plot(df_price.close.values, color='green', label='close')
plt.plot(df_price.low.values, color='blue', label='low')
plt.plot(df_price.high.values, color='black', label='high')
#plt.plot(df_stock_norm.volume.values, color='gray', label='volume')
plt.title('stock')
plt.xlabel('time [days]')
plt.ylabel('price/volume')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Model 1: LSTM**
#
# The next code initializes a random seed for TensorFlow for reproducibility. The code defines an LSTM model using the Sequential() API from TensorFlow. It adds LSTM layers with dropout regularization, followed by dense output layers. The model is compiled with an Adam optimizer and mean squared error loss. The model is trained on the training data (X_train, y_train) with a specified number of epochs, batch size, and validation split. Early stopping and model checkpointing are used as callbacks.

# %%
import time

tf.random.set_seed(42) # set random seed for reproducibility

#LSTM architecture
model = Sequential()
# First LSTM layer with Dropout regularisation
model.add(LSTM(units=50, input_shape=(X_train.shape[1], X_train.shape[2]),return_sequences=True))
model.add(Dropout(0.2))
# Second LSTM layer
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
# Third LSTM layer
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
# Fourth LSTM layer
model.add(LSTM(units=50))
model.add(Dropout(0.5))
# The output layer
model.add(Dense(units=50, kernel_initializer='uniform', activation='tanh'))
model.add(Dense(units=1, kernel_initializer='uniform', activation='linear'))

earlystop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
callbacks_list = [earlystop]

# Compiling the RNN
model.compile(optimizer='adam',loss='mean_squared_error')

# Fitting to the training set
LSTM=model.fit(X_train,y_train,epochs=100,batch_size=35, validation_split=0.05, verbose=1,callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 7s 686ms/step - loss: 0.3161 - val_loss: 0.0718
# Epoch 2/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3052 - val_loss: 0.0646
# Epoch 3/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2885 - val_loss: 0.0527
# Epoch 4/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2570 - val_loss: 0.0326
# Epoch 5/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2048 - val_loss: 0.0062
# Epoch 6/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1156 - val_loss: 0.0324
# Epoch 7/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0292 - val_loss: 0.2619
# Epoch 8/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0670 - val_loss: 0.2181
# Epoch 9/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0373 - val_loss: 0.0853
# Epoch 10/100
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 7, 50)             11200
#
#  dropout (Dropout)           (None, 7, 50)             0
#
#  lstm_1 (LSTM)               (None, 7, 50)             20200
#
#  dropout_1 (Dropout)         (None, 7, 50)             0
#
#  lstm_2 (LSTM)               (None, 7, 50)             20200
#
#  dropout_2 (Dropout)         (None, 7, 50)             0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 50)                2550
#
#  dense_1 (Dense)             (None, 1)                 51
#
# ...
# Total params: 74,401
# Trainable params: 74,401
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The code plots the training loss and validation loss from the model training history using pd.DataFrame(LSTM.history) and the plot() function.

# %%
# %matplotlib inline
losses = pd.DataFrame(LSTM.history)
losses.plot()
# Out:
# <Axes: >

# %% [markdown]
# **Model Prediction**
#
# The code segment uses the trained LSTM model to make predictions on the training and testing data. The predicted stock prices are transformed back to their original scale using y_scaler.inverse_transform(). The original stock prices (trainY, testY) are also transformed back to their original scale.

# %%
trainPredict = model.predict(X_train)
testPredict = model.predict(X_test)

trainPredict = y_scaler.inverse_transform(trainPredict)
trainY = y_scaler.inverse_transform([y_train])
testPredict = y_scaler.inverse_transform(testPredict)
testY = y_scaler.inverse_transform([y_test])
# Out:
# ...
# 1/1 [==============================] - 0s 21ms/step

# %%
plot_predicted = testPredict.copy()
plot_predicted = plot_predicted.reshape(testPredict.shape[0], testPredict.shape[1])
plot_actual = testY.copy()
plot_actual = plot_actual.reshape(testPredict.shape[0], testPredict.shape[1])
print(plot_actual.shape)
print(plot_predicted.shape)
# Out:
# (11, 1)
# (11, 1)

# %%
plot_x = df.index.copy()

# %% [markdown]
# The actual and predicted values are plotted to visualize the model's performance.

# %%
plt.figure(figsize=(20,7))
plot_x = plot_x[-10:]
plot_x = pd.to_datetime(plot_x)
plt.plot(pd.DataFrame(plot_predicted), label='Predicted')
plt.plot(pd.DataFrame(plot_actual), label='Actual')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# The code calculates the root mean squared error (RMSE) for the training and testing predictions using the mean_squared_error() function from sklearn.metrics.

# %%
from sklearn.metrics import mean_squared_error, r2_score

trainScore = mean_squared_error(trainY[0], trainPredict[:,0]) ** .5
print('Train Score: %.2f RMSE' % (trainScore))
testScore = mean_squared_error(testY[0], testPredict[:,0]) ** .5
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 0.96 RMSE
# Test Score: 1.50 RMSE

# %% [markdown]
# The stock price data is reshaped for plotting purposes, and the training and testing predictions are assigned to appropriate variables.

# %%
stock_prices = df_price.close.values.astype('float32')
stock_prices = stock_prices.reshape(len(stock_prices), 1)

# %%
trainPredictPlot = np.empty_like(stock_prices)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[17:len(trainPredict)+17, :] = trainPredict

testPredictPlot = np.empty_like(stock_prices)
testPredictPlot[:, :] = np.nan
testPredictPlot[(len(stock_prices) - testPredict.shape[0]):len(stock_prices), :] = testPredict

# %% [markdown]
# Finally, a plot is created to show the actual closing prices, as well as the predicted prices on both the training and testing sets.

# %%
plt.figure(figsize=(20,7))
plt.plot(pd.DataFrame(stock_prices, columns=["close"], index=data.index).close, label='Actual')
plt.plot(pd.DataFrame(trainPredictPlot, columns=["close"], index=data.index).close, label='Training')
plt.plot(pd.DataFrame(testPredictPlot, columns=["close"], index=data.index).close, label='Testing')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Hyperparameter Tuning**
#
# The code defines a function called build_model() to build a neural network model with hyperparameters to be tuned using Keras Tuner. The model includes convolutional, LSTM, and dense layers. The hyperparameters include the number of layers, dropout rate, number of units, number of filters, and kernel size.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Bidirectional, LSTM, Dropout, Dense, Lambda
from tensorflow.keras.optimizers import Adam
# !pip install keras-tuner
import keras_tuner as kt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 5.2 MB/s eta 0:00:00
# ...

# %%
def build_model(hp):

    # Define all hyperparameters
    n_layers = hp.Choice('n_layers', [1, 2, 3])
    dropout_rate = hp.Choice('dropout_rate', [0.2, 0.3, 0.4, 0.5])
    n_units = hp.Choice('n_units', [50, 100, 200])
    n_filters = hp.Choice('n_filters', [32, 64, 128])
    kernel_size = hp.Choice('kernel_size', [2, 3, 5])

    # Model architecture
    model = Sequential()

    # Conv1D for feature extraction
    model.add(Conv1D(filters=n_filters, kernel_size=kernel_size, activation='relu', input_shape=[X_train.shape[1], X_train.shape[2]]))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))

    # Add LSTM layers
    for i in range(n_layers):
        if i == 0:
            # First layer specifies return sequences if more than one LSTM layer
            model.add(Bidirectional(LSTM(n_units, return_sequences=(n_layers != 1), activation='relu')))
        else:
            # Middle layers return sequences, last layer doesn't
            model.add(Bidirectional(LSTM(n_units, return_sequences=(i != n_layers - 1), activation='relu')))

        # Add Dropout after each LSTM layer
        model.add(Dropout(dropout_rate))

    # Output layer
    model.add(Dense(units=50, kernel_initializer='uniform', activation='tanh'))
    model.add(Dense(units=1, kernel_initializer='uniform', activation='linear'))

    # Compile the model
    model.compile(
        loss='mean_squared_error',
        optimizer = Adam(hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        metrics = ['mean_absolute_error']
    )

    # Return model
    return model

# %%
BATCH_SIZE=32

# %% [markdown]
# The code initializes a random search using Keras Tuner to find the best hyperparameters for the model. It searches for the best hyperparameters using the training data (X_train, y_train) with a validation split.

# %%
# Initialize Random Searcher
random_searcher = kt.RandomSearch(
    hypermodel=build_model,
    objective='val_loss',
    max_trials=15,
    seed=42,
    project_name="Stock-Search"
)

# Start Searching
search = random_searcher.search(
    X_train,y_train,
    validation_split=0.05,
    epochs = 30,
    batch_size = BATCH_SIZE
)
# Out:
# Trial 15 Complete [00h 00m 06s]
# val_loss: 0.023055516183376312
#
# Best val_loss So Far: 0.0016893526772037148
# Total elapsed time: 00h 01m 24s

# %%
# Collect the best model LSTM Model Architecture obtained by Random Searcher
best_model = build_model(random_searcher.get_best_hyperparameters(num_trials=1)[0])

# Model Architecture
best_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_1 (Conv1D)           (None, 6, 64)             704
#
#  batch_normalization_1 (Batc  (None, 6, 64)            256
#  hNormalization)
#
#  max_pooling1d_1 (MaxPooling  (None, 3, 64)            0
#  1D)
#
#  bidirectional_1 (Bidirectio  (None, 3, 200)           132000
#  nal)
#
#  dropout_1 (Dropout)         (None, 3, 200)            0
#
#  bidirectional_2 (Bidirectio  (None, 200)              240800
#  nal)
#
#  dropout_2 (Dropout)         (None, 200)               0
#
#  dense_2 (Dense)             (None, 50)                10050
#
#  dense_3 (Dense)             (None, 1)                 51
#
# ...
# Total params: 383,861
# Trainable params: 383,733
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# The best model architecture obtained from the random search is extracted and compiled. The best model is trained on the training data with a validation split and early stopping. The best model is saved as "BestModel.h5".

# %%
# Compile Model
best_model.compile(
    loss='mean_squared_error',
    optimizer=Adam(best_model.optimizer.learning_rate),
    metrics=['mean_absolute_error']
)

# Model Training
best_model_history = best_model.fit(
    X_train,y_train,
    validation_split=0.05,
    epochs = 100,
    batch_size = BATCH_SIZE*2,
    callbacks = [
        EarlyStopping(patience=20, restore_best_weights=True),
        ModelCheckpoint("BestModel.h5", save_best_only=True)
    ]
)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 5s 541ms/step - loss: 0.3104 - mean_absolute_error: 0.5359 - val_loss: 0.0700 - val_mean_absolute_error: 0.2600
# Epoch 2/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.2802 - mean_absolute_error: 0.5081 - val_loss: 0.0619 - val_mean_absolute_error: 0.2442
# Epoch 3/100
# 2/2 [==============================] - 0s 79ms/step - loss: 0.2358 - mean_absolute_error: 0.4624 - val_loss: 0.0501 - val_mean_absolute_error: 0.2190
# Epoch 4/100
# 2/2 [==============================] - 0s 74ms/step - loss: 0.1675 - mean_absolute_error: 0.3775 - val_loss: 0.0333 - val_mean_absolute_error: 0.1770
# Epoch 5/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.1000 - mean_absolute_error: 0.2754 - val_loss: 0.0150 - val_mean_absolute_error: 0.1154
# Epoch 6/100
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0945 - mean_absolute_error: 0.2542 - val_loss: 0.0082 - val_mean_absolute_error: 0.0812
# ...

# %% [markdown]
# The best model is loaded from the saved file and evaluated on the testing data.

# %%
#  Load model
best_model = tf.keras.models.load_model('BestModel.h5')
best_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_1 (Conv1D)           (None, 6, 64)             704
#
#  batch_normalization_1 (Batc  (None, 6, 64)            256
#  hNormalization)
#
#  max_pooling1d_1 (MaxPooling  (None, 3, 64)            0
#  1D)
#
#  bidirectional_1 (Bidirectio  (None, 3, 200)           132000
#  nal)
#
#  dropout_1 (Dropout)         (None, 3, 200)            0
#
#  bidirectional_2 (Bidirectio  (None, 200)              240800
#  nal)
#
#  dropout_2 (Dropout)         (None, 200)               0
#
#  dense_2 (Dense)             (None, 50)                10050
#
#  dense_3 (Dense)             (None, 1)                 51
#
# ...
# Total params: 383,861
# Trainable params: 383,733
# Non-trainable params: 128
# _________________________________________________________________

# %%
best_model.evaluate(X_test,y_test)
# Out:
# 1/1 [==============================] - 0s 453ms/step - loss: 0.0241 - mean_absolute_error: 0.1390
# [0.02411048486828804, 0.13900715112686157]

# %% [markdown]
# The code calculates the validation mean squared error and mean absolute error for the best model and prints the results.

# %%
# Evaluate the best  model
best_test_loss, best_test_acc = best_model.evaluate(X_test,y_test)
print(f"Validation MSE after Tuning     : {best_test_loss} ")
print(f"Validation MAE after Tuning : {best_test_acc}  ")
# Out:
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0241 - mean_absolute_error: 0.1390
# Validation MSE after Tuning     : 0.02411048486828804
# Validation MAE after Tuning : 0.13900715112686157

# %% [markdown]
# The training and validation accuracy and loss from the best model training history are extracted and plotted using matplotlib.pyplot.

# %%
# Extract the history from the best USE model
accuracy = best_model_history.history['mean_absolute_error']
val_accuracy = best_model_history.history['val_mean_absolute_error']

loss = best_model_history.history['loss']
val_loss = best_model_history.history['val_loss']

epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'b', label='Training MAE')
plt.plot(epochs, val_accuracy, 'r', label='Validation MAE')

plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')

plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# The code makes predictions using the best model on the training and testing data. The predictions are transformed back to their original scale.

# %%
trainPredict = best_model.predict(X_train)
testPredict = best_model.predict(X_test)

trainPredict = y_scaler.inverse_transform(trainPredict)
trainY = y_scaler.inverse_transform([y_train])
testPredict = y_scaler.inverse_transform(testPredict)
testY = y_scaler.inverse_transform([y_test])
# Out:
# ...
# 1/1 [==============================] - 0s 17ms/step

# %%
plot_predicted = testPredict.copy()
plot_predicted = plot_predicted.reshape(testPredict.shape[0], testPredict.shape[1])
plot_actual = testY.copy()
plot_actual = plot_actual.reshape(testPredict.shape[0], testPredict.shape[1])
print(plot_actual.shape)
print(plot_predicted.shape)
# Out:
# (11, 1)
# (11, 1)

# %%
plot_x = df.index.copy()

# %% [markdown]
# The predicted and actual stock prices are plotted using the plot() function. The figure size is set, and a legend is included.

# %%
plt.figure(figsize=(20,7))
plot_x = plot_x[-10:]
plot_x = pd.to_datetime(plot_x)
plt.plot(pd.DataFrame(plot_predicted), label='Predicted')
plt.plot(pd.DataFrame(plot_actual), label='Actual')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# The code calculates the root mean squared error (RMSE) for the training and testing predictions using the mean_squared_error() function from sklearn.metrics.

# %%
from sklearn.metrics import mean_squared_error, r2_score

trainScore = mean_squared_error(trainY[0], trainPredict[:,0]) ** .5
print('Train Score: %.2f RMSE' % (trainScore))
testScore = mean_squared_error(testY[0], testPredict[:,0]) ** .5
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 1.58 RMSE
# Test Score: 1.14 RMSE

# %% [markdown]
# The stock price data is reshaped for plotting purposes, and the training and testing predictions are assigned to appropriate variables.

# %%
stock_prices = df_price.close.values.astype('float32')
stock_prices = stock_prices.reshape(len(stock_prices), 1)

# %%
trainPredictPlot = np.empty_like(stock_prices)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[17:len(trainPredict)+17, :] = trainPredict

testPredictPlot = np.empty_like(stock_prices)
testPredictPlot[:, :] = np.nan
testPredictPlot[(len(stock_prices) - testPredict.shape[0]):len(stock_prices), :] = testPredict

# %% [markdown]
# The code plots the actual, training, and testing stock prices using the plot() function. It sets the figure size and includes a legend.

# %%
plt.figure(figsize=(20,7))
plt.plot(pd.DataFrame(stock_prices, columns=["close"], index=data.index).close, label='Actual')
plt.plot(pd.DataFrame(trainPredictPlot, columns=["close"], index=data.index).close, label='Training')
plt.plot(pd.DataFrame(testPredictPlot, columns=["close"], index=data.index).close, label='Testing')
plt.legend(loc='best')
plt.show()
